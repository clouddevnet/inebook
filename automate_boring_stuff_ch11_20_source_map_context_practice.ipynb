# %% [markdown]
# # Automate the Boring Stuff: Chapters 11-20 Source Map, Context, and Practice
#
# This notebook continues the chapter-by-chapter companion format for chapters 11-20
# of Al Sweigart's *Automate the Boring Stuff with Python*, 3rd edition.
#
# Official book site: https://automatetheboringstuff.com/
#
# Each source-mapped example includes:
#
# - The chapter and section where it appears.
# - A preview of the source block.
# - A 4-line explanation of purpose, concept, real-world importance, and caution.
# - Either a runnable adapted cell or a practice rewrite cell for examples that need
#   external files, websites, credentials, installed apps, or user input.
#
# Later chapters automate real systems. Use sample files, fake accounts, and test
# sandboxes before running anything against your real data.

# %%
import csv
import io
import json
import logging
import random
import re
import sqlite3
import tempfile
import time
from pathlib import Path
from pprint import pprint

print("Setup complete.")

# %% [markdown]
# ## Coverage Summary

# %% [markdown]
# - 11 ORGANIZING FILES: 22 code blocks mapped from https://automatetheboringstuff.com/3e/chapter11.html
# - 12 DESIGNING AND DEPLOYING COMMAND LINE PROGRAMS: 50 code blocks mapped from https://automatetheboringstuff.com/3e/chapter12.html
# - 13 WEB SCRAPING: 46 code blocks mapped from https://automatetheboringstuff.com/3e/chapter13.html
# - 14 EXCEL SPREADSHEETS: 36 code blocks mapped from https://automatetheboringstuff.com/3e/chapter14.html
# - 15 GOOGLE SHEETS: 34 code blocks mapped from https://automatetheboringstuff.com/3e/chapter15.html
# - 16 SQLITE DATABASES: 49 code blocks mapped from https://automatetheboringstuff.com/3e/chapter16.html
# - 17 PDF AND WORD DOCUMENTS: 32 code blocks mapped from https://automatetheboringstuff.com/3e/chapter17.html
# - 18 CSV, JSON, AND XML FILES: 35 code blocks mapped from https://automatetheboringstuff.com/3e/chapter18.html
# - 19 KEEPING TIME, SCHEDULING TASKS, AND LAUNCHING PROGRAMS: 29 code blocks mapped from https://automatetheboringstuff.com/3e/chapter19.html
# - 20 SENDING EMAIL, TEXTS, AND PUSH NOTIFICATIONS: 15 code blocks mapped from https://automatetheboringstuff.com/3e/chapter20.html

# %% [markdown]
# ## 11 ORGANIZING FILES
#
# Source: https://automatetheboringstuff.com/3e/chapter11.html

# %% [markdown]
# ### The shutil Module

# %% [markdown]
# #### Source example 11.1
#
# Checklist note: captured from section **The shutil Module**.
#
# **Context**
#
# 1. This example belongs to the chapter on organizing files and folders, and shows one small building block from the section `The shutil Module`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# from pathlib import Path
#
# >>>
# h = Path.home()
#
# >>>
# (h / 'spam').mkdir(exist_ok=True)
#
# >>>
# with open(h / 'spam/file1.txt', 'w', encoding='utf-8') as file:
#
# ...
# file.write('Hello')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# from pathlib import Path
#
# >>>
# h = Path.home()
#
# >>>
# (h / 'spam').mkdir(exist_ok=True)
#
# >>>
# with open(h / 'spam/file1.txt', 'w', encoding='utf-8') as file:
#
# ...
# file.write('Hello')
#
# ...
# ```

# %%
# Practice rewrite for source example 11.1
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 11.2
#
# Checklist note: captured from section **The shutil Module**.
#
# **Context**
#
# 1. This example demonstrates file-management automation: copying, moving, deleting safely, or compressing files.
# 2. The key idea is that paths are data, so your program can inspect many files and apply the same rule consistently.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. This matters when cleaning Downloads folders, archiving reports, collecting logs, or preparing project backups.
# 5. Use sample folders first, because a small path mistake can affect many files quickly.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import shutil
#
# >>>
# from pathlib import Path
#
# >>>
# h = Path.home()
#
#
# ❶
#  >>>
# shutil.copy(h / 'spam/file1.txt', h)
#
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import shutil
#
# >>>
# from pathlib import Path
#
# >>>
# h = Path.home()
#
#
# ❶
#  >>>
# shutil.copy(h / 'spam/file1.txt', h)
#
# 'C:\\Users\\Al\\file1.txt'
#
# ❷
#  >>>
# shutil.copy(h / 'spam/file1.txt', h / 'spam/file2.txt')
#
# WindowsPath('C:/Users/Al/spam/file2.txt')
# ```

# %%
# Practice rewrite for source example 11.2
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 11.3
#
# Checklist note: captured from section **The shutil Module**.
#
# **Context**
#
# 1. This example demonstrates file-management automation: copying, moving, deleting safely, or compressing files.
# 2. The key idea is that paths are data, so your program can inspect many files and apply the same rule consistently.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. This matters when cleaning Downloads folders, archiving reports, collecting logs, or preparing project backups.
# 5. Use sample folders first, because a small path mistake can affect many files quickly.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import shutil
#
# >>>
# from pathlib import Path
#
# >>>
# h = Path.home()
#
# >>>
# shutil.copytree(h / 'spam', h / 'spam_backup')
#
# WindowsPath('C:/Users/Al/spam_backup')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import shutil
#
# >>>
# from pathlib import Path
#
# >>>
# h = Path.home()
#
# >>>
# shutil.copytree(h / 'spam', h / 'spam_backup')
#
# WindowsPath('C:/Users/Al/spam_backup')
# ```

# %%
# Practice rewrite for source example 11.3
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 11.4
#
# Checklist note: captured from section **The shutil Module**.
#
# **Context**
#
# 1. This example demonstrates file-management automation: copying, moving, deleting safely, or compressing files.
# 2. The key idea is that paths are data, so your program can inspect many files and apply the same rule consistently.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. This matters when cleaning Downloads folders, archiving reports, collecting logs, or preparing project backups.
# 5. Use sample folders first, because a small path mistake can affect many files quickly.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import shutil
#
# >>>
# from pathlib import Path
#
# >>>
# h = Path.home()
#
# >>>
# (h / 'spam2').mkdir()
#
# >>>
# shutil.move(h / 'spam/file1.txt', h / 'spam2')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import shutil
#
# >>>
# from pathlib import Path
#
# >>>
# h = Path.home()
#
# >>>
# (h / 'spam2').mkdir()
#
# >>>
# shutil.move(h / 'spam/file1.txt', h / 'spam2')
#
# 'C:\\Users\\Al\\spam2\\file1.txt'
# ```

# %%
# Practice rewrite for source example 11.4
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 11.5
#
# Checklist note: captured from section **The shutil Module**.
#
# **Context**
#
# 1. This example demonstrates file-management automation: copying, moving, deleting safely, or compressing files.
# 2. The key idea is that paths are data, so your program can inspect many files and apply the same rule consistently.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. This matters when cleaning Downloads folders, archiving reports, collecting logs, or preparing project backups.
# 5. Use sample folders first, because a small path mistake can affect many files quickly.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# shutil.move(h / 'spam/file1.txt', h / 'spam2/new_name.txt')
#
# 'C:\\Users\\Al\\spam2\\new_name.txt'
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# shutil.move(h / 'spam/file1.txt', h / 'spam2/new_name.txt')
#
# 'C:\\Users\\Al\\spam2\\new_name.txt'
# ```

# %%
# Practice rewrite for source example 11.5
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 11.6
#
# Checklist note: captured from section **The shutil Module**.
#
# **Context**
#
# 1. This example belongs to the chapter on organizing files and folders, and shows one small building block from the section `The shutil Module`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# import os
# from pathlib import Path
# for filename in Path.home().glob('*.
# r
# xt'):
#     os.unlink(filename)
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# import os
# from pathlib import Path
# for filename in Path.home().glob('*.
# r
# xt'):
#     os.unlink(filename)
# ```

# %%
# Practice rewrite for source example 11.6
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 11.7
#
# Checklist note: captured from section **The shutil Module**.
#
# **Context**
#
# 1. This example belongs to the chapter on organizing files and folders, and shows one small building block from the section `The shutil Module`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# import os
# from pathlib import Path
# for filename in Path.home().glob('*.rxt'):
#     #os.unlink(filename)
#     print('Deleting', filename)
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# import os
# from pathlib import Path
# for filename in Path.home().glob('*.rxt'):
#     #os.unlink(filename)
#     print('Deleting', filename)
# ```

# %%
# Practice rewrite for source example 11.7
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 11.8
#
# Checklist note: captured from section **The shutil Module**.
#
# **Context**
#
# 1. This example demonstrates file-management automation: copying, moving, deleting safely, or compressing files.
# 2. The key idea is that paths are data, so your program can inspect many files and apply the same rule consistently.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. This matters when cleaning Downloads folders, archiving reports, collecting logs, or preparing project backups.
# 5. Use sample folders first, because a small path mistake can affect many files quickly.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import send2trash
#
# >>>
# send2trash.send2trash('file1.txt')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import send2trash
#
# >>>
# send2trash.send2trash('file1.txt')
# ```

# %%
# Practice rewrite for source example 11.8
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Walking a Directory Tree

# %% [markdown]
# #### Source example 11.9
#
# Checklist note: captured from section **Walking a Directory Tree**.
#
# **Context**
#
# 1. This example belongs to the chapter on organizing files and folders, and shows one small building block from the section `Walking a Directory Tree`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import os
#
# >>>
# os.listdir(r'C:\Users\Al')
#
# ['.anaconda', '.android', '.cache', '.dotnet', '.eclipse', '.gitconfig',
#
# --snip--
#
# '__pycache__']
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import os
#
# >>>
# os.listdir(r'C:\Users\Al')
#
# ['.anaconda', '.android', '.cache', '.dotnet', '.eclipse', '.gitconfig',
#
# --snip--
#
# '__pycache__']
# ```

# %%
# Practice rewrite for source example 11.9
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 11.10
#
# Checklist note: captured from section **Walking a Directory Tree**.
#
# **Context**
#
# 1. This example belongs to the chapter on organizing files and folders, and shows one small building block from the section `Walking a Directory Tree`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# from pathlib import Path
#
# >>>
# home = Path.home()
#
# >>>
# list(home.iterdir())
#
# [WindowsPath('C:/Users/Al/.anaconda'), WindowsPath('C:/Users/Al/.android'),
# WindowsPath('C:/Users/Al/.cache'),
#
# --snip--
#
# # ... 1 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# from pathlib import Path
#
# >>>
# home = Path.home()
#
# >>>
# list(home.iterdir())
#
# [WindowsPath('C:/Users/Al/.anaconda'), WindowsPath('C:/Users/Al/.android'),
# WindowsPath('C:/Users/Al/.cache'),
#
# --snip--
#
# WindowsPath('C:/Users/Al/__pycache__')]
# ```

# %%
# Practice rewrite for source example 11.10
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 11.11
#
# Checklist note: captured from section **Walking a Directory Tree**.
#
# **Context**
#
# 1. This example belongs to the chapter on organizing files and folders, and shows one small building block from the section `Walking a Directory Tree`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# from pathlib import Path
#
# >>>
# h = Path.home()
#
# >>>
# (h / 'spam').mkdir(exist_ok=True)
#
# >>>
# (h / 'spam/eggs').mkdir(exist_ok=True)
#
# >>>
# (h / 'spam/eggs2').mkdir(exist_ok=True)
# # ... 18 more line(s) in this source example
# ```

# %%
# Adapted from source example 11.11
# At this point, the folders and files now exist.

# %% [markdown]
# #### Source example 11.12
#
# Checklist note: captured from section **Walking a Directory Tree**.
#
# **Context**
#
# 1. This example demonstrates file-management automation: copying, moving, deleting safely, or compressing files.
# 2. The key idea is that paths are data, so your program can inspect many files and apply the same rule consistently.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. This matters when cleaning Downloads folders, archiving reports, collecting logs, or preparing project backups.
# 5. Use sample folders first, because a small path mistake can affect many files quickly.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# import os, shutil
# from pathlib import Path
# h = Path.home()
#
# for folder_name, subfolders, filenames in os.walk(h / 'spam'):
#     print('The current folder is ' + folder_name)
#
#     for subfolder in subfolders:
#         print('SUBFOLDER OF ' + folder_name + ': ' + subfolder)
#
#     for filename in filenames:
#         print('FILE INSIDE ' + folder_name + ': '+ filename)
#         # Rename file to uppercase:
#         p = Path(folder_name)
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# import os, shutil
# from pathlib import Path
# h = Path.home()
#
# for folder_name, subfolders, filenames in os.walk(h / 'spam'):
#     print('The current folder is ' + folder_name)
#
#     for subfolder in subfolders:
#         print('SUBFOLDER OF ' + folder_name + ': ' + subfolder)
#
#     for filename in filenames:
#         print('FILE INSIDE ' + folder_name + ': '+ filename)
#         # Rename file to uppercase:
#         p = Path(folder_name)
#         shutil.move(p / filename, p / filename.upper())
#
#     print('')
# ```

# %%
# Practice rewrite for source example 11.12
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 11.13
#
# Checklist note: captured from section **Walking a Directory Tree**.
#
# **Context**
#
# 1. This example belongs to the chapter on organizing files and folders, and shows one small building block from the section `Walking a Directory Tree`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# The current folder is C:\Users\Al\spam
# SUBFOLDER OF C:\Users\Al\spam: eggs
# SUBFOLDER OF C:\Users\Al\spam: eggs2
# FILE INSIDE C:\Users\Al\spam: file1.txt
#
# The current folder is C:\Users\Al\spam\eggs
# SUBFOLDER OF C:\Users\Al\spam\eggs: bacon
# FILE INSIDE C:\Users\Al\spam\eggs: file2.txt
# FILE INSIDE C:\Users\Al\spam\eggs: file3.txt
#
# The current folder is C:\Users\Al\spam\eggs\bacon
# FILE INSIDE C:\Users\Al\spam\eggs\bacon: file4.txt
#
# The current folder is C:\Users\Al\spam\eggs2
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# The current folder is C:\Users\Al\spam
# SUBFOLDER OF C:\Users\Al\spam: eggs
# SUBFOLDER OF C:\Users\Al\spam: eggs2
# FILE INSIDE C:\Users\Al\spam: file1.txt
#
# The current folder is C:\Users\Al\spam\eggs
# SUBFOLDER OF C:\Users\Al\spam\eggs: bacon
# FILE INSIDE C:\Users\Al\spam\eggs: file2.txt
# FILE INSIDE C:\Users\Al\spam\eggs: file3.txt
#
# The current folder is C:\Users\Al\spam\eggs\bacon
# FILE INSIDE C:\Users\Al\spam\eggs\bacon: file4.txt
#
# The current folder is C:\Users\Al\spam\eggs2
# ```

# %%
# Practice rewrite for source example 11.13
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Compressing Files with the zipfile Module

# %% [markdown]
# #### Source example 11.14
#
# Checklist note: captured from section **Compressing Files with the zipfile Module**.
#
# **Context**
#
# 1. This example demonstrates file-management automation: copying, moving, deleting safely, or compressing files.
# 2. The key idea is that paths are data, so your program can inspect many files and apply the same rule consistently.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. This matters when cleaning Downloads folders, archiving reports, collecting logs, or preparing project backups.
# 5. Use sample folders first, because a small path mistake can affect many files quickly.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import zipfile
#
# >>>
# with open('file1.txt', 'w', encoding='utf-8') as file_obj:
#
# ...
# file_obj.write('Hello' * 10000)
#
# ...
# >>>
# with zipfile.ZipFile('example.zip', 'w') as example_zip:
#
# ...
# # ... 4 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import zipfile
#
# >>>
# with open('file1.txt', 'w', encoding='utf-8') as file_obj:
#
# ...
# file_obj.write('Hello' * 10000)
#
# ...
# >>>
# with zipfile.ZipFile('example.zip', 'w') as example_zip:
#
# ...
# example_zip.write('file1.txt', compress_type=zipfile.ZIP_DEFLATED,
#
#
#         compresslevel=9)
# ```

# %%
# Practice rewrite for source example 11.14
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 11.15
#
# Checklist note: captured from section **Compressing Files with the zipfile Module**.
#
# **Context**
#
# 1. This example demonstrates file-management automation: copying, moving, deleting safely, or compressing files.
# 2. The key idea is that paths are data, so your program can inspect many files and apply the same rule consistently.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. This matters when cleaning Downloads folders, archiving reports, collecting logs, or preparing project backups.
# 5. Use sample folders first, because a small path mistake can affect many files quickly.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import zipfile
#
#
# >>>
# example_zip = zipfile.ZipFile('example.zip')
#
# >>>
# example_zip.namelist()
#
# ['file1.txt']
#
# >>>
# file1_info = example_zip.getinfo('file1.txt')
# # ... 21 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import zipfile
#
#
# >>>
# example_zip = zipfile.ZipFile('example.zip')
#
# >>>
# example_zip.namelist()
#
# ['file1.txt']
#
# >>>
# file1_info = example_zip.getinfo('file1.txt')
#
# >>>
# file1_info.file_size
#
# 50000
# >>>
# file1_info.compress_size
#
# 97
#
# ❶
#  >>>
# f'Compressed file is {round(file1_info.file_size / file1_info
#
#
#     .compress_size, 2)}x smaller!'
#
#
# 'Compressed file is 515.46x smaller!'
# >>>
# example_zip.close()
# ```

# %%
# Practice rewrite for source example 11.15
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 11.16
#
# Checklist note: captured from section **Compressing Files with the zipfile Module**.
#
# **Context**
#
# 1. This example demonstrates file-management automation: copying, moving, deleting safely, or compressing files.
# 2. The key idea is that paths are data, so your program can inspect many files and apply the same rule consistently.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. This matters when cleaning Downloads folders, archiving reports, collecting logs, or preparing project backups.
# 5. Use sample folders first, because a small path mistake can affect many files quickly.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import zipfile
#
# >>>
# example_zip = zipfile.ZipFile('example.zip')
#
#
# ❶
#  >>>
# example_zip.extractall()
#
# >>>
# example_zip.close()
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import zipfile
#
# >>>
# example_zip = zipfile.ZipFile('example.zip')
#
#
# ❶
#  >>>
# example_zip.extractall()
#
# >>>
# example_zip.close()
# ```

# %%
# Practice rewrite for source example 11.16
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 11.17
#
# Checklist note: captured from section **Compressing Files with the zipfile Module**.
#
# **Context**
#
# 1. This example belongs to the chapter on organizing files and folders, and shows one small building block from the section `Compressing Files with the zipfile Module`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# example_zip.extract('file1.txt')
#
# 'C:\\Users\\Al\\Desktop\\file1.txt'
# >>>
# example_zip.extract('file1.txt', 'C:\\some\\new\\folders')
#
# 'C:\\some\\new\\folders\\file1.txt'
# >>>
# example_zip.close()
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# example_zip.extract('file1.txt')
#
# 'C:\\Users\\Al\\Desktop\\file1.txt'
# >>>
# example_zip.extract('file1.txt', 'C:\\some\\new\\folders')
#
# 'C:\\some\\new\\folders\\file1.txt'
# >>>
# example_zip.close()
# ```

# %%
# Practice rewrite for source example 11.17
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 11.18
#
# Checklist note: captured from section **Compressing Files with the zipfile Module**.
#
# **Context**
#
# 1. This example demonstrates file-management automation: copying, moving, deleting safely, or compressing files.
# 2. The key idea is that paths are data, so your program can inspect many files and apply the same rule consistently.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. This matters when cleaning Downloads folders, archiving reports, collecting logs, or preparing project backups.
# 5. Use sample folders first, because a small path mistake can affect many files quickly.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# # backup_to_zip.py - Copies an entire folder and its contents into
# # a ZIP file whose filename increments
#
# import zipfile, os
# from pathlib import Path
#
# def backup_to_zip(folder):
#     # Back up the entire contents of "folder" into a ZIP file.
#     folder = Path(folder)  # Make sure folder is a Path object, not string.
#
#     # Figure out the ZIP filename this code should use, based on
#     # what files already exist.
#
# ❶
# # ... 19 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # backup_to_zip.py - Copies an entire folder and its contents into
# # a ZIP file whose filename increments
#
# import zipfile, os
# from pathlib import Path
#
# def backup_to_zip(folder):
#     # Back up the entire contents of "folder" into a ZIP file.
#     folder = Path(folder)  # Make sure folder is a Path object, not string.
#
#     # Figure out the ZIP filename this code should use, based on
#     # what files already exist.
#
# ❶
#  number = 1
#
# ❷
#  while True:
#
#         zip_filename = Path(folder.parts[-1] + '_' + str(number) + '.zip')
#         if not zip_filename.exists():
#             break
#         number = number + 1
#
#
# ❸
#  # TODO: Create the ZIP file.
#
#
#     # TODO: Walk the entire folder tree and compress the files in each folder.
#     print('Done.')
#
# backup_to_zip(Path.home() / 'spam')
# ```

# %%
# Practice rewrite for source example 11.18
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 11.19
#
# Checklist note: captured from section **Compressing Files with the zipfile Module**.
#
# **Context**
#
# 1. This example demonstrates file-management automation: copying, moving, deleting safely, or compressing files.
# 2. The key idea is that paths are data, so your program can inspect many files and apply the same rule consistently.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. This matters when cleaning Downloads folders, archiving reports, collecting logs, or preparing project backups.
# 5. Use sample folders first, because a small path mistake can affect many files quickly.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# # backup_to_zip.py - Copies an entire folder and its contents into
# # a ZIP file whose filename increments
#
#
# --snip--
#
#
#
# # Create the ZIP file.
#
#
#     print(f'Creating {zip_filename}...')
#
#
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # backup_to_zip.py - Copies an entire folder and its contents into
# # a ZIP file whose filename increments
#
#
# --snip--
#
#
#
# # Create the ZIP file.
#
#
#     print(f'Creating {zip_filename}...')
#
#
#     backup_zip = zipfile.ZipFile(zip_filename, 'w')
#
#
#     # TODO: Walk the entire folder tree and compress the files in each folder.
#     print('Done.')
#
# backup_to_zip(Path.home() / 'spam')
# ```

# %%
# Practice rewrite for source example 11.19
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 11.20
#
# Checklist note: captured from section **Compressing Files with the zipfile Module**.
#
# **Context**
#
# 1. This example belongs to the chapter on organizing files and folders, and shows one small building block from the section `Compressing Files with the zipfile Module`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# # backup_to_zip.py - Copies an entire folder and its contents into
# # a ZIP file whose filename increments
#
#
# --snip--
#
#
#
#     # Walk the entire folder tree and compress the files in each folder.
#
#
#
# ❶
#  for folder_name, subfolders, filenames in os.walk(folder):
# # ... 27 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # backup_to_zip.py - Copies an entire folder and its contents into
# # a ZIP file whose filename increments
#
#
# --snip--
#
#
#
#     # Walk the entire folder tree and compress the files in each folder.
#
#
#
# ❶
#  for folder_name, subfolders, filenames in os.walk(folder):
#
#
#         folder_name = Path(folder_name)
#
#
#         print(f'Adding files in folder {folder_name}...')
#
#
#
# # Add all the files in this folder to the ZIP file.
#
#
#
# ❷
#  for filename in filenames:
#
#
#             print(f'Adding file {filename}...')
#
#
#             backup_zip.write(folder_name / filename)
#
#
#     backup_zip.close()
#
#     print('Done.')
# backup_to_zip(Path.home() / 'spam')
# ```

# %%
# Practice rewrite for source example 11.20
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 11.21
#
# Checklist note: captured from section **Compressing Files with the zipfile Module**.
#
# **Context**
#
# 1. This example belongs to the chapter on organizing files and folders, and shows one small building block from the section `Compressing Files with the zipfile Module`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# Creating spam_1.zip...
# Adding files in spam...
# Adding file file1.txt...
# Done.
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# Creating spam_1.zip...
# Adding files in spam...
# Adding file file1.txt...
# Done.
# ```

# %%
# Practice rewrite for source example 11.21
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Practice Programs

# %% [markdown]
# #### Source example 11.22
#
# Checklist note: captured from section **Practice Programs**.
#
# **Context**
#
# 1. This example belongs to the chapter on organizing files and folders, and shows one small building block from the section `Practice Programs`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter turns chapter 10 file reading/writing into practical folder automation, while still relying on loops, strings, and conditionals from the basics.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# files/folders -> inspect paths -> choose action -> copy/move/archive -> verify result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# for i in range(1, 121):
#
#
# ...     if i not in (42, 86, 103):
#
#
# ...         with open(f'spam{str(i).zfill(3)}.txt', 'w') as file:
#
#
# ...             pass
#
# ...
# ```

# %%
# Adapted from source example 11.22
if i not in (42, 86, 103):
        with open(f'spam{str(i).zfill(3)}.txt', 'w') as file:
            pass

# %% [markdown]
# ### Chapter 11 Practice Checkpoint

# %%
# Chapter 11 checkpoint
# Choose three source examples from this chapter.
# For each one:
# 1. Explain what input it expects.
# 2. Explain what output or side effect it creates.
# 3. Rewrite it with safe sample data.

# %% [markdown]
# ### Extra Practice for Chapter 11

# %% [markdown]
# #### Practice: organize files by extension

# %%
from pathlib import Path
import tempfile
import shutil

sandbox = Path(tempfile.gettempdir()) / "atsbs_ch11_organize"
sandbox.mkdir(exist_ok=True)

for name in ["report.txt", "photo.png", "notes.txt", "sales.csv"]:
    (sandbox / name).write_text("sample", encoding="utf-8")

for path in sandbox.iterdir():
    if path.is_file():
        target_dir = sandbox / path.suffix.removeprefix(".")
        target_dir.mkdir(exist_ok=True)
        shutil.copy(path, target_dir / path.name)

print("Organized copy created at:", sandbox)

# %% [markdown]
# ## 12 DESIGNING AND DEPLOYING COMMAND LINE PROGRAMS
#
# Source: https://automatetheboringstuff.com/3e/chapter12.html

# %% [markdown]
# ### Using the Terminal

# %% [markdown]
# #### Source example 12.1
#
# Checklist note: captured from section **Using the Terminal**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Using the Terminal`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# C:\Users\al>
# your commands go here
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# C:\Users\al>
# your commands go here
# ```

# %%
# Practice rewrite for source example 12.1
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.2
#
# Checklist note: captured from section **Using the Terminal**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Using the Terminal`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# al@Als-MacBook-Pro ~ %
# your commands go here
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# al@Als-MacBook-Pro ~ %
# your commands go here
# ```

# %%
# Practice rewrite for source example 12.2
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.3
#
# Checklist note: captured from section **Using the Terminal**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Using the Terminal`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# al@al-VirtualBox:~$
# your commands go here
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# al@al-VirtualBox:~$
# your commands go here
# ```

# %%
# Practice rewrite for source example 12.3
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.4
#
# Checklist note: captured from section **Using the Terminal**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Using the Terminal`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# C:\Users\al>
# cd Desktop
#
# C:\Users\al\Desktop>
# cd ..
#
# C:\Users\al>
# cd C:\Windows\System32
#
# C:\Windows\System32>
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# C:\Users\al>
# cd Desktop
#
# C:\Users\al\Desktop>
# cd ..
#
# C:\Users\al>
# cd C:\Windows\System32
#
# C:\Windows\System32>
# ```

# %%
# Practice rewrite for source example 12.4
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.5
#
# Checklist note: captured from section **Using the Terminal**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Using the Terminal`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# C:\Windows\System32>
# D:
#
# D:\>
# cd backup
#
# D:\backup>
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# C:\Windows\System32>
# D:
#
# D:\>
# cd backup
#
# D:\backup>
# ```

# %%
# Practice rewrite for source example 12.5
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.6
#
# Checklist note: captured from section **Using the Terminal**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Using the Terminal`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# C:\Users\al>
# dir
#
#
# --snip--
#
# 08/26/2036  06:42 PM           171,304 _recursive-centaur.png
# 08/18/2035  11:25 AM             1,278 _viminfo
# 08/13/2035  12:58 AM    <DIR>          __pycache__
#               77 File(s)     83,805,114 bytes
#              108 Dir(s)  149,225,267,200 bytes free
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# C:\Users\al>
# dir
#
#
# --snip--
#
# 08/26/2036  06:42 PM           171,304 _recursive-centaur.png
# 08/18/2035  11:25 AM             1,278 _viminfo
# 08/13/2035  12:58 AM    <DIR>          __pycache__
#               77 File(s)     83,805,114 bytes
#              108 Dir(s)  149,225,267,200 bytes free
# ```

# %%
# Practice rewrite for source example 12.6
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.7
#
# Checklist note: captured from section **Using the Terminal**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Using the Terminal`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# al@al-virtual-machine:~$
# echo $PATH
#
# /home/al/.local/bin:/home/al/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/
# usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# al@al-virtual-machine:~$
# echo $PATH
#
# /home/al/.local/bin:/home/al/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/
# usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin
# ```

# %%
# Practice rewrite for source example 12.7
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.8
#
# Checklist note: captured from section **Using the Terminal**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Using the Terminal`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# export PATH=/Users/al/Scripts:$PATH
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# export PATH=/Users/al/Scripts:$PATH
# ```

# %%
# Practice rewrite for source example 12.8
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.9
#
# Checklist note: captured from section **Using the Terminal**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Using the Terminal`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# export PATH=/home/al/Scripts:$PATH
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# export PATH=/home/al/Scripts:$PATH
# ```

# %%
# Practice rewrite for source example 12.9
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.10
#
# Checklist note: captured from section **Using the Terminal**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Using the Terminal`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# al@Als-MacBook-Pro ~ %
# which python3
#
# /Library/Frameworks/Python.framework/Versions/3.13/bin/python3
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# al@Als-MacBook-Pro ~ %
# which python3
#
# /Library/Frameworks/Python.framework/Versions/3.13/bin/python3
# ```

# %%
# Practice rewrite for source example 12.10
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.11
#
# Checklist note: captured from section **Using the Terminal**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Using the Terminal`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# C:\Users\al>
# where python
#
# C:\Users\al\AppData\Local\Programs\Python\Python313\python.exe
# C:\Users\al\AppData\Local\Programs\Python\Python312\python.exe
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# C:\Users\al>
# where python
#
# C:\Users\al\AppData\Local\Programs\Python\Python313\python.exe
# C:\Users\al\AppData\Local\Programs\Python\Python312\python.exe
# ```

# %%
# Practice rewrite for source example 12.11
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Virtual Environments

# %% [markdown]
# #### Source example 12.12
#
# Checklist note: captured from section **Virtual Environments**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Virtual Environments`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# C:\Users\al>
# C:\Users\al>
# cd Scripts
#
# C:\Users\al\Scripts>
# python -m venv .venv
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# C:\Users\al>
# C:\Users\al>
# cd Scripts
#
# C:\Users\al\Scripts>
# python -m venv .venv
# ```

# %%
# Practice rewrite for source example 12.12
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.13
#
# Checklist note: captured from section **Virtual Environments**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Virtual Environments`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# C:\Users\al\Scripts>
# cd .venv\Scripts
#
# C:\Users\al\Scripts\.venv\Scripts>
# activate.bat
#
# (.venv) C:\Users\al\Scripts\.venv\Scripts>
# where python.exe
#
# C:\Users\Al\Scripts\.venv\Scripts\python.exe
# C:\Users\Al\AppData\Local\Programs\Python\Python313\python.exe
# C:\Users\Al\AppData\Local\Programs\Python\Python312\python.exe
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# C:\Users\al\Scripts>
# cd .venv\Scripts
#
# C:\Users\al\Scripts\.venv\Scripts>
# activate.bat
#
# (.venv) C:\Users\al\Scripts\.venv\Scripts>
# where python.exe
#
# C:\Users\Al\Scripts\.venv\Scripts\python.exe
# C:\Users\Al\AppData\Local\Programs\Python\Python313\python.exe
# C:\Users\Al\AppData\Local\Programs\Python\Python312\python.exe
# ```

# %%
# Practice rewrite for source example 12.13
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.14
#
# Checklist note: captured from section **Virtual Environments**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Virtual Environments`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# al@al-virtual-machine:~/Scripts$
# cd .venv/bin
#
# al@al-virtual-machine:~/Scripts/.venv/bin$
# source activate
#
# (.venv) al@al-virtual-machine:~/Scripts/.venv/bin$ which python3
# /home/al/Scripts/.venv/bin/python3
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# al@al-virtual-machine:~/Scripts$
# cd .venv/bin
#
# al@al-virtual-machine:~/Scripts/.venv/bin$
# source activate
#
# (.venv) al@al-virtual-machine:~/Scripts/.venv/bin$ which python3
# /home/al/Scripts/.venv/bin/python3
# ```

# %%
# Practice rewrite for source example 12.14
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.15
#
# Checklist note: captured from section **Virtual Environments**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Virtual Environments`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# (.venv) C:\Users\al\Scripts\.venv\Scripts>
# python -m pip list
#
# Package    Version
# ---------- -------
# pip        23.0
# setuptools 65.5.0
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# (.venv) C:\Users\al\Scripts\.venv\Scripts>
# python -m pip list
#
# Package    Version
# ---------- -------
# pip        23.0
# setuptools 65.5.0
# ```

# %%
# Practice rewrite for source example 12.15
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Installing Python Packages with pip

# %% [markdown]
# #### Source example 12.16
#
# Checklist note: captured from section **Installing Python Packages with pip**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Installing Python Packages with pip`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# C:\Users\al>
# python –m pip install
# package_name
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# C:\Users\al>
# python –m pip install
# package_name
# ```

# %%
# Practice rewrite for source example 12.16
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.17
#
# Checklist note: captured from section **Installing Python Packages with pip**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Installing Python Packages with pip`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# C:\Users\al>
# python -m pip list
#
# Package                   Version     Editable project location
# ------------------------- ----------- -------------------------
# altgraph                  0.17.3
# argon2-cffi               21.3.0
# argon2-cffi-bindings      21.2.0
# async-generator           1.10
#
# --snip--
#
# wsproto                   1.2.0
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# C:\Users\al>
# python -m pip list
#
# Package                   Version     Editable project location
# ------------------------- ----------- -------------------------
# altgraph                  0.17.3
# argon2-cffi               21.3.0
# argon2-cffi-bindings      21.2.0
# async-generator           1.10
#
# --snip--
#
# wsproto                   1.2.0
# ```

# %%
# Practice rewrite for source example 12.17
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.18
#
# Checklist note: captured from section **Installing Python Packages with pip**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Installing Python Packages with pip`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# python –m pip install automateboringstuff3
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# python –m pip install automateboringstuff3
# ```

# %%
# Practice rewrite for source example 12.18
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.19
#
# Checklist note: captured from section **Installing Python Packages with pip**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Installing Python Packages with pip`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# python3 –m pip install automateboringstuff3
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# python3 –m pip install automateboringstuff3
# ```

# %%
# Practice rewrite for source example 12.19
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Self-Aware Python Programs

# %% [markdown]
# #### Source example 12.20
#
# Checklist note: captured from section **Self-Aware Python Programs**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Self-Aware Python Programs`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# try:
#     import nonexistentModule
# except ModuleNotFoundError:
#     print('This code runs if nonexistentModule was not found.')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# try:
#     import nonexistentModule
# except ModuleNotFoundError:
#     print('This code runs if nonexistentModule was not found.')
# ```

# %%
# Practice rewrite for source example 12.20
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Text-Based Program Design

# %% [markdown]
# #### Source example 12.21
#
# Checklist note: captured from section **Text-Based Program Design**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Text-Based Program Design`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import bext
#
# >>>
# bext.fg('red')
#
#
# >>>
# print('This text is red.')
#
# This text is red.
# >>>
# bext.bg('blue')
#
# # ... 14 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import bext
#
# >>>
# bext.fg('red')
#
#
# >>>
# print('This text is red.')
#
# This text is red.
# >>>
# bext.bg('blue')
#
# >>>
# print('Red text on blue background is an ugly color scheme.')
#
# Red text on blue background is an ugly color scheme.
# >>>
# bext.fg('reset')
#
# >>>
# bext.bg('reset')
#
# >>>
# print('The text is normal again. Ah, much better.')
#
# The text is normal again. Ah, much better.
# ```

# %%
# Practice rewrite for source example 12.21
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.22
#
# Checklist note: captured from section **Text-Based Program Design**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Text-Based Program Design`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# import os
# def clear():
#     os.system('cls' if os.name == 'nt' else 'clear')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# import os
# def clear():
#     os.system('cls' if os.name == 'nt' else 'clear')
# ```

# %%
# Practice rewrite for source example 12.22
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.23
#
# Checklist note: captured from section **Text-Based Program Design**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Text-Based Program Design`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import playsound3
#
# >>>
# playsound3.playsound('hello.mp3')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import playsound3
#
# >>>
# playsound3.playsound('hello.mp3')
# ```

# %%
# Practice rewrite for source example 12.23
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### A Short Program: Snowstorm

# %% [markdown]
# #### Source example 12.24
#
# Checklist note: captured from section **A Short Program: Snowstorm**.
#
# **Context**
#
# 1. This example shows how a Python script receives options and filenames from the command line.
# 2. Command line arguments make a script reusable because the behavior changes without editing the source code.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. That is important for tools you want to run from terminals, scheduled jobs, shortcuts, or other programs.
# 5. Practice with harmless inputs first, then add validation and helpful error messages.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# import os, random, time, sys
#
# TOP    = chr(9600)  # Character 9600 is '
# ▀
# '
# BOTTOM = chr(9604)  # Character 9604 is '
# ▄
# '
# FULL   = chr(9608)  # Character 9608 is '
# █
# '
#
# # Set the snowstorm density to the command line argument:
# DENSITY = 4  # Default snow density is 4%
# # ... 26 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# import os, random, time, sys
#
# TOP    = chr(9600)  # Character 9600 is '
# ▀
# '
# BOTTOM = chr(9604)  # Character 9604 is '
# ▄
# '
# FULL   = chr(9608)  # Character 9608 is '
# █
# '
#
# # Set the snowstorm density to the command line argument:
# DENSITY = 4  # Default snow density is 4%
# if len(sys.argv) > 1:
#     DENSITY = int(sys.argv[1])
#
# def clear():
#     os.system('cls' if os.name == 'nt' else 'clear')
#
# while True:
#     clear()  # Clear the terminal window.
#
#     # Loop over each row and column:
#     for y in range(20):
#         for x in range(40):
#             if random.randint(0, 99) < DENSITY:
#                 # Print snow:
#                 print(random.choice([TOP, BOTTOM]), end='')
#
#             else:
#                 # Print empty space:
#                 print(' ', end='')
#         print()  # Print a newline.
#
#     # Print the snow-covered ground:
#     print(FULL * 40 + '\n' + FULL * 40)
#     print('(Ctrl-C to stop.)')
#
#     time.sleep(0.2)  # Pause for a bit.
# ```

# %%
# Practice rewrite for source example 12.24
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Deploying Python Programs

# %% [markdown]
# #### Source example 12.25
#
# Checklist note: captured from section **Deploying Python Programs**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Deploying Python Programs`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# @call %HOMEDRIVE%%HOMEPATH%\Scripts\.venv\Scripts\activate.bat
# @python %HOMEDRIVE%%HOMEPATH%\Scripts\yourScript.py %*
# @pause
# @deactivate
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# @call %HOMEDRIVE%%HOMEPATH%\Scripts\.venv\Scripts\activate.bat
# @python %HOMEDRIVE%%HOMEPATH%\Scripts\yourScript.py %*
# @pause
# @deactivate
# ```

# %%
# Practice rewrite for source example 12.25
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.26
#
# Checklist note: captured from section **Deploying Python Programs**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Deploying Python Programs`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# source ~/Scripts/.venv/bin/activate
# python3 ~/Scripts/yourScript.py
# deactivate
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# source ~/Scripts/.venv/bin/activate
# python3 ~/Scripts/yourScript.py
# deactivate
# ```

# %%
# Practice rewrite for source example 12.26
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.27
#
# Checklist note: captured from section **Deploying Python Programs**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Deploying Python Programs`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# #!/usr/bin/env bash
# source ~/Scripts/.venv/bin/activate
# python3 ~/Scripts/yourScript.py
# read -p "Press any key to continue..." -n1 –s
# deactivate
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# #!/usr/bin/env bash
# source ~/Scripts/.venv/bin/activate
# python3 ~/Scripts/yourScript.py
# read -p "Press any key to continue..." -n1 –s
# deactivate
# ```

# %%
# Practice rewrite for source example 12.27
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.28
#
# Checklist note: captured from section **Deploying Python Programs**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Deploying Python Programs`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# [Desktop Entry]
# Name=yourScript
# Exec=gnome-terminal -- /home/al/Scripts/yourScript
# Type=Application
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# [Desktop Entry]
# Name=yourScript
# Exec=gnome-terminal -- /home/al/Scripts/yourScript
# Type=Application
# ```

# %%
# Practice rewrite for source example 12.28
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### A Short Program: Copying the Current Working Directory

# %% [markdown]
# #### Source example 12.29
#
# Checklist note: captured from section **A Short Program: Copying the Current Working Directory**.
#
# **Context**
#
# 1. This example shows how a Python script receives options and filenames from the command line.
# 2. Command line arguments make a script reusable because the behavior changes without editing the source code.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. That is important for tools you want to run from terminals, scheduled jobs, shortcuts, or other programs.
# 5. Practice with harmless inputs first, then add validation and helpful error messages.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# import pyperclip, os, sys
# if len(sys.argv) > 1:
#     os.chdir(sys.argv[1])
# pyperclip.copy(os.getcwd())
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# import pyperclip, os, sys
# if len(sys.argv) > 1:
#     os.chdir(sys.argv[1])
# pyperclip.copy(os.getcwd())
# ```

# %%
# Practice rewrite for source example 12.29
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.30
#
# Checklist note: captured from section **A Short Program: Copying the Current Working Directory**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Copying the Current Working Directory`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# @call %HOMEDRIVE%%HOMEPATH%\Scripts\.venv\Scripts\activate.bat
# @python %HOMEDRIVE%%HOMEPATH%\Scripts\ccwd.py %*
# @deactivate
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# @call %HOMEDRIVE%%HOMEPATH%\Scripts\.venv\Scripts\activate.bat
# @python %HOMEDRIVE%%HOMEPATH%\Scripts\ccwd.py %*
# @deactivate
# ```

# %%
# Practice rewrite for source example 12.30
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.31
#
# Checklist note: captured from section **A Short Program: Copying the Current Working Directory**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Copying the Current Working Directory`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# C:\Users\al>
# ccwd
#
# C:\Users\al>
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# C:\Users\al>
# ccwd
#
# C:\Users\al>
# ```

# %%
# Practice rewrite for source example 12.31
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.32
#
# Checklist note: captured from section **A Short Program: Copying the Current Working Directory**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Copying the Current Working Directory`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# source ~/Scripts/.venv/bin/activate
# python3 ~/Scripts/ccwd.py
# deactivate
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# source ~/Scripts/.venv/bin/activate
# python3 ~/Scripts/ccwd.py
# deactivate
# ```

# %%
# Practice rewrite for source example 12.32
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.33
#
# Checklist note: captured from section **A Short Program: Copying the Current Working Directory**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Copying the Current Working Directory`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# al@Als-MacBook-Pro ~ %
# cd ~/Scripts
#
# al@Als-MacBook-Pro Scripts %
# chmod u+x ccwd.command
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# al@Als-MacBook-Pro ~ %
# cd ~/Scripts
#
# al@Als-MacBook-Pro Scripts %
# chmod u+x ccwd.command
# ```

# %%
# Practice rewrite for source example 12.33
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.34
#
# Checklist note: captured from section **A Short Program: Copying the Current Working Directory**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Copying the Current Working Directory`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# al@Als-MacBook-Pro ~ %
# ccwd.command
#
# al@Als-MacBook-Pro ~ %
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# al@Als-MacBook-Pro ~ %
# ccwd.command
#
# al@Als-MacBook-Pro ~ %
# ```

# %%
# Practice rewrite for source example 12.34
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.35
#
# Checklist note: captured from section **A Short Program: Copying the Current Working Directory**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Copying the Current Working Directory`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# #!/usr/bin/env bash
# source ~/Scripts/.venv/bin/activate
# python3 ~/Scripts/ccwd.py
# deactivate
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# #!/usr/bin/env bash
# source ~/Scripts/.venv/bin/activate
# python3 ~/Scripts/ccwd.py
# deactivate
# ```

# %%
# Practice rewrite for source example 12.35
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.36
#
# Checklist note: captured from section **A Short Program: Copying the Current Working Directory**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Copying the Current Working Directory`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# al@al-VirtualBox:~$
# cd ~/Scripts
#
# al@al-VirtualBox:~/Scripts$
# chmod u+x ccwd
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# al@al-VirtualBox:~$
# cd ~/Scripts
#
# al@al-VirtualBox:~/Scripts$
# chmod u+x ccwd
# ```

# %%
# Practice rewrite for source example 12.36
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.37
#
# Checklist note: captured from section **A Short Program: Copying the Current Working Directory**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Copying the Current Working Directory`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# al@al-VirtualBox:~$
# ccwd
#
# al@al-VirtualBox:~$
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# al@al-VirtualBox:~$
# ccwd
#
# al@al-VirtualBox:~$
# ```

# %%
# Practice rewrite for source example 12.37
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### A Short Program: Clipboard Recorder

# %% [markdown]
# #### Source example 12.38
#
# Checklist note: captured from section **A Short Program: Clipboard Recorder**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# import pyperclip, time
#
# print('Recording clipboard... (Ctrl-C to stop)')
# previous_content = ''
# try:
#     while True:
#         content = pyperclip.paste()  # Get clipboard contents.
#
#         if content != previous_content:
#             # If it's different from the previous, print it:
#             print(content)
#             previous_content = content
#
#         time.sleep(0.01)  # Pause to avoid hogging the CPU.
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# import pyperclip, time
#
# print('Recording clipboard... (Ctrl-C to stop)')
# previous_content = ''
# try:
#     while True:
#         content = pyperclip.paste()  # Get clipboard contents.
#
#         if content != previous_content:
#             # If it's different from the previous, print it:
#             print(content)
#             previous_content = content
#
#         time.sleep(0.01)  # Pause to avoid hogging the CPU.
# except KeyboardInterrupt:
#     pass
# ```

# %%
# Practice rewrite for source example 12.38
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.39
#
# Checklist note: captured from section **A Short Program: Clipboard Recorder**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Clipboard Recorder`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# import pyperclip, time
#
# print('Recording clipboard... (Ctrl-C to stop)')
# previous_content = ''
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# import pyperclip, time
#
# print('Recording clipboard... (Ctrl-C to stop)')
# previous_content = ''
# ```

# %%
# Practice rewrite for source example 12.39
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.40
#
# Checklist note: captured from section **A Short Program: Clipboard Recorder**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Clipboard Recorder`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# try:
#     while True:
#         content = pyperclip.paste()  # Get clipboard contents.
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# try:
#     while True:
#         content = pyperclip.paste()  # Get clipboard contents.
# ```

# %%
# Practice rewrite for source example 12.40
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.41
#
# Checklist note: captured from section **A Short Program: Clipboard Recorder**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Clipboard Recorder`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
#         if content != previous_content:
#             # If it's different from the previous, print it:
#             print(content)
#             previous_content = content
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
#         if content != previous_content:
#             # If it's different from the previous, print it:
#             print(content)
#             previous_content = content
# ```

# %%
# Practice rewrite for source example 12.41
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.42
#
# Checklist note: captured from section **A Short Program: Clipboard Recorder**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
#         time.sleep(0.01)  # Pause to avoid hogging the CPU.
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
#         time.sleep(0.01)  # Pause to avoid hogging the CPU.
# ```

# %%
# Practice rewrite for source example 12.42
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.43
#
# Checklist note: captured from section **A Short Program: Clipboard Recorder**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Clipboard Recorder`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# except KeyboardInterrupt:
#     pass
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# except KeyboardInterrupt:
#     pass
# ```

# %%
# Practice rewrite for source example 12.43
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.44
#
# Checklist note: captured from section **A Short Program: Clipboard Recorder**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Clipboard Recorder`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# @call %HOMEDRIVE%%HOMEPATH%\Scripts\.venv\Scripts\activate.bat
# @python %HOMEDRIVE%%HOMEPATH%\Scripts\cliprec.py %*
#
# @pause
# @deactivate
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# @call %HOMEDRIVE%%HOMEPATH%\Scripts\.venv\Scripts\activate.bat
# @python %HOMEDRIVE%%HOMEPATH%\Scripts\cliprec.py %*
#
# @pause
# @deactivate
# ```

# %%
# Practice rewrite for source example 12.44
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.45
#
# Checklist note: captured from section **A Short Program: Clipboard Recorder**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Clipboard Recorder`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# source ~/Scripts/.venv/bin/activate
# python3 ~/Scripts/cliprec.py
# deactivate
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# source ~/Scripts/.venv/bin/activate
# python3 ~/Scripts/cliprec.py
# deactivate
# ```

# %%
# Practice rewrite for source example 12.45
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.46
#
# Checklist note: captured from section **A Short Program: Clipboard Recorder**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Clipboard Recorder`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# al@Als-MacBook-Pro ~ %
# cd ~/Scripts
#
# al@Als-MacBook-Pro Scripts %
# chmod u+x cliprec.command
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# al@Als-MacBook-Pro ~ %
# cd ~/Scripts
#
# al@Als-MacBook-Pro Scripts %
# chmod u+x cliprec.command
# ```

# %%
# Practice rewrite for source example 12.46
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.47
#
# Checklist note: captured from section **A Short Program: Clipboard Recorder**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Clipboard Recorder`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# #!/usr/bin/env bash
# source ~/Scripts/.venv/bin/activate
# python3 ~/Scripts/cliprec.py
# read -p "Press any key to continue..." -n1 –s
# deactivate
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# #!/usr/bin/env bash
# source ~/Scripts/.venv/bin/activate
# python3 ~/Scripts/cliprec.py
# read -p "Press any key to continue..." -n1 –s
# deactivate
# ```

# %%
# Practice rewrite for source example 12.47
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.48
#
# Checklist note: captured from section **A Short Program: Clipboard Recorder**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Clipboard Recorder`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# al@al-VirtualBox:~$
# cd ~/Scripts
#
# al@al-VirtualBox:~/Scripts$
# chmod u+x cliprec
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# al@al-VirtualBox:~$
# cd ~/Scripts
#
# al@al-VirtualBox:~/Scripts$
# chmod u+x cliprec
# ```

# %%
# Practice rewrite for source example 12.48
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 12.49
#
# Checklist note: captured from section **A Short Program: Clipboard Recorder**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `A Short Program: Clipboard Recorder`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# [Desktop Entry]
# Name=Clipboard Recorder
# Exec=gnome-terminal -- /home/al/cliprec
# Type=Application
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# [Desktop Entry]
# Name=Clipboard Recorder
# Exec=gnome-terminal -- /home/al/cliprec
# Type=Application
# ```

# %%
# Practice rewrite for source example 12.49
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Compiling Python Programs with PyInstaller

# %% [markdown]
# #### Source example 12.50
#
# Checklist note: captured from section **Compiling Python Programs with PyInstaller**.
#
# **Context**
#
# 1. This example belongs to the chapter on building command line programs, and shows one small building block from the section `Compiling Python Programs with PyInstaller`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter wraps earlier functions and file logic into reusable command-line tools, so the same script can work with different inputs.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# terminal args -> parse options -> call functions -> produce output/errors
# ```
#
# **Code Preview**
#
# ```python
# C:\Users\al>
# python -m PyInstaller --onefile yourScript.py
#
# 378 INFO: PyInstaller:
# X
# .
# X
# .
# X
#
# 378 INFO: Python: 3.
# XX
# .
# XX
# # ... 18 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# C:\Users\al>
# python -m PyInstaller --onefile yourScript.py
#
# 378 INFO: PyInstaller:
# X
# .
# X
# .
# X
#
# 378 INFO: Python: 3.
# XX
# .
# XX
#
# 392 INFO: Platform: Windows-
# XX
# -
# XX
# .
# X
# .
# XXXX
#
# 393 INFO: wrote C:\Users\al\Desktop\hello-test\hello.spec
# 399 INFO: UPX is not available.
#
# --snip--
#
# 11940 INFO: Appending PKG archive to EXE
# 11950 INFO: Fixing EXE headers
# 13622 INFO: Building EXE from EXE-00.toc completed successfully.
# ```

# %%
# Practice rewrite for source example 12.50
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Chapter 12 Practice Checkpoint

# %%
# Chapter 12 checkpoint
# Choose three source examples from this chapter.
# For each one:
# 1. Explain what input it expects.
# 2. Explain what output or side effect it creates.
# 3. Rewrite it with safe sample data.

# %% [markdown]
# ### Extra Practice for Chapter 12

# %% [markdown]
# #### Practice: command-line style function

# %%
def rename_preview(prefix, filenames):
    planned = []
    for number, filename in enumerate(filenames, start=1):
        planned.append((filename, f"{prefix}_{number:03d}_{filename}"))
    return planned

for old, new in rename_preview("invoice", ["jan.pdf", "feb.pdf", "mar.pdf"]):
    print(f"{old} -> {new}")

# %% [markdown]
# ## 13 WEB SCRAPING
#
# Source: https://automatetheboringstuff.com/3e/chapter13.html

# %% [markdown]
# ### HTTP and HTTPS

# %% [markdown]
# #### Source example 13.1
#
# Checklist note: captured from section **HTTP and HTTPS**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `HTTP and HTTPS`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import webbrowser
#
# >>>
# webbrowser.open('https://inventwithpython.com/')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import webbrowser
#
# >>>
# webbrowser.open('https://inventwithpython.com/')
# ```

# %%
# Practice rewrite for source example 13.1
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.2
#
# Checklist note: captured from section **HTTP and HTTPS**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `HTTP and HTTPS`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# C:\Users\al>
# showmap 777 Valencia St, San Francisco, CA 94110
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# C:\Users\al>
# showmap 777 Valencia St, San Francisco, CA 94110
# ```

# %%
# Practice rewrite for source example 13.2
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.3
#
# Checklist note: captured from section **HTTP and HTTPS**.
#
# **Context**
#
# 1. This example shows how a Python script receives options and filenames from the command line.
# 2. Command line arguments make a script reusable because the behavior changes without editing the source code.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. That is important for tools you want to run from terminals, scheduled jobs, shortcuts, or other programs.
# 5. Practice with harmless inputs first, then add validation and helpful error messages.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# # showmap.py - Launches a map in the browser using an address from the
# # command line or clipboard
#
# import webbrowser, sys
# if len(sys.argv) > 1:
#     # Get address from command line.
#     address = ' '.join(sys.argv[1:])
#
# # TODO: Get address from clipboard.
#
# # TODO: Open the web browser.
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # showmap.py - Launches a map in the browser using an address from the
# # command line or clipboard
#
# import webbrowser, sys
# if len(sys.argv) > 1:
#     # Get address from command line.
#     address = ' '.join(sys.argv[1:])
#
# # TODO: Get address from clipboard.
#
# # TODO: Open the web browser.
# ```

# %%
# Practice rewrite for source example 13.3
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.4
#
# Checklist note: captured from section **HTTP and HTTPS**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `HTTP and HTTPS`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# showmap 777 Valencia St, San Francisco, CA 94110
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# showmap 777 Valencia St, San Francisco, CA 94110
# ```

# %%
# Practice rewrite for source example 13.4
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.5
#
# Checklist note: captured from section **HTTP and HTTPS**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `HTTP and HTTPS`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# ['showmap.py', '777', 'Valencia', 'St, ', 'San', 'Francisco, ', 'CA', '94110']
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# ['showmap.py', '777', 'Valencia', 'St, ', 'San', 'Francisco, ', 'CA', '94110']
# ```

# %%
# Practice rewrite for source example 13.5
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.6
#
# Checklist note: captured from section **HTTP and HTTPS**.
#
# **Context**
#
# 1. This example shows how a Python script receives options and filenames from the command line.
# 2. Command line arguments make a script reusable because the behavior changes without editing the source code.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. That is important for tools you want to run from terminals, scheduled jobs, shortcuts, or other programs.
# 5. Practice with harmless inputs first, then add validation and helpful error messages.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# # showmap.py - Launches a map in the browser using an address from the
# # command line or clipboard
#
#
# import webbrowser, sys
# , pyperclip
#
# if len(sys.argv) > 1:
#     # Get address from command line.
#     address = ' '.join(sys.argv[1:])
#
# else:
#
#     # Get address from clipboard.
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # showmap.py - Launches a map in the browser using an address from the
# # command line or clipboard
#
#
# import webbrowser, sys
# , pyperclip
#
# if len(sys.argv) > 1:
#     # Get address from command line.
#     address = ' '.join(sys.argv[1:])
#
# else:
#
#     # Get address from clipboard.
#
#     address = pyperclip.paste()
#
#
# # Open the web browser.
#
# webbrowser.open('https://www.openstreetmap.org/search?query=' + address)
# ```

# %%
# Practice rewrite for source example 13.6
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Downloading Files from the Web with the requests Module

# %% [markdown]
# #### Source example 13.7
#
# Checklist note: captured from section **Downloading Files from the Web with the requests Module**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import requests
#
#
# ❶
#  >>>
# response = requests.get('https://automatetheboringstuff.com/files/rj.txt')
#
# >>>
# type(response)
#
# <class 'requests.models.Response'>
#
# ❷
# # ... 15 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import requests
#
#
# ❶
#  >>>
# response = requests.get('https://automatetheboringstuff.com/files/rj.txt')
#
# >>>
# type(response)
#
# <class 'requests.models.Response'>
#
# ❷
#  >>>
# response.status_code == requests.codes.ok
#
# True
# >>>
# len(response.text)
#
# 178978
# >>>
# print(response.text[:210])
#
# The Project Gutenberg EBook of Romeo and Juliet, by William Shakespeare
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# ```

# %%
# Practice rewrite for source example 13.7
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.8
#
# Checklist note: captured from section **Downloading Files from the Web with the requests Module**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# response = requests.get('https://inventwithpython.com/page_that_does_not_exist')
#
# >>>
# response.raise_for_status()
#
# Traceback (most recent call last):
#   File "<python-input-0>", line 1, in <module>
#
#   File "C:\Users\Al\AppData\Local\Programs\Python\Python
# XX
# \lib\site-packages\
# requests\models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# response = requests.get('https://inventwithpython.com/page_that_does_not_exist')
#
# >>>
# response.raise_for_status()
#
# Traceback (most recent call last):
#   File "<python-input-0>", line 1, in <module>
#
#   File "C:\Users\Al\AppData\Local\Programs\Python\Python
# XX
# \lib\site-packages\
# requests\models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 404 Client Error: Not Found for url:
# https://inventwithpython.com/page_that_does_not_exist.html
# ```

# %%
# Practice rewrite for source example 13.8
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.9
#
# Checklist note: captured from section **Downloading Files from the Web with the requests Module**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# import requests
# response = requests.get('https://inventwithpython.com/page_that_does_not_exist')
# try:
#     response.raise_for_status()
# except Exception as exc:
#     print(f'There was a problem: {exc}')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# import requests
# response = requests.get('https://inventwithpython.com/page_that_does_not_exist')
# try:
#     response.raise_for_status()
# except Exception as exc:
#     print(f'There was a problem: {exc}')
# ```

# %%
# Practice rewrite for source example 13.9
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.10
#
# Checklist note: captured from section **Downloading Files from the Web with the requests Module**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `Downloading Files from the Web with the requests Module`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# There was a problem: 404 Client Error: Not Found for url:
# https://inventwithpython.com/page_that_does_not_exist.html
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# There was a problem: 404 Client Error: Not Found for url:
# https://inventwithpython.com/page_that_does_not_exist.html
# ```

# %%
# Practice rewrite for source example 13.10
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.11
#
# Checklist note: captured from section **Downloading Files from the Web with the requests Module**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import requests
#
# >>>
# response = requests.get('https://automatetheboringstuff.com/files/rj.txt')
#
# >>>
# response.raise_for_status()
#
# >>>
# with open('RomeoAndJuliet.txt', 'wb') as play_file:
#
# ...
# for chunk in response.iter_content(100000):
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import requests
#
# >>>
# response = requests.get('https://automatetheboringstuff.com/files/rj.txt')
#
# >>>
# response.raise_for_status()
#
# >>>
# with open('RomeoAndJuliet.txt', 'wb') as play_file:
#
# ...
# for chunk in response.iter_content(100000):
#
# ...
#      play_file.write(chunk)
#
# ...
# 100000
# 78978
# ```

# %%
# Practice rewrite for source example 13.11
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Accessing a Weather API

# %% [markdown]
# #### Source example 13.12
#
# Checklist note: captured from section **Accessing a Weather API**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import requests
#
# >>>
# city_name = 'San Francisco'
#
# >>>
# state_code = 'CA'
#
# >>>
# country_code = 'US'
#
# >>>
# API_key = '30ee784a80d81480dab1749d33980112'
# # ... 29 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import requests
#
# >>>
# city_name = 'San Francisco'
#
# >>>
# state_code = 'CA'
#
# >>>
# country_code = 'US'
#
# >>>
# API_key = '30ee784a80d81480dab1749d33980112'
# # Not a real API key
# >>>
# response = requests.get(f'https://api.openweathermap.org/geo/1.0/
#
#
# direct?q={city_name},{state_code},{country_code}&appid={API_key}')
#
# >>>
# response.text
# # This is a Python string.
# '[{"name":"San Francisco","local_names":{"id":"San Francisco",
#
# --snip--
#
# ,"lat":37.7790262,"lon":-122.419906,"country":"US","state":"California"}]'
# >>>
# import json
#
# >>>
# response_data = json.loads(response.text)
#
# >>>
# response_data
#   # This is a Python data structure.
# [{"name":"San Francisco","local_names":{"id":"San Francisco",
#
# --snip--
#
# ,"lat":37.7790262,"lon":-122.419906,"country":"US","state":"California"}]
# ```

# %%
# Practice rewrite for source example 13.12
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.13
#
# Checklist note: captured from section **Accessing a Weather API**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `Accessing a Weather API`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# response_data[0]['lat']
#
# 37.7790262
# >>>
# response_data[0]['lon']
#
# -122.419906
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# response_data[0]['lat']
#
# 37.7790262
# >>>
# response_data[0]['lon']
#
# -122.419906
# ```

# %%
# Practice rewrite for source example 13.13
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.14
#
# Checklist note: captured from section **Accessing a Weather API**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# lat = json.loads(response.text)[0]['lat']
#
# >>>
# lon = json.loads(response.text)[0]['lon']
#
# >>>
# response = requests.get(f'https://api.openweathermap.org/data/2.5/
#
#
# weather?lat={lat}&lon={lon}&appid={API_key}')
#
# >>>
# response_data = json.loads(response.text)
# # ... 22 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# lat = json.loads(response.text)[0]['lat']
#
# >>>
# lon = json.loads(response.text)[0]['lon']
#
# >>>
# response = requests.get(f'https://api.openweathermap.org/data/2.5/
#
#
# weather?lat={lat}&lon={lon}&appid={API_key}')
#
# >>>
# response_data = json.loads(response.text)
#
# >>>
# response_data
#
# {'coord': {'lon': -122.4199, 'lat': 37.779}, 'weather': [{'id': 803,
#
# --snip--
#
# 'timezone': -25200, 'id': 5391959, 'name': 'San Francisco', 'cod': 200}
#
# >>>
# response_data['main']['temp']
#
# 285.44
# >>>
# round(285.44 - 273.15, 1)
#   # Convert Kelvin to Celsius.
# 12.3
# >>>
# round(285.44 * (9 / 5) - 459.67, 1)
#   # Convert Kelvin to Fahrenheit.
# 54.1
# ```

# %%
# Practice rewrite for source example 13.14
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Understanding HTML

# %% [markdown]
# #### Source example 13.15
#
# Checklist note: captured from section **Understanding HTML**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `Understanding HTML`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# <b>Hello</b>, world!
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# <b>Hello</b>, world!
# ```

# %%
# Practice rewrite for source example 13.15
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.16
#
# Checklist note: captured from section **Understanding HTML**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `Understanding HTML`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# <a href="https://inventwithpython.com”>This text is a link</a>
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# <a href="https://inventwithpython.com”>This text is a link</a>
# ```

# %%
# Practice rewrite for source example 13.16
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.17
#
# Checklist note: captured from section **Understanding HTML**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `Understanding HTML`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# <div class="col-sm-10 forecast-text">Sunny, with a high near 64.
# West wind 11 to 16 mph, with gusts as high as 21 mph.</div>
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# <div class="col-sm-10 forecast-text">Sunny, with a high near 64.
# West wind 11 to 16 mph, with gusts as high as 21 mph.</div>
# ```

# %%
# Practice rewrite for source example 13.17
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Parsing HTML with Beautiful Soup

# %% [markdown]
# #### Source example 13.18
#
# Checklist note: captured from section **Parsing HTML with Beautiful Soup**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `Parsing HTML with Beautiful Soup`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# <!-- This is an HTML comment. -->
#
# <html>
# <head>
#     <title>Example Website Title</title>
#     <style>
#         .slogan {
#             color: gray;
#             font-size: 2em;
#         }
#     </style>
# </head>
# <body>
#     <h1>Example Website</h1>
# # ... 15 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# <!-- This is an HTML comment. -->
#
# <html>
# <head>
#     <title>Example Website Title</title>
#     <style>
#         .slogan {
#             color: gray;
#             font-size: 2em;
#         }
#     </style>
# </head>
# <body>
#     <h1>Example Website</h1>
#     <p>This <p> tag puts <b>content</b> into a <i>single</i> paragraph.</p>
#     <p><a href="https://inventwithpython.com”>This text is a link</a> to books by <span id=
# "author">Al Sweigart</span>.</p>
#     <p><img src="wow_such_zophie_thumb.webp" alt="Close-up of my cat Zophie." /></p>
#     <p class="slogan">Learn to program in Python!</p>
#     <form>
#         <p><label>Username: <input id="login_user" placeholder="admin" /></label></p>
#         <p><label>Password: <input id="login_pass" type="password" placeholder="swordfish" />
#
#     </form>
# </label></p>
#     <p><label>Agree to disagree: <input type="checkbox" /></label><input type="submit"
# value="Fake Button" /></p>
# </body>
# </html>
# ```

# %%
# Practice rewrite for source example 13.18
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.19
#
# Checklist note: captured from section **Parsing HTML with Beautiful Soup**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import requests, bs4
#
# >>>
# res = requests.get('https://autbor.com/example3.html')
#
# >>>
# res.raise_for_status()
#
# >>>
# example_soup = bs4.BeautifulSoup(res.text, 'html.parser')
#
# >>>
# type(example_soup)
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import requests, bs4
#
# >>>
# res = requests.get('https://autbor.com/example3.html')
#
# >>>
# res.raise_for_status()
#
# >>>
# example_soup = bs4.BeautifulSoup(res.text, 'html.parser')
#
# >>>
# type(example_soup)
#
# <class 'bs4.BeautifulSoup'>
# ```

# %%
# Practice rewrite for source example 13.19
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.20
#
# Checklist note: captured from section **Parsing HTML with Beautiful Soup**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import bs4
#
# >>>
# with open('example3.html') as example_file:
#
# ...
# example_soup = bs4.BeautifulSoup(example_file, 'html.parser')
#
# ...
# >>>
# type(example_soup)
#
# <class 'bs4.BeautifulSoup'>
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import bs4
#
# >>>
# with open('example3.html') as example_file:
#
# ...
# example_soup = bs4.BeautifulSoup(example_file, 'html.parser')
#
# ...
# >>>
# type(example_soup)
#
# <class 'bs4.BeautifulSoup'>
# ```

# %%
# Practice rewrite for source example 13.20
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.21
#
# Checklist note: captured from section **Parsing HTML with Beautiful Soup**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import bs4
#
# >>>
# example_file = open('example3.html')
#
# >>>
# example_soup = bs4.BeautifulSoup(example_file.read(), 'html.parser')
#
# >>>
# elems = example_soup.select('#author')
#
# >>>
# type(elems)
# # ... 22 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import bs4
#
# >>>
# example_file = open('example3.html')
#
# >>>
# example_soup = bs4.BeautifulSoup(example_file.read(), 'html.parser')
#
# >>>
# elems = example_soup.select('#author')
#
# >>>
# type(elems)
#  # elems is a list of Tag objects.
# <class 'bs4.element.ResultSet'>
# >>>
# len(elems)
#
# 1
# >>>
# type(elems[0])
#
# <class 'bs4.element.Tag'>
# >>>
# str(elems[0])
#   # The Tag object as a string
# '<span id="author">Al Sweigart</span>'
# >>>
# elems[0].get_text()
#   # The inner text of the element
# 'Al Sweigart'
# >>>
# elems[0].attrs
#
# {'id': 'author'}
# ```

# %%
# Practice rewrite for source example 13.21
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.22
#
# Checklist note: captured from section **Parsing HTML with Beautiful Soup**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# p_elems = example_soup.select('p')
#
# >>>
# str(p_elems[0])
#
# '<p>This <p> tag puts <b>content</b> into a <i>single</i> paragraph.</p>'
# >>>
# p_elems[0].get_text()
#
# 'This <p> tag puts content into a single paragraph.'
# >>>
# str(p_elems[1])
#
# # ... 14 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# p_elems = example_soup.select('p')
#
# >>>
# str(p_elems[0])
#
# '<p>This <p> tag puts <b>content</b> into a <i>single</i> paragraph.</p>'
# >>>
# p_elems[0].get_text()
#
# 'This <p> tag puts content into a single paragraph.'
# >>>
# str(p_elems[1])
#
# '<p> <a href="https://inventwithpython.com/”>This text is a link</a> to books by
# <span id="author">Al Sweigart</span>.</p>'
# >>>
# p_elems[1].get_text()
#
# 'This text is a link to books by Al Sweigart.'
# >>>
# str(p_elems[2])
#
# '<p><img alt="Close-up of my cat Zophie." src="wow_such_zophie_thumb.webp"/></p>'
# >>>
# p_elems[2].get_text()
#
# ''
# ```

# %%
# Practice rewrite for source example 13.22
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.23
#
# Checklist note: captured from section **Parsing HTML with Beautiful Soup**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import bs4
#
# >>>
# soup = bs4.BeautifulSoup(open('example3.html'), 'html.parser')
#
# >>>
# span_elem = soup.select('span')[0]
#
# >>>
# str(span_elem)
#
# '<span id="author">Al Sweigart</span>'
# >>>
# # ... 11 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import bs4
#
# >>>
# soup = bs4.BeautifulSoup(open('example3.html'), 'html.parser')
#
# >>>
# span_elem = soup.select('span')[0]
#
# >>>
# str(span_elem)
#
# '<span id="author">Al Sweigart</span>'
# >>>
# span_elem.get('id')
#
# 'author'
# >>>
# span_elem.get('some_nonexistent_addr') == None
#
# True
# >>>
# span_elem.attrs
#
# {'id': 'author'}
# ```

# %%
# Practice rewrite for source example 13.23
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.24
#
# Checklist note: captured from section **Parsing HTML with Beautiful Soup**.
#
# **Context**
#
# 1. This example shows how a Python script receives options and filenames from the command line.
# 2. Command line arguments make a script reusable because the behavior changes without editing the source code.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. That is important for tools you want to run from terminals, scheduled jobs, shortcuts, or other programs.
# 5. Practice with harmless inputs first, then add validation and helpful error messages.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# # searchpypi.py - Opens several search results on pypi.org
#
# import requests, sys, webbrowser, bs4
#
# print('Searching...')  # Display text while downloading the search results page.
# res = requests.get('https://pypi.org/search/?q=' + ' '.join(sys.argv[1:]))
# res.raise_for_status()
#
# # TODO: Retrieve top search result links.
#
# # TODO: Open a browser tab for each result.
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # searchpypi.py - Opens several search results on pypi.org
#
# import requests, sys, webbrowser, bs4
#
# print('Searching...')  # Display text while downloading the search results page.
# res = requests.get('https://pypi.org/search/?q=' + ' '.join(sys.argv[1:]))
# res.raise_for_status()
#
# # TODO: Retrieve top search result links.
#
# # TODO: Open a browser tab for each result.
# ```

# %%
# Practice rewrite for source example 13.24
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.25
#
# Checklist note: captured from section **Parsing HTML with Beautiful Soup**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# # searchpypi.py - Opens several search results on pypi.org
# import requests, sys, webbrowser, bs4
#
# --snip--
#
# # Retrieve top search result links.
#
# soup = bs4.BeautifulSoup(res.text, 'html.parser')
#
# # Open a browser tab for each result.
#
# link_elems = soup.select('.package-snippet')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # searchpypi.py - Opens several search results on pypi.org
# import requests, sys, webbrowser, bs4
#
# --snip--
#
# # Retrieve top search result links.
#
# soup = bs4.BeautifulSoup(res.text, 'html.parser')
#
# # Open a browser tab for each result.
#
# link_elems = soup.select('.package-snippet')
# ```

# %%
# Practice rewrite for source example 13.25
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.26
#
# Checklist note: captured from section **Parsing HTML with Beautiful Soup**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# # searchpypi.py - Opens several search results on pypi.org
# import requests, sys, webbrowser, bs4
# --
# snip
# --
# # Open a browser tab for each result.
# link_elems = soup.select('.package-snippet')
#
# num_open = min(5, len(link_elems))
#
#
# for i in range(num_open):
#
#
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # searchpypi.py - Opens several search results on pypi.org
# import requests, sys, webbrowser, bs4
# --
# snip
# --
# # Open a browser tab for each result.
# link_elems = soup.select('.package-snippet')
#
# num_open = min(5, len(link_elems))
#
#
# for i in range(num_open):
#
#
#     url_to_open = 'https://pypi.org' + link_elems[i].get('href')
#
#
#     print('Opening', url_to_open)
#
#
#     webbrowser.open(url_to_open)
# ```

# %%
# Practice rewrite for source example 13.26
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.27
#
# Checklist note: captured from section **Parsing HTML with Beautiful Soup**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# # downloadXkcdComics.py - Downloads XKCD comics
#
# import requests, os, bs4, time
#
# url = 'https://xkcd.com'  # Starting URL
# os.makedirs('xkcd', exist_ok=True)  # Store comics in ./xkcd
# num_downloads = 0
# MAX_DOWNLOADS = 10
# while not url.endswith('#') and num_downloads < MAX_DOWNLOADS:
#     # TODO: Download the page.
#
#     # TODO: Find the URL of the comic image.
#
#     # TODO: Download the image.
# # ... 6 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # downloadXkcdComics.py - Downloads XKCD comics
#
# import requests, os, bs4, time
#
# url = 'https://xkcd.com'  # Starting URL
# os.makedirs('xkcd', exist_ok=True)  # Store comics in ./xkcd
# num_downloads = 0
# MAX_DOWNLOADS = 10
# while not url.endswith('#') and num_downloads < MAX_DOWNLOADS:
#     # TODO: Download the page.
#
#     # TODO: Find the URL of the comic image.
#
#     # TODO: Download the image.
#
#     # TODO: Save the image to ./xkcd.
#
#     # TODO: Get the Prev button's url.
#
# print('Done.')
# ```

# %%
# Practice rewrite for source example 13.27
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.28
#
# Checklist note: captured from section **Parsing HTML with Beautiful Soup**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# # downloadXkcdComics.py - Downloads XKCD comics
#
# import requests, os, bs4, time
#
# url = 'https://xkcd.com'  # Starting URL
# os.makedirs('xkcd', exist_ok=True)  # Store comics in ./xkcd
# num_downloads = 0
#
# MAX_DOWNLOADS = 10
# while not url.endswith('#') and num_downloads < MAX_DOWNLOADS:
#     # Download the page.
#
#     print(f'Downloading page {url}...')
#
# # ... 22 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # downloadXkcdComics.py - Downloads XKCD comics
#
# import requests, os, bs4, time
#
# url = 'https://xkcd.com'  # Starting URL
# os.makedirs('xkcd', exist_ok=True)  # Store comics in ./xkcd
# num_downloads = 0
#
# MAX_DOWNLOADS = 10
# while not url.endswith('#') and num_downloads < MAX_DOWNLOADS:
#     # Download the page.
#
#     print(f'Downloading page {url}...')
#
#
#     res = requests.get(url)
#
#
#     res.raise_for_status()
#
#
#
#
#
# soup = bs4.BeautifulSoup(res.text, 'html.parser')
#
#
#     # TODO: Find the URL of the comic image.
#
#     # TODO: Download the image.
#
#     # TODO: Save the image to ./xkcd.
#
#     # TODO: Get the Prev button's url.
#
# print('Done.')
# ```

# %%
# Practice rewrite for source example 13.28
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.29
#
# Checklist note: captured from section **Parsing HTML with Beautiful Soup**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# # downloadXkcdComics.py - Downloads XKCD comics
#
# import requests, os, bs4, time
#
# --
# snip
# --
#
#     # Find the URL of the comic image.
#
#     comic_elem = soup.select('#comic img')
#
#
#     if comic_elem == []:
# # ... 26 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # downloadXkcdComics.py - Downloads XKCD comics
#
# import requests, os, bs4, time
#
# --
# snip
# --
#
#     # Find the URL of the comic image.
#
#     comic_elem = soup.select('#comic img')
#
#
#     if comic_elem == []:
#
#
#         print('Could not find comic image.')
#
#
#     else:
#
#
#         comic_URL = 'https:' + comic_elem[0].get('src')
#
#         # Download the image.
#
#         print(f'Downloading image {comic_URL}...')
#
#
#         res = requests.get(comic_URL)
#
#
#         res.raise_for_status()
#
#
#     # TODO: Save the image to ./xkcd.
#
#     # TODO: Get the Prev button's url.
#
# print('Done.')
# ```

# %%
# Practice rewrite for source example 13.29
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.30
#
# Checklist note: captured from section **Parsing HTML with Beautiful Soup**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# # downloadXkcdComics.py - Downloads XKCD comics
#
# import requests, os, bs4, time
#
# --
# snip
# --
#
#     # Save the image to ./xkcd.
#
#         image_file = open(os.path.join('xkcd', os.path.basename(comic_URL)), 'wb')
#
#
#             for chunk in res.iter_content(100000):
# # ... 23 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # downloadXkcdComics.py - Downloads XKCD comics
#
# import requests, os, bs4, time
#
# --
# snip
# --
#
#     # Save the image to ./xkcd.
#
#         image_file = open(os.path.join('xkcd', os.path.basename(comic_URL)), 'wb')
#
#
#             for chunk in res.iter_content(100000):
#
#
#                image_file.write(chunk)
#
#
#             image_file.close()
#
#
#     # Get the Prev button's URL.
#
#       prev_link = soup.select('a[rel="prev"]')[0]
#
#
#       url = 'https://xkcd.com' + prev_link.get('href')
#
#
#       num_downloads += 1
#
#
#       time.sleep(1)
# # Pause so we don't hammer the web server.
#
# print('Done.')
# ```

# %%
# Practice rewrite for source example 13.30
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.31
#
# Checklist note: captured from section **Parsing HTML with Beautiful Soup**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `Parsing HTML with Beautiful Soup`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# Downloading page https://xkcd.com...
# Downloading image https://imgs.xkcd.com/comics/phone_alarm.png...
# Downloading page https://xkcd.com/1358/...
# Downloading image https://imgs.xkcd.com/comics/nro.png...
# Downloading page https://xkcd.com/1357/...
# Downloading image https://imgs.xkcd.com/comics/free_speech.png...
# Downloading page https://xkcd.com/1356/...
# Downloading image https://imgs.xkcd.com/comics/orbital_mechanics.png...
# Downloading page https://xkcd.com/1355/...
# Downloading image https://imgs.xkcd.com/comics/airplane_message.png...
# Downloading page https://xkcd.com/1354/...
# Downloading image https://imgs.xkcd.com/comics/heartbleed_explanation.png...
# --
# snip
# # ... 1 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# Downloading page https://xkcd.com...
# Downloading image https://imgs.xkcd.com/comics/phone_alarm.png...
# Downloading page https://xkcd.com/1358/...
# Downloading image https://imgs.xkcd.com/comics/nro.png...
# Downloading page https://xkcd.com/1357/...
# Downloading image https://imgs.xkcd.com/comics/free_speech.png...
# Downloading page https://xkcd.com/1356/...
# Downloading image https://imgs.xkcd.com/comics/orbital_mechanics.png...
# Downloading page https://xkcd.com/1355/...
# Downloading image https://imgs.xkcd.com/comics/airplane_message.png...
# Downloading page https://xkcd.com/1354/...
# Downloading image https://imgs.xkcd.com/comics/heartbleed_explanation.png...
# --
# snip
# --
# ```

# %%
# Practice rewrite for source example 13.31
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Controlling the Browser with Selenium

# %% [markdown]
# #### Source example 13.32
#
# Checklist note: captured from section **Controlling the Browser with Selenium**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# from selenium import webdriver
#
# >>>
# browser = webdriver.Firefox()
#
# >>>
# type(browser)
#
# <class 'selenium.webdriver.firefox.webdriver.WebDriver'>
# >>>
# browser.get('https://inventwithpython.com')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# from selenium import webdriver
#
# >>>
# browser = webdriver.Firefox()
#
# >>>
# type(browser)
#
# <class 'selenium.webdriver.firefox.webdriver.WebDriver'>
# >>>
# browser.get('https://inventwithpython.com')
# ```

# %%
# Practice rewrite for source example 13.32
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.33
#
# Checklist note: captured from section **Controlling the Browser with Selenium**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# browser = webdriver.Firefox()
# browser.get('https://autbor.com/example3.html')
# elems = browser.find_elements(By.CSS_SELECTOR, 'p')
# print(elems[0].text)
# print(elems[0].get_property('innerHTML'))
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# browser = webdriver.Firefox()
# browser.get('https://autbor.com/example3.html')
# elems = browser.find_elements(By.CSS_SELECTOR, 'p')
# print(elems[0].text)
# print(elems[0].get_property('innerHTML'))
# ```

# %%
# Practice rewrite for source example 13.33
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.34
#
# Checklist note: captured from section **Controlling the Browser with Selenium**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `Controlling the Browser with Selenium`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# This <p> tag puts content into a single paragraph.
# This <p> tag puts <b>content</b> into a <i>single</i> paragraph.
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# This <p> tag puts content into a single paragraph.
# This <p> tag puts <b>content</b> into a <i>single</i> paragraph.
# ```

# %%
# Practice rewrite for source example 13.34
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.35
#
# Checklist note: captured from section **Controlling the Browser with Selenium**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# from selenium import webdriver
#
# >>>
# from selenium.webdriver.common.by import By
#
# >>>
# browser = webdriver.Firefox()
#
# >>>
# browser.get('https://autbor.com/example3.html')
#
# >>>
# link_elem = browser.find_element(By.LINK_TEXT, 'This text is a link')
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# from selenium import webdriver
#
# >>>
# from selenium.webdriver.common.by import By
#
# >>>
# browser = webdriver.Firefox()
#
# >>>
# browser.get('https://autbor.com/example3.html')
#
# >>>
# link_elem = browser.find_element(By.LINK_TEXT, 'This text is a link')
#
# >>>
# type(link_elem)
#
# <class 'selenium.webdriver.remote.webelement.WebElement'>
# >>>
# link_elem.click()
# # Follows the "This text is a link" link
# ```

# %%
# Practice rewrite for source example 13.35
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.36
#
# Checklist note: captured from section **Controlling the Browser with Selenium**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# from selenium import webdriver
#
# >>>
# from selenium.webdriver.common.by import By
#
# >>>
# browser = webdriver.Firefox()
#
# >>>
# browser.get('https://autbor.com/example3.html')
#
# >>>
# user_elem = browser.find_element(By.ID, 'login_user')
# # ... 16 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# from selenium import webdriver
#
# >>>
# from selenium.webdriver.common.by import By
#
# >>>
# browser = webdriver.Firefox()
#
# >>>
# browser.get('https://autbor.com/example3.html')
#
# >>>
# user_elem = browser.find_element(By.ID, 'login_user')
#
# >>>
# user_elem.send_keys('
# your_real_username_here
# ')
#
# >>>
# password_elem = browser.find_element(By.ID, 'login_pass')
#
# >>>
# password_elem.send_keys('
# your_real_password_here
# ')
#
# >>>
# password_elem.submit()
# ```

# %%
# Practice rewrite for source example 13.36
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.37
#
# Checklist note: captured from section **Controlling the Browser with Selenium**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `Controlling the Browser with Selenium`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# Keys.ENTER  Keys.PAGE_UP       Keys.DOWN
# Keys.RETURN  Keys.ESCAPE        Keys.LEFT
# Keys.HOME    Keys.BACK_SPACE    Keys.RIGHT
# Keys.END     Keys.DELETE        Keys.TAB
# Keys.PAGE_DOWN   Keys.UP        Keys.F1 to Keys.F12
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# Keys.ENTER  Keys.PAGE_UP       Keys.DOWN
# Keys.RETURN  Keys.ESCAPE        Keys.LEFT
# Keys.HOME    Keys.BACK_SPACE    Keys.RIGHT
# Keys.END     Keys.DELETE        Keys.TAB
# Keys.PAGE_DOWN   Keys.UP        Keys.F1 to Keys.F12
# ```

# %%
# Practice rewrite for source example 13.37
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.38
#
# Checklist note: captured from section **Controlling the Browser with Selenium**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# from selenium import webdriver
#
# >>>
# from selenium.webdriver.common.by import By
#
# >>>
# from selenium.webdriver.common.keys import Keys
#
# >>>
# browser = webdriver.Firefox()
#
# >>>
# browser.get('https://nostarch.com')
# # ... 10 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# from selenium import webdriver
#
# >>>
# from selenium.webdriver.common.by import By
#
# >>>
# from selenium.webdriver.common.keys import Keys
#
# >>>
# browser = webdriver.Firefox()
#
# >>>
# browser.get('https://nostarch.com')
#
# >>>
# html_elem = browser.find_element(By.TAG_NAME, 'html')
#
# >>>
# html_elem.send_keys(Keys.END)
#   # Scrolls to bottom
# >>>
# html_elem.send_keys(Keys.HOME)
#   # Scrolls to top
# ```

# %%
# Practice rewrite for source example 13.38
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Controlling the Browser with Playwright

# %% [markdown]
# #### Source example 13.39
#
# Checklist note: captured from section **Controlling the Browser with Playwright**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `Controlling the Browser with Playwright`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# from playwright.sync_api import sync_playwright
# with sync_playwright() as playwright:
#     browser = playwright.firefox.launch()
#     page = browser.new_page()
#
#     page.goto('https://autbor.com/example3.html')
#     print(page.title())
#     browser.close()
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# from playwright.sync_api import sync_playwright
# with sync_playwright() as playwright:
#     browser = playwright.firefox.launch()
#     page = browser.new_page()
#
#     page.goto('https://autbor.com/example3.html')
#     print(page.title())
#     browser.close()
# ```

# %%
# Practice rewrite for source example 13.39
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.40
#
# Checklist note: captured from section **Controlling the Browser with Playwright**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `Controlling the Browser with Playwright`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# from playwright.sync_api import sync_playwright
#
# >>>
# playwright = sync_playwright().start()
#
# >>>
# browser = playwright.firefox.launch(headless=False, slow_mo=50)
#
# >>>
# page = browser.new_page()
#
# >>>
# page.goto('https://autbor.com/example3.html')
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# from playwright.sync_api import sync_playwright
#
# >>>
# playwright = sync_playwright().start()
#
# >>>
# browser = playwright.firefox.launch(headless=False, slow_mo=50)
#
# >>>
# page = browser.new_page()
#
# >>>
# page.goto('https://autbor.com/example3.html')
#
# <Response url='https://autbor.com/example3.html' request=<Request
#  url='https://autbor.com/example3.html' method='GET'>>
# >>>
# browser.close()
#
# >>>
# playwright.stop()
# ```

# %%
# Practice rewrite for source example 13.40
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.41
#
# Checklist note: captured from section **Controlling the Browser with Playwright**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `Controlling the Browser with Playwright`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# from playwright.sync_api import sync_playwright
# with sync_playwright() as playwright:
#     browser = playwright.firefox.launch(headless=False, slow_mo=50)
#     page = browser.new_page()
#     page.goto('https://autbor.com/example3.html')
#     elems = page.locator('p')
#     print(elems.nth(0).inner_text())
#     print(elems.nth(0).inner_html())
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# from playwright.sync_api import sync_playwright
# with sync_playwright() as playwright:
#     browser = playwright.firefox.launch(headless=False, slow_mo=50)
#     page = browser.new_page()
#     page.goto('https://autbor.com/example3.html')
#     elems = page.locator('p')
#     print(elems.nth(0).inner_text())
#     print(elems.nth(0).inner_html())
# ```

# %%
# Practice rewrite for source example 13.41
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.42
#
# Checklist note: captured from section **Controlling the Browser with Playwright**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `Controlling the Browser with Playwright`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# This <p> tag puts content into a single paragraph.
# This <p> tag puts <b>content</b> into a <i>single</i> paragraph.
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# This <p> tag puts content into a single paragraph.
# This <p> tag puts <b>content</b> into a <i>single</i> paragraph.
# ```

# %%
# Practice rewrite for source example 13.42
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.43
#
# Checklist note: captured from section **Controlling the Browser with Playwright**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `Controlling the Browser with Playwright`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# from playwright.sync_api import sync_playwright
#
# >>>
# playwright = sync_playwright().start()
#
# >>>
# browser = playwright.firefox.launch(headless=False, slow_mo=50)
#
# >>>
# page = browser.new_page()
#
# >>>
# page.goto('https://autbor.com/example3.html')
# # ... 39 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# from playwright.sync_api import sync_playwright
#
# >>>
# playwright = sync_playwright().start()
#
# >>>
# browser = playwright.firefox.launch(headless=False, slow_mo=50)
#
# >>>
# page = browser.new_page()
#
# >>>
# page.goto('https://autbor.com/example3.html')
#
# <Response url='https://autbor.com/example3.html' request=<Request
#  url='https://autbor.com/example3.html' method='GET'>>
# >>>
# page.click('input[type=checkbox]')
#   # Checks the checkbox
# >>>
# page.click('input[type=checkbox]')
#   # Unchecks the checkbox
# >>>
# page.click('a')
#   # Clicks the link
# >>>
# page.go_back()
#
# >>>
# checkbox_elem = page.get_by_role('checkbox')
#   # Calls a Locator method
# >>>
# checkbox_elem.check()
#   # Checks the checkbox
# >>>
# checkbox_elem.uncheck()
#   # Unchecks the checkbox
# >>>
# checkbox_elem.set_checked(True)
#   # Checks the checkbox
# >>>
# checkbox_elem.set_checked(False)
#   # Unchecks the checkbox
# >>>
# page.get_by_text('is a link').click()
#   # Uses a Locator method
#
# >>>
# browser.close()
#
# >>>
# playwright.stop()
# ```

# %%
# Practice rewrite for source example 13.43
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.44
#
# Checklist note: captured from section **Controlling the Browser with Playwright**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `Controlling the Browser with Playwright`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# from playwright.sync_api import sync_playwright
#
# >>>
# playwright = sync_playwright().start()
#
# >>>
# browser = playwright.firefox.launch(headless=False, slow_mo=50)
#
# >>>
# page = browser.new_page()
#
# >>>
# page.goto('https://autbor.com/example3.html')
# # ... 21 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# from playwright.sync_api import sync_playwright
#
# >>>
# playwright = sync_playwright().start()
#
# >>>
# browser = playwright.firefox.launch(headless=False, slow_mo=50)
#
# >>>
# page = browser.new_page()
#
# >>>
# page.goto('https://autbor.com/example3.html')
#
# <Response url='https://autbor.com/example3.html' request=<Request
# url='https://autbor.com/example3.html' method='GET'>>
# >>>
# page.locator('#login_user').fill('
# your_real_username_here
# ')
#
# >>>
# page.locator('#login_pass').fill('
# your_real_password_here
# ')
#
# >>>
# page.locator('input[type=submit]').click()
#
# >>>
# browser.close()
#
# >>>
# playwright.stop()
# ```

# %%
# Practice rewrite for source example 13.44
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.45
#
# Checklist note: captured from section **Controlling the Browser with Playwright**.
#
# **Context**
#
# 1. This example belongs to the chapter on web scraping and browser automation, and shows one small building block from the section `Controlling the Browser with Playwright`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# >>>
# from playwright.sync_api import sync_playwright
#
# >>>
# playwright = sync_playwright().start()
#
# >>>
# browser = playwright.firefox.launch(headless=False, slow_mo=50)
#
# >>>
# page = browser.new_page()
#
# >>>
# page.goto('https://autbor.com/example3.html')
# # ... 14 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# from playwright.sync_api import sync_playwright
#
# >>>
# playwright = sync_playwright().start()
#
# >>>
# browser = playwright.firefox.launch(headless=False, slow_mo=50)
#
# >>>
# page = browser.new_page()
#
# >>>
# page.goto('https://autbor.com/example3.html')
#
# <Response url='https://autbor.com/example3.html' request=<Request
# url='https://autbor.com/example3.html' method='GET'>>
# >>>
# page.locator('html').press('End')
# # Scrolls to bottom
# >>>
# page.locator('html').press('Home')
# # Scrolls to top
# >>>
# browser.close()
#
# >>>
# playwright.stop()
# ```

# %%
# Practice rewrite for source example 13.45
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 13.46
#
# Checklist note: captured from section **Controlling the Browser with Playwright**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter builds on strings, regex, dictionaries, and file output: web pages become another source of text and structured data.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# URL/HTML -> fetch/open page -> parse/select elements -> extract/save data
# ```
#
# **Code Preview**
#
# ```python
# 'Backquote'    'Escape'    'ArrowDown'
# 'Minus'     'End'       'ArrowRight'
# 'Equal'     'Enter'     'ArrowUp'
# 'Backslash' 'Home'      'F1' to 'F12'
# 'Backspace' 'Insert'    'Digit0' to 'Digit9'
# 'Tab'       'PageUp'    'KeyA' to 'KeyZ'
# 'Delete'    'PageDown'
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# 'Backquote'    'Escape'    'ArrowDown'
# 'Minus'     'End'       'ArrowRight'
# 'Equal'     'Enter'     'ArrowUp'
# 'Backslash' 'Home'      'F1' to 'F12'
# 'Backspace' 'Insert'    'Digit0' to 'Digit9'
# 'Tab'       'PageUp'    'KeyA' to 'KeyZ'
# 'Delete'    'PageDown'
# ```

# %%
# Practice rewrite for source example 13.46
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Chapter 13 Practice Checkpoint

# %%
# Chapter 13 checkpoint
# Choose three source examples from this chapter.
# For each one:
# 1. Explain what input it expects.
# 2. Explain what output or side effect it creates.
# 3. Rewrite it with safe sample data.

# %% [markdown]
# ### Extra Practice for Chapter 13

# %% [markdown]
# #### Practice: parse a saved HTML snippet

# %%
from bs4 import BeautifulSoup

html = '''
<main>
  <article class="product"><h2>Keyboard</h2><span class="price">$79</span></article>
  <article class="product"><h2>Mouse</h2><span class="price">$35</span></article>
</main>
'''

soup = BeautifulSoup(html, "html.parser")
for product in soup.select(".product"):
    print(product.select_one("h2").get_text(strip=True), product.select_one(".price").get_text(strip=True))

# %% [markdown]
# ## 14 EXCEL SPREADSHEETS
#
# Source: https://automatetheboringstuff.com/3e/chapter14.html

# %% [markdown]
# ### Reading Excel Files

# %% [markdown]
# #### Source example 14.1
#
# Checklist note: captured from section **Reading Excel Files**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('example3.xlsx')
#
# >>>
# type(wb)
#
# <class 'openpyxl.workbook.workbook.Workbook'>
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('example3.xlsx')
#
# >>>
# type(wb)
#
# <class 'openpyxl.workbook.workbook.Workbook'>
# ```

# %%
# Practice rewrite for source example 14.1
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.2
#
# Checklist note: captured from section **Reading Excel Files**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('example3.xlsx')
#
# >>>
# wb.sheetnames
# # The workbook's sheets' names
# ['Sheet1', 'Sheet2', 'Sheet3']
# >>>
# sheet = wb['Sheet3']
# # Get a sheet from the workbook.
# >>>
# # ... 18 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('example3.xlsx')
#
# >>>
# wb.sheetnames
# # The workbook's sheets' names
# ['Sheet1', 'Sheet2', 'Sheet3']
# >>>
# sheet = wb['Sheet3']
# # Get a sheet from the workbook.
# >>>
# sheet
#
# <Worksheet "Sheet3">
# >>>
# type(sheet)
#
# <class 'openpyxl.worksheet.worksheet.Worksheet'>
# >>>
# sheet.title
# # Get the sheet's title as a string.
# 'Sheet3'
# >>>
# another_sheet = wb.active
# # Get the active sheet.
# >>>
# another_sheet
#
# <Worksheet "Sheet1">
# ```

# %%
# Practice rewrite for source example 14.2
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.3
#
# Checklist note: captured from section **Reading Excel Files**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('example3.xlsx')
#
# >>>
# sheet = wb['Sheet1']
# # Get a sheet from the workbook.
# >>>
# sheet['A1']
# # Get a cell from the sheet.
# <Cell 'Sheet1'.A1>
# >>>
# # ... 23 more line(s) in this source example
# ```

# %%
# Adapted from source example 14.3
# Get the row, column, and value from the cell.

# %% [markdown]
# #### Source example 14.4
#
# Checklist note: captured from section **Reading Excel Files**.
#
# **Context**
#
# 1. This example belongs to the chapter on working with Excel spreadsheets, and shows one small building block from the section `Reading Excel Files`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# sheet.cell(row=1, column=2)
#
# <Cell 'Sheet1'.B1>
# >>>
# sheet.cell(row=1, column=2).value
#
# 'Apples'
# >>>
# for i in range(1, 8, 2):
# # Go through every other row.
#
# ...     print(i, sheet.cell(row=i, column=2).value)
#
# # ... 5 more line(s) in this source example
# ```

# %%
# Adapted from source example 14.4
print(i, sheet.cell(row=i, column=2).value)

# %% [markdown]
# #### Source example 14.5
#
# Checklist note: captured from section **Reading Excel Files**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('example3.xlsx')
#
# >>>
# sheet = wb['Sheet1']
#
# >>>
# sheet.max_row
# # Get the highest row number.
# 7
# >>>
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('example3.xlsx')
#
# >>>
# sheet = wb['Sheet1']
#
# >>>
# sheet.max_row
# # Get the highest row number.
# 7
# >>>
# sheet.max_column
# # Get the highest column number.
# 3
# ```

# %%
# Practice rewrite for source example 14.5
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.6
#
# Checklist note: captured from section **Reading Excel Files**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# from openpyxl.utils import get_column_letter, column_index_from_string
#
# >>>
# get_column_letter(1)
#   # Translate column 1 to a letter.
# 'A'
# >>>
# get_column_letter(2
# )
# 'B'
# # ... 26 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import openpyxl
#
# >>>
# from openpyxl.utils import get_column_letter, column_index_from_string
#
# >>>
# get_column_letter(1)
#   # Translate column 1 to a letter.
# 'A'
# >>>
# get_column_letter(2
# )
# 'B'
# >>>
# get_column_letter(27)
#
# 'AA'
# >>>
# get_column_letter(900)
#
# 'AHP'
# >>>
# wb = openpyxl.load_workbook('example3.xlsx')
#
# >>>
# sheet = wb['Sheet1']
#
# >>>
# get_column_letter(sheet.max_column)
#
# 'C'
# >>>
# column_index_from_string('A')
#  # Get A's number.
# 1
# >>>
# column_index_from_string('AA')
#
# 27
# ```

# %%
# Practice rewrite for source example 14.6
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.7
#
# Checklist note: captured from section **Reading Excel Files**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('example3.xlsx')
#
# >>>
# sheet = wb['Sheet1']
#
# >>>
# sheet['A1':'C3']
# # Get cells A1 to C3.
# ((<Cell 'Sheet1'.A1>, <Cell 'Sheet1'.B1>, <Cell 'Sheet1'.C1>), (<Cell 'Sheet1'.A2>, <Cell
# 'Sheet1'.B2>, <Cell 'Sheet1'.C2>), (<Cell 'Sheet1'.A3>, <Cell 'Sheet1'.B3>, <Cell
# # ... 41 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('example3.xlsx')
#
# >>>
# sheet = wb['Sheet1']
#
# >>>
# sheet['A1':'C3']
# # Get cells A1 to C3.
# ((<Cell 'Sheet1'.A1>, <Cell 'Sheet1'.B1>, <Cell 'Sheet1'.C1>), (<Cell 'Sheet1'.A2>, <Cell
# 'Sheet1'.B2>, <Cell 'Sheet1'.C2>), (<Cell 'Sheet1'.A3>, <Cell 'Sheet1'.B3>, <Cell
# 'Sheet1'.C3>))
# >>>
# for row_of_cell_objects in sheet['A1':'C3']:
#
# ❶
#
#
# ...     for cell_obj in row_of_cell_objects:
#
# ❷
#
#
# ...         print(cell_obj.coordinate, cell_obj.value)
#
#
# ...     print('--- END OF ROW ---')
#
# ...
# A1 2035-04-05 13:34:02
# B1 Apples
# C1 73
#
# ---
# END OF ROW
# ---
#
# A2 2035-04-05 03:41:23
# B2 Cherries
# C2 85
#
# ---
# END OF ROW
# ---
#
# A3 2035-04-06 12:46:51
# B3 Pears
# C3 14
#
# ---
# END OF ROW
# ---
# ```

# %%
# Practice rewrite for source example 14.7
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.8
#
# Checklist note: captured from section **Reading Excel Files**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('example3.xlsx')
#
# >>>
# sheet = wb['Sheet1']
#
# >>>
# list(sheet.columns)[1]
# # Get the second column's cells.
# (<Cell 'Sheet1'.B1>, <Cell 'Sheet1'.B2>, <Cell 'Sheet1'.B3>, <Cell 'Sheet1'.B4>, <Cell
# 'Sheet1'.B5>, <Cell 'Sheet1'.B6>, <Cell 'Sheet1'.B7>)
# # ... 14 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('example3.xlsx')
#
# >>>
# sheet = wb['Sheet1']
#
# >>>
# list(sheet.columns)[1]
# # Get the second column's cells.
# (<Cell 'Sheet1'.B1>, <Cell 'Sheet1'.B2>, <Cell 'Sheet1'.B3>, <Cell 'Sheet1'.B4>, <Cell
# 'Sheet1'.B5>, <Cell 'Sheet1'.B6>, <Cell 'Sheet1'.B7>)
# >>>
# for cell_obj in list(sheet.columns)[1]:
#
# ...
# print(cell_obj.value)
#
# ...
# Apples
# Cherries
# Pears
# Oranges
# Apples
# Bananas
# Strawberries
# ```

# %%
# Practice rewrite for source example 14.8
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.9
#
# Checklist note: captured from section **Reading Excel Files**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# # readCensusExcel.py - Tabulates county population and census tracts
#
#
# ❶
#  import openpyxl, pprint
# print('Opening workbook...')
#
# ❷
#  wb = openpyxl.load_workbook('censuspopdata.xlsx')
#
# ❸
#  sheet = wb['Population by Census Tract']
# county_data = {}
#
# # ... 11 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # readCensusExcel.py - Tabulates county population and census tracts
#
#
# ❶
#  import openpyxl, pprint
# print('Opening workbook...')
#
# ❷
#  wb = openpyxl.load_workbook('censuspopdata.xlsx')
#
# ❸
#  sheet = wb['Population by Census Tract']
# county_data = {}
#
# # TODO: Fill in county_data with each county's population and tracts.
# print('Reading rows...')
#
# ❹
#  for row in range(2, sheet.max_row + 1):
#     # Each row in the spreadsheet has data for one census tract.
#     state  = sheet['B' + str(row)].value
#     county = sheet['C' + str(row)].value
#     pop    = sheet['D' + str(row)].value
#
# # TODO: Open a new text file and write the contents of county_data to it.
# ```

# %%
# Practice rewrite for source example 14.9
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.10
#
# Checklist note: captured from section **Reading Excel Files**.
#
# **Context**
#
# 1. This example belongs to the chapter on working with Excel spreadsheets, and shows one small building block from the section `Reading Excel Files`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# {'AK': {'Aleutians East': {'pop': 3141, 'tracts': 1},
#         'Aleutians West': {'pop': 5561, 'tracts': 2},
#         'Anchorage': {'pop': 291826, 'tracts': 55},
#         'Bethel': {'pop': 17013, 'tracts': 3},
#         'Bristol Bay': {'pop': 997, 'tracts': 1},
#
# --snip--
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# {'AK': {'Aleutians East': {'pop': 3141, 'tracts': 1},
#         'Aleutians West': {'pop': 5561, 'tracts': 2},
#         'Anchorage': {'pop': 291826, 'tracts': 55},
#         'Bethel': {'pop': 17013, 'tracts': 3},
#         'Bristol Bay': {'pop': 997, 'tracts': 1},
#
# --snip--
# ```

# %%
# Practice rewrite for source example 14.10
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.11
#
# Checklist note: captured from section **Reading Excel Files**.
#
# **Context**
#
# 1. This example belongs to the chapter on working with Excel spreadsheets, and shows one small building block from the section `Reading Excel Files`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# county_data['AK']['Anchorage']['pop']
#
# 291826
# >>>
# county_data['AK']['Anchorage']['tracts']
#
# 55
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# county_data['AK']['Anchorage']['pop']
#
# 291826
# >>>
# county_data['AK']['Anchorage']['tracts']
#
# 55
# ```

# %%
# Practice rewrite for source example 14.11
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.12
#
# Checklist note: captured from section **Reading Excel Files**.
#
# **Context**
#
# 1. This example belongs to the chapter on working with Excel spreadsheets, and shows one small building block from the section `Reading Excel Files`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# county_data[
# state abbrev
# ][
# county
# ]['tracts']
# county_data[
# state abbrev
# ][
# county
# ]['pop']
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# county_data[
# state abbrev
# ][
# county
# ]['tracts']
# county_data[
# state abbrev
# ][
# county
# ]['pop']
# ```

# %%
# Practice rewrite for source example 14.12
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.13
#
# Checklist note: captured from section **Reading Excel Files**.
#
# **Context**
#
# 1. This example belongs to the chapter on working with Excel spreadsheets, and shows one small building block from the section `Reading Excel Files`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# # readCensusExcel.py - Tabulates county population and census tracts
#
#
# --snip--
#
#
# for row in range(2, sheet.max_row + 1):
#     # Each row in the spreadsheet has data for one census tract.
#     state  = sheet['B' + str(row)].value
#     county = sheet['C' + str(row)].value
#     pop    = sheet['D' + str(row)].value
#
#
#     # Make sure the key for this state exists.
# # ... 33 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # readCensusExcel.py - Tabulates county population and census tracts
#
#
# --snip--
#
#
# for row in range(2, sheet.max_row + 1):
#     # Each row in the spreadsheet has data for one census tract.
#     state  = sheet['B' + str(row)].value
#     county = sheet['C' + str(row)].value
#     pop    = sheet['D' + str(row)].value
#
#
#     # Make sure the key for this state exists.
#
#
#
# ❶
#  county_data.setdefault(state, {})
#
#
#     # Make sure the key for this county in this state exists.
#
#
#
# ❷
#  county_data[state].setdefault(county, {'tracts': 0, 'pop': 0})
#
#
#
#     # Each row represents one census tract, so increment by one.
#
#
#
# ❸
#  county_data[state][county]['tracts'] += 1
#
#
#     # Increase the county pop by the pop in this census tract.
#
#
#
# ❹
#  county_data[state][county]['pop'] += int(pop)
#
#
# # TODO: Open a new text file and write the contents of county_data to it.
# ```

# %%
# Practice rewrite for source example 14.13
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.14
#
# Checklist note: captured from section **Reading Excel Files**.
#
# **Context**
#
# 1. This example belongs to the chapter on working with Excel spreadsheets, and shows one small building block from the section `Reading Excel Files`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# # readCensusExcel.py - Tabulates county population and census tracts.
#
#
# --snip--
#
#
#
# # Open a new text file and write the contents of county_data to it.
#
#
# print('Writing results...')
#
#
# result_file = open('census2010.py', 'w')
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # readCensusExcel.py - Tabulates county population and census tracts.
#
#
# --snip--
#
#
#
# # Open a new text file and write the contents of county_data to it.
#
#
# print('Writing results...')
#
#
# result_file = open('census2010.py', 'w')
#
#
# result_file.write('allData = ' + pprint.pformat(county_data))
#
#
# result_file.close()
#
#
# print('Done.')
# ```

# %%
# Practice rewrite for source example 14.14
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.15
#
# Checklist note: captured from section **Reading Excel Files**.
#
# **Context**
#
# 1. This example belongs to the chapter on working with Excel spreadsheets, and shows one small building block from the section `Reading Excel Files`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import census2010
#
# >>>
# census2010.allData['AK']['Anchorage']
#
# {'pop': 291826, 'tracts': 55}
# >>>
# anchorage_pop = census2010.allData['AK']['Anchorage']['pop']
#
# >>>
# print('The 2010 population of Anchorage was ' + str(anchorage_pop))
#
# The 2010 population of Anchorage was 291826
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import census2010
#
# >>>
# census2010.allData['AK']['Anchorage']
#
# {'pop': 291826, 'tracts': 55}
# >>>
# anchorage_pop = census2010.allData['AK']['Anchorage']['pop']
#
# >>>
# print('The 2010 population of Anchorage was ' + str(anchorage_pop))
#
# The 2010 population of Anchorage was 291826
# ```

# %%
# Practice rewrite for source example 14.15
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Writing Excel Documents

# %% [markdown]
# #### Source example 14.16
#
# Checklist note: captured from section **Writing Excel Documents**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.Workbook()
# # Create a blank workbook.
# >>>
# wb.sheetnames
# # The workbook starts with one sheet.
# ['Sheet']
# >>>
# sheet = wb.active
#
# >>>
# # ... 10 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.Workbook()
# # Create a blank workbook.
# >>>
# wb.sheetnames
# # The workbook starts with one sheet.
# ['Sheet']
# >>>
# sheet = wb.active
#
# >>>
# sheet.title
#
# 'Sheet'
# >>>
# sheet.title = 'Spam Bacon Eggs Sheet'
# # Change the title.
# >>>
# wb.sheetnames
#
# ['Spam Bacon Eggs Sheet']
# ```

# %%
# Practice rewrite for source example 14.16
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.17
#
# Checklist note: captured from section **Writing Excel Documents**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('example3.xlsx')
#
# >>>
# sheet = wb['Sheet1']
#
# >>>
# sheet.title = 'Spam Spam Spam'
#
# >>>
# wb.save('example3_copy.xlsx')
# # ... 1 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('example3.xlsx')
#
# >>>
# sheet = wb['Sheet1']
#
# >>>
# sheet.title = 'Spam Spam Spam'
#
# >>>
# wb.save('example3_copy.xlsx')
# # Save the workbook.
# ```

# %%
# Practice rewrite for source example 14.17
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.18
#
# Checklist note: captured from section **Writing Excel Documents**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.Workbook()
#
# >>>
# wb.sheetnames
#
# ['Sheet']
# >>>
# wb.create_sheet()
# # Add a new sheet.
#
# # ... 22 more line(s) in this source example
# ```

# %%
# Adapted from source example 14.18
# Create a new sheet at index 0.

# %% [markdown]
# #### Source example 14.19
#
# Checklist note: captured from section **Writing Excel Documents**.
#
# **Context**
#
# 1. This example belongs to the chapter on working with Excel spreadsheets, and shows one small building block from the section `Writing Excel Documents`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# wb.sheetnames
#
# ['First Sheet', 'Sheet', 'Middle Sheet', 'Sheet1']
# >>>
# del wb['Middle Sheet']
#
# >>>
# del wb['Sheet1']
#
# >>>
# wb.sheetnames
#
# ['First Sheet', 'Sheet']
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# wb.sheetnames
#
# ['First Sheet', 'Sheet', 'Middle Sheet', 'Sheet1']
# >>>
# del wb['Middle Sheet']
#
# >>>
# del wb['Sheet1']
#
# >>>
# wb.sheetnames
#
# ['First Sheet', 'Sheet']
# ```

# %%
# Practice rewrite for source example 14.19
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.20
#
# Checklist note: captured from section **Writing Excel Documents**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.Workbook()
#
# >>>
# sheet = wb['Sheet']
#
# >>>
# sheet['A1'] = 'Hello, world!'
# # Edit the cell's value.
# >>>
# sheet['A1'].value
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.Workbook()
#
# >>>
# sheet = wb['Sheet']
#
# >>>
# sheet['A1'] = 'Hello, world!'
# # Edit the cell's value.
# >>>
# sheet['A1'].value
#
# 'Hello, world!'
# ```

# %%
# Practice rewrite for source example 14.20
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.21
#
# Checklist note: captured from section **Writing Excel Documents**.
#
# **Context**
#
# 1. This example belongs to the chapter on working with Excel spreadsheets, and shows one small building block from the section `Writing Excel Documents`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# if produce_name == 'Celery':
#     cell_obj = 1.19
# if produce_name == 'Garlic':
#     cell_obj = 3.07
# if produce_name == 'Lemon':
#     cell_obj = 1.27
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# if produce_name == 'Celery':
#     cell_obj = 1.19
# if produce_name == 'Garlic':
#     cell_obj = 3.07
# if produce_name == 'Lemon':
#     cell_obj = 1.27
# ```

# %%
# Practice rewrite for source example 14.21
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.22
#
# Checklist note: captured from section **Writing Excel Documents**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# # updateProduce.py - Corrects costs in produce sales spreadsheet
#
# import openpyxl
#
# wb = openpyxl.load_workbook('produceSales3.xlsx')
# sheet = wb['Sheet']
#
# # The produce types and their updated prices
# PRICE_UPDATES = {'Garlic': 3.07,
#                  'Celery': 1.19,
#                  'Lemon': 1.27}
#
# # TODO: Loop through the rows and update the prices.
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # updateProduce.py - Corrects costs in produce sales spreadsheet
#
# import openpyxl
#
# wb = openpyxl.load_workbook('produceSales3.xlsx')
# sheet = wb['Sheet']
#
# # The produce types and their updated prices
# PRICE_UPDATES = {'Garlic': 3.07,
#                  'Celery': 1.19,
#                  'Lemon': 1.27}
#
# # TODO: Loop through the rows and update the prices.
# ```

# %%
# Practice rewrite for source example 14.22
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.23
#
# Checklist note: captured from section **Writing Excel Documents**.
#
# **Context**
#
# 1. This example belongs to the chapter on working with Excel spreadsheets, and shows one small building block from the section `Writing Excel Documents`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# # updateProduce.py - Corrects costs in produce sales spreadsheet
#
#
# --snip--
#
#
#
# # Loop through the rows and update the prices.
#
#
# ❶
#  for row_num in range(2, sheet.max_row + 1):
# # Skip the first row.
#
# # ... 16 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # updateProduce.py - Corrects costs in produce sales spreadsheet
#
#
# --snip--
#
#
#
# # Loop through the rows and update the prices.
#
#
# ❶
#  for row_num in range(2, sheet.max_row + 1):
# # Skip the first row.
#
#
# ❷
#  produce_name = sheet.cell(row=row_num, column=1).value
#
#
# ❸
#  if produce_name in PRICE_UPDATES:
#
#
#         sheet.cell(row=row_num, column=2).value = PRICE_UPDATES[produce_name]
#
#
#
# ❹
#
# wb.save('updatedProduceSales3.xlsx')
# ```

# %%
# Practice rewrite for source example 14.23
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Setting the Font Style of Cells

# %% [markdown]
# #### Source example 14.24
#
# Checklist note: captured from section **Setting the Font Style of Cells**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# from openpyxl.styles import Font
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# from openpyxl.styles import Font
# ```

# %%
# Practice rewrite for source example 14.24
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.25
#
# Checklist note: captured from section **Setting the Font Style of Cells**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# from openpyxl.styles import Font
#
# >>>
# wb = openpyxl.Workbook()
#
# >>>
# sheet = wb['Sheet']
#
#
# ❶
# # ... 13 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import openpyxl
#
# >>>
# from openpyxl.styles import Font
#
# >>>
# wb = openpyxl.Workbook()
#
# >>>
# sheet = wb['Sheet']
#
#
# ❶
#  >>>
# italic_24_font = Font(size=24, italic=True)
#
#
# ❷
#  >>>
# sheet['A1'].font = italic_24_font
#
# >>>
# sheet['A1'] = 'Hello, world!'
#
# >>>
# wb.save('styles3.xlsx')
# ```

# %%
# Practice rewrite for source example 14.25
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.26
#
# Checklist note: captured from section **Setting the Font Style of Cells**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# from openpyxl.styles import Font
#
# >>>
# wb = openpyxl.Workbook()
#
# >>>
# sheet = wb['Sheet']
#
# >>>
# bold_font = Font(name='Times New Roman', bold=True)
# # ... 21 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import openpyxl
#
# >>>
# from openpyxl.styles import Font
#
# >>>
# wb = openpyxl.Workbook()
#
# >>>
# sheet = wb['Sheet']
#
# >>>
# bold_font = Font(name='Times New Roman', bold=True)
#
# >>>
# sheet['A1'].font = bold_font
#
# >>>
# sheet['A1'] = 'Bold Times New Roman'
#
#
#
# >>>
# italic_font = Font(size=24, italic=True)
#
# >>>
# sheet['B3'].font = italic_font
#
# >>>
# sheet['B3'] = '24 pt Italic'
#
#
# >>>
# wb.save('styles3.xlsx')
# ```

# %%
# Practice rewrite for source example 14.26
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Formulas

# %% [markdown]
# #### Source example 14.27
#
# Checklist note: captured from section **Formulas**.
#
# **Context**
#
# 1. This example belongs to the chapter on working with Excel spreadsheets, and shows one small building block from the section `Formulas`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# sheet['B9'] = '=SUM(B1:B8)'
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# sheet['B9'] = '=SUM(B1:B8)'
# ```

# %%
# Practice rewrite for source example 14.27
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.28
#
# Checklist note: captured from section **Formulas**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.Workbook()
#
# >>>
# sheet = wb['Sheet']
#
# >>>
# sheet['A1'] = 200
#
# >>>
# sheet['A2'] = 300
# # ... 6 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.Workbook()
#
# >>>
# sheet = wb['Sheet']
#
# >>>
# sheet['A1'] = 200
#
# >>>
# sheet['A2'] = 300
#
# >>>
# sheet['A3'] = '=SUM(A1:A2)'
#  # Set the formula.
# >>>
# wb.save('writeFormula3.xlsx')
# ```

# %%
# Practice rewrite for source example 14.28
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.29
#
# Checklist note: captured from section **Formulas**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>> # Be sure to open writeFormula3.xlsx in Excel and save it first.
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('writeFormula3.xlsx')
#   # Open without data_only.
# >>>
# wb.active['A3'].value
#   # Get the formula string.
# '=SUM(A1:A2)'
# >>>
#  wb = openpyxl.load_workbook('writeFormula3.xlsx', data_only=True)
#   # Open with data_only.
# # ... 4 more line(s) in this source example
# ```

# %%
# Adapted from source example 14.29
# Be sure to open writeFormula3.xlsx in Excel and save it first.

# %% [markdown]
# ### Adjusting Rows and Columns

# %% [markdown]
# #### Source example 14.30
#
# Checklist note: captured from section **Adjusting Rows and Columns**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.Workbook()
#
# >>>
# sheet = wb['Sheet']
#
# >>>
# sheet['A1'] = 'Tall row'
#
# >>>
# sheet['B2'] = 'Wide column'
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.Workbook()
#
# >>>
# sheet = wb['Sheet']
#
# >>>
# sheet['A1'] = 'Tall row'
#
# >>>
# sheet['B2'] = 'Wide column'
#
# >>>
# sheet.row_dimensions[1].height = 70
#
# >>>
# sheet.column_dimensions['B'].width = 20
#
# >>>
# wb.save('dimensions3.xlsx')
# ```

# %%
# Practice rewrite for source example 14.30
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.31
#
# Checklist note: captured from section **Adjusting Rows and Columns**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.Workbook()
#
# >>>
# sheet = wb['Sheet']
#
# >>>
# sheet.merge_cells('A1:D3')
# # Merge all these cells.
# >>>
# sheet['A1'] = 'Twelve cells merged together.'
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.Workbook()
#
# >>>
# sheet = wb['Sheet']
#
# >>>
# sheet.merge_cells('A1:D3')
# # Merge all these cells.
# >>>
# sheet['A1'] = 'Twelve cells merged together.'
#
# >>>
# sheet.merge_cells('C5:D5')
# # Merge these two cells.
# >>>
# sheet['C5'] = 'Two merged cells.'
#
# >>>
# wb.save('merged3.xlsx')
# ```

# %%
# Practice rewrite for source example 14.31
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.32
#
# Checklist note: captured from section **Adjusting Rows and Columns**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('merged3.xlsx')
#
# >>>
# sheet = wb['Sheet']
#
# >>>
# sheet.unmerge_cells('A1:D3')
# # Split these cells up.
# >>>
# sheet.unmerge_cells('C5:D5')
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('merged3.xlsx')
#
# >>>
# sheet = wb['Sheet']
#
# >>>
# sheet.unmerge_cells('A1:D3')
# # Split these cells up.
# >>>
# sheet.unmerge_cells('C5:D5')
#
# >>>
# wb.save('unmerged3.xlsx')
# ```

# %%
# Practice rewrite for source example 14.32
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.33
#
# Checklist note: captured from section **Adjusting Rows and Columns**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('produceSales3.xlsx')
#
# >>>
# sheet = wb.active
#
# >>>
# sheet.freeze_panes = 'A2'
# # Freeze the rows above A2.
# >>>
# wb.save('freezeExample3.xlsx')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.load_workbook('produceSales3.xlsx')
#
# >>>
# sheet = wb.active
#
# >>>
# sheet.freeze_panes = 'A2'
# # Freeze the rows above A2.
# >>>
# wb.save('freezeExample3.xlsx')
# ```

# %%
# Practice rewrite for source example 14.33
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Charts

# %% [markdown]
# #### Source example 14.34
#
# Checklist note: captured from section **Charts**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.Workbook()
#
# >>>
# sheet = wb.active
#
# >>>
# for i in range(1, 11):
# # Create some data in column A.
# ...
#      sheet['A' + str(i)] = i * i
# # ... 27 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import openpyxl
#
# >>>
# wb = openpyxl.Workbook()
#
# >>>
# sheet = wb.active
#
# >>>
# for i in range(1, 11):
# # Create some data in column A.
# ...
#      sheet['A' + str(i)] = i * i
#
# ...
# >>>
# ref_obj = openpyxl.chart.Reference(sheet, 1, 1,
#
# 1, 10)
#
#
# >>>
# series_obj = openpyxl.chart.Series(ref_obj, title='First series')
#
#
# >>>
# chart_obj = openpyxl.chart.BarChart()
#
# >>>
# chart_obj.title = 'My Chart'
#
# >>>
# chart_obj.append(series_obj)
#
#
# >>>
# sheet.add_chart(chart_obj, 'C5')
#
# >>>
# wb.save('sampleChart3.xlsx')
# ```

# %%
# Practice rewrite for source example 14.34
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Practice Programs

# %% [markdown]
# #### Source example 14.35
#
# Checklist note: captured from section **Practice Programs**.
#
# **Context**
#
# 1. This example belongs to the chapter on working with Excel spreadsheets, and shows one small building block from the section `Practice Programs`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# py multiplicationTable.py 6
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# py multiplicationTable.py 6
# ```

# %%
# Practice rewrite for source example 14.35
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 14.36
#
# Checklist note: captured from section **Practice Programs**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter applies lists, dictionaries, loops, and file concepts to spreadsheets, which are one of the most common real-world data sources.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# workbook file -> sheet/rows/cells -> transform values -> save workbook
# ```
#
# **Code Preview**
#
# ```python
# python blankRowInserter.py 3 2 myProduce.xlsx
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# python blankRowInserter.py 3 2 myProduce.xlsx
# ```

# %%
# Practice rewrite for source example 14.36
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Chapter 14 Practice Checkpoint

# %%
# Chapter 14 checkpoint
# Choose three source examples from this chapter.
# For each one:
# 1. Explain what input it expects.
# 2. Explain what output or side effect it creates.
# 3. Rewrite it with safe sample data.

# %% [markdown]
# ### Extra Practice for Chapter 14

# %% [markdown]
# #### Practice: spreadsheet-like rows without needing Excel files

# %%
rows = [
    ["Name", "Hours", "Rate"],
    ["Ada", 6, 50],
    ["Grace", 8, 55],
    ["Linus", 5, 60],
]

totals = []
for name, hours, rate in rows[1:]:
    totals.append({"name": name, "pay": hours * rate})

print(totals)

# %% [markdown]
# ## 15 GOOGLE SHEETS
#
# Source: https://automatetheboringstuff.com/3e/chapter15.html

# %% [markdown]
# ### Spreadsheet Objects

# %% [markdown]
# #### Source example 15.1
#
# Checklist note: captured from section **Spreadsheet Objects**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss = ezsheets.Spreadsheet()
#
# >>>
# ss.title = 'Title of My New Spreadsheet'
#
# >>>
# ss.title
#
# 'Title of My New Spreadsheet'
# >>>
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss = ezsheets.Spreadsheet()
#
# >>>
# ss.title = 'Title of My New Spreadsheet'
#
# >>>
# ss.title
#
# 'Title of My New Spreadsheet'
# >>>
# ss.url
#
# 'https://docs.google.com/spreadsheets/d/1gxz-Qr2-RNtqi_d7wWlsDlbtPLRQigcEXvCtdVwmH40/'
# >>>
# ss.id
#
# '1gxz-Qr2-RNtqi_d7wWlsDlbtPLRQigcEXvCtdVwmH40'
# ```

# %%
# Practice rewrite for source example 15.1
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.2
#
# Checklist note: captured from section **Spreadsheet Objects**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss1 = ezsheets.Spreadsheet('https://autbor.com/examplegs')
#
# >>>
# ss2 = ezsheets.Spreadsheet('https://docs.google.com/spreadsheets/d/1TzOJxh
#
#
# NKr15tzdZxTqtQ3EmDP6em_elnbtmZIcyu8vI/')
#
# >>>
# ss3 = ezsheets.Spreadsheet('1TzOJxhNKr15tzdZxTqtQ3EmDP6em_elnbtmZIcyu8vI')
# # ... 5 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss1 = ezsheets.Spreadsheet('https://autbor.com/examplegs')
#
# >>>
# ss2 = ezsheets.Spreadsheet('https://docs.google.com/spreadsheets/d/1TzOJxh
#
#
# NKr15tzdZxTqtQ3EmDP6em_elnbtmZIcyu8vI/')
#
# >>>
# ss3 = ezsheets.Spreadsheet('1TzOJxhNKr15tzdZxTqtQ3EmDP6em_elnbtmZIcyu8vI')
#
# >>>
# ss1 == ss2 == ss3
#   # These are the same spreadsheet.
# True
# ```

# %%
# Practice rewrite for source example 15.2
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.3
#
# Checklist note: captured from section **Spreadsheet Objects**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss = ezsheets.upload('
# my_spreadsheet.xlsx
# ')
#
# >>>
# ss.title
#
# '
# my_spreadsheet
# '
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss = ezsheets.upload('
# my_spreadsheet.xlsx
# ')
#
# >>>
# ss.title
#
# '
# my_spreadsheet
# '
# ```

# %%
# Practice rewrite for source example 15.3
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.4
#
# Checklist note: captured from section **Spreadsheet Objects**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# ezsheets.listSpreadsheets()
#
# {'
# 1J-Jx6Ne2K_vqI9J2SO-TAXOFbxx_9tUjwnkPC22LjeU
# ': 'Education Data'}
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# ezsheets.listSpreadsheets()
#
# {'
# 1J-Jx6Ne2K_vqI9J2SO-TAXOFbxx_9tUjwnkPC22LjeU
# ': 'Education Data'}
# ```

# %%
# Practice rewrite for source example 15.4
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.5
#
# Checklist note: captured from section **Spreadsheet Objects**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezsheets
#
# >>>
# example_ss = ezsheets.Spreadsheet('https://autbor.com/examplegs')
#
# >>>
# ss = ezsheets.Spreadsheet()
#
# >>>
# example_ss.sheets[0].copyTo(ss)
#
# >>>
# ss.sheets[0].delete()
# # ... 5 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezsheets
#
# >>>
# example_ss = ezsheets.Spreadsheet('https://autbor.com/examplegs')
#
# >>>
# ss = ezsheets.Spreadsheet()
#
# >>>
# example_ss.sheets[0].copyTo(ss)
#
# >>>
# ss.sheets[0].delete()
#   # Delete the Sheet1 sheet.
# >>>
# ss.url
#
# 'https://docs.google.com/spreadsheets/d/15gjrbgTmUzItRt9KUcL4JajLaQU70xanstB1dXKoSlM/'
# ```

# %%
# Practice rewrite for source example 15.5
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.6
#
# Checklist note: captured from section **Spreadsheet Objects**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# ss.title
#   # The title of the spreadsheet
# 'Untitled spreadsheet'
# >>>
# ss.title = 'Sweigart Books'
#   # Change the title.
# >>>
# ss.id
#   # The unique ID (a read-only attribute)
# '15gjrbgTmUzItRt9KUcL4JajLaQU70xanstB1dXKoSlM'
# >>>
# ss.url
#   # The original URL (a read-only attribute)
# # ... 24 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# ss.title
#   # The title of the spreadsheet
# 'Untitled spreadsheet'
# >>>
# ss.title = 'Sweigart Books'
#   # Change the title.
# >>>
# ss.id
#   # The unique ID (a read-only attribute)
# '15gjrbgTmUzItRt9KUcL4JajLaQU70xanstB1dXKoSlM'
# >>>
# ss.url
#   # The original URL (a read-only attribute)
# 'https://docs.google.com/spreadsheets/d/15gjrbgTmUzItRt9KUcL4JajLaQU70xanstB1dXKoSlM/'
# >>>
# ss.sheetTitles
#   # The titles of all the Sheet objects
# ('Copy of Books',)
# >>>
# ss.sheets
#   # The Sheet objects in this Spreadsheet, in order
# (<Sheet sheetId=1464919459, title='Copy of Books', rowCount=1000, columnCount=26>,)
# >>>
# ss.sheets[0]
#   # The first Sheet object in this Spreadsheet
# <Sheet sheetId=1464919459, title='Copy of Books', rowCount=1000, columnCount=26>
# >>>
# ss['Copy of Books']
#   # Sheets can also be accessed by title.
# <Sheet sheetId=1464919459, title='Copy of Books', rowCount=1000, columnCount=26>
# >>>
# ss.Sheet('New blank sheet')
#   # Create a new sheet.
# <Sheet sheetId=1759616008, title='New blank sheet', rowCount=1000, columnCount=26>
# >>>
# ss.sheets[1].delete()
#   # Delete the second Sheet object in this Spreadsheet.
# ```

# %%
# Practice rewrite for source example 15.6
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.7
#
# Checklist note: captured from section **Spreadsheet Objects**.
#
# **Context**
#
# 1. This example belongs to the chapter on automating Google Sheets, and shows one small building block from the section `Spreadsheet Objects`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# ss.refresh()
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# ss.refresh()
# ```

# %%
# Practice rewrite for source example 15.7
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.8
#
# Checklist note: captured from section **Spreadsheet Objects**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss = ezsheets.Spreadsheet('https://autbor.com/examplegs')
#
# >>>
# ss.title
#
# 'Sweigart Books (DO NOT DELETE)'
# >>>
# ss.downloadAsExcel()
#   # Downloads the spreadsheet as an Excel file
# 'Sweigart_Books.xlsx'
# # ... 20 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss = ezsheets.Spreadsheet('https://autbor.com/examplegs')
#
# >>>
# ss.title
#
# 'Sweigart Books (DO NOT DELETE)'
# >>>
# ss.downloadAsExcel()
#   # Downloads the spreadsheet as an Excel file
# 'Sweigart_Books.xlsx'
# >>>
# ss.downloadAsODS()
#   # Downloads the spreadsheet as an OpenOffice file
# 'Sweigart_Books.ods'
# >>>
# ss.downloadAsCSV()
#   # Downloads only the first sheet as a CSV file
# 'Sweigart_Books.csv'
# >>>
# ss.downloadAsTSV()
#   # Downloads only the first sheet as a TSV file
# 'Sweigart_Books.tsv'
# >>>
# ss.downloadAsPDF()
#   # Downloads the spreadsheet as a PDF
# 'Sweigart_Books.pdf'
# >>>
# ss.downloadAsHTML()
#   # Downloads the spreadsheet as a ZIP of HTML files
# 'Sweigart_Books.zip'
# ```

# %%
# Practice rewrite for source example 15.8
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.9
#
# Checklist note: captured from section **Spreadsheet Objects**.
#
# **Context**
#
# 1. This example belongs to the chapter on automating Google Sheets, and shows one small building block from the section `Spreadsheet Objects`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# ss.downloadAsExcel('
# a_different_filename
# .xlsx
# ')
#
# '
# a_different_filename
# .xlsx'
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# ss.downloadAsExcel('
# a_different_filename
# .xlsx
# ')
#
# '
# a_different_filename
# .xlsx'
# ```

# %%
# Practice rewrite for source example 15.9
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.10
#
# Checklist note: captured from section **Spreadsheet Objects**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss = ezsheets.Spreadsheet()
#   # Create the spreadsheet.
# >>>
# ezsheets.listSpreadsheets()
#   # Confirm that we've created a spreadsheet.
# {'1aCw2NNJSZblDbhygVv77kPsL3djmgV5zJZllSOZ_mRk': 'Delete me'}
# >>>
# ss.delete()
#   # Delete the spreadsheet.
# >>>
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss = ezsheets.Spreadsheet()
#   # Create the spreadsheet.
# >>>
# ezsheets.listSpreadsheets()
#   # Confirm that we've created a spreadsheet.
# {'1aCw2NNJSZblDbhygVv77kPsL3djmgV5zJZllSOZ_mRk': 'Delete me'}
# >>>
# ss.delete()
#   # Delete the spreadsheet.
# >>>
# ezsheets.listSpreadsheets()
#   # Spreadsheets in the Trash folder are still listed.
# {'1aCw2NNJSZblDbhygVv77kPsL3djmgV5zJZllSOZ_mRk': 'Delete me'}
# ```

# %%
# Practice rewrite for source example 15.10
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.11
#
# Checklist note: captured from section **Spreadsheet Objects**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# ss.delete(permanent=True)
#
# >>>
# ezsheets.listSpreadsheets()
#
# {}
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# ss.delete(permanent=True)
#
# >>>
# ezsheets.listSpreadsheets()
#
# {}
# ```

# %%
# Practice rewrite for source example 15.11
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Sheet Objects

# %% [markdown]
# #### Source example 15.12
#
# Checklist note: captured from section **Sheet Objects**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss = ezsheets.Spreadsheet()
#   # Starts with a sheet named Sheet1
# >>>
# sheet2 = ss.Sheet('Spam')
#
# >>>
# sheet3 = ss.Sheet('Eggs')
#
# >>>
# ss.sheets
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss = ezsheets.Spreadsheet()
#   # Starts with a sheet named Sheet1
# >>>
# sheet2 = ss.Sheet('Spam')
#
# >>>
# sheet3 = ss.Sheet('Eggs')
#
# >>>
# ss.sheets
#   # The Sheet objects in this Spreadsheet, in order
# (<Sheet sheetId=0, title='Sheet1', rowCount=1000, columnCount=26>, <Sheet sheetId=284204004,
# title='Spam', rowCount=1000, columnCount=26>, <Sheet sheetId=1920032872, title='Eggs',
# rowCount=1000, columnCount=26>)
# >>>
# ss.sheets[0]
#   # Gets the first Sheet object in this Spreadsheet
# <Sheet sheetId=0, title='Sheet1', rowCount=1000, columnCount=26>
# ```

# %%
# Practice rewrite for source example 15.12
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.13
#
# Checklist note: captured from section **Sheet Objects**.
#
# **Context**
#
# 1. This example belongs to the chapter on automating Google Sheets, and shows one small building block from the section `Sheet Objects`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# ss.sheetTitles
#   # The titles of all the Sheet objects in this Spreadsheet
# ('Sheet1', 'Spam', 'Eggs')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# ss.sheetTitles
#   # The titles of all the Sheet objects in this Spreadsheet
# ('Sheet1', 'Spam', 'Eggs')
# ```

# %%
# Practice rewrite for source example 15.13
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.14
#
# Checklist note: captured from section **Sheet Objects**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss = ezsheets.Spreadsheet()
#
# >>>
# ss.title = 'My Spreadsheet'
#
#
# >>>
# sheet = ss.sheets[0]
#   # Get the first sheet in this spreadsheet.
# >>>
# # ... 37 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss = ezsheets.Spreadsheet()
#
# >>>
# ss.title = 'My Spreadsheet'
#
#
# >>>
# sheet = ss.sheets[0]
#   # Get the first sheet in this spreadsheet.
# >>>
# sheet.title
#
# 'Sheet1'
# >>>
# sheet['A1'] = 'Name'
#   # Set the value in cell A1.
# >>>
# sheet['B1'] = 'Age'
#
# >>>
# sheet['C1'] = 'Favorite Movie'
#
# >>>
# sheet['A1']
#   # Read the value in cell A1.
# 'Name'
# >>>
# sheet['A2']
#   # Empty cells return a blank string.
# ''
# >>>
# sheet[2, 1]
#   # Column 2, Row 1 is the same address as B1.
# 'Age'
# >>>
# sheet['A2'] = 'Alice'
#
# >>>
# sheet['B2'] = 30
#
# >>>
# sheet['C2'] = 'RoboCop'
#
# >>>
# sheet['B2']
#   # Note that all data is returned as strings.
# '30'
# ```

# %%
# Practice rewrite for source example 15.14
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.15
#
# Checklist note: captured from section **Sheet Objects**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ezsheets.convertAddress('A2')
#   # Converts addresses...
# (1, 2)
# >>>
# ezsheets.convertAddress(1, 2)
#   # ...and converts them back, too.
# 'A2'
# >>>
# ezsheets.getColumnLetterOf(2)
#
# # ... 13 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ezsheets.convertAddress('A2')
#   # Converts addresses...
# (1, 2)
# >>>
# ezsheets.convertAddress(1, 2)
#   # ...and converts them back, too.
# 'A2'
# >>>
# ezsheets.getColumnLetterOf(2)
#
# 'B'
# >>>
# ezsheets.getColumnNumberOf('B')
#
# 2
# >>>
# ezsheets.getColumnLetterOf(999)
#
# 'ALK'
# >>>
# ezsheets.getColumnNumberOf('ZZZ')
#
# 18278
# ```

# %%
# Practice rewrite for source example 15.15
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.16
#
# Checklist note: captured from section **Sheet Objects**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss = ezsheets.upload('produceSales3.xlsx')
#
# >>>
# sheet = ss.sheets[0]
#
# >>>
# sheet.getRow(1)
#   # The first row is row 1, not row 0.
# ['PRODUCE', 'COST PER POUND', 'POUNDS SOLD', 'TOTAL', '', '']
# >>>
# # ... 42 more line(s) in this source example
# ```

# %%
# Adapted from source example 15.16
# Make the Python list contain uppercase strings:

# %% [markdown]
# #### Source example 15.17
#
# Checklist note: captured from section **Sheet Objects**.
#
# **Context**
#
# 1. This example belongs to the chapter on automating Google Sheets, and shows one small building block from the section `Sheet Objects`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# rows = sheet.getRows()
#   # Get every row in the spreadsheet.
# >>>
# rows[0]
#   # Examine the values in the first row.
# ['PRODUCE', 'COST PER POUND', 'POUNDS SOLD', 'TOTAL', '', '']
# >>>
# rows[1]
#
# ['POTATOES', '0.86', '21.6', '18.58', '', '']
# >>>
# rows[1][0] = 'PUMPKIN'
#   # Change the produce name.
# # ... 21 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# rows = sheet.getRows()
#   # Get every row in the spreadsheet.
# >>>
# rows[0]
#   # Examine the values in the first row.
# ['PRODUCE', 'COST PER POUND', 'POUNDS SOLD', 'TOTAL', '', '']
# >>>
# rows[1]
#
# ['POTATOES', '0.86', '21.6', '18.58', '', '']
# >>>
# rows[1][0] = 'PUMPKIN'
#   # Change the produce name.
# >>>
# rows[1]
#
# ['PUMPKIN', '0.86', '21.6', '18.58', '', '']
# >>>
# rows[10]
#
# ['OKRA', '2.26', '40', '90.4', '', '']
# >>>
# rows[10][2] = '400'
#   # Change the pounds sold.
# >>>
# rows[10][3] = '904'
#   # Change the total.
# >>>
# rows[10]
#
# ['OKRA', '2.26', '400', '904', '', '']
# >>>
# sheet.updateRows(rows)
#   # Update the online spreadsheet with the changes.
# ```

# %%
# Practice rewrite for source example 15.17
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.18
#
# Checklist note: captured from section **Sheet Objects**.
#
# **Context**
#
# 1. This example belongs to the chapter on automating Google Sheets, and shows one small building block from the section `Sheet Objects`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# sheet.rowCount
#   # The number of rows in the sheet
# 23758
# >>>
# sheet.columnCount
#   # The number of columns in the sheet
# 6
# >>>
# sheet.columnCount = 4
#   # Change the number of columns to 4.
# >>>
# sheet.columnCount
#   # Now the number of columns in the sheet is 4.
# # ... 1 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# sheet.rowCount
#   # The number of rows in the sheet
# 23758
# >>>
# sheet.columnCount
#   # The number of columns in the sheet
# 6
# >>>
# sheet.columnCount = 4
#   # Change the number of columns to 4.
# >>>
# sheet.columnCount
#   # Now the number of columns in the sheet is 4.
# 4
# ```

# %%
# Practice rewrite for source example 15.18
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.19
#
# Checklist note: captured from section **Sheet Objects**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss = ezsheets.Spreadsheet()
#
# >>>
# ss.title = 'Multiple Sheets'
#
# >>>
# ss.sheetTitles
#
# ('Sheet1',)
# >>>
# # ... 19 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss = ezsheets.Spreadsheet()
#
# >>>
# ss.title = 'Multiple Sheets'
#
# >>>
# ss.sheetTitles
#
# ('Sheet1',)
# >>>
# ss.Sheet('Spam')
#   # Create a new sheet at the end of the list of sheets.
# <Sheet sheetId=2032744541, title='Spam', rowCount=1000, columnCount=26>
# >>>
# ss.Sheet('Eggs')
#   # Create another new sheet.
# <Sheet sheetId=417452987, title='Eggs', rowCount=1000, columnCount=26>
# >>>
# ss.sheetTitles
#
# ('Sheet1', 'Spam', 'Eggs')
# >>>
# ss.Sheet('Bacon', 0)
#   # Create a sheet at index 0 in the list of sheets.
# <Sheet sheetId=814694991, title='Bacon', rowCount=1000, columnCount=26>
# >>>
# ss.sheetTitles
#
# ('Bacon', 'Sheet1', 'Spam', 'Eggs')
# ```

# %%
# Practice rewrite for source example 15.19
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.20
#
# Checklist note: captured from section **Sheet Objects**.
#
# **Context**
#
# 1. This example belongs to the chapter on automating Google Sheets, and shows one small building block from the section `Sheet Objects`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# ss.sheetTitles
#
# ('Bacon', 'Sheet1', 'Spam', 'Eggs')
# >>>
# ss.sheets[0].index
#
# 0
# >>>
# ss.sheets[0].index = 2
#   # Move the sheet at index 0 to index 2.
# >>>
# ss.sheetTitles
#
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# ss.sheetTitles
#
# ('Bacon', 'Sheet1', 'Spam', 'Eggs')
# >>>
# ss.sheets[0].index
#
# 0
# >>>
# ss.sheets[0].index = 2
#   # Move the sheet at index 0 to index 2.
# >>>
# ss.sheetTitles
#
# ('Sheet1', 'Spam', 'Bacon', 'Eggs')
# >>>
# ss.sheets[2].index = 0
#   # Move the sheet at index 2 to index 0.
# >>>
# ss.sheetTitles
#
# ('Bacon', 'Sheet1', 'Spam', 'Eggs')
# ```

# %%
# Practice rewrite for source example 15.20
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.21
#
# Checklist note: captured from section **Sheet Objects**.
#
# **Context**
#
# 1. This example belongs to the chapter on automating Google Sheets, and shows one small building block from the section `Sheet Objects`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# ss.sheetTitles
#
# ('Bacon', 'Sheet1', 'Spam', 'Eggs')
# >>>
# ss.sheets[0].delete()
#   # Delete the sheet at index 0: the "Bacon" sheet.
# >>>
# ss.sheetTitles
#
# ('Sheet1', 'Spam', 'Eggs')
# >>>
# ss['Spam'].delete()
#   # Delete the "Spam" sheet.
# # ... 21 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# ss.sheetTitles
#
# ('Bacon', 'Sheet1', 'Spam', 'Eggs')
# >>>
# ss.sheets[0].delete()
#   # Delete the sheet at index 0: the "Bacon" sheet.
# >>>
# ss.sheetTitles
#
# ('Sheet1', 'Spam', 'Eggs')
# >>>
# ss['Spam'].delete()
#   # Delete the "Spam" sheet.
# >>>
# ss.sheetTitles
#
# ('Sheet1', 'Eggs')
# >>>
# sheet = ss['Eggs']
#   # Assign a variable to the "Eggs" sheet.
# >>>
# sheet.delete()
#   # Delete the "Eggs" sheet.
# >>>
# ss.sheetTitles
#
# ('Sheet1',)
# >>>
# ss.sheets[0].clear()
#   # Clear all the cells on the "Sheet1" sheet.
# >>>
# ss.sheetTitles
#   # The "Sheet1" sheet is empty but still exists.
# ('Sheet1',)
# ```

# %%
# Practice rewrite for source example 15.21
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.22
#
# Checklist note: captured from section **Sheet Objects**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss1 = ezsheets.Spreadsheet()
#
# >>>
# ss1.title = 'First Spreadsheet'
#
# >>>
# ss1.sheets[0].title = 'Spam'
#   # ss1 will have a sheet named Spam.
#
# >>>
# # ... 22 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss1 = ezsheets.Spreadsheet()
#
# >>>
# ss1.title = 'First Spreadsheet'
#
# >>>
# ss1.sheets[0].title = 'Spam'
#   # ss1 will have a sheet named Spam.
#
# >>>
# ss2 = ezsheets.Spreadsheet()
#
# >>>
# ss2.title = 'Second Spreadsheet'
#
# >>>
# ss2.sheets[0].title = 'Eggs'
#   # ss2 will have a sheet named Eggs.
# >>>
# ss1[0]
#
# <Sheet sheetId=0, title='Spam', rowCount=1000, columnCount=26>
# >>>
# ss1[0].updateRow(1, ['Some', 'data', 'in', 'the', 'first', 'row'])
#
# >>>
# ss1[0].copyTo(ss2)
#   # Copy the ss1's Sheet1 to the ss2 spreadsheet.
# >>>
# ss2.sheetTitles
#   # ss2 now contains a copy of ss1's Sheet1.
# ('Eggs', 'Copy of Spam')
# ```

# %%
# Practice rewrite for source example 15.22
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Google Forms

# %% [markdown]
# #### Source example 15.23
#
# Checklist note: captured from section **Google Forms**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# import ezsheets
# ss = ezsheets.Spreadsheet('https://autbor.com/boringcoin')
# accounts = {}  # Keys are names, and values are amounts.
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# import ezsheets
# ss = ezsheets.Spreadsheet('https://autbor.com/boringcoin')
# accounts = {}  # Keys are names, and values are amounts.
# ```

# %%
# Practice rewrite for source example 15.23
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.24
#
# Checklist note: captured from section **Google Forms**.
#
# **Context**
#
# 1. This example belongs to the chapter on automating Google Sheets, and shows one small building block from the section `Google Forms`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# # Each row is a transaction. Loop over each one:
# for row in ss.sheets[0].getRows():
#     sender, recipient, amount = row[0], row[1], int(row[2])
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # Each row is a transaction. Loop over each one:
# for row in ss.sheets[0].getRows():
#     sender, recipient, amount = row[0], row[1], int(row[2])
# ```

# %%
# Practice rewrite for source example 15.24
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.25
#
# Checklist note: captured from section **Google Forms**.
#
# **Context**
#
# 1. This example belongs to the chapter on automating Google Sheets, and shows one small building block from the section `Google Forms`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
#     if sender == 'PRE-MINE':
#         # The 'PRE-MINE' sender invents money out of thin air.
#         accounts.setdefault(recipient, 0)
#         accounts[recipient] += amount
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
#     if sender == 'PRE-MINE':
#         # The 'PRE-MINE' sender invents money out of thin air.
#         accounts.setdefault(recipient, 0)
#         accounts[recipient] += amount
# ```

# %%
# Practice rewrite for source example 15.25
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.26
#
# Checklist note: captured from section **Google Forms**.
#
# **Context**
#
# 1. This example belongs to the chapter on automating Google Sheets, and shows one small building block from the section `Google Forms`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
#     else:
#         # Move funds from the sender to the recipient.
#         accounts.setdefault(sender, 0)
#         accounts.setdefault(recipient, 0)
#         accounts[sender] -= amount
#         accounts[recipient] += amount
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
#     else:
#         # Move funds from the sender to the recipient.
#         accounts.setdefault(sender, 0)
#         accounts.setdefault(recipient, 0)
#         accounts[sender] -= amount
#         accounts[recipient] += amount
# ```

# %%
# Practice rewrite for source example 15.26
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.27
#
# Checklist note: captured from section **Google Forms**.
#
# **Context**
#
# 1. This example belongs to the chapter on automating Google Sheets, and shows one small building block from the section `Google Forms`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# print(accounts)
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# print(accounts)
# ```

# %%
# Practice rewrite for source example 15.27
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.28
#
# Checklist note: captured from section **Google Forms**.
#
# **Context**
#
# 1. This example belongs to the chapter on automating Google Sheets, and shows one small building block from the section `Google Forms`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# total = 0
# for amount in accounts.values():
#     total += amount
# print('Total Boringcoins:', total)
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# total = 0
# for amount in accounts.values():
#     total += amount
# print('Total Boringcoins:', total)
# ```

# %%
# Practice rewrite for source example 15.28
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.29
#
# Checklist note: captured from section **Google Forms**.
#
# **Context**
#
# 1. This example belongs to the chapter on automating Google Sheets, and shows one small building block from the section `Google Forms`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# {'Al Sweigart': 999058553, 'Miles Bron': 38283, 'not_a_scammer': 48441,
# 'some hacker': 44429, 'Tech Bro': 53424, 'Claire Debella': 54443,
# 'Credulous Journalist': 50408, 'Birdie Jay': 36832, 'Carol': 82867, 'Mark Z.':
#  68650, 'Bob': 37920, 'Andi Brand': 57218, 'Eve': 88296, 'Al Sweigart sock
#
# #27': 78080, 'Tax evader': 40937, 'Duke Cody': 17544, 'Lionel Toussaint':
# 54650, 'some scammer': 2694, 'Alice': 44503, 'David': 41828}
# Total Boringcoins: 1000000000
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# {'Al Sweigart': 999058553, 'Miles Bron': 38283, 'not_a_scammer': 48441,
# 'some hacker': 44429, 'Tech Bro': 53424, 'Claire Debella': 54443,
# 'Credulous Journalist': 50408, 'Birdie Jay': 36832, 'Carol': 82867, 'Mark Z.':
#  68650, 'Bob': 37920, 'Andi Brand': 57218, 'Eve': 88296, 'Al Sweigart sock
#
# #27': 78080, 'Tax evader': 40937, 'Duke Cody': 17544, 'Lionel Toussaint':
# 54650, 'some scammer': 2694, 'Alice': 44503, 'David': 41828}
# Total Boringcoins: 1000000000
# ```

# %%
# Practice rewrite for source example 15.29
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.30
#
# Checklist note: captured from section **Google Forms**.
#
# **Context**
#
# 1. This example belongs to the chapter on automating Google Sheets, and shows one small building block from the section `Google Forms`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# python addBoringcoinTransaction.py "Al Sweigart" Eve 2000
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# python addBoringcoinTransaction.py "Al Sweigart" Eve 2000
# ```

# %%
# Practice rewrite for source example 15.30
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.31
#
# Checklist note: captured from section **Google Forms**.
#
# **Context**
#
# 1. This example shows how a Python script receives options and filenames from the command line.
# 2. Command line arguments make a script reusable because the behavior changes without editing the source code.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. That is important for tools you want to run from terminals, scheduled jobs, shortcuts, or other programs.
# 5. Practice with harmless inputs first, then add validation and helpful error messages.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# import sys, ezsheets
#
# if len(sys.argv) < 4:
#     print('Usage: python addBoringcoinTransaction.py sender recipient amount')
#     sys.exit()
#
# # Get the transaction info from the command line arguments:
# sender, recipient, amount = sys.argv[1:]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# import sys, ezsheets
#
# if len(sys.argv) < 4:
#     print('Usage: python addBoringcoinTransaction.py sender recipient amount')
#     sys.exit()
#
# # Get the transaction info from the command line arguments:
# sender, recipient, amount = sys.argv[1:]
# ```

# %%
# Practice rewrite for source example 15.31
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.32
#
# Checklist note: captured from section **Google Forms**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# # Change this URL to your copy of the Google Sheet, or else you'll
# # get a "The caller does not have permission" error.
# ss = ezsheets.Spreadsheet('
# https://autbor.com/boringcoin
# ')
# sheet = ss.sheets[0]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # Change this URL to your copy of the Google Sheet, or else you'll
# # get a "The caller does not have permission" error.
# ss = ezsheets.Spreadsheet('
# https://autbor.com/boringcoin
# ')
# sheet = ss.sheets[0]
# ```

# %%
# Practice rewrite for source example 15.32
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 15.33
#
# Checklist note: captured from section **Google Forms**.
#
# **Context**
#
# 1. This example belongs to the chapter on automating Google Sheets, and shows one small building block from the section `Google Forms`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# # Add one more row to the sheet for a new transaction:
# sheet.rowCount += 1
#
# sheet[1, sheet.rowCount] = sender
# sheet[2, sheet.rowCount] = recipient
# sheet[3, sheet.rowCount] = amount
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # Add one more row to the sheet for a new transaction:
# sheet.rowCount += 1
#
# sheet[1, sheet.rowCount] = sender
# sheet[2, sheet.rowCount] = recipient
# sheet[3, sheet.rowCount] = amount
# ```

# %%
# Practice rewrite for source example 15.33
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Practice Programs

# %% [markdown]
# #### Source example 15.34
#
# Checklist note: captured from section **Practice Programs**.
#
# **Context**
#
# 1. This example introduces cloud spreadsheet automation through Google Sheets APIs or helper libraries.
# 2. The main idea is authenticated access: your script needs permission before it can read or update online sheets.
# 3. This chapter extends spreadsheet thinking to shared cloud data, adding authentication and remote updates to the same row-and-cell mindset.
# 4. This is valuable when teams already collaborate in shared sheets and you want automation without manual downloads.
# 5. Keep credentials private and test with a throwaway sheet before touching team data.
#
# **Concept Flow**
#
# ```text
# credentials -> cloud sheet -> rows/cells -> read/update -> shared result
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss = ezsheets.Spreadsheet('1jDZEdvSIh4TmZxccyy0ZXrH-ELlrwq8_YYiZrEOB4jg')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezsheets
#
# >>>
# ss = ezsheets.Spreadsheet('1jDZEdvSIh4TmZxccyy0ZXrH-ELlrwq8_YYiZrEOB4jg')
# ```

# %%
# Practice rewrite for source example 15.34
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Chapter 15 Practice Checkpoint

# %%
# Chapter 15 checkpoint
# Choose three source examples from this chapter.
# For each one:
# 1. Explain what input it expects.
# 2. Explain what output or side effect it creates.
# 3. Rewrite it with safe sample data.

# %% [markdown]
# ### Extra Practice for Chapter 15

# %% [markdown]
# #### Practice: simulate a shared sheet update

# %%
sheet_rows = [
    {"task": "backup", "status": "todo"},
    {"task": "report", "status": "done"},
]

for row in sheet_rows:
    if row["task"] == "backup":
        row["status"] = "done"

print(sheet_rows)

# %% [markdown]
# ## 16 SQLITE DATABASES
#
# Source: https://automatetheboringstuff.com/3e/chapter16.html

# %% [markdown]
# ### Creating Databases and Tables

# %% [markdown]
# #### Source example 16.1
#
# Checklist note: captured from section **Creating Databases and Tables**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('example.db', isolation_level=None)
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('example.db', isolation_level=None)
# ```

# %%
# Practice rewrite for source example 16.1
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.2
#
# Checklist note: captured from section **Creating Databases and Tables**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('example.db', isolation_level=None)
#
# >>>
# conn.execute('CREATE TABLE IF NOT EXISTS cats (name TEXT NOT NULL,
#
#
# birthdate TEXT, fur TEXT, weight_kg REAL) STRICT')
#
# <sqlite3.Cursor object at 0x00000201B2399540>
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('example.db', isolation_level=None)
#
# >>>
# conn.execute('CREATE TABLE IF NOT EXISTS cats (name TEXT NOT NULL,
#
#
# birthdate TEXT, fur TEXT, weight_kg REAL) STRICT')
#
# <sqlite3.Cursor object at 0x00000201B2399540>
# ```

# %%
# Practice rewrite for source example 16.2
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.3
#
# Checklist note: captured from section **Creating Databases and Tables**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# sqlite3.sqlite_version
#
# '3.
# xx
# .
# xx
# '
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# sqlite3.sqlite_version
#
# '3.
# xx
# .
# xx
# '
# ```

# %%
# Practice rewrite for source example 16.3
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.4
#
# Checklist note: captured from section **Creating Databases and Tables**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('example.db', isolation_level=None)
#
# >>>
# conn.execute('SELECT name FROM sqlite_schema WHERE type="table"').fetchall()
#
# [('cats',)]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('example.db', isolation_level=None)
#
# >>>
# conn.execute('SELECT name FROM sqlite_schema WHERE type="table"').fetchall()
#
# [('cats',)]
# ```

# %%
# Practice rewrite for source example 16.4
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.5
#
# Checklist note: captured from section **Creating Databases and Tables**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('example.db', isolation_level=None)
#
# >>>
# conn.execute('PRAGMA TABLE_INFO(cats)').fetchall()
#
# [(0, 'name', 'TEXT', 1, None, 0), (1, 'birthdate', 'TEXT', 0, None, 0), (2,
# 'fur', 'TEXT', 0, None, 0), (3, 'weight_kg', 'REAL', 0, None, 0)]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('example.db', isolation_level=None)
#
# >>>
# conn.execute('PRAGMA TABLE_INFO(cats)').fetchall()
#
# [(0, 'name', 'TEXT', 1, None, 0), (1, 'birthdate', 'TEXT', 0, None, 0), (2,
# 'fur', 'TEXT', 0, None, 0), (3, 'weight_kg', 'REAL', 0, None, 0)]
# ```

# %%
# Practice rewrite for source example 16.5
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### CRUD Database Operations

# %% [markdown]
# #### Source example 16.6
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('example.db', isolation_level=None)
#
# >>>
# conn.execute('CREATE TABLE IF NOT EXISTS cats (name TEXT NOT NULL, birthdate TEXT,
#
#
# fur TEXT, weight_kg REAL) STRICT')
#
# <sqlite3.Cursor object at 0x00000201B2399540>
# >>>
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('example.db', isolation_level=None)
#
# >>>
# conn.execute('CREATE TABLE IF NOT EXISTS cats (name TEXT NOT NULL, birthdate TEXT,
#
#
# fur TEXT, weight_kg REAL) STRICT')
#
# <sqlite3.Cursor object at 0x00000201B2399540>
# >>>
# conn.execute('INSERT INTO cats VALUES ("Zophie", "2021-01-24", "black", 5.6)')
#
# <sqlite3.Cursor object at 0x00000162842E78C0>
# ```

# %%
# Practice rewrite for source example 16.6
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.7
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# cat_name = 'Zophie'
#
# >>>
# cat_bday = '2021-01-24'
#
# >>>
# fur_color = 'black'
#
# >>>
# cat_weight = 5.6
#
# >>>
# conn.execute(f'INSERT INTO cats VALUES ("{cat_name}", "{cat_bday}",
# # ... 5 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# cat_name = 'Zophie'
#
# >>>
# cat_bday = '2021-01-24'
#
# >>>
# fur_color = 'black'
#
# >>>
# cat_weight = 5.6
#
# >>>
# conn.execute(f'INSERT INTO cats VALUES ("{cat_name}", "{cat_bday}",
#
#
# "{fur_color}", {cat_weight})')
#
# <sqlite3.Cursor object at 0x0000022B91BB7C40>
# ```

# %%
# Practice rewrite for source example 16.7
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.8
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('INSERT INTO cats VALUES (?, ?, ?, ?)', [cat_name, cat_bday,
#
#
# fur_color, cat_weight])
#
# <sqlite3.Cursor object at 0x0000022B91BB7C40>
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('INSERT INTO cats VALUES (?, ?, ?, ?)', [cat_name, cat_bday,
#
#
# fur_color, cat_weight])
#
# <sqlite3.Cursor object at 0x0000022B91BB7C40>
# ```

# %%
# Practice rewrite for source example 16.8
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.9
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('example.db', isolation_level=None)
#
# >>>
# conn.execute('SELECT * FROM cats').fetchall()
#
# [('Zophie', '2021-01-24', 'black', 5.6)]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('example.db', isolation_level=None)
#
# >>>
# conn.execute('SELECT * FROM cats').fetchall()
#
# [('Zophie', '2021-01-24', 'black', 5.6)]
# ```

# %%
# Practice rewrite for source example 16.9
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.10
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('SELECT rowid, name FROM cats').fetchall()
#
# [(1, 'Zophie')]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('SELECT rowid, name FROM cats').fetchall()
#
# [(1, 'Zophie')]
# ```

# %%
# Practice rewrite for source example 16.10
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.11
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# for row in conn.execute('SELECT * FROM cats'):
#
#
# ...     print('Row data:', row)
#
# ...
# print(row[0], 'is one of my favorite cats.')
# # ... 11 more line(s) in this source example
# ```

# %%
# Adapted from source example 16.11
print('Row data:', row)

# %% [markdown]
# #### Source example 16.12
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# conn.execute('SELECT * FROM cats WHERE fur = "black"').fetchall()
#
# [
# ❶
# ('Zophie', '2021-01-24', 'black', 5.6), ('Toby', '2021-05-17', 'black',
# 6.8), ('Thor', '2013-05-14', 'black', 5.2), ('Sassy', '2017-08-20', 'black',
# 7.5), ('Hope', '2016-05-22', 'black', 7.6)]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# conn.execute('SELECT * FROM cats WHERE fur = "black"').fetchall()
#
# [
# ❶
# ('Zophie', '2021-01-24', 'black', 5.6), ('Toby', '2021-05-17', 'black',
# 6.8), ('Thor', '2013-05-14', 'black', 5.2), ('Sassy', '2017-08-20', 'black',
# 7.5), ('Hope', '2016-05-22', 'black', 7.6)]
# ```

# %%
# Practice rewrite for source example 16.12
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.13
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import pprint
#
# >>>
# matching_cats = conn.execute('SELECT * FROM cats WHERE fur = "black"
#
#
# OR birthdate >= "2024-01-01"').fetchall()
#
# >>>
# pprint.pprint(matching_cats)
#
# [('Zophie', '2021-01-24', 'black', 5.6),
#  ('Toby', '2021-05-17', 'black', 6.8),
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import pprint
#
# >>>
# matching_cats = conn.execute('SELECT * FROM cats WHERE fur = "black"
#
#
# OR birthdate >= "2024-01-01"').fetchall()
#
# >>>
# pprint.pprint(matching_cats)
#
# [('Zophie', '2021-01-24', 'black', 5.6),
#  ('Toby', '2021-05-17', 'black', 6.8),
#  ('Taffy', '2024-12-09', 'white', 7.0),
#  ('Hollie', '2024-08-07', 'calico', 6.0),
#  ('Lewis', '2024-03-19', 'orange tabby', 5.1),
#  ('Thor', '2013-05-14', 'black', 5.2),
#  ('Shell', '2024-06-16', 'tortoiseshell', 6.5),
#  ('Jasmine', '2024-09-05', 'orange tabby', 6.3),
#  ('Sassy', '2017-08-20', 'black', 7.5),
#  ('Hope', '2016-05-22', 'black', 7.6)]
# ```

# %%
# Practice rewrite for source example 16.13
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.14
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('SELECT rowid, name FROM cats WHERE name LIKE "%y"').fetchall()
#
# [(5, 'Toby'), (11, 'Molly'), (12, 'Dusty'), (17, 'Mandy'), (18, 'Taffy'), (25, 'Rocky'), (27,
# 'Bobby'), (30, 'Misty'), (34, 'Mitsy'), (38, 'Colby'), (40, 'Riley'), (46, 'Ruby'), (65,
# 'Daisy'), (67, 'Crosby'), (72, 'Harry'), (77, 'Sassy'), (85, 'Lily'), (93, 'Spunky')]
# >>>
# conn.execute('SELECT rowid, name FROM cats WHERE name LIKE "Ja%"').fetchall()
#
# [(3, 'Jacob'), (49, 'Java'), (75, 'Jasmine'), (80, 'Jamison')]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('SELECT rowid, name FROM cats WHERE name LIKE "%y"').fetchall()
#
# [(5, 'Toby'), (11, 'Molly'), (12, 'Dusty'), (17, 'Mandy'), (18, 'Taffy'), (25, 'Rocky'), (27,
# 'Bobby'), (30, 'Misty'), (34, 'Mitsy'), (38, 'Colby'), (40, 'Riley'), (46, 'Ruby'), (65,
# 'Daisy'), (67, 'Crosby'), (72, 'Harry'), (77, 'Sassy'), (85, 'Lily'), (93, 'Spunky')]
# >>>
# conn.execute('SELECT rowid, name FROM cats WHERE name LIKE "Ja%"').fetchall()
#
# [(3, 'Jacob'), (49, 'Java'), (75, 'Jasmine'), (80, 'Jamison')]
# ```

# %%
# Practice rewrite for source example 16.14
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.15
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('SELECT rowid, name FROM cats WHERE name LIKE "%ob%"').fetchall()
#
# [(3, 'Jacob'), (5, 'Toby'), (27, 'Bobby')]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('SELECT rowid, name FROM cats WHERE name LIKE "%ob%"').fetchall()
#
# [(3, 'Jacob'), (5, 'Toby'), (27, 'Bobby')]
# ```

# %%
# Practice rewrite for source example 16.15
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.16
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('SELECT rowid, name FROM cats WHERE name GLOB "*m*"').fetchall()
#
# [(4, 'Gumdrop'), (9, 'Thomas'), (44, 'Sam'), (63, 'Cinnamon'), (75, 'Jasmine'),
# (79, 'Samantha'), (80, 'Jamison')]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('SELECT rowid, name FROM cats WHERE name GLOB "*m*"').fetchall()
#
# [(4, 'Gumdrop'), (9, 'Thomas'), (44, 'Sam'), (63, 'Cinnamon'), (75, 'Jasmine'),
# (79, 'Samantha'), (80, 'Jamison')]
# ```

# %%
# Practice rewrite for source example 16.16
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.17
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3, pprint
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# pprint.pprint(conn.execute('SELECT * FROM cats ORDER BY fur').fetchall())
#
# [('Iris', '2017-07-13', 'bengal', 6.8),
#  ('Ruby', '2023-12-22', 'bengal', 5.0),
#  ('Elton', '2020-05-28', 'bengal', 5.4),
#  ('Toby', '2021-05-17', 'black', 6.8),
#  ('Thor', '2013-05-14', 'black', 5.2),
# # ... 5 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3, pprint
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# pprint.pprint(conn.execute('SELECT * FROM cats ORDER BY fur').fetchall())
#
# [('Iris', '2017-07-13', 'bengal', 6.8),
#  ('Ruby', '2023-12-22', 'bengal', 5.0),
#  ('Elton', '2020-05-28', 'bengal', 5.4),
#  ('Toby', '2021-05-17', 'black', 6.8),
#  ('Thor', '2013-05-14', 'black', 5.2),
#
# --snip--
#
#  ('Celine', '2015-04-18', 'white', 7.3),
#  ('Daisy', '2019-03-19', 'white', 6.0)]
# ```

# %%
# Practice rewrite for source example 16.17
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.18
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# cur = conn.execute('SELECT * FROM cats ORDER BY fur, birthdate')
#
# >>>
# pprint.pprint(cur.fetchall())
#
# [('Iris', '2017-07-13', 'bengal', 6.8),
#  ('Elton', '2020-05-28', 'bengal', 5.4),
#  ('Ruby', '2023-12-22', 'bengal', 5.0),
#  ('Thor', '2013-05-14', 'black', 5.2),
#  ('Hope', '2016-05-22', 'black', 7.6),
#
# --snip--
#
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# cur = conn.execute('SELECT * FROM cats ORDER BY fur, birthdate')
#
# >>>
# pprint.pprint(cur.fetchall())
#
# [('Iris', '2017-07-13', 'bengal', 6.8),
#  ('Elton', '2020-05-28', 'bengal', 5.4),
#  ('Ruby', '2023-12-22', 'bengal', 5.0),
#  ('Thor', '2013-05-14', 'black', 5.2),
#  ('Hope', '2016-05-22', 'black', 7.6),
#
# --snip--
#
#  ('Ginger', '2020-09-22', 'white', 5.8),
#  ('Taffy', '2024-12-09', 'white', 7.0)]
# ```

# %%
# Practice rewrite for source example 16.18
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.19
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# cur = conn.execute('SELECT * FROM cats ORDER BY fur ASC, birthdate DESC')
#
# >>>
# pprint.pprint(cur.fetchall())
#
#
# [('Ruby', '2023-12-22', 'bengal', 5.0),
#  ('Elton', '2020-05-28', 'bengal', 5.4),
#  ('Iris', '2017-07-13', 'bengal', 6.8),
#  ('Toby', '2021-05-17', 'black', 6.8),
#  ('Sassy', '2017-08-20', 'black', 7.5),
#
# --snip--
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# cur = conn.execute('SELECT * FROM cats ORDER BY fur ASC, birthdate DESC')
#
# >>>
# pprint.pprint(cur.fetchall())
#
#
# [('Ruby', '2023-12-22', 'bengal', 5.0),
#  ('Elton', '2020-05-28', 'bengal', 5.4),
#  ('Iris', '2017-07-13', 'bengal', 6.8),
#  ('Toby', '2021-05-17', 'black', 6.8),
#  ('Sassy', '2017-08-20', 'black', 7.5),
#
# --snip--
#
#  ('Mitsy', '2015-05-29', 'white', 5.0),
#  ('Celine', '2015-04-18', 'white', 7.3)]
# ```

# %%
# Practice rewrite for source example 16.19
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.20
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# conn.execute('SELECT * FROM cats').fetchall()[:3]
#   # This is inefficient.
# [('Zophie', '2021-01-24', 'gray tabby', 5.6), ('Miguel', '2016-12-24',
# 'siamese', 6.2), ('Jacob', '2022-02-20', 'orange and white', 5.5)]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# conn.execute('SELECT * FROM cats').fetchall()[:3]
#   # This is inefficient.
# [('Zophie', '2021-01-24', 'gray tabby', 5.6), ('Miguel', '2016-12-24',
# 'siamese', 6.2), ('Jacob', '2022-02-20', 'orange and white', 5.5)]
# ```

# %%
# Practice rewrite for source example 16.20
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.21
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('SELECT * FROM cats LIMIT 3').fetchall()
#
# [('Zophie', '2021-01-24', 'gray tabby', 5.6), ('Miguel', '2016-12-24',
# 'siamese', 6.2), ('Jacob', '2022-02-20', 'orange and white', 5.5)]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('SELECT * FROM cats LIMIT 3').fetchall()
#
# [('Zophie', '2021-01-24', 'gray tabby', 5.6), ('Miguel', '2016-12-24',
# 'siamese', 6.2), ('Jacob', '2022-02-20', 'orange and white', 5.5)]
# ```

# %%
# Practice rewrite for source example 16.21
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.22
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('SELECT * FROM cats WHERE fur="orange" ORDER BY birthdate LIMIT 4').fetchall()
#
# [('Mittens', '2013-07-03', 'orange', 7.4), ('Piers', '2014-07-08', 'orange', 5.2),
# ('Misty', '2016-07-08', 'orange', 5.2), ('Blaze', '2023-01-16', 'orange', 7.4)]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('SELECT * FROM cats WHERE fur="orange" ORDER BY birthdate LIMIT 4').fetchall()
#
# [('Mittens', '2013-07-03', 'orange', 7.4), ('Piers', '2014-07-08', 'orange', 5.2),
# ('Misty', '2016-07-08', 'orange', 5.2), ('Blaze', '2023-01-16', 'orange', 7.4)]
# ```

# %%
# Practice rewrite for source example 16.22
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.23
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# conn.execute('CREATE INDEX idx_name ON cats (name)')
#
# <sqlite3.Cursor object at 0x0000013EC121A040>
# >>>
# conn.execute('CREATE INDEX idx_birthdate ON cats (birthdate)')
#
# <sqlite3.Cursor object at 0x0000013EC121A040>
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# conn.execute('CREATE INDEX idx_name ON cats (name)')
#
# <sqlite3.Cursor object at 0x0000013EC121A040>
# >>>
# conn.execute('CREATE INDEX idx_birthdate ON cats (birthdate)')
#
# <sqlite3.Cursor object at 0x0000013EC121A040>
# ```

# %%
# Practice rewrite for source example 16.23
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.24
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('SELECT name FROM sqlite_schema WHERE type = "index" AND
#
#
# tbl_name = "cats"').fetchall()
#
# [('idx_name',), ('idx_birthdate',)]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('SELECT name FROM sqlite_schema WHERE type = "index" AND
#
#
# tbl_name = "cats"').fetchall()
#
# [('idx_name',), ('idx_birthdate',)]
# ```

# %%
# Practice rewrite for source example 16.24
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.25
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('SELECT name FROM sqlite_schema WHERE type = "index" AND
#
#
# tbl_name = "cats"').fetchall()
#
# [('idx_birthdate',), ('idx_name',)]
# >>>
# conn.execute('DROP INDEX idx_name')
#
# <sqlite3.Cursor object at 0x0000013EC121A040>
# >>>
# conn.execute('SELECT name FROM sqlite_schema WHERE type = "index" AND
#
# # ... 4 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('SELECT name FROM sqlite_schema WHERE type = "index" AND
#
#
# tbl_name = "cats"').fetchall()
#
# [('idx_birthdate',), ('idx_name',)]
# >>>
# conn.execute('DROP INDEX idx_name')
#
# <sqlite3.Cursor object at 0x0000013EC121A040>
# >>>
# conn.execute('SELECT name FROM sqlite_schema WHERE type = "index" AND
#
#
# tbl_name = "cats"').fetchall()
#
# [('idx_birthdate',)]
# ```

# %%
# Practice rewrite for source example 16.25
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.26
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# conn.execute('SELECT * FROM cats WHERE rowid = 1').fetchall()
#
# [('Zophie', '2021-01-24', 'black', 5.6)]
# >>>
# conn.execute('UPDATE cats SET fur = "gray tabby" WHERE rowid = 1')
#
# <sqlite3.Cursor object at 0x0000013EC121A040>
# # ... 4 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# conn.execute('SELECT * FROM cats WHERE rowid = 1').fetchall()
#
# [('Zophie', '2021-01-24', 'black', 5.6)]
# >>>
# conn.execute('UPDATE cats SET fur = "gray tabby" WHERE rowid = 1')
#
# <sqlite3.Cursor object at 0x0000013EC121A040>
# >>>
# conn.execute('SELECT * FROM cats WHERE rowid = 1').fetchall()
#
# [('Zophie', '2021-01-24', 'gray tabby', 5.6)]
# ```

# %%
# Practice rewrite for source example 16.26
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.27
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example belongs to the chapter on storing structured data in SQLite databases, and shows one small building block from the section `CRUD Database Operations`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('UPDATE cats SET fur = "orange and white" WHERE fur = "white and orange"')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('UPDATE cats SET fur = "orange and white" WHERE fur = "white and orange"')
# ```

# %%
# Practice rewrite for source example 16.27
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.28
#
# Checklist note: captured from section **CRUD Database Operations**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# conn.execute('SELECT rowid, * FROM cats WHERE rowid = 1').fetchall()
#
# [(1, 'Zophie', '2021-01-24', 'gray tabby', 5.6)]
# >>>
# conn.execute('DELETE FROM cats WHERE rowid = 1')
#
# <sqlite3.Cursor object at 0x0000020322D183C0>
# # ... 4 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# conn.execute('SELECT rowid, * FROM cats WHERE rowid = 1').fetchall()
#
# [(1, 'Zophie', '2021-01-24', 'gray tabby', 5.6)]
# >>>
# conn.execute('DELETE FROM cats WHERE rowid = 1')
#
# <sqlite3.Cursor object at 0x0000020322D183C0>
# >>>
# conn.execute('SELECT * FROM cats WHERE rowid = 1').fetchall()
#
# []
# ```

# %%
# Practice rewrite for source example 16.28
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Rolling Back Transactions

# %% [markdown]
# #### Source example 16.29
#
# Checklist note: captured from section **Rolling Back Transactions**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# conn.execute('BEGIN')
#
# <sqlite3.Cursor object at 0x00000219C8BF7C40>
# >>>
# conn.execute('INSERT INTO cats VALUES ("Socks", "2022-04-04", "white", 4.2)')
#
# <sqlite3.Cursor object at 0x00000219C8BF7C40>
# # ... 16 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# conn.execute('BEGIN')
#
# <sqlite3.Cursor object at 0x00000219C8BF7C40>
# >>>
# conn.execute('INSERT INTO cats VALUES ("Socks", "2022-04-04", "white", 4.2)')
#
# <sqlite3.Cursor object at 0x00000219C8BF7C40>
# >>>
# conn.execute('INSERT INTO cats VALUES ("Fluffy", "2022-10-30", "gray", 4.5)')
#
# <sqlite3.Cursor object at 0x00000219C8BF7C40>
#
# >>>
# conn.rollback()
#   # This undoes the INSERT statements.
# >>>
# conn.execute('SELECT * FROM cats WHERE name = "Socks"').fetchall()
#
# []
# >>>
# conn.execute('SELECT * FROM cats WHERE name = "Fluffy"').fetchall()
#
# []
# ```

# %%
# Practice rewrite for source example 16.29
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.30
#
# Checklist note: captured from section **Rolling Back Transactions**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('BEGIN')
#
# <sqlite3.Cursor object at 0x00000219C8BF7C40>
# >>>
# conn.execute('INSERT INTO cats VALUES ("Socks", "2022-04-04", "white", 4.2)')
#
# <sqlite3.Cursor object at 0x00000219C8BF7C40>
# >>>
# conn.execute('INSERT INTO cats VALUES ("Fluffy", "2022-10-30", "gray", 4.5)')
#
# <sqlite3.Cursor object at 0x00000219C8BF7C40>
# >>>
# conn.commit()
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('BEGIN')
#
# <sqlite3.Cursor object at 0x00000219C8BF7C40>
# >>>
# conn.execute('INSERT INTO cats VALUES ("Socks", "2022-04-04", "white", 4.2)')
#
# <sqlite3.Cursor object at 0x00000219C8BF7C40>
# >>>
# conn.execute('INSERT INTO cats VALUES ("Fluffy", "2022-10-30", "gray", 4.5)')
#
# <sqlite3.Cursor object at 0x00000219C8BF7C40>
# >>>
# conn.commit()
#
# >>>
# conn.execute('SELECT * FROM cats WHERE name = "Socks"').fetchall()
#
# [('Socks', '2022-04-04', 'white', 4.2)]
# >>>
# conn.execute('SELECT * FROM cats WHERE name = "Fluffy"').fetchall()
#
# [('Fluffy', '2022-10-30', 'gray', 4.5)]
# ```

# %%
# Practice rewrite for source example 16.30
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Backing Up Databases

# %% [markdown]
# #### Source example 16.31
#
# Checklist note: captured from section **Backing Up Databases**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# backup_conn = sqlite3.connect('backup.db', isolation_level=None)
#
# >>>
# conn.backup(backup_conn)
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# backup_conn = sqlite3.connect('backup.db', isolation_level=None)
#
# >>>
# conn.backup(backup_conn)
# ```

# %%
# Practice rewrite for source example 16.31
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Altering and Dropping Tables

# %% [markdown]
# #### Source example 16.32
#
# Checklist note: captured from section **Altering and Dropping Tables**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# conn.execute('SELECT name FROM sqlite_schema WHERE type="table"').fetchall()
#
# [('cats',)]
# >>>
# conn.execute('ALTER TABLE cats RENAME TO felines')
#   # Rename the table.
# <sqlite3.Cursor object at 0x000001EDDB477C40>
# # ... 4 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# conn.execute('SELECT name FROM sqlite_schema WHERE type="table"').fetchall()
#
# [('cats',)]
# >>>
# conn.execute('ALTER TABLE cats RENAME TO felines')
#   # Rename the table.
# <sqlite3.Cursor object at 0x000001EDDB477C40>
# >>>
# conn.execute('SELECT name FROM sqlite_schema WHERE type="table"').fetchall()
#
# [('felines',)]
# ```

# %%
# Practice rewrite for source example 16.32
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.33
#
# Checklist note: captured from section **Altering and Dropping Tables**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('PRAGMA TABLE_INFO(felines)').fetchall()[2]
#   # List the third column.
# (2, 'fur', 'TEXT', 0, None, 0)
# >>>
# conn.execute('ALTER TABLE felines RENAME COLUMN fur TO description')
#
# <sqlite3.Cursor object at 0x000001EDDB477C40>
# >>>
# conn.execute('PRAGMA TABLE_INFO(felines)').fetchall()[2]
#   # List the third column.
# (2, 'description', 'TEXT', 0, None, 0)
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('PRAGMA TABLE_INFO(felines)').fetchall()[2]
#   # List the third column.
# (2, 'fur', 'TEXT', 0, None, 0)
# >>>
# conn.execute('ALTER TABLE felines RENAME COLUMN fur TO description')
#
# <sqlite3.Cursor object at 0x000001EDDB477C40>
# >>>
# conn.execute('PRAGMA TABLE_INFO(felines)').fetchall()[2]
#   # List the third column.
# (2, 'description', 'TEXT', 0, None, 0)
# ```

# %%
# Practice rewrite for source example 16.33
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.34
#
# Checklist note: captured from section **Altering and Dropping Tables**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('ALTER TABLE felines ADD COLUMN is_loved INTEGER DEFAULT 1')
#
# <sqlite3.Cursor object at 0x000001EDDB477C40>
# >>>
# import pprint
#
# >>>
# pprint.pprint(conn.execute('SELECT * FROM felines LIMIT 3').fetchall())
#
# [('Zophie', '2021-01-24', 'gray tabby', 5.6, 1),
#  ('Miguel', '2016-12-24', 'siamese', 6.2, 1),
#  ('Jacob', '2022-02-20', 'orange and white', 5.5, 1)]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('ALTER TABLE felines ADD COLUMN is_loved INTEGER DEFAULT 1')
#
# <sqlite3.Cursor object at 0x000001EDDB477C40>
# >>>
# import pprint
#
# >>>
# pprint.pprint(conn.execute('SELECT * FROM felines LIMIT 3').fetchall())
#
# [('Zophie', '2021-01-24', 'gray tabby', 5.6, 1),
#  ('Miguel', '2016-12-24', 'siamese', 6.2, 1),
#  ('Jacob', '2022-02-20', 'orange and white', 5.5, 1)]
# ```

# %%
# Practice rewrite for source example 16.34
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.35
#
# Checklist note: captured from section **Altering and Dropping Tables**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('PRAGMA TABLE_INFO(felines)').fetchall()
#   # List all columns.
# [(0, 'name', 'TEXT', 1, None, 0), (1, 'birthdate', 'TEXT', 0, None, 0), (2, 'description', 'TEXT',
# 0, None, 0), (3, 'weight_kg', 'REAL', 0, None, 0), (4, 'is_loved', 'INTEGER', 0, '1', 0)]
# >>>
# conn.execute('ALTER TABLE felines DROP COLUMN is_loved')
#   # Delete the column.
# <sqlite3.Cursor object at 0x000001EDDB477C40>
# >>>
# conn.execute('PRAGMA TABLE_INFO(felines)').fetchall()
#   # List all columns.
# [(0, 'name', 'TEXT', 1, None, 0), (1, 'birthdate', 'TEXT', 0, None, 0), (2, 'description', 'TEXT',
# 0, None, 0), (3, 'weight_kg', 'REAL', 0, None, 0)]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('PRAGMA TABLE_INFO(felines)').fetchall()
#   # List all columns.
# [(0, 'name', 'TEXT', 1, None, 0), (1, 'birthdate', 'TEXT', 0, None, 0), (2, 'description', 'TEXT',
# 0, None, 0), (3, 'weight_kg', 'REAL', 0, None, 0), (4, 'is_loved', 'INTEGER', 0, '1', 0)]
# >>>
# conn.execute('ALTER TABLE felines DROP COLUMN is_loved')
#   # Delete the column.
# <sqlite3.Cursor object at 0x000001EDDB477C40>
# >>>
# conn.execute('PRAGMA TABLE_INFO(felines)').fetchall()
#   # List all columns.
# [(0, 'name', 'TEXT', 1, None, 0), (1, 'birthdate', 'TEXT', 0, None, 0), (2, 'description', 'TEXT',
# 0, None, 0), (3, 'weight_kg', 'REAL', 0, None, 0)]
# ```

# %%
# Practice rewrite for source example 16.35
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.36
#
# Checklist note: captured from section **Altering and Dropping Tables**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('SELECT name FROM sqlite_schema WHERE type="table"').fetchall()
#
# [('felines',)]
# >>>
# conn.execute('DROP TABLE felines')
#   # Delete the entire table.
# <sqlite3.Cursor object at 0x000001EDDB477C40>
# >>>
# conn.execute('SELECT name FROM sqlite_schema WHERE type="table"').fetchall()
#
# []
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('SELECT name FROM sqlite_schema WHERE type="table"').fetchall()
#
# [('felines',)]
# >>>
# conn.execute('DROP TABLE felines')
#   # Delete the entire table.
# <sqlite3.Cursor object at 0x000001EDDB477C40>
# >>>
# conn.execute('SELECT name FROM sqlite_schema WHERE type="table"').fetchall()
#
# []
# ```

# %%
# Practice rewrite for source example 16.36
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Joining Multiple Tables with Foreign Keys

# %% [markdown]
# #### Source example 16.37
#
# Checklist note: captured from section **Joining Multiple Tables with Foreign Keys**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# conn.execute('PRAGMA foreign_keys = ON')
#
# <sqlite3.Cursor object at 0x000001E730AD03C0>
# >>>
# conn.execute('CREATE TABLE IF NOT EXISTS vaccinations (vaccine TEXT,
#
#
# # ... 6 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# conn.execute('PRAGMA foreign_keys = ON')
#
# <sqlite3.Cursor object at 0x000001E730AD03C0>
# >>>
# conn.execute('CREATE TABLE IF NOT EXISTS vaccinations (vaccine TEXT,
#
#
# date_administered TEXT, administered_by TEXT, cat_id INTEGER,
#
#
# FOREIGN KEY(cat_id) REFERENCES cats(rowid)) STRICT')
#
# <sqlite3.Cursor object at 0x000001CA42767D40>
# ```

# %%
# Practice rewrite for source example 16.37
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.38
#
# Checklist note: captured from section **Joining Multiple Tables with Foreign Keys**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('INSERT INTO vaccinations VALUES ("rabies", "2023-06-06", "Dr. Echo", 1)')
#
# <sqlite3.Cursor object at 0x000001CA42767D40>
# >>>
# conn.execute('INSERT INTO vaccinations VALUES ("FeLV", "2023-06-06", "Dr. Echo", 1)')
#
# <sqlite3.Cursor object at 0x000001CA42767D40>
# >>>
# conn.execute('SELECT * FROM vaccinations').fetchall()
#
# [('rabies', '2023-06-06', 'Dr. Echo', 1), ('FeLV', '2023-06-06', 'Dr. Echo', 1)]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('INSERT INTO vaccinations VALUES ("rabies", "2023-06-06", "Dr. Echo", 1)')
#
# <sqlite3.Cursor object at 0x000001CA42767D40>
# >>>
# conn.execute('INSERT INTO vaccinations VALUES ("FeLV", "2023-06-06", "Dr. Echo", 1)')
#
# <sqlite3.Cursor object at 0x000001CA42767D40>
# >>>
# conn.execute('SELECT * FROM vaccinations').fetchall()
#
# [('rabies', '2023-06-06', 'Dr. Echo', 1), ('FeLV', '2023-06-06', 'Dr. Echo', 1)]
# ```

# %%
# Practice rewrite for source example 16.38
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.39
#
# Checklist note: captured from section **Joining Multiple Tables with Foreign Keys**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('SELECT rowid, * FROM cats WHERE name = "Mango"').fetchall()
#
# [(23, 'Mango', '2017-02-12', 'tuxedo', 6.8)]
# >>>
# conn.execute('INSERT INTO vaccinations VALUES ("rabies", "2023-07-11", "Dr. Echo", 23)')
#
# <sqlite3.Cursor object at 0x000001CA42767D40>
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('SELECT rowid, * FROM cats WHERE name = "Mango"').fetchall()
#
# [(23, 'Mango', '2017-02-12', 'tuxedo', 6.8)]
# >>>
# conn.execute('INSERT INTO vaccinations VALUES ("rabies", "2023-07-11", "Dr. Echo", 23)')
#
# <sqlite3.Cursor object at 0x000001CA42767D40>
# ```

# %%
# Practice rewrite for source example 16.39
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.40
#
# Checklist note: captured from section **Joining Multiple Tables with Foreign Keys**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('SELECT * FROM cats INNER JOIN vaccinations ON cats.rowid =
#
#
# vaccinations.cat_id').fetchall()
#
# [('Zophie', '2021-01-24', 'gray tabby', 5.6, 'rabies', '2023-06-06', 'Dr. Echo', 1),
#  ('Zophie', '2021-01-24', 'gray tabby', 5.6, 'FeLV', '2023-06-06', 'Dr. Echo', 1),
#  ('Mango', '2017-02-12', 'tuxedo', 6.8, 'rabies', '2023-07-11', 'Dr. Echo', 23)]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('SELECT * FROM cats INNER JOIN vaccinations ON cats.rowid =
#
#
# vaccinations.cat_id').fetchall()
#
# [('Zophie', '2021-01-24', 'gray tabby', 5.6, 'rabies', '2023-06-06', 'Dr. Echo', 1),
#  ('Zophie', '2021-01-24', 'gray tabby', 5.6, 'FeLV', '2023-06-06', 'Dr. Echo', 1),
#  ('Mango', '2017-02-12', 'tuxedo', 6.8, 'rabies', '2023-07-11', 'Dr. Echo', 23)]
# ```

# %%
# Practice rewrite for source example 16.40
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.41
#
# Checklist note: captured from section **Joining Multiple Tables with Foreign Keys**.
#
# **Context**
#
# 1. This example belongs to the chapter on storing structured data in SQLite databases, and shows one small building block from the section `Joining Multiple Tables with Foreign Keys`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# conn.execute('PRAGMA foreign_keys = ON')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# conn.execute('PRAGMA foreign_keys = ON')
# ```

# %%
# Practice rewrite for source example 16.41
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### In-Memory Databases and Backups

# %% [markdown]
# #### Source example 16.42
#
# Checklist note: captured from section **In-Memory Databases and Backups**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# memory_db_conn = sqlite3.connect(':memory:',
#
#
# isolation_level=None)
#   # Create an in-memory database.
# >>>
# memory_db_conn.execute('CREATE TABLE test (name TEXT, number REAL)')
#
# <sqlite3.Cursor object at 0x000001E730AD0340>
# >>>
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# memory_db_conn = sqlite3.connect(':memory:',
#
#
# isolation_level=None)
#   # Create an in-memory database.
# >>>
# memory_db_conn.execute('CREATE TABLE test (name TEXT, number REAL)')
#
# <sqlite3.Cursor object at 0x000001E730AD0340>
# >>>
# memory_db_conn.execute('INSERT INTO test VALUES ("foo", 3.14)')
#
# <sqlite3.Cursor object at 0x000001D9B0A07EC0>
# >>>
# file_db_conn = sqlite3.connect('test.db', isolation_level=None)
#
# >>>
# memory_db_conn.backup(file_db_conn)
#   # Save the database to test.db.
# ```

# %%
# Practice rewrite for source example 16.42
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.43
#
# Checklist note: captured from section **In-Memory Databases and Backups**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# file_db_conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# memory_db_conn = sqlite3.connect(':memory:', isolation_level=None)
#
# >>>
# file_db_conn.backup(memory_db_conn)
#
# >>>
# memory_db_conn.execute('SELECT * FROM cats LIMIT 3').fetchall()
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# file_db_conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# memory_db_conn = sqlite3.connect(':memory:', isolation_level=None)
#
# >>>
# file_db_conn.backup(memory_db_conn)
#
# >>>
# memory_db_conn.execute('SELECT * FROM cats LIMIT 3').fetchall()
#
# [('Zophie', '2021-01-24', 'gray tabby', 5.6), ('Miguel', '2016-12-24',
# 'siamese', 6.2), ('Jacob', '2022-02-20', 'orange and white', 5.5)]
# ```

# %%
# Practice rewrite for source example 16.43
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Copying Databases

# %% [markdown]
# #### Source example 16.44
#
# Checklist note: captured from section **Copying Databases**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# with open('sweigartcats-queries.txt', 'w', encoding='utf-8') as fileObj:
#
# ...
# for line in conn.iterdump():
#
# ...
# fileObj.write(line + '\n')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import sqlite3
#
# >>>
# conn = sqlite3.connect('sweigartcats.db', isolation_level=None)
#
# >>>
# with open('sweigartcats-queries.txt', 'w', encoding='utf-8') as fileObj:
#
# ...
# for line in conn.iterdump():
#
# ...
# fileObj.write(line + '\n')
# ```

# %%
# Practice rewrite for source example 16.44
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.45
#
# Checklist note: captured from section **Copying Databases**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# BEGIN TRANSACTION;
# CREATE TABLE "cats" (name TEXT NOT NULL, birthdate TEXT, fur TEXT, weight_kg REAL) STRICT;
# INSERT INTO "cats" VALUES('Zophie','2021-01-24','gray tabby',5.6);
# INSERT INTO "cats" VALUES('Miguel','2016-12-24','siamese',6.2);
# INSERT INTO "cats" VALUES('Jacob','2022-02-20','orange and white',5.5);
#
# --snip--
#
# INSERT INTO "cats" VALUES('Spunky','2015-09-04','gray',5.9);
# INSERT INTO "cats" VALUES('Shadow','2021-01-18','calico',6.0);
# COMMIT;
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# BEGIN TRANSACTION;
# CREATE TABLE "cats" (name TEXT NOT NULL, birthdate TEXT, fur TEXT, weight_kg REAL) STRICT;
# INSERT INTO "cats" VALUES('Zophie','2021-01-24','gray tabby',5.6);
# INSERT INTO "cats" VALUES('Miguel','2016-12-24','siamese',6.2);
# INSERT INTO "cats" VALUES('Jacob','2022-02-20','orange and white',5.5);
#
# --snip--
#
# INSERT INTO "cats" VALUES('Spunky','2015-09-04','gray',5.9);
# INSERT INTO "cats" VALUES('Shadow','2021-01-18','calico',6.0);
# COMMIT;
# ```

# %%
# Practice rewrite for source example 16.45
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### SQLite Apps

# %% [markdown]
# #### Source example 16.46
#
# Checklist note: captured from section **SQLite Apps**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# C:\Users\Al>
# sqlite3 example.db
#
# SQLite version 3.
# xx.xx
#
# Enter ".help" for usage hints.
# sqlite>
# CREATE TABLE IF NOT EXISTS cats (name TEXT NOT NULL,
#
#
# birthdate TEXT, fur TEXT, weight_kg REAL) STRICT;
#
# sqlite>
# # ... 6 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# C:\Users\Al>
# sqlite3 example.db
#
# SQLite version 3.
# xx.xx
#
# Enter ".help" for usage hints.
# sqlite>
# CREATE TABLE IF NOT EXISTS cats (name TEXT NOT NULL,
#
#
# birthdate TEXT, fur TEXT, weight_kg REAL) STRICT;
#
# sqlite>
# INSERT INTO cats VALUES ('Zophie', '2021-01-24', 'gray tabby', 4.7);
#
# sqlite>
# SELECT * from cats;
#
# Zophie|2021-01-24|gray tabby|4.7
# ```

# %%
# Practice rewrite for source example 16.46
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.47
#
# Checklist note: captured from section **SQLite Apps**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# sqlite>
# .tables
#
# cats
# sqlite>
# .headers on
#
# sqlite>
# SELECT * from cats;
#
# name|birthdate|fur|weight_kg
# Zophie|2021-01-24|gray tabby|4.7
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# sqlite>
# .tables
#
# cats
# sqlite>
# .headers on
#
# sqlite>
# SELECT * from cats;
#
# name|birthdate|fur|weight_kg
# Zophie|2021-01-24|gray tabby|4.7
# ```

# %%
# Practice rewrite for source example 16.47
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Practice Programs

# %% [markdown]
# #### Source example 16.48
#
# Checklist note: captured from section **Practice Programs**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# CREATE TABLE IF NOT EXISTS meals (name TEXT) STRICT
# CREATE TABLE IF NOT EXISTS ingredients (name TEXT,
# meal_id INTEGER, FOREIGN KEY(meal_id) REFERENCES meals
# (rowid)) STRICT
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# CREATE TABLE IF NOT EXISTS meals (name TEXT) STRICT
# CREATE TABLE IF NOT EXISTS ingredients (name TEXT,
# meal_id INTEGER, FOREIGN KEY(meal_id) REFERENCES meals
# (rowid)) STRICT
# ```

# %%
# Practice rewrite for source example 16.48
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 16.49
#
# Checklist note: captured from section **Practice Programs**.
#
# **Context**
#
# 1. This example belongs to the chapter on storing structured data in SQLite databases, and shows one small building block from the section `Practice Programs`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter upgrades dictionaries and files into databases, giving you a reliable way to store, query, and update structured records.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# records -> table schema -> insert/query/update -> report/export
# ```
#
# **Code Preview**
#
# ```python
# >
# onigiri:rice,nori,salt,sesame seeds
#
# Meal added: onigiri
# >
# chicken and rice:chicken,rice,cream of chicken soup
#
# Meal added: chicken and rice
# >
# onigiri
#
# Ingredients of onigiri:
#   rice
#   nori
# # ... 15 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >
# onigiri:rice,nori,salt,sesame seeds
#
# Meal added: onigiri
# >
# chicken and rice:chicken,rice,cream of chicken soup
#
# Meal added: chicken and rice
# >
# onigiri
#
# Ingredients of onigiri:
#   rice
#   nori
#   salt
#   sesame seeds
# >
# chicken
#
# Meals that use chicken:
#   chicken and rice
# >
# rice
#
# Meals that use rice:
#   onigiri
# chicken and rice
# >
# quit
# ```

# %%
# Practice rewrite for source example 16.49
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Chapter 16 Practice Checkpoint

# %%
# Chapter 16 checkpoint
# Choose three source examples from this chapter.
# For each one:
# 1. Explain what input it expects.
# 2. Explain what output or side effect it creates.
# 3. Rewrite it with safe sample data.

# %% [markdown]
# ### Extra Practice for Chapter 16

# %% [markdown]
# #### Practice: tiny SQLite project

# %%
import sqlite3

connection = sqlite3.connect(":memory:")
cursor = connection.cursor()
cursor.execute("CREATE TABLE tasks (name TEXT, done INTEGER)")
cursor.executemany("INSERT INTO tasks VALUES (?, ?)", [("backup", 0), ("report", 1), ("email", 0)])

cursor.execute("SELECT name FROM tasks WHERE done = ?", (0,))
print(cursor.fetchall())
connection.close()

# %% [markdown]
# ## 17 PDF AND WORD DOCUMENTS
#
# Source: https://automatetheboringstuff.com/3e/chapter17.html

# %% [markdown]
# ### PDF Documents

# %% [markdown]
# #### Source example 17.1
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import pypdf
#
#
# ❶
#  >>>
# reader = pypdf.PdfReader('Recursion_Chapter1.pdf')
#
#
# ❷
#  >>>
# len(reader.pages)
#
# 18
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import pypdf
#
#
# ❶
#  >>>
# reader = pypdf.PdfReader('Recursion_Chapter1.pdf')
#
#
# ❷
#  >>>
# len(reader.pages)
#
# 18
# ```

# %%
# Practice rewrite for source example 17.1
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.2
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# import pypdf
# import pdfminer.high_level
#
# PDF_FILENAME = 'Recursion_Chapter1.pdf'
# TEXT_FILENAME = 'recursion.txt'
#
# text = ''
# try:
#     reader = pypdf.PdfReader(PDF_FILENAME)
#
# ❶
#  for page in reader.pages:
#
# ❷
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# import pypdf
# import pdfminer.high_level
#
# PDF_FILENAME = 'Recursion_Chapter1.pdf'
# TEXT_FILENAME = 'recursion.txt'
#
# text = ''
# try:
#     reader = pypdf.PdfReader(PDF_FILENAME)
#
# ❶
#  for page in reader.pages:
#
# ❷
#  text += page.extract_text()
# except Exception:
#
# ❸
#  text = pdfminer.high_level.extract_text(PDF_FILENAME)
# with open(TEXT_FILENAME, 'w', encoding='utf-8') as file_obj:
#
# ❹
#  file_obj.write(text)
# ```

# %%
# Practice rewrite for source example 17.2
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.3
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example belongs to the chapter on reading and creating PDF and Word documents, and shows one small building block from the section `PDF Documents`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# 1
# WHAT IS RECURSION?
# Recursion has an intimidating reputation.
# It's considered hard to understand, but
# at its core, it depends on only two things:
#  function calls and stack data structures.
# Most new programmers trace through what a program does by follow -
# ing the execution. It's an easy way to read code: you just put your finger
#
# --snip--
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# 1
# WHAT IS RECURSION?
# Recursion has an intimidating reputation.
# It's considered hard to understand, but
# at its core, it depends on only two things:
#  function calls and stack data structures.
# Most new programmers trace through what a program does by follow -
# ing the execution. It's an easy way to read code: you just put your finger
#
# --snip--
# ```

# %%
# Practice rewrite for source example 17.3
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.4
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example belongs to the chapter on reading and creating PDF and Word documents, and shows one small building block from the section `PDF Documents`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# WHAT IS RECURSION?
#
# Recursion has an intimidating reputation. It's considered hard
# to understand, but at its core, it depends on only two things:
# function calls and stack data structures. Most new programmers
# trace through what a program does by following the execution.
# It's an easy way to read code: you just put your finger...
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# WHAT IS RECURSION?
#
# Recursion has an intimidating reputation. It's considered hard
# to understand, but at its core, it depends on only two things:
# function calls and stack data structures. Most new programmers
# trace through what a program does by following the execution.
# It's an easy way to read code: you just put your finger...
# ```

# %%
# Practice rewrite for source example 17.4
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.5
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# import pypdf
# PDF_FILENAME = 'Recursion_Chapter1.pdf'
#
# reader = pypdf.PdfReader(PDF_FILENAME)
#
# ❶
#  image_num = 0
#
# ❷
#  for i, page in enumerate(reader.pages):
#     print(f'Reading page {i+1} - {len(page.images)} images found...')
#     try:
#
# ❸
# # ... 15 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# import pypdf
# PDF_FILENAME = 'Recursion_Chapter1.pdf'
#
# reader = pypdf.PdfReader(PDF_FILENAME)
#
# ❶
#  image_num = 0
#
# ❷
#  for i, page in enumerate(reader.pages):
#     print(f'Reading page {i+1} - {len(page.images)} images found...')
#     try:
#
# ❸
#  for image in page.images:
#
# ❹
#  with open(f'{image_num}_page{i+1}_{image.name}', 'wb') as file:
#
# ❺
#  file.write(image.data)
#             print(f'Wrote {image_num}_page{i+1}_{image.name}...')
#
# ❻
#  image_num += 1
#     except Exception as exc:
#
# ❼
#  print(f'Skipped page {i+1} due to error: {exc}')
# ```

# %%
# Practice rewrite for source example 17.5
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.6
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example belongs to the chapter on reading and creating PDF and Word documents, and shows one small building block from the section `PDF Documents`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# Reading page 1 - 7 images found...
# Wrote 0_page1_Im0.jpg...
# Wrote 1_page1_Im1.png...
#
# --snip--
#
# Reading page 7 - 1 images found...
# Skipped page 7 due to error: not enough image data
#
# --snip--
#
# Reading page 17 - 0 images found...
# Reading page 18 - 0 images found...
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# Reading page 1 - 7 images found...
# Wrote 0_page1_Im0.jpg...
# Wrote 1_page1_Im1.png...
#
# --snip--
#
# Reading page 7 - 1 images found...
# Skipped page 7 due to error: not enough image data
#
# --snip--
#
# Reading page 17 - 0 images found...
# Reading page 18 - 0 images found...
# ```

# %%
# Practice rewrite for source example 17.6
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.7
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import pypdf
#
#
# ❶
#  >>>
# writer = pypdf.PdfWriter()
#
#
# ❷
#  >>>
# writer.append('Recursion_Chapter1.pdf', (0, 5))
#
# >>>
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import pypdf
#
#
# ❶
#  >>>
# writer = pypdf.PdfWriter()
#
#
# ❷
#  >>>
# writer.append('Recursion_Chapter1.pdf', (0, 5))
#
# >>>
# with open('first_five_pages.pdf', 'wb') as file:
#
#
# ❸
#  ...
# writer.write(file)
#
# ...
# (False, <_io.BufferedWriter name='first_five_pages.pdf'>)
# ```

# %%
# Practice rewrite for source example 17.7
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.8
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example belongs to the chapter on reading and creating PDF and Word documents, and shows one small building block from the section `PDF Documents`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# list(range(0, 5))
#   # Passing (0, 5) makes append() copy these pages:
# [0, 1, 2, 3, 4]
# >>>
# list(range(0, 5, 2))
#   # Passing (0, 5, 2) makes append() copy these pages:
# [0, 2, 4]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# list(range(0, 5))
#   # Passing (0, 5) makes append() copy these pages:
# [0, 1, 2, 3, 4]
# >>>
# list(range(0, 5, 2))
#   # Passing (0, 5, 2) makes append() copy these pages:
# [0, 2, 4]
# ```

# %%
# Practice rewrite for source example 17.8
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.9
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# writer.append('Recursion_Chapter1.pdf', [0, 1, 2, 3, 4])
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# writer.append('Recursion_Chapter1.pdf', [0, 1, 2, 3, 4])
# ```

# %%
# Practice rewrite for source example 17.9
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.10
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# writer.merge(2, 'Recursion_Chapter1.pdf', (0, 5))
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# writer.merge(2, 'Recursion_Chapter1.pdf', (0, 5))
# ```

# %%
# Practice rewrite for source example 17.10
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.11
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import pypdf
#
# >>>
# writer = pypdf.PdfWriter()
#
# >>>
# writer.append('Recursion_Chapter1.pdf')
#
#
# ❶
#  >>>
# for i in range(len(writer.pages)):
#
# # ... 19 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import pypdf
#
# >>>
# writer = pypdf.PdfWriter()
#
# >>>
# writer.append('Recursion_Chapter1.pdf')
#
#
# ❶
#  >>>
# for i in range(len(writer.pages)):
#
# ...
# ❷
#
# writer.pages[i].rotate(90)
#
# ...
# {'/ArtBox': [21, 21, 525, 687], '/BleedBox': [12, 12, 534, 696],
#
# --snip--
#
#
# >>>
# with open('rotated.pdf', 'wb') as file:
#
# ...
# writer.write(file)
#
# ...
# (False, <_io.BufferedWriter name='rotated.pdf'>)
# ```

# %%
# Practice rewrite for source example 17.11
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.12
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example demonstrates database work: creating tables, inserting rows, querying, or updating records.
# 2. A database lets you ask precise questions of structured data without manually scanning files.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. SQLite is practical for personal tools, local caches, app prototypes, logs, and repeatable reports.
# 5. Use parameterized queries for user input and commit changes deliberately.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import pypdf
#
# >>>
# writer = pypdf.PdfWriter()
#
# >>>
# writer.append('Recursion_Chapter1.pdf')
#
#
# ❶
#  >>>
# writer.add_blank_page()
#
# # ... 17 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import pypdf
#
# >>>
# writer = pypdf.PdfWriter()
#
# >>>
# writer.append('Recursion_Chapter1.pdf')
#
#
# ❶
#  >>>
# writer.add_blank_page()
#
# {'/Type': '/Page', '/Resources': {}, '/MediaBox': [0.0, 0.0,
# 546, 708], '/Parent': IndirectObject(1, 0, 2629126028624)}
#
# ❷
#  >>>
# writer.insert_blank_page(index=2)
#
# {'/Type': '/Page', '/Parent': NullObject, '/Resources': {},
# '/MediaBox': RectangleObject([0.0, 0.0, 546, 708])}
# >>>
# with open('with_blanks.pdf', 'wb') as file:
#
# ...
# writer.write(file)
#   # Save the writer object to a PDF file.
# ...
# (False, <_io.BufferedWriter name='with_blanks.pdf'>)
# ```

# %%
# Practice rewrite for source example 17.12
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.13
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import pypdf
#
# >>>
# writer = pypdf.PdfWriter()
#
# >>>
# writer.append('Recursion_Chapter1.pdf')
#
#
# ❶
#  >>>
# watermark_page = pypdf.PdfReader('watermark.pdf').pages[0]
#
# # ... 17 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import pypdf
#
# >>>
# writer = pypdf.PdfWriter()
#
# >>>
# writer.append('Recursion_Chapter1.pdf')
#
#
# ❶
#  >>>
# watermark_page = pypdf.PdfReader('watermark.pdf').pages[0]
#
# >>>
# for page in writer.pages:
#
#
# ❷
#  ...
# page.merge_page(watermark_page, over=False)
#
# ...
# >>>
# with open('with_watermark.pdf', 'wb') as file:
#
# ...
# writer.write(file)
#
# ...
# (False, <_io.BufferedWriter name='with_watermark.pdf'>)
# ```

# %%
# Practice rewrite for source example 17.13
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.14
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import pypdf
#
# >>>
# writer = pypdf.PdfWriter()
#
# >>>
# writer.append('Recursion_Chapter1.pdf')
#
#
# >>>
# writer.encrypt('swordfish', algorithm='AES-256')
#
# >>>
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import pypdf
#
# >>>
# writer = pypdf.PdfWriter()
#
# >>>
# writer.append('Recursion_Chapter1.pdf')
#
#
# >>>
# writer.encrypt('swordfish', algorithm='AES-256')
#
# >>>
# with open('encrypted.pdf', 'wb') as file:
#
# ...
# writer.write(file)
#
# ...
# (False, <_io.BufferedWriter name='encrypted.pdf'>)
# ```

# %%
# Practice rewrite for source example 17.14
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.15
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import pypdf
#
#
# ❶
#  >>>
# reader = pypdf.PdfReader('encrypted.pdf')
#
# >>>
# writer = pypdf.PdfWriter()
#
#
# ❷
#  >>>
# # ... 38 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import pypdf
#
#
# ❶
#  >>>
# reader = pypdf.PdfReader('encrypted.pdf')
#
# >>>
# writer = pypdf.PdfWriter()
#
#
# ❷
#  >>>
# reader.is_encrypted
#
# True
#
# ❸
#  >>>
# reader.pages[0]
#
# Traceback (most recent call last):
#
# --snip--
#
# pypdf.errors.FileNotDecryptedError: File has not been decrypted
#
# ❹
#  >>>
# reader.decrypt('an incorrect password').name
#
# 'NOT_DECRYPTED'
#
# ❺
#  >>>
# reader.decrypt('swordfish').name
#
# 'OWNER_PASSWORD'
#
# ❻
#  >>>
# writer.append(reader)
#
# >>>
# with open('decrypted.pdf', 'wb') as file:
#
# ...
# writer.write(file)
#
# ...
# (False, <_io.BufferedWriter name='decrypted.pdf'>)
# ```

# %%
# Practice rewrite for source example 17.15
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.16
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# # combine_pdfs.py - Combines all the PDFs in the current working directory
# # into a single PDF
#
#
# ❶
#  import pypdf, os
#
# # Get all the PDF filenames.
# pdf_filenames = []
#
# for filename in os.listdir('.'):
#     if filename.endswith('.pdf'):
#
# ❷
# # ... 14 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # combine_pdfs.py - Combines all the PDFs in the current working directory
# # into a single PDF
#
#
# ❶
#  import pypdf, os
#
# # Get all the PDF filenames.
# pdf_filenames = []
#
# for filename in os.listdir('.'):
#     if filename.endswith('.pdf'):
#
# ❷
#  pdf_files.append(filename)
#
# ❸
#  pdf_filenames.sort(key=str.lower)
#
#
# ❹
#  writer = pypdf.PdfWriter()
#
# # TODO: Loop through all the PDF files.
#
# # TODO: Copy all pages after the first page.
#
# # TODO: Save the resulting PDF to a file.
# ```

# %%
# Practice rewrite for source example 17.16
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.17
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# # combine_pdfs.py - Combines all the PDFs in the current working directory
# # into a single PDF
#
# import pypdf, os
#
#
# --snip--
#
#
#
# # Loop through all the PDF files:
#
#
# for pdf_filename in pdf_filenames:
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # combine_pdfs.py - Combines all the PDFs in the current working directory
# # into a single PDF
#
# import pypdf, os
#
#
# --snip--
#
#
#
# # Loop through all the PDF files:
#
#
# for pdf_filename in pdf_filenames:
#
#
#     reader = pypdf.PdfReader(pdf_filename)
#
#
#     # Copy all pages after the first page:
#
#
#     writer.append(pdf_filename, (1, len(reader.pages)))
#
#
# # TODO: Save the resulting PDF to a file.
# ```

# %%
# Practice rewrite for source example 17.17
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.18
#
# Checklist note: captured from section **PDF Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# # combine_pdfs.py - Combines all the PDFs in the current working directory
# # into a single PDF
#
# import pypdf, os
#
#
# --snip--
#
#
#
# # Save the resulting PDF to a file:
#
#
# with open('combined.pdf', 'wb') as file:
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # combine_pdfs.py - Combines all the PDFs in the current working directory
# # into a single PDF
#
# import pypdf, os
#
#
# --snip--
#
#
#
# # Save the resulting PDF to a file:
#
#
# with open('combined.pdf', 'wb') as file:
#
#
#     writer.write(file)
# ```

# %%
# Practice rewrite for source example 17.18
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Word Documents

# %% [markdown]
# #### Source example 17.19
#
# Checklist note: captured from section **Word Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import docx
#
# >>>
# doc = docx.Document('demo.docx')
#
# >>>
# len(doc.paragraphs)
#
# 7
# >>>
# doc.paragraphs[0].text
#
# 'Document Title'
# # ... 24 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import docx
#
# >>>
# doc = docx.Document('demo.docx')
#
# >>>
# len(doc.paragraphs)
#
# 7
# >>>
# doc.paragraphs[0].text
#
# 'Document Title'
# >>>
# doc.paragraphs[1].text
#
# 'A plain paragraph with some bold text and some italic'
# >>>
# len(doc.paragraphs[1].runs)
#
# 4
# >>>
# doc.paragraphs[1].runs[0].text
#
# 'A plain paragraph with some '
# >>>
# doc.paragraphs[1].runs[1].text
#
# 'bold'
# >>>
# doc.paragraphs[1].runs[2].text
#
# ' and some '
# >>>
# doc.paragraphs[1].runs[3].text
#
# 'italic'
# ```

# %%
# Practice rewrite for source example 17.19
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.20
#
# Checklist note: captured from section **Word Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# import docx
#
# def get_text(filename):
#     doc = docx.Document(filename)
#     full_text = []
#     for para in doc.paragraphs:
#         full_text.append(para.text)
#     return '\n'.join(full_text)
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# import docx
#
# def get_text(filename):
#     doc = docx.Document(filename)
#     full_text = []
#     for para in doc.paragraphs:
#         full_text.append(para.text)
#     return '\n'.join(full_text)
# ```

# %%
# Practice rewrite for source example 17.20
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.21
#
# Checklist note: captured from section **Word Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import readDocx
#
# >>>
# print(readDocx.get_text('demo.docx'))
#
# Document Title
# A plain paragraph with some bold text and some italic
# Heading, level 1
# Intense quote
# first item in unordered list
# first item in ordered list
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import readDocx
#
# >>>
# print(readDocx.get_text('demo.docx'))
#
# Document Title
# A plain paragraph with some bold text and some italic
# Heading, level 1
# Intense quote
# first item in unordered list
# first item in ordered list
# ```

# %%
# Practice rewrite for source example 17.21
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.22
#
# Checklist note: captured from section **Word Documents**.
#
# **Context**
#
# 1. This example belongs to the chapter on reading and creating PDF and Word documents, and shows one small building block from the section `Word Documents`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# full_text.append(
# '  ' +
# para.text)
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# full_text.append(
# '  ' +
# para.text)
# ```

# %%
# Practice rewrite for source example 17.22
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.23
#
# Checklist note: captured from section **Word Documents**.
#
# **Context**
#
# 1. This example belongs to the chapter on reading and creating PDF and Word documents, and shows one small building block from the section `Word Documents`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# return '\n
# \n
# '.join(full_text)
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# return '\n
# \n
# '.join(full_text)
# ```

# %%
# Practice rewrite for source example 17.23
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.24
#
# Checklist note: captured from section **Word Documents**.
#
# **Context**
#
# 1. This example belongs to the chapter on reading and creating PDF and Word documents, and shows one small building block from the section `Word Documents`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# 'Normal'   'Heading 5' 'List Bullet'       'List Paragraph'
# 'Body Text' 'Heading 6' 'List Bullet 2'     'MacroText'
# 'Body Text 2'   'Heading 7' 'List Bullet 3'     'No Spacing'
# 'Body Text 3'   'Heading 8' 'List Continue'     'Quote'
# 'Caption'   'Heading 9' 'List Continue 2'   'Subtitle'
# 'Heading 1' 'Intense Quote' 'List Continue 3'   'TOC Heading'
# 'Heading 2' 'List'      'List Number '      'Title'
# 'Heading 3' 'List 2'    'List Number 2'
# 'Heading 4' 'List 3'    'List Number 3'
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# 'Normal'   'Heading 5' 'List Bullet'       'List Paragraph'
# 'Body Text' 'Heading 6' 'List Bullet 2'     'MacroText'
# 'Body Text 2'   'Heading 7' 'List Bullet 3'     'No Spacing'
# 'Body Text 3'   'Heading 8' 'List Continue'     'Quote'
# 'Caption'   'Heading 9' 'List Continue 2'   'Subtitle'
# 'Heading 1' 'Intense Quote' 'List Continue 3'   'TOC Heading'
# 'Heading 2' 'List'      'List Number '      'Title'
# 'Heading 3' 'List 2'    'List Number 2'
# 'Heading 4' 'List 3'    'List Number 3'
# ```

# %%
# Practice rewrite for source example 17.24
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.25
#
# Checklist note: captured from section **Word Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import docx
#
# >>>
# doc = docx.Document('demo.docx')
#
# >>>
# doc.paragraphs[0].text
#
# 'Document Title'
# >>>
# doc.paragraphs[0].style
#   # The exact id may be different.
# _ParagraphStyle('Title') id: 3095631007984
# # ... 25 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import docx
#
# >>>
# doc = docx.Document('demo.docx')
#
# >>>
# doc.paragraphs[0].text
#
# 'Document Title'
# >>>
# doc.paragraphs[0].style
#   # The exact id may be different.
# _ParagraphStyle('Title') id: 3095631007984
# >>>
# doc.paragraphs[0].style = 'Normal'
#
# >>>
# doc.paragraphs[1].text
#
# 'A plain paragraph with some bold text and some italic'
# >>>
# (doc.paragraphs[1].runs[0].text, doc.paragraphs[1].runs[1].text,
#
#
# doc.paragraphs[1].runs[2].text, doc.paragraphs[1].runs[3].text)
#
# ('A plain paragraph with some ', 'bold', ' and some ', 'italic')
# >>>
# doc.paragraphs[1].runs[0].style = 'Quote Char'
#
# >>>
# doc.paragraphs[1].runs[1].underline = True
#
# >>>
# doc.paragraphs[1].runs[3].underline = True
#
# >>>
# doc.save('restyled.docx')
# ```

# %%
# Practice rewrite for source example 17.25
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.26
#
# Checklist note: captured from section **Word Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import docx
#
# >>>
# doc = docx.Document()
#
# >>>
# doc.add_paragraph('Hello, world!')
#
# <docx.text.paragraph.Paragraph object at 0x0000000003B56F60>
# >>>
# doc.save('helloworld.docx')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import docx
#
# >>>
# doc = docx.Document()
#
# >>>
# doc.add_paragraph('Hello, world!')
#
# <docx.text.paragraph.Paragraph object at 0x0000000003B56F60>
# >>>
# doc.save('helloworld.docx')
# ```

# %%
# Practice rewrite for source example 17.26
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.27
#
# Checklist note: captured from section **Word Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import docx
#
# >>>
# doc = docx.Document()
#
# >>>
# doc.add_paragraph('Hello world!')
#
# <docx.text.paragraph.Paragraph object at 0x000000000366AD30>
# >>>
# para_obj_1 = doc.add_paragraph('This is a second paragraph.')
#
# >>>
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import docx
#
# >>>
# doc = docx.Document()
#
# >>>
# doc.add_paragraph('Hello world!')
#
# <docx.text.paragraph.Paragraph object at 0x000000000366AD30>
# >>>
# para_obj_1 = doc.add_paragraph('This is a second paragraph.')
#
# >>>
# para_obj_2 = doc.add_paragraph('This is a yet another paragraph.')
#
# >>>
# para_obj_1.add_run(' This text is being added to the second paragraph.')
#
# <docx.text.run.Run object at 0x0000000003A2C860>
# >>>
# doc.save('multipleParagraphs.docx')
# ```

# %%
# Practice rewrite for source example 17.27
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.28
#
# Checklist note: captured from section **Word Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# doc.add_paragraph('Hello, world!', 'Title')
#
# <docx.text.paragraph.Paragraph object at 0x00000213E6FA9190>
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# doc.add_paragraph('Hello, world!', 'Title')
#
# <docx.text.paragraph.Paragraph object at 0x00000213E6FA9190>
# ```

# %%
# Practice rewrite for source example 17.28
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.29
#
# Checklist note: captured from section **Word Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import docx
#
# >>>
# doc = docx.Document()
#
# >>>
# doc.add_heading('Header 0', 0)
#
# <docx.text.paragraph.Paragraph object at 0x00000000036CB3C8>
# >>>
# doc.add_heading('Header 1', 1)
#
# <docx.text.paragraph.Paragraph object at 0x00000000036CB630>
# # ... 14 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import docx
#
# >>>
# doc = docx.Document()
#
# >>>
# doc.add_heading('Header 0', 0)
#
# <docx.text.paragraph.Paragraph object at 0x00000000036CB3C8>
# >>>
# doc.add_heading('Header 1', 1)
#
# <docx.text.paragraph.Paragraph object at 0x00000000036CB630>
# >>>
# doc.add_heading('Header 2', 2)
#
# <docx.text.paragraph.Paragraph object at 0x00000000036CB828>
# >>>
# doc.add_heading('Header 3', 3)
#
# <docx.text.paragraph.Paragraph object at 0x00000000036CB2E8>
# >>>
# doc.add_heading('Header 4', 4)
#
# <docx.text.paragraph.Paragraph object at 0x00000000036CB3C8>
# >>>
# doc.save('headings.docx')
# ```

# %%
# Practice rewrite for source example 17.29
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.30
#
# Checklist note: captured from section **Word Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# doc = docx.Document()
#
# >>>
# doc.add_paragraph('This is on the first page!')
#
# <docx.text.paragraph.Paragraph object at 0x0000000003785518>
#
# ❶
#  >>>
# doc.paragraphs[0].runs[0].add_break(docx.enum.text.WD_BREAK.PAGE)
#
# >>>
# doc.add_paragraph('This is on the second page!')
# # ... 4 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# doc = docx.Document()
#
# >>>
# doc.add_paragraph('This is on the first page!')
#
# <docx.text.paragraph.Paragraph object at 0x0000000003785518>
#
# ❶
#  >>>
# doc.paragraphs[0].runs[0].add_break(docx.enum.text.WD_BREAK.PAGE)
#
# >>>
# doc.add_paragraph('This is on the second page!')
#
# <docx.text.paragraph.Paragraph object at 0x00000000037855F8>
# >>>
# doc.save('twoPage.docx')
# ```

# %%
# Practice rewrite for source example 17.30
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 17.31
#
# Checklist note: captured from section **Word Documents**.
#
# **Context**
#
# 1. This example shows document automation for PDF or Word files.
# 2. The useful skill is extracting text or assembling documents from predictable pieces.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. This helps with invoices, forms, reports, contracts, meeting notes, and document-heavy office workflows.
# 5. Document layouts can be tricky, so inspect the output visually when formatting matters.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# >>>
# doc.add_picture('zophie.png', width=docx.shared.Inches(1), height=docx.shared.Cm(4))
#
# <docx.shape.InlineShape object at 0x00000000036C7D30>
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# doc.add_picture('zophie.png', width=docx.shared.Inches(1), height=docx.shared.Cm(4))
#
# <docx.shape.InlineShape object at 0x00000000036C7D30>
# ```

# %%
# Practice rewrite for source example 17.31
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Practice Programs

# %% [markdown]
# #### Source example 17.32
#
# Checklist note: captured from section **Practice Programs**.
#
# **Context**
#
# 1. This example belongs to the chapter on reading and creating PDF and Word documents, and shows one small building block from the section `Practice Programs`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter applies text processing and file I/O to office documents, where automation often means extracting or generating reports.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# document file -> extract/compose text -> format content -> save document
# ```
#
# **Code Preview**
#
# ```python
# Prof. Plum
# Miss Scarlet
# Col. Mustard
# Al Sweigart
# RoboCop
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# Prof. Plum
# Miss Scarlet
# Col. Mustard
# Al Sweigart
# RoboCop
# ```

# %%
# Practice rewrite for source example 17.32
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Chapter 17 Practice Checkpoint

# %%
# Chapter 17 checkpoint
# Choose three source examples from this chapter.
# For each one:
# 1. Explain what input it expects.
# 2. Explain what output or side effect it creates.
# 3. Rewrite it with safe sample data.

# %% [markdown]
# ### Extra Practice for Chapter 17

# %% [markdown]
# #### Practice: document paragraph assembly

# %%
title = "Weekly Report"
bullets = ["Backups completed", "Invoices checked", "Three follow-ups pending"]

document_text = [title, "=" * len(title), ""]
for bullet in bullets:
    document_text.append(f"- {bullet}")

print("\n".join(document_text))

# %% [markdown]
# ## 18 CSV, JSON, AND XML FILES
#
# Source: https://automatetheboringstuff.com/3e/chapter18.html

# %% [markdown]
# ### The CSV Format

# %% [markdown]
# #### Source example 18.1
#
# Checklist note: captured from section **The CSV Format**.
#
# **Context**
#
# 1. This example belongs to the chapter on processing CSV, JSON, and XML data files, and shows one small building block from the section `The CSV Format`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# 4/5/2035 13:34,Apples,73
# 4/5/2035 3:41,Cherries,85
# 4/6/2035 12:46,Pears,14
# 4/8/2035 8:59,Oranges,52
# 4/10/2035 2:07,Apples,152
# 4/10/2035 18:10,Bananas,23
# 4/10/2035 2:40,Strawberries,98
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# 4/5/2035 13:34,Apples,73
# 4/5/2035 3:41,Cherries,85
# 4/6/2035 12:46,Pears,14
# 4/8/2035 8:59,Oranges,52
# 4/10/2035 2:07,Apples,152
# 4/10/2035 18:10,Bananas,23
# 4/10/2035 2:40,Strawberries,98
# ```

# %%
# Practice rewrite for source example 18.1
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.2
#
# Checklist note: captured from section **The CSV Format**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import csv
#
# >>>
# example_file = open('example3.csv')
#
# >>>
# example_reader = csv.reader(example_file)
#
# >>>
# example_data = list(example_reader)
#
# >>>
# example_data
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import csv
#
# >>>
# example_file = open('example3.csv')
#
# >>>
# example_reader = csv.reader(example_file)
#
# >>>
# example_data = list(example_reader)
#
# >>>
# example_data
#
# [['4/5/2035 13:34', 'Apples', '73'], ['4/5/2035 3:41', 'Cherries', '85'],
# ['4/6/2035 12:46', 'Pears', '14'], ['4/8/2035 8:59', 'Oranges', '52'],
# ['4/10/2035 2:07', 'Apples', '152'], ['4/10/2035 18:10', 'Bananas', '23'],
# ['4/10/2035 2:40', 'Strawberries', '98']]
# >>>
# example_file.close()
# ```

# %%
# Practice rewrite for source example 18.2
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.3
#
# Checklist note: captured from section **The CSV Format**.
#
# **Context**
#
# 1. This example belongs to the chapter on processing CSV, JSON, and XML data files, and shows one small building block from the section `The CSV Format`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# example_data[0][0]
#   # First row, first column
# '4/5/2035 13:34'
# >>>
# example_data[0][1]
#   # First row, second column
# 'Apples'
# >>>
# example_data[0][2]
#   # First row, third column
# '73'
# >>>
# example_data[1][1]
# # ... 6 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# example_data[0][0]
#   # First row, first column
# '4/5/2035 13:34'
# >>>
# example_data[0][1]
#   # First row, second column
# 'Apples'
# >>>
# example_data[0][2]
#   # First row, third column
# '73'
# >>>
# example_data[1][1]
#   # Second row, second column
# 'Cherries'
# >>>
# example_data[6][1]
#   # Seventh row, second column
# 'Strawberries'
# ```

# %%
# Practice rewrite for source example 18.3
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.4
#
# Checklist note: captured from section **The CSV Format**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import csv
#
# >>>
# example_file = open('example3.csv')
#
# >>>
# example_reader = csv.reader(example_file)
#
#
# ❶
#  >>>
# for row in example_reader:
#
# # ... 13 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import csv
#
# >>>
# example_file = open('example3.csv')
#
# >>>
# example_reader = csv.reader(example_file)
#
#
# ❶
#  >>>
# for row in example_reader:
#
# ...
# ❷
#
# print('Row #' + str(example_reader.line_num) + ' ' + str(row))
#
# ...
# Row #1 ['4/5/2035 13:34', 'Apples', '73']
# Row #2 ['4/5/2035 3:41', 'Cherries', '85']
# Row #3 ['4/6/2035 12:46', 'Pears', '14']
# Row #4 ['4/8/2035 8:59', 'Oranges', '52']
# Row #5 ['4/10/2035 2:07', 'Apples', '152']
# Row #6 ['4/10/2035 18:10', 'Bananas', '23']
# Row #7 ['4/10/2035 2:40', 'Strawberries', '98']
# ```

# %%
# Practice rewrite for source example 18.4
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.5
#
# Checklist note: captured from section **The CSV Format**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import csv
#
#
# ❶
#  >>>
# output_file = open('output.csv', 'w', newline='')
#
#
# ❷
#  >>>
# output_writer = csv.writer(output_file)
#
# >>>
# # ... 13 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import csv
#
#
# ❶
#  >>>
# output_file = open('output.csv', 'w', newline='')
#
#
# ❷
#  >>>
# output_writer = csv.writer(output_file)
#
# >>>
# output_writer.writerow(['spam', 'eggs', 'bacon', 'ham'])
#
# 21
# >>>
# output_writer.writerow(['Hello, world!', 'eggs', 'bacon', 'ham'])
#
# 32
# >>>
# output_writer.writerow([1, 2, 3.141592, 4])
#
# 16
# >>>
# output_file.close()
# ```

# %%
# Practice rewrite for source example 18.5
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.6
#
# Checklist note: captured from section **The CSV Format**.
#
# **Context**
#
# 1. This example belongs to the chapter on processing CSV, JSON, and XML data files, and shows one small building block from the section `The CSV Format`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# spam,eggs,bacon,ham
# "Hello, world!",eggs,bacon,ham
# 1,2,3.141592,4
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# spam,eggs,bacon,ham
# "Hello, world!",eggs,bacon,ham
# 1,2,3.141592,4
# ```

# %%
# Practice rewrite for source example 18.6
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.7
#
# Checklist note: captured from section **The CSV Format**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import csv
#
# >>>
# output_file = open('output.tsv', 'w', newline='')
#
# >>>
# output_writer = csv.writer(output_file, delimiter='\t', lineterminator='\n\n')
#
# ❶
#
# >>>
# output_writer.writerow(['spam', 'eggs', 'bacon', 'ham'])
#
# # ... 11 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import csv
#
# >>>
# output_file = open('output.tsv', 'w', newline='')
#
# >>>
# output_writer = csv.writer(output_file, delimiter='\t', lineterminator='\n\n')
#
# ❶
#
# >>>
# output_writer.writerow(['spam', 'eggs', 'bacon', 'ham'])
#
# 21
# >>>
# output_writer.writerow(['Hello, world!', 'eggs', 'bacon', 'ham'])
#
# 30
# >>>
# output_writer.writerow([1, 2, 3.141592, 4])
#
# 16
# >>>
# output_file.close()
# ```

# %%
# Practice rewrite for source example 18.7
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.8
#
# Checklist note: captured from section **The CSV Format**.
#
# **Context**
#
# 1. This example belongs to the chapter on processing CSV, JSON, and XML data files, and shows one small building block from the section `The CSV Format`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# spam    eggs    bacon   ham
#
# Hello, world!   eggs    bacon   ham
#
# 1   2   3.141592    4
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# spam    eggs    bacon   ham
#
# Hello, world!   eggs    bacon   ham
#
# 1   2   3.141592    4
# ```

# %%
# Practice rewrite for source example 18.8
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.9
#
# Checklist note: captured from section **The CSV Format**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import csv
#
# >>>
# example_file = open('exampleWithHeader3.csv')
#
# >>>
# example_dict_reader = csv.DictReader(example_file)
#
#
# ❶
#  >>>
# example_dict_data = list(example_dict_reader)
#
# # ... 32 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import csv
#
# >>>
# example_file = open('exampleWithHeader3.csv')
#
# >>>
# example_dict_reader = csv.DictReader(example_file)
#
#
# ❶
#  >>>
# example_dict_data = list(example_dict_reader)
#
# >>>
# example_dict_data
#
# [{'Timestamp': '4/5/2035 3:41', 'Fruit': 'Cherries', 'Quantity': '85'},
# {'Timestamp': '4/6/2035 12:46', 'Fruit': 'Pears', 'Quantity': '14'},
# {'Timestamp': '4/8/2035 8:59', 'Fruit': 'Oranges', 'Quantity': '52'},
# {'Timestamp': '4/10/2035 2:07', 'Fruit': 'Apples', 'Quantity': '152'},
# {'Timestamp': '4/10/2035 18:10', 'Fruit': 'Bananas', 'Quantity': '23'},
# {'Timestamp': '4/10/2035 2:40', 'Fruit': 'Strawberries', 'Quantity': '98'}]
# >>>
# example_file = open('exampleWithHeader3.csv')
#
# >>>
# example_dict_reader = csv.DictReader(example_file)
#
#
# ❷
#  >>>
# for row in example_dict_reader:
#
# ...
# print(row['Timestamp'], row['Fruit'], row['Quantity'])
#
# ...
# 4/5/2035 13:34 Apples 73
# 4/5/2035 3:41 Cherries 85
# 4/6/2035 12:46 Pears 14
# 4/8/2035 8:59 Oranges 52
#
# 4/10/2035 2:07 Apples 152
# 4/10/2035 18:10 Bananas 23
# 4/10/2035 2:40 Strawberries 98
# ```

# %%
# Practice rewrite for source example 18.9
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.10
#
# Checklist note: captured from section **The CSV Format**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import csv
#
# >>>
# example_file = open('example3.csv')
#
# >>>
# example_dict_reader = csv.DictReader(example_file, ['time', 'name', 'amount'])
#
# >>>
# for row in example_dict_reader:
#
# ...
# print(row['time'], row['name'], row['amount'])
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import csv
#
# >>>
# example_file = open('example3.csv')
#
# >>>
# example_dict_reader = csv.DictReader(example_file, ['time', 'name', 'amount'])
#
# >>>
# for row in example_dict_reader:
#
# ...
# print(row['time'], row['name'], row['amount'])
#
# ...
# 4/5/2035 13:34 Apples 73
# 4/5/2035 3:41 Cherries 85
# 4/6/2035 12:46 Pears 14
# 4/8/2035 8:59 Oranges 52
# 4/10/2035 2:07 Apples 152
# 4/10/2035 18:10 Bananas 23
# 4/10/2035 2:40 Strawberries 98
# ```

# %%
# Practice rewrite for source example 18.10
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.11
#
# Checklist note: captured from section **The CSV Format**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import csv
#
# >>>
# output_file = open('output.csv', 'w', newline='')
#
# >>>
# output_dict_writer = csv.DictWriter(output_file, ['Name', 'Pet', 'Phone'])
#
# >>>
# output_dict_writer.writeheader()
#
# 16
# >>>
# # ... 13 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import csv
#
# >>>
# output_file = open('output.csv', 'w', newline='')
#
# >>>
# output_dict_writer = csv.DictWriter(output_file, ['Name', 'Pet', 'Phone'])
#
# >>>
# output_dict_writer.writeheader()
#
# 16
# >>>
# output_dict_writer.writerow({'Name': 'Alice', 'Pet': 'cat', 'Phone': '555-1234'})
#
# 20
# >>>
# output_dict_writer.writerow({'Name': 'Bob', 'Phone': '555-9999'})
#
# 15
# >>>
# output_dict_writer.writerow({'Phone': '555-5555', 'Name': 'Carol', 'Pet': 'dog'})
#
# 20
# >>>
# output_file.close()
# ```

# %%
# Practice rewrite for source example 18.11
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.12
#
# Checklist note: captured from section **The CSV Format**.
#
# **Context**
#
# 1. This example belongs to the chapter on processing CSV, JSON, and XML data files, and shows one small building block from the section `The CSV Format`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# Name,Pet,Phone
# Alice,cat,555-1234
# Bob,,555-9999
# Carol,dog,555-5555
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# Name,Pet,Phone
# Alice,cat,555-1234
# Bob,,555-9999
# Carol,dog,555-5555
# ```

# %%
# Practice rewrite for source example 18.12
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.13
#
# Checklist note: captured from section **The CSV Format**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# # Removes the header line from csv files
# import csv, os
#
# os.makedirs('headerRemoved', exist_ok=True)
#
# # Loop through every file in the current working directory.
# for csv_filename in os.listdir('.'):
#     if not csv_filename.endswith('.csv'):
#
# ❶
#  continue  # Skip non-CSV files.
#
#     print('Removing header from ' + csv_filename + '...')
#
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # Removes the header line from csv files
# import csv, os
#
# os.makedirs('headerRemoved', exist_ok=True)
#
# # Loop through every file in the current working directory.
# for csv_filename in os.listdir('.'):
#     if not csv_filename.endswith('.csv'):
#
# ❶
#  continue  # Skip non-CSV files.
#
#     print('Removing header from ' + csv_filename + '...')
#
#     # TODO: Read the CSV file (skipping the first row).
#
#     # TODO: Write the CSV file.
# ```

# %%
# Practice rewrite for source example 18.13
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.14
#
# Checklist note: captured from section **The CSV Format**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# # Removes the header line from csv files
# import csv, os
#
#
# --snip--
#
#
#
#     # Read the CSV file (skipping the first row).
#
#
# csv_rows = []
#
#
# # ... 23 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # Removes the header line from csv files
# import csv, os
#
#
# --snip--
#
#
#
#     # Read the CSV file (skipping the first row).
#
#
# csv_rows = []
#
#
# csv_file_obj = open(csv_filename)
#
#
#     reader_obj = csv.reader(csv_file_obj)
#
#
# for row in reader_obj:
#
#
# if reader_obj.line_num == 1:
#
#
# continue
# # Skip the first row.
#
#
# csv_rows.append(row)
#
#
# csv_file_obj.close()
#
#
#     # TODO: Write the CSV file.
# ```

# %%
# Practice rewrite for source example 18.14
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.15
#
# Checklist note: captured from section **The CSV Format**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# # Removes the header line from csv files
# import csv, os
#
#
# --snip--
#
#
# # Loop through every file in the current working directory.
#
# ❶
#  for csv_filename in os.listdir('.'):
#     if not csv_filename.endswith('.csv'):
#         continue    # Skip non-CSV files.
#
# # ... 24 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # Removes the header line from csv files
# import csv, os
#
#
# --snip--
#
#
# # Loop through every file in the current working directory.
#
# ❶
#  for csv_filename in os.listdir('.'):
#     if not csv_filename.endswith('.csv'):
#         continue    # Skip non-CSV files.
#
#
# --snip--
#
#
#
#     # Write the CSV file.
#
#
# csv_file_obj = open(os.path.join('headerRemoved', csv_filename), 'w',
#
#
#                  newline='')
#
#
# csv_writer = csv.writer(csv_file_obj)
#
#
# for row in csv_rows:
#
#
# csv_writer.writerow(row)
#
#
# csv_file_obj.close()
# ```

# %%
# Practice rewrite for source example 18.15
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.16
#
# Checklist note: captured from section **The CSV Format**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# Removing header from NAICS_data_1048.csv...
# Removing header from NAICS_data_1218.csv...
#
# --snip--
#
# Removing header from NAICS_data_9834.csv...
# Removing header from NAICS_data_9986.csv...
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# Removing header from NAICS_data_1048.csv...
# Removing header from NAICS_data_1218.csv...
#
# --snip--
#
# Removing header from NAICS_data_9834.csv...
# Removing header from NAICS_data_9986.csv...
# ```

# %%
# Practice rewrite for source example 18.16
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Versatile Plaintext Formats

# %% [markdown]
# #### Source example 18.17
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example belongs to the chapter on processing CSV, JSON, and XML data files, and shows one small building block from the section `Versatile Plaintext Formats`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# {
#     "name": "Alice Doe",
#     "age": 30,
#     "car": None,
#     "programmer": True,
#     "address": {
#         "street": "100 Larkin St.",
#         "city": "San Francisco",
#         "zip": "94102"
#     },
#     "phone": [
#         {
#             "type": "mobile",
#             "number": "415-555-7890"
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# {
#     "name": "Alice Doe",
#     "age": 30,
#     "car": None,
#     "programmer": True,
#     "address": {
#         "street": "100 Larkin St.",
#         "city": "San Francisco",
#         "zip": "94102"
#     },
#     "phone": [
#         {
#             "type": "mobile",
#             "number": "415-555-7890"
#         },
#         {
#             "type": "work",
#             "number": "415-555-1234"
#         }
#     ]
# }
# ```

# %%
# Practice rewrite for source example 18.17
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.18
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example belongs to the chapter on processing CSV, JSON, and XML data files, and shows one small building block from the section `Versatile Plaintext Formats`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# {
#   "name": "Alice Doe",
#   "age": 30,
#   "car": null,
#   "programmer": true,
#   "address": {
#     "street": "100 Larkin St.",
#     "city": "San Francisco",
#
#     "zip": "94102"
#   },
#   "phone": [
#     {
#       "type": "mobile",
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# {
#   "name": "Alice Doe",
#   "age": 30,
#   "car": null,
#   "programmer": true,
#   "address": {
#     "street": "100 Larkin St.",
#     "city": "San Francisco",
#
#     "zip": "94102"
#   },
#   "phone": [
#     {
#       "type": "mobile",
#       "number": "415-555-7890"
#     },
#     {
#       "type": "work",
#       "number": "415-555-1234"
#     }
#   ]
# }
# ```

# %%
# Practice rewrite for source example 18.18
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.19
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# ❶
#  >>>
# import json
#
# >>>
# json_string = '{"name": "Alice Doe", "age": 30, "car": null, "programmer":
#
#
#  true, "address": {"street": "100 Larkin St.", "city": "San Francisco", "zip":
#
#
#  "94102"}, "phone": [{"type": "mobile", "number": "415-555-7890"}, {"type":
#
#
# # ... 14 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# ❶
#  >>>
# import json
#
# >>>
# json_string = '{"name": "Alice Doe", "age": 30, "car": null, "programmer":
#
#
#  true, "address": {"street": "100 Larkin St.", "city": "San Francisco", "zip":
#
#
#  "94102"}, "phone": [{"type": "mobile", "number": "415-555-7890"}, {"type":
#
#
# "work", "number": "415-555-1234"}]}'
#
#
# ❷
#  >>>
# python_data = json.loads(json_string)
#
# >>>
# python_data
#
# {'name': 'Alice Doe', 'age': 30, 'car': None, 'programmer': True, 'address':
# {'street': '100 Larkin St.', 'city': 'San Francisco', 'zip': '94102'},
# 'phone': [{'type': 'mobile', 'number': '415-555-7890'}, {'type': 'work',
# 'number': '415-555-1234'}]}
# ```

# %%
# Practice rewrite for source example 18.19
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.20
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import json
#
# >>>
# python_data = {'name': 'Alice Doe', 'age': 30, 'car': None, 'programmer': True, 'address':
#
#
# {'street': '100 Larkin St.', 'city': 'San Francisco', 'zip': '94102'}, 'phone': [{'type':
#
#
# 'mobile', 'number': '415-555-7890'}, {'type': 'work', 'number': '415-555-1234'}]}
#
# >>>
# json_string = json.dumps(python_data)
# # ... 30 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import json
#
# >>>
# python_data = {'name': 'Alice Doe', 'age': 30, 'car': None, 'programmer': True, 'address':
#
#
# {'street': '100 Larkin St.', 'city': 'San Francisco', 'zip': '94102'}, 'phone': [{'type':
#
#
# 'mobile', 'number': '415-555-7890'}, {'type': 'work', 'number': '415-555-1234'}]}
#
# >>>
# json_string = json.dumps(python_data)
#
# ❶
#
# >>>
# print(json_string)
# ❷
#
# {"name": "Alice Doe", "age": 30, "car": null, "programmer": true, "address": {"street":
# "100 Larkin St.", "city": "San Francisco", "zip": "94102"}, "phone": [{"type": "mobile",
# "number": "415-555-7890"}, {"type": "work", "number": "415-555-1234"}]}
# >>>
# json_string = json.dumps(python_data, indent=2)
#
# ❸
#
# >>>
# print(json_string)
#
# {
#   "name": "Alice Doe",
#   "age": 30,
#   "car": null,
#   "programmer": true,
#   "address": {
#     "street": "100 Larkin St.",
#     "city": "San Francisco",
#
# --snip--
#
# }
# ```

# %%
# Practice rewrite for source example 18.20
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.21
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# <person>
#     <name>Alice Doe</name>
#     <age>30</age>
#     <programmer>true</programmer>
#     <car xsi:nil="true" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
#     <address>
#         <street>100 Larkin St.</street>
#         <city>San Francisco</city>
#         <zip>94102</zip>
#     </address>
#     <phone>
#         <phoneEntry>
#             <type>mobile</type>
#             <number>415-555-7890</number>
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# <person>
#     <name>Alice Doe</name>
#     <age>30</age>
#     <programmer>true</programmer>
#     <car xsi:nil="true" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
#     <address>
#         <street>100 Larkin St.</street>
#         <city>San Francisco</city>
#         <zip>94102</zip>
#     </address>
#     <phone>
#         <phoneEntry>
#             <type>mobile</type>
#             <number>415-555-7890</number>
#         </phoneEntry>
#         <phoneEntry>
#             <type>work</type>
#             <number>415-555-1234</number>
#         </phoneEntry>
#     </phone>
# </person>
# ```

# %%
# Practice rewrite for source example 18.21
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.22
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example belongs to the chapter on processing CSV, JSON, and XML data files, and shows one small building block from the section `Versatile Plaintext Formats`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# <person><name>Alice Doe</name></person>
# <person><name>Bob Smith</name></person>
# <person><name>Carol Watanabe</name></person>
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# <person><name>Alice Doe</name></person>
# <person><name>Bob Smith</name></person>
# <person><name>Carol Watanabe</name></person>
# ```

# %%
# Practice rewrite for source example 18.22
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.23
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example belongs to the chapter on processing CSV, JSON, and XML data files, and shows one small building block from the section `Versatile Plaintext Formats`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# <address>
#     <street>100 Larkin St.</street>
#     <city>San Francisco</city>
#     <zip>94102</zip>
# </address>
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# <address>
#     <street>100 Larkin St.</street>
#     <city>San Francisco</city>
#     <zip>94102</zip>
# </address>
# ```

# %%
# Practice rewrite for source example 18.23
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.24
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example belongs to the chapter on processing CSV, JSON, and XML data files, and shows one small building block from the section `Versatile Plaintext Formats`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# <address street="100 Larkin St." city="San Francisco" zip="94102" />
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# <address street="100 Larkin St." city="San Francisco" zip="94102" />
# ```

# %%
# Practice rewrite for source example 18.24
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.25
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# ❶
#  >>>
# import xml.etree.ElementTree as ET
#
#
# ❷
#  >>>
# xml_string = """<person><name>Alice Doe</name><age>30</age>
#
#
# <programmer>true</programmer><car xsi:nil="true" xmlns:xsi=
#
#
# "http://www.w3.org/2001/XMLSchema-instance”/><address><street>
# # ... 22 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# ❶
#  >>>
# import xml.etree.ElementTree as ET
#
#
# ❷
#  >>>
# xml_string = """<person><name>Alice Doe</name><age>30</age>
#
#
# <programmer>true</programmer><car xsi:nil="true" xmlns:xsi=
#
#
# "http://www.w3.org/2001/XMLSchema-instance”/><address><street>
#
#
# 100 Larkin St.</street><city>San Francisco</city><zip>94102</zip>
#
#
# </address><phone><phoneEntry><type>mobile</type><number>415-555-
#
#
# 7890</number></phoneEntry><phoneEntry><type>work</type><number>
#
#
# 415-555-1234</number></phoneEntry></phone></person>"""
#
#
# ❸
#  >>>
# root = ET.fromstring(xml_string)
#
# >>>
# root
#
# <Element 'person' at 0x000001942999BBA0>
# ```

# %%
# Practice rewrite for source example 18.25
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.26
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import xml.etree.ElementTree as ET
#
# >>>
# tree = ET.parse('my_data.xml')
#
# >>>
# root = tree.getroot()
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import xml.etree.ElementTree as ET
#
# >>>
# tree = ET.parse('my_data.xml')
#
# >>>
# root = tree.getroot()
# ```

# %%
# Practice rewrite for source example 18.26
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.27
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example belongs to the chapter on processing CSV, JSON, and XML data files, and shows one small building block from the section `Versatile Plaintext Formats`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# root.tag
#
# 'person'
# >>>
# list(root)
#
# [<Element 'name' at 0x00000150BA4ADDF0>, <Element 'age' at
# 0x00000150BA4ADF30>, <Element 'programmer' at 0x00000150BA4ADEE0>,
# <Element 'car' at 0x00000150BA4ADD00>, <Element 'address' at
# 0x00000150BA4ADCB0>, <Element 'phone' at 0x00000150BA4ADA30>]
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# root.tag
#
# 'person'
# >>>
# list(root)
#
# [<Element 'name' at 0x00000150BA4ADDF0>, <Element 'age' at
# 0x00000150BA4ADF30>, <Element 'programmer' at 0x00000150BA4ADEE0>,
# <Element 'car' at 0x00000150BA4ADD00>, <Element 'address' at
# 0x00000150BA4ADCB0>, <Element 'phone' at 0x00000150BA4ADA30>]
# ```

# %%
# Practice rewrite for source example 18.27
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.28
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example belongs to the chapter on processing CSV, JSON, and XML data files, and shows one small building block from the section `Versatile Plaintext Formats`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# root[0].tag
#
# 'name'
# >>>
# root[0].text
#
# 'Alice Doe'
# >>>
# root[3].tag
#
# 'car'
# >>>
# root[3].text == None
# # ... 16 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# root[0].tag
#
# 'name'
# >>>
# root[0].text
#
# 'Alice Doe'
# >>>
# root[3].tag
#
# 'car'
# >>>
# root[3].text == None
#   # <car/> has no text.
#
#
# True
# >>>
# root[4].tag
#
# 'address'
# >>>
# root[4][0].tag
#
# 'street'
# >>>
# root[4][0].text
#
# '100 Larkin St.'
# ```

# %%
# Practice rewrite for source example 18.28
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.29
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example belongs to the chapter on processing CSV, JSON, and XML data files, and shows one small building block from the section `Versatile Plaintext Formats`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# for elem in root:
#
# ...
# print(elem.tag, '--', elem.text)
#
# ...
# name -- Alice Doe
# age -- 30
# programmer -- true
# car -- None
# address -- None
# phone -- None
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# for elem in root:
#
# ...
# print(elem.tag, '--', elem.text)
#
# ...
# name -- Alice Doe
# age -- 30
# programmer -- true
# car -- None
# address -- None
# phone -- None
# ```

# %%
# Practice rewrite for source example 18.29
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.30
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example belongs to the chapter on processing CSV, JSON, and XML data files, and shows one small building block from the section `Versatile Plaintext Formats`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# for elem in root.iter():
#
# ...
# print(elem.tag, '--', elem.text)
#
#
# ...
# person -- None
# name -- Alice Doe
# age -- 30
# programmer -- true
# car -- None
# address -- None
# # ... 10 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# for elem in root.iter():
#
# ...
# print(elem.tag, '--', elem.text)
#
#
# ...
# person -- None
# name -- Alice Doe
# age -- 30
# programmer -- true
# car -- None
# address -- None
# street -- 100 Larkin St.
# city -- San Francisco
# zip -- 94102
# phone -- None
# phoneEntry -- None
# type -- mobile
# number -- 415-555-7890
# phoneEntry -- None
# type -- work
# number -- 415-555-1234
# ```

# %%
# Practice rewrite for source example 18.30
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.31
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example belongs to the chapter on processing CSV, JSON, and XML data files, and shows one small building block from the section `Versatile Plaintext Formats`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# for elem in root.iter('number'):
#
# ...
# print(elem.tag, '--', elem.text)
#
# ...
# number -- 415-555-7890
# number -- 415-555-1234
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# for elem in root.iter('number'):
#
# ...
# print(elem.tag, '--', elem.text)
#
# ...
# number -- 415-555-7890
# number -- 415-555-1234
# ```

# %%
# Practice rewrite for source example 18.31
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.32
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import xmltodict
#
# >>>
# xml_string = """<person><name>Alice Doe</name><age>30</age>
#
#
# <programmer>true</programmer><car xsi:nil="true" xmlns:xsi=
#
#
# "http://www.w3.org/2001/XMLSchema-instance”/><address><street>
#
#
# 100 Larkin St.</street><city>San Francisco</city><zip>94102
# # ... 23 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import xmltodict
#
# >>>
# xml_string = """<person><name>Alice Doe</name><age>30</age>
#
#
# <programmer>true</programmer><car xsi:nil="true" xmlns:xsi=
#
#
# "http://www.w3.org/2001/XMLSchema-instance”/><address><street>
#
#
# 100 Larkin St.</street><city>San Francisco</city><zip>94102
#
#
# </zip></address><phone><phoneEntry><type>mobile</type><number>
#
#
# 415-555-7890</number></phoneEntry><phoneEntry><type>work</type>
#
#
# <number>415-555-1234</number></phoneEntry></phone></person>"""
#
# >>>
# python_data = xmltodict.parse(xml_string)
#
# >>>
# python_data
#
# {'person': {'name': 'Alice Doe', 'age': '30', 'programmer': 'true',
# 'car': {'@xsi:nil': 'true', '@xmlns:xsi': 'http://www.w3.org/2001/
#
# XMLSchema-instance'}, 'address': {'street': '100 Larkin St.', 'city':
# 'San Francisco', 'zip': '94102'}, 'phone': {'phoneEntry': [{'type':
# 'mobile', 'number': '415-555-7890'}, {'type': 'work', 'number':
# '415-555-1234'}]}}}
# ```

# %%
# Practice rewrite for source example 18.32
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.33
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import xml.etree.ElementTree as ET
#
# >>>
# person = ET.Element('person')
#   # Create the root XML element.
# >>>
# name = ET.SubElement(person, 'name')
#   # Create <name> and put it under <person>.
# >>>
# name.text = 'Alice Doe'
#   # Set the text between <name> and </name>.
# >>>
# age = ET.SubElement(person, 'age')
# # ... 27 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import xml.etree.ElementTree as ET
#
# >>>
# person = ET.Element('person')
#   # Create the root XML element.
# >>>
# name = ET.SubElement(person, 'name')
#   # Create <name> and put it under <person>.
# >>>
# name.text = 'Alice Doe'
#   # Set the text between <name> and </name>.
# >>>
# age = ET.SubElement(person, 'age')
#
# >>>
# age.text = '30'
#   # XML content is always a string.
# >>>
# programmer = ET.SubElement(person, 'programmer')
#
# >>>
# programmer.text = 'true'
#
# >>>
# car = ET.SubElement(person, 'car')
#
# >>>
# car.set('xsi:nil', 'true')
#
# >>>
# car.set('xmlns:xsi', 'http://www.w3.org/2001/XMLSchema-instance')
#
# >>>
# address = ET.SubElement(person, 'address')
#
# >>>
# street = ET.SubElement(address, 'street')
#
# >>>
# street.text = '100 Larkin St.'
# ```

# %%
# Practice rewrite for source example 18.33
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 18.34
#
# Checklist note: captured from section **Versatile Plaintext Formats**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# >>>
# ET.tostring(person, encoding='utf-8').decode('utf-8')
#
# '<person><name>Alice Doe</name><age>30</age><programmer>true</programmer>
# <car xsi:nil="true" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# <address><street>100 Larkin St.</street></address></person>'
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# ET.tostring(person, encoding='utf-8').decode('utf-8')
#
# '<person><name>Alice Doe</name><age>30</age><programmer>true</programmer>
# <car xsi:nil="true" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"/>
# <address><street>100 Larkin St.</street></address></person>'
# ```

# %%
# Practice rewrite for source example 18.34
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Practice Program: Excel-to-CSV Converter

# %% [markdown]
# #### Source example 18.35
#
# Checklist note: captured from section **Practice Program: Excel-to-CSV Converter**.
#
# **Context**
#
# 1. This example demonstrates spreadsheet automation with workbooks, sheets, cells, rows, or formulas.
# 2. Python treats a spreadsheet as structured data, so you can read, transform, and write it systematically.
# 3. This chapter connects directly to dictionaries, lists, strings, and files because CSV, JSON, and XML are structured-data formats.
# 4. This saves time when cleaning reports, generating invoices, updating trackers, or merging spreadsheet exports.
# 5. Always keep a backup copy before writing changes to an important spreadsheet.
#
# **Concept Flow**
#
# ```text
# CSV/JSON/XML file -> parser -> Python lists/dicts -> transform -> write/export
# ```
#
# **Code Preview**
#
# ```python
# for excel_file in os.listdir('.'):
#     # Skip non-xlsx files, load the workbook object.
#     for sheet_name in wb.sheetnames:
#         # Loop through every sheet in the workbook.
#         # Create the CSV filename from the Excel filename and sheet title.
#         # Create the csv.writer object for this CSV file.
#
#         # Loop through every row in the sheet.
#         for row_num in range(1, sheet.max_row + 1):
#             row_data = []    # Append each cell to this list.
#             # Loop through each cell in the row.
#             for col_num in range(1, sheet.max_column + 1):
#                 # Append each cell's data to row_data
#
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# for excel_file in os.listdir('.'):
#     # Skip non-xlsx files, load the workbook object.
#     for sheet_name in wb.sheetnames:
#         # Loop through every sheet in the workbook.
#         # Create the CSV filename from the Excel filename and sheet title.
#         # Create the csv.writer object for this CSV file.
#
#         # Loop through every row in the sheet.
#         for row_num in range(1, sheet.max_row + 1):
#             row_data = []    # Append each cell to this list.
#             # Loop through each cell in the row.
#             for col_num in range(1, sheet.max_column + 1):
#                 # Append each cell's data to row_data
#
#             # Write the row_data list to the CSV file.
#
#         csv_file.close()
# ```

# %%
# Practice rewrite for source example 18.35
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Chapter 18 Practice Checkpoint

# %%
# Chapter 18 checkpoint
# Choose three source examples from this chapter.
# For each one:
# 1. Explain what input it expects.
# 2. Explain what output or side effect it creates.
# 3. Rewrite it with safe sample data.

# %% [markdown]
# ### Extra Practice for Chapter 18

# %% [markdown]
# #### Practice: CSV to JSON transformation

# %%
import csv
import io
import json

csv_text = "name,score\nAda,98\nGrace,95\nLinus,91\n"
rows = list(csv.DictReader(io.StringIO(csv_text)))

for row in rows:
    row["score"] = int(row["score"])

print(json.dumps(rows, indent=2))

# %% [markdown]
# ## 19 KEEPING TIME, SCHEDULING TASKS, AND LAUNCHING PROGRAMS
#
# Source: https://automatetheboringstuff.com/3e/chapter19.html

# %% [markdown]
# ### The time Module

# %% [markdown]
# #### Source example 19.1
#
# Checklist note: captured from section **The time Module**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import time
#
# >>>
# time.time()
#
# 1773813875.3518236
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import time
#
# >>>
# time.time()
#
# 1773813875.3518236
# ```

# %%
# Practice rewrite for source example 19.1
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.2
#
# Checklist note: captured from section **The time Module**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import time
#
# >>>
# time.ctime()
#
# 'Tue Mar 17 11:05:38 2026'
# >>>
# this_moment = time.time()
#
# >>>
# time.ctime(this_moment)
#
# 'Tue Mar 17 11:05:45 2026'
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import time
#
# >>>
# time.ctime()
#
# 'Tue Mar 17 11:05:38 2026'
# >>>
# this_moment = time.time()
#
# >>>
# time.ctime(this_moment)
#
# 'Tue Mar 17 11:05:45 2026'
# ```

# %%
# Practice rewrite for source example 19.2
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.3
#
# Checklist note: captured from section **The time Module**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# # Measure how long it takes to multiply 100,000 numbers.
# import time
#
# ❶
#  def calculate_product():
#     # Calculate the product of the first 100,000 numbers.
#     product = 1
#     for i in range(1, 100001):
#         product = product * i
#     return product
#
#
# ❷
#  start_time = time.time()
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # Measure how long it takes to multiply 100,000 numbers.
# import time
#
# ❶
#  def calculate_product():
#     # Calculate the product of the first 100,000 numbers.
#     product = 1
#     for i in range(1, 100001):
#         product = product * i
#     return product
#
#
# ❷
#  start_time = time.time()
# result = calculate_product()
#
# ❸
#  end_time = time.time()
#
# ❹
#  print(f'It took {end_time – start_time} seconds to calculate.')
# ```

# %%
# Practice rewrite for source example 19.3
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.4
#
# Checklist note: captured from section **The time Module**.
#
# **Context**
#
# 1. This example belongs to the chapter on time, scheduling, and launching programs, and shows one small building block from the section `The time Module`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# It took 2.844162940979004 seconds to calculate.
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# It took 2.844162940979004 seconds to calculate.
# ```

# %%
# Practice rewrite for source example 19.4
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.5
#
# Checklist note: captured from section **The time Module**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import time
#
# >>>
# for i in range(3):
#
# ...
# ❶
#
# print('Tick')
#
# ...
# ❷
#
# # ... 25 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import time
#
# >>>
# for i in range(3):
#
# ...
# ❶
#
# print('Tick')
#
# ...
# ❷
#
# time.sleep(1)
#
# ...
# ❸
#
# print('Tock')
#
# ...
# ❹
#
# time.sleep(1)
#
# ...
# Tick
# Tock
# Tick
# Tock
# Tick
# Tock
#
# ❺
#  >>>
# time.sleep(5)
#
# >>>
# ```

# %%
# Practice rewrite for source example 19.5
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.6
#
# Checklist note: captured from section **The time Module**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# # A simple stopwatch program
# import time
#
# # Display the program's instructions.
# print('Press ENTER to begin and to mark laps. Ctrl-C quits.')
# input()  # Press Enter to begin.
# print('Started.')
# start_time = time.time()  # Get the first lap's start time.
# last_time = start_time
# lap_number = 1
#
# # TODO: Start tracking the lap times.
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # A simple stopwatch program
# import time
#
# # Display the program's instructions.
# print('Press ENTER to begin and to mark laps. Ctrl-C quits.')
# input()  # Press Enter to begin.
# print('Started.')
# start_time = time.time()  # Get the first lap's start time.
# last_time = start_time
# lap_number = 1
#
# # TODO: Start tracking the lap times.
# ```

# %%
# Practice rewrite for source example 19.6
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.7
#
# Checklist note: captured from section **The time Module**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# # A simple stopwatch program
# import time
#
#
# --snip--
#
#
#
# # Start tracking the lap times.
#
#
# ❶
#
# try:
# # ... 39 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # A simple stopwatch program
# import time
#
#
# --snip--
#
#
#
# # Start tracking the lap times.
#
#
# ❶
#
# try:
#
#
# ❷
#
# while True:
#
#
# input()
#
#
# ❸
#
# lap_time = round(time.time() – last_time, 2)
#
#
# ❹
#  total_time = round(time.time() – start_time, 2)
#
#
#
# ❺
#  print(f'Lap #{lap_number}: {total_time}({lap_time})', end='')
#
#
#         lap_number += 1
#
#
#         last_time = time.time()
# # Reset the last lap time.
#
# ❻
#
# except KeyboardInterrupt:
#
#
#     # Handle the Ctrl-C exception to keep its error message from displaying.
#
#
#     print('\nDone.')
# ```

# %%
# Practice rewrite for source example 19.7
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### The datetime Module

# %% [markdown]
# #### Source example 19.8
#
# Checklist note: captured from section **The datetime Module**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import datetime
#
#
# ❶
#  >>>
# datetime.datetime.now()
#
#
# ❷
#  datetime.datetime(2026, 2, 27, 11, 10, 49, 727297)
#
# ❸
#  >>>
# # ... 14 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import datetime
#
#
# ❶
#  >>>
# datetime.datetime.now()
#
#
# ❷
#  datetime.datetime(2026, 2, 27, 11, 10, 49, 727297)
#
# ❸
#  >>>
# dt = datetime.datetime(2026, 10, 21, 16, 29, 0)
#
#
# ❹
#  >>>
# dt.year, dt.month, dt.day
#
# (2026, 10, 21)
#
# ❺
#  >>>
# dt.hour, dt.minute, dt.second
#
# (16, 29, 0)
# ```

# %%
# Practice rewrite for source example 19.8
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.9
#
# Checklist note: captured from section **The datetime Module**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import datetime, time
#
# >>>
# datetime.datetime.fromtimestamp(1000000)
#
# datetime.datetime(1970, 1, 12, 5, 46, 40)
# >>>
# datetime.datetime.fromtimestamp(time.time())
#
# datetime.datetime(2026, 10, 21, 16, 30, 0, 604980)
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import datetime, time
#
# >>>
# datetime.datetime.fromtimestamp(1000000)
#
# datetime.datetime(1970, 1, 12, 5, 46, 40)
# >>>
# datetime.datetime.fromtimestamp(time.time())
#
# datetime.datetime(2026, 10, 21, 16, 30, 0, 604980)
# ```

# %%
# Practice rewrite for source example 19.9
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.10
#
# Checklist note: captured from section **The datetime Module**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import datetime
#
#
# ❶
#  >>>
# halloween_2026 = datetime.datetime(2026, 10, 31, 0, 0, 0)
#
#
# ❷
#  >>>
# new_years_2027 = datetime.datetime(2027, 1, 1, 0, 0, 0)
#
# >>>
# # ... 24 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import datetime
#
#
# ❶
#  >>>
# halloween_2026 = datetime.datetime(2026, 10, 31, 0, 0, 0)
#
#
# ❷
#  >>>
# new_years_2027 = datetime.datetime(2027, 1, 1, 0, 0, 0)
#
# >>>
# oct_31_2026 = datetime.datetime(2026, 10, 31, 0, 0, 0)
#
#
# ❸
#  >>>
# halloween_2026 == oct_31_2026
#
# True
#
# ❹
#  >>>
# halloween_2026 > new_years_2027
#
# False
#
# ❺
#  >>>
# new_years_2027 > halloween_2026
#
# True
# >>>
# new_years_2027 != oct_31_2026
#
# True
# ```

# %%
# Practice rewrite for source example 19.10
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.11
#
# Checklist note: captured from section **The datetime Module**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import datetime
#
#
# ❶
#  >>>
# delta = datetime.timedelta(days=11, hours=10, minutes=9, seconds=8)
#
#
# ❷
#  >>>
# delta.days, delta.seconds, delta.microseconds
#
# (11, 36548, 0)
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import datetime
#
#
# ❶
#  >>>
# delta = datetime.timedelta(days=11, hours=10, minutes=9, seconds=8)
#
#
# ❷
#  >>>
# delta.days, delta.seconds, delta.microseconds
#
# (11, 36548, 0)
# >>>
# delta.total_seconds()
#
# 986948.0
# >>>
# str(delta)
#
# '11 days, 10:09:08'
# ```

# %%
# Practice rewrite for source example 19.11
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.12
#
# Checklist note: captured from section **The datetime Module**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import datetime
#
# >>>
# now = datetime.datetime.now()
#
# >>>
# now
#
# datetime.datetime(2026, 12, 2, 18, 38, 50, 636181)
# >>>
# thousand_days = datetime.timedelta(days=1000)
#
# >>>
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import datetime
#
# >>>
# now = datetime.datetime.now()
#
# >>>
# now
#
# datetime.datetime(2026, 12, 2, 18, 38, 50, 636181)
# >>>
# thousand_days = datetime.timedelta(days=1000)
#
# >>>
# now + thousand_days
#
# datetime.datetime(2029, 8, 28, 18, 38, 50, 636181)
# ```

# %%
# Practice rewrite for source example 19.12
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.13
#
# Checklist note: captured from section **The datetime Module**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import datetime
#
#
# ❶
#  >>>
# oct_21st = datetime.datetime(2026, 10, 21, 16, 29, 0)
#
#
# ❷
#  >>>
# about_thirty_years = datetime.timedelta(days=365 * 30)
#
# >>>
# # ... 11 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import datetime
#
#
# ❶
#  >>>
# oct_21st = datetime.datetime(2026, 10, 21, 16, 29, 0)
#
#
# ❷
#  >>>
# about_thirty_years = datetime.timedelta(days=365 * 30)
#
# >>>
# oct_21st
#
# datetime.datetime(2026, 10, 21, 16, 29)
# >>>
# oct_21st – about_thirty_years
#
# datetime.datetime(1996, 10, 28, 16, 29)
# >>>
# oct_21st - (2 * about_thirty_years)
#
# datetime.datetime(1966, 11, 5, 16, 29)
# ```

# %%
# Practice rewrite for source example 19.13
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.14
#
# Checklist note: captured from section **The datetime Module**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# import datetime
# import time
# halloween_2039 = datetime.datetime(2039, 10, 31, 0, 0, 0)
# while datetime.datetime.now() < halloween_2039:
#     time.sleep(1)  # Wait 1 second before looping to check again.
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# import datetime
# import time
# halloween_2039 = datetime.datetime(2039, 10, 31, 0, 0, 0)
# while datetime.datetime.now() < halloween_2039:
#     time.sleep(1)  # Wait 1 second before looping to check again.
# ```

# %%
# Practice rewrite for source example 19.14
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.15
#
# Checklist note: captured from section **The datetime Module**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# oct_21st = datetime.datetime(2026, 10, 21, 16, 29, 0)
#
# >>>
# oct_21st.strftime('%Y/%m/%d %H:%M:%S')
#
# '2026/10/21 16:29:00'
# >>>
# oct_21st.strftime('%I:%M %p')
#
# '04:29 PM'
# >>>
# oct_21st.strftime("%B of '%y")
#
# # ... 1 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# oct_21st = datetime.datetime(2026, 10, 21, 16, 29, 0)
#
# >>>
# oct_21st.strftime('%Y/%m/%d %H:%M:%S')
#
# '2026/10/21 16:29:00'
# >>>
# oct_21st.strftime('%I:%M %p')
#
# '04:29 PM'
# >>>
# oct_21st.strftime("%B of '%y")
#
# "October of '26"
# ```

# %%
# Practice rewrite for source example 19.15
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.16
#
# Checklist note: captured from section **The datetime Module**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# ❶
#  >>>
# datetime.datetime.strptime('October 21, 2026', '%B %d, %Y')
#
# datetime.datetime(2026, 10, 21, 0, 0)
# >>>
# datetime.datetime.strptime('2026/10/21 16:29:00', '%Y/%m/%d %H:%M:%S')
#
# datetime.datetime(2026, 10, 21, 16, 29)
# >>>
# datetime.datetime.strptime("October of '26", "%B of '%y")
#
# datetime.datetime(2026, 10, 1, 0, 0)
# >>>
# # ... 11 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# ❶
#  >>>
# datetime.datetime.strptime('October 21, 2026', '%B %d, %Y')
#
# datetime.datetime(2026, 10, 21, 0, 0)
# >>>
# datetime.datetime.strptime('2026/10/21 16:29:00', '%Y/%m/%d %H:%M:%S')
#
# datetime.datetime(2026, 10, 21, 16, 29)
# >>>
# datetime.datetime.strptime("October of '26", "%B of '%y")
#
# datetime.datetime(2026, 10, 1, 0, 0)
# >>>
# datetime.datetime.strptime("November of '63", "%B of '%y")
#
#
# ❷
#  datetime.datetime(2063, 11, 1, 0, 0)
# >>>
# datetime.datetime.strptime("November of '73", "%B of '%y")
#
#
# ❸
#  datetime.datetime(1973, 11, 1, 0, 0)
# ```

# %%
# Practice rewrite for source example 19.16
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Launching Other Programs from Python

# %% [markdown]
# #### Source example 19.17
#
# Checklist note: captured from section **Launching Other Programs from Python**.
#
# **Context**
#
# 1. This example belongs to the chapter on time, scheduling, and launching programs, and shows one small building block from the section `Launching Other Programs from Python`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import subprocess
#
# >>>
# subprocess.run(['C:\\Windows\\System32\\calc.exe'])
#
# CompletedProcess(args=['C:\\Windows\\System32\\calc.exe'], returncode=0)
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import subprocess
#
# >>>
# subprocess.run(['C:\\Windows\\System32\\calc.exe'])
#
# CompletedProcess(args=['C:\\Windows\\System32\\calc.exe'], returncode=0)
# ```

# %%
# Practice rewrite for source example 19.17
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.18
#
# Checklist note: captured from section **Launching Other Programs from Python**.
#
# **Context**
#
# 1. This example belongs to the chapter on time, scheduling, and launching programs, and shows one small building block from the section `Launching Other Programs from Python`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import subprocess
#
# >>>
# subprocess.run(['/usr/bin/gnome-calculator'])
#
# CompletedProcess(args=['/usr/bin/gnome-calculator'], returncode=0)
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import subprocess
#
# >>>
# subprocess.run(['/usr/bin/gnome-calculator'])
#
# CompletedProcess(args=['/usr/bin/gnome-calculator'], returncode=0)
# ```

# %%
# Practice rewrite for source example 19.18
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.19
#
# Checklist note: captured from section **Launching Other Programs from Python**.
#
# **Context**
#
# 1. This example belongs to the chapter on time, scheduling, and launching programs, and shows one small building block from the section `Launching Other Programs from Python`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import subprocess
#
# >>>
# subprocess.run(['open', '/System/Applications/Calculator.app'])
#
# CompletedProcess(args=['open', '/System/Applications/Calculator.app'], returncode=0)
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import subprocess
#
# >>>
# subprocess.run(['open', '/System/Applications/Calculator.app'])
#
# CompletedProcess(args=['open', '/System/Applications/Calculator.app'], returncode=0)
# ```

# %%
# Practice rewrite for source example 19.19
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.20
#
# Checklist note: captured from section **Launching Other Programs from Python**.
#
# **Context**
#
# 1. This example belongs to the chapter on time, scheduling, and launching programs, and shows one small building block from the section `Launching Other Programs from Python`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import subprocess
#
# >>>
# calc_proc = subprocess.Popen(['C:\\Windows\\System32\\calc.exe'])
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import subprocess
#
# >>>
# calc_proc = subprocess.Popen(['C:\\Windows\\System32\\calc.exe'])
# ```

# %%
# Practice rewrite for source example 19.20
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.21
#
# Checklist note: captured from section **Launching Other Programs from Python**.
#
# **Context**
#
# 1. This example belongs to the chapter on time, scheduling, and launching programs, and shows one small building block from the section `Launching Other Programs from Python`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import subprocess
#
#
# ❶
#  >>>
# calc_proc = subprocess.Popen(['c:\\Windows\\System32\\calc.exe'])
#
#
# ❷
#  >>>
# calc_proc.poll() == None
#
# True
# # ... 10 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import subprocess
#
#
# ❶
#  >>>
# calc_proc = subprocess.Popen(['c:\\Windows\\System32\\calc.exe'])
#
#
# ❷
#  >>>
# calc_proc.poll() == None
#
# True
#
# ❸
#  >>>
# calc_proc.wait()
# # Doesn't return until Calculator closes
# 0
# >>>
# calc_proc.poll()
#
# 0
# ```

# %%
# Practice rewrite for source example 19.21
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.22
#
# Checklist note: captured from section **Launching Other Programs from Python**.
#
# **Context**
#
# 1. This example belongs to the chapter on time, scheduling, and launching programs, and shows one small building block from the section `Launching Other Programs from Python`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import subprocess
#
# >>>
# paint_proc = subprocess.Popen('c:\\Windows\\System32\\mspaint.exe')
#
# >>>
# paint_proc.kill()
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import subprocess
#
# >>>
# paint_proc = subprocess.Popen('c:\\Windows\\System32\\mspaint.exe')
#
# >>>
# paint_proc.kill()
# ```

# %%
# Practice rewrite for source example 19.22
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.23
#
# Checklist note: captured from section **Launching Other Programs from Python**.
#
# **Context**
#
# 1. This example belongs to the chapter on time, scheduling, and launching programs, and shows one small building block from the section `Launching Other Programs from Python`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# subprocess.run(['C:\\Windows\\notepad.exe', 'C:\\Users\Al\\hello.txt'])
#
# CompletedProcess(args=['C:\\Windows\\notepad.exe', 'C:\\Users\\Al\\hello.txt'], returncode=0)
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# subprocess.run(['C:\\Windows\\notepad.exe', 'C:\\Users\Al\\hello.txt'])
#
# CompletedProcess(args=['C:\\Windows\\notepad.exe', 'C:\\Users\\Al\\hello.txt'], returncode=0)
# ```

# %%
# Practice rewrite for source example 19.23
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.24
#
# Checklist note: captured from section **Launching Other Programs from Python**.
#
# **Context**
#
# 1. This example belongs to the chapter on time, scheduling, and launching programs, and shows one small building block from the section `Launching Other Programs from Python`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import subprocess
#
# >>>
# proc = subprocess.run(['ping', '-n', '4', 'nostarch.com'], capture_output=True, text=True)
#
# >>>
# print(proc.stdout)
#
# Pinging nostarch.com [104.20.120.46] with 32 bytes of data:
# Reply from 104.20.120.46: bytes=32 time=19ms TTL=59
# Reply from 104.20.120.46: bytes=32 time=17ms TTL=59
# Reply from 104.20.120.46: bytes=32 time=97ms TTL=59
# Reply from 104.20.120.46: bytes=32 time=217ms TTL=59
# # ... 5 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import subprocess
#
# >>>
# proc = subprocess.run(['ping', '-n', '4', 'nostarch.com'], capture_output=True, text=True)
#
# >>>
# print(proc.stdout)
#
# Pinging nostarch.com [104.20.120.46] with 32 bytes of data:
# Reply from 104.20.120.46: bytes=32 time=19ms TTL=59
# Reply from 104.20.120.46: bytes=32 time=17ms TTL=59
# Reply from 104.20.120.46: bytes=32 time=97ms TTL=59
# Reply from 104.20.120.46: bytes=32 time=217ms TTL=59
#
# Ping statistics for 104.20.120.46:
#     Packets: Sent = 4, Received = 4, Lost = 0 (0% loss),
# Approximate round trip times in milli-seconds:
#     Minimum = 17ms, Maximum = 217ms, Average = 87ms
# ```

# %%
# Practice rewrite for source example 19.24
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.25
#
# Checklist note: captured from section **Launching Other Programs from Python**.
#
# **Context**
#
# 1. This example belongs to the chapter on time, scheduling, and launching programs, and shows one small building block from the section `Launching Other Programs from Python`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# >>>
# file_obj = open('hello.txt', 'w')
# # Create a hello.txt file.
# >>>
# file_obj.write('Hello, world!')
#
# 13
# >>>
# file_obj.close()
#
# >>>
# import subprocess
#
# >>>
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# file_obj = open('hello.txt', 'w')
# # Create a hello.txt file.
# >>>
# file_obj.write('Hello, world!')
#
# 13
# >>>
# file_obj.close()
#
# >>>
# import subprocess
#
# >>>
# subprocess.run(['
# start
# ', 'hello.txt'], shell=True)
# ```

# %%
# Practice rewrite for source example 19.25
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.26
#
# Checklist note: captured from section **Launching Other Programs from Python**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# # https://autbor.com/simplecountdown.py - A simple countdown script
#
# import time, subprocess
#
#
# ❶
#  time_left = 60
# while time_left > 0:
#
# ❷
#  print(time_left)
#
# ❸
#  time.sleep(1)
# # ... 5 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # https://autbor.com/simplecountdown.py - A simple countdown script
#
# import time, subprocess
#
#
# ❶
#  time_left = 60
# while time_left > 0:
#
# ❷
#  print(time_left)
#
# ❸
#  time.sleep(1)
#
# ❹
#  time_left = time_left - 1
#
# # TODO: At the end of the countdown, play a sound file.
# ```

# %%
# Practice rewrite for source example 19.26
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.27
#
# Checklist note: captured from section **Launching Other Programs from Python**.
#
# **Context**
#
# 1. This example belongs to the chapter on time, scheduling, and launching programs, and shows one small building block from the section `Launching Other Programs from Python`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# # https://autbor.com/simplecountdown.py - A simple countdown script
#
#
# --snip--
#
#
#
# # At the end of the countdown, play a sound file.
#
#
# #subprocess.run(['start', 'alarm.wav'], shell=True)  # Windows
#
#
# #subprocess.run(['open', 'alarm.wav'])  # macOS and Linux
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# # https://autbor.com/simplecountdown.py - A simple countdown script
#
#
# --snip--
#
#
#
# # At the end of the countdown, play a sound file.
#
#
# #subprocess.run(['start', 'alarm.wav'], shell=True)  # Windows
#
#
# #subprocess.run(['open', 'alarm.wav'])  # macOS and Linux
# ```

# %%
# Practice rewrite for source example 19.27
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Practice Programs

# %% [markdown]
# #### Source example 19.28
#
# Checklist note: captured from section **Practice Programs**.
#
# **Context**
#
# 1. This example belongs to the chapter on time, scheduling, and launching programs, and shows one small building block from the section `Practice Programs`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# Lap #1: 3.56 (3.56)
# Lap #2: 8.63 (5.07)
# Lap #3: 17.68 (9.05)
# Lap #4: 19.11 (1.43)
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# Lap #1: 3.56 (3.56)
# Lap #2: 8.63 (5.07)
# Lap #3: 17.68 (9.05)
# Lap #4: 19.11 (1.43)
# ```

# %%
# Practice rewrite for source example 19.28
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 19.29
#
# Checklist note: captured from section **Practice Programs**.
#
# **Context**
#
# 1. This example belongs to the chapter on time, scheduling, and launching programs, and shows one small building block from the section `Practice Programs`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter adds time as a trigger or measurement around earlier scripts, turning one-off code into scheduled automation.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# current time/event -> wait/schedule/measure -> run task -> log/notify
# ```
#
# **Code Preview**
#
# ```python
# Lap # 1:   3.56 (  3.56)
# Lap # 2:   8.63 (  5.07)
# Lap # 3:  17.68 (  9.05)
# Lap # 4:  19.11 (  1.43)
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# Lap # 1:   3.56 (  3.56)
# Lap # 2:   8.63 (  5.07)
# Lap # 3:  17.68 (  9.05)
# Lap # 4:  19.11 (  1.43)
# ```

# %%
# Practice rewrite for source example 19.29
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Chapter 19 Practice Checkpoint

# %%
# Chapter 19 checkpoint
# Choose three source examples from this chapter.
# For each one:
# 1. Explain what input it expects.
# 2. Explain what output or side effect it creates.
# 3. Rewrite it with safe sample data.

# %% [markdown]
# ### Extra Practice for Chapter 19

# %% [markdown]
# #### Practice: elapsed time measurement

# %%
import time

start = time.time()
total = sum(range(1_000_000))
elapsed = time.time() - start

print("Total:", total)
print(f"Elapsed seconds: {elapsed:.4f}")

# %% [markdown]
# ## 20 SENDING EMAIL, TEXTS, AND PUSH NOTIFICATIONS
#
# Source: https://automatetheboringstuff.com/3e/chapter20.html

# %% [markdown]
# ### The Gmail API

# %% [markdown]
# #### Source example 20.1
#
# Checklist note: captured from section **The Gmail API**.
#
# **Context**
#
# 1. This example belongs to the chapter on sending email, texts, and push notifications, and shows one small building block from the section `The Gmail API`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects earlier automation to people: once a script finishes or fails, it can send a message with the result.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# script result -> format message -> authenticate service -> send notification
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezgmail
#
# >>>
# ezgmail.init()
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezgmail
#
# >>>
# ezgmail.init()
# ```

# %%
# Practice rewrite for source example 20.1
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 20.2
#
# Checklist note: captured from section **The Gmail API**.
#
# **Context**
#
# 1. This example demonstrates outbound or inbound notification automation.
# 2. Your script connects to a service, authenticates, formats a message, and sends or receives information.
# 3. This chapter connects earlier automation to people: once a script finishes or fails, it can send a message with the result.
# 4. Notifications turn scripts into useful assistants that can report results, failures, reminders, or alerts.
# 5. Use app passwords or tokens securely and avoid sending real messages while practicing.
#
# **Concept Flow**
#
# ```text
# script result -> format message -> authenticate service -> send notification
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezgmail
#
# >>>
# ezgmail.send('recipient@example.com', 'Subject line', 'Body of the email')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezgmail
#
# >>>
# ezgmail.send('recipient@example.com', 'Subject line', 'Body of the email')
# ```

# %%
# Practice rewrite for source example 20.2
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 20.3
#
# Checklist note: captured from section **The Gmail API**.
#
# **Context**
#
# 1. This example demonstrates outbound or inbound notification automation.
# 2. Your script connects to a service, authenticates, formats a message, and sends or receives information.
# 3. This chapter connects earlier automation to people: once a script finishes or fails, it can send a message with the result.
# 4. Notifications turn scripts into useful assistants that can report results, failures, reminders, or alerts.
# 5. Use app passwords or tokens securely and avoid sending real messages while practicing.
#
# **Concept Flow**
#
# ```text
# script result -> format message -> authenticate service -> send notification
# ```
#
# **Code Preview**
#
# ```python
# >>>
# ezgmail.send('recipient@example.com', 'Subject line', 'Body of the email',
#
#
# ['attachment1.jpg', 'attachment2.mp3'])
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# ezgmail.send('recipient@example.com', 'Subject line', 'Body of the email',
#
#
# ['attachment1.jpg', 'attachment2.mp3'])
# ```

# %%
# Practice rewrite for source example 20.3
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 20.4
#
# Checklist note: captured from section **The Gmail API**.
#
# **Context**
#
# 1. This example demonstrates outbound or inbound notification automation.
# 2. Your script connects to a service, authenticates, formats a message, and sends or receives information.
# 3. This chapter connects earlier automation to people: once a script finishes or fails, it can send a message with the result.
# 4. Notifications turn scripts into useful assistants that can report results, failures, reminders, or alerts.
# 5. Use app passwords or tokens securely and avoid sending real messages while practicing.
#
# **Concept Flow**
#
# ```text
# script result -> format message -> authenticate service -> send notification
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezgmail
#
# >>>
# ezgmail.send('recipient@example.com', 'Subject line', 'Body of the
#
#
# email', cc='friend@example.com', bcc='otherfriend@example.com,
#
#
# someoneelse@example.com')
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezgmail
#
# >>>
# ezgmail.send('recipient@example.com', 'Subject line', 'Body of the
#
#
# email', cc='friend@example.com', bcc='otherfriend@example.com,
#
#
# someoneelse@example.com')
# ```

# %%
# Practice rewrite for source example 20.4
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 20.5
#
# Checklist note: captured from section **The Gmail API**.
#
# **Context**
#
# 1. This example demonstrates outbound or inbound notification automation.
# 2. Your script connects to a service, authenticates, formats a message, and sends or receives information.
# 3. This chapter connects earlier automation to people: once a script finishes or fails, it can send a message with the result.
# 4. Notifications turn scripts into useful assistants that can report results, failures, reminders, or alerts.
# 5. Use app passwords or tokens securely and avoid sending real messages while practicing.
#
# **Concept Flow**
#
# ```text
# script result -> format message -> authenticate service -> send notification
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezgmail
#
# >>>
# ezgmail.EMAIL_ADDRESS
#
# 'example@gmail.com'
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezgmail
#
# >>>
# ezgmail.EMAIL_ADDRESS
#
# 'example@gmail.com'
# ```

# %%
# Practice rewrite for source example 20.5
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 20.6
#
# Checklist note: captured from section **The Gmail API**.
#
# **Context**
#
# 1. This example belongs to the chapter on sending email, texts, and push notifications, and shows one small building block from the section `The Gmail API`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects earlier automation to people: once a script finishes or fails, it can send a message with the result.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# script result -> format message -> authenticate service -> send notification
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezgmail
#
# >>>
# unread_threads = ezgmail.unread()
# # List of GmailThread objects
# >>>
# ezgmail.summary(unread_threads)
#
# Al, Jon - Do you want to watch RoboCop this weekend? - Dec 09
# Jon - Thanks for stopping me from buying Bitcoin. - Dec 09
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezgmail
#
# >>>
# unread_threads = ezgmail.unread()
# # List of GmailThread objects
# >>>
# ezgmail.summary(unread_threads)
#
# Al, Jon - Do you want to watch RoboCop this weekend? - Dec 09
# Jon - Thanks for stopping me from buying Bitcoin. - Dec 09
# ```

# %%
# Practice rewrite for source example 20.6
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 20.7
#
# Checklist note: captured from section **The Gmail API**.
#
# **Context**
#
# 1. This example demonstrates time-based programming: dates, durations, delays, or scheduled actions.
# 2. Programs need explicit time handling because humans use many time formats and computers need exact values.
# 3. This chapter connects earlier automation to people: once a script finishes or fails, it can send a message with the result.
# 4. This is important for reminders, backups, status checks, reports, and anything that runs regularly.
# 5. Be careful with time zones, long sleeps, and scripts that might keep running longer than expected.
#
# **Concept Flow**
#
# ```text
# script result -> format message -> authenticate service -> send notification
# ```
#
# **Code Preview**
#
# ```python
# >>>
# len(unread_threads)
#
# 2
# >>>
# str(unread_threads[0])
#
# "<GmailThread len=2 snippet= Do you want to watch RoboCop this weekend?'>"
# >>>
# len(unread_threads[0].messages)
#
# 2
# >>>
# str(unread_threads[0].messages[0])
# # ... 24 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# len(unread_threads)
#
# 2
# >>>
# str(unread_threads[0])
#
# "<GmailThread len=2 snippet= Do you want to watch RoboCop this weekend?'>"
# >>>
# len(unread_threads[0].messages)
#
# 2
# >>>
# str(unread_threads[0].messages[0])
#
# "<GmailMessage from='Al Sweigart <al@inventwithpython.com>' to='Jon Doe
# <example@gmail.com>' timestamp=datetime.datetime(2026, 12, 9, 13, 28, 48)
# subject='RoboCop' snippet='Do you want to watch RoboCop this weekend?'>"
# >>>
# unread_threads[0].messages[0].subject
#
# 'RoboCop'
# >>>
# unread_threads[0].messages[0].body
#
# 'Do you want to watch RoboCop this weekend?\r\n'
# >>>
# unread_threads[0].messages[0].timestamp
#
# datetime.datetime(2026, 12, 9, 13, 28, 48)
# >>>
# unread_threads[0].messages[0].sender
#
# 'Al Sweigart <al@inventwithpython.com>'
# >>>
# unread_threads[0].messages[0].recipient
#
# 'Jon Doe <example@gmail.com>'
# ```

# %%
# Practice rewrite for source example 20.7
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 20.8
#
# Checklist note: captured from section **The Gmail API**.
#
# **Context**
#
# 1. This example belongs to the chapter on sending email, texts, and push notifications, and shows one small building block from the section `The Gmail API`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects earlier automation to people: once a script finishes or fails, it can send a message with the result.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# script result -> format message -> authenticate service -> send notification
# ```
#
# **Code Preview**
#
# ```python
# >>>
# recent_threads = ezgmail.recent()
#
# >>>
# len(recent_threads)
#
# 25
# >>>
# recent_threads = ezgmail.recent(maxResults=100)
#
# >>>
# len(recent_threads)
#
# 46
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# recent_threads = ezgmail.recent()
#
# >>>
# len(recent_threads)
#
# 25
# >>>
# recent_threads = ezgmail.recent(maxResults=100)
#
# >>>
# len(recent_threads)
#
# 46
# ```

# %%
# Practice rewrite for source example 20.8
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 20.9
#
# Checklist note: captured from section **The Gmail API**.
#
# **Context**
#
# 1. This example belongs to the chapter on sending email, texts, and push notifications, and shows one small building block from the section `The Gmail API`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects earlier automation to people: once a script finishes or fails, it can send a message with the result.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# script result -> format message -> authenticate service -> send notification
# ```
#
# **Code Preview**
#
# ```python
# >>>
# result_threads = ezgmail.search('RoboCop')
#
# >>>
# len(result_threads)
#
#
# 1
# >>>
# ezgmail.summary(result_threads)
#
# Al, Jon - Do you want to watch RoboCop this weekend? - Dec 09
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# result_threads = ezgmail.search('RoboCop')
#
# >>>
# len(result_threads)
#
#
# 1
# >>>
# ezgmail.summary(result_threads)
#
# Al, Jon - Do you want to watch RoboCop this weekend? - Dec 09
# ```

# %%
# Practice rewrite for source example 20.9
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 20.10
#
# Checklist note: captured from section **The Gmail API**.
#
# **Context**
#
# 1. This example belongs to the chapter on sending email, texts, and push notifications, and shows one small building block from the section `The Gmail API`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects earlier automation to people: once a script finishes or fails, it can send a message with the result.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# script result -> format message -> authenticate service -> send notification
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import ezgmail
#
# >>>
# threads = ezgmail.search('vacation photos')
#
# >>>
# threads[0].messages[0].attachments
#
# ['tulips.jpg', 'canal.jpg', 'bicycles.jpg']
# >>>
# threads[0].messages[0].downloadAttachment('tulips.jpg')
#
# >>>
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import ezgmail
#
# >>>
# threads = ezgmail.search('vacation photos')
#
# >>>
# threads[0].messages[0].attachments
#
# ['tulips.jpg', 'canal.jpg', 'bicycles.jpg']
# >>>
# threads[0].messages[0].downloadAttachment('tulips.jpg')
#
# >>>
# threads[0].messages[0].downloadAllAttachments(downloadFolder='vacation2026')
#
# ['tulips.jpg', 'canal.jpg', 'bicycles.jpg']
# ```

# %%
# Practice rewrite for source example 20.10
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Push Notifications

# %% [markdown]
# #### Source example 20.11
#
# Checklist note: captured from section **Push Notifications**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter connects earlier automation to people: once a script finishes or fails, it can send a message with the result.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# script result -> format message -> authenticate service -> send notification
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import requests
#
# >>>
# requests.post('https://ntfy.sh/AlSweigartZPgxBQ42', 'Hello, world!')
#
# <Response [200]>
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import requests
#
# >>>
# requests.post('https://ntfy.sh/AlSweigartZPgxBQ42', 'Hello, world!')
#
# <Response [200]>
# ```

# %%
# Practice rewrite for source example 20.11
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 20.12
#
# Checklist note: captured from section **Push Notifications**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter connects earlier automation to people: once a script finishes or fails, it can send a message with the result.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# script result -> format message -> authenticate service -> send notification
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import requests
#
# >>>
# requests.post('https://ntfy.sh/AlSweigartZPgxBQ42', 'The rent is too high!',
#
#
# headers={'Title':'Important: Read this!', 'Tags': 'warning,neutral_face', 'Priority':'5'})
#
# <Response [200]>
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import requests
#
# >>>
# requests.post('https://ntfy.sh/AlSweigartZPgxBQ42', 'The rent is too high!',
#
#
# headers={'Title':'Important: Read this!', 'Tags': 'warning,neutral_face', 'Priority':'5'})
#
# <Response [200]>
# ```

# %%
# Practice rewrite for source example 20.12
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 20.13
#
# Checklist note: captured from section **Push Notifications**.
#
# **Context**
#
# 1. This example shows how Python can fetch web pages or inspect browser-visible HTML.
# 2. The core skill is separating page structure from page appearance so you can extract the data you need.
# 3. This chapter connects earlier automation to people: once a script finishes or fails, it can send a message with the result.
# 4. This is useful for monitoring prices, collecting public data, checking pages, or filling repetitive forms.
# 5. Respect site terms, rate limits, robots policies, and login/security boundaries.
#
# **Concept Flow**
#
# ```text
# script result -> format message -> authenticate service -> send notification
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import requests
#
# >>>
# resp = requests.get('https://ntfy.sh/AlSweigartZPgxBQ42/json?poll=1')
#
# >>>
# resp.text
#
# '{"id":"1jnHKeFNqwnS","time":1797823340,"expires":1797866540,"event":
# "message","topic":"AlSweigartZPgxBQ42","message":"Hello, world!"}\n
# {"id":"wZ22cjyKXw1F","time":1797823712,"expires":1797866912,"event":
# "message","topic":"AlSweigartZPgxBQ42","title":"Important: Read this!",
# "message":"The rent is too high!","priority":5,"tags":["warning",
# # ... 1 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import requests
#
# >>>
# resp = requests.get('https://ntfy.sh/AlSweigartZPgxBQ42/json?poll=1')
#
# >>>
# resp.text
#
# '{"id":"1jnHKeFNqwnS","time":1797823340,"expires":1797866540,"event":
# "message","topic":"AlSweigartZPgxBQ42","message":"Hello, world!"}\n
# {"id":"wZ22cjyKXw1F","time":1797823712,"expires":1797866912,"event":
# "message","topic":"AlSweigartZPgxBQ42","title":"Important: Read this!",
# "message":"The rent is too high!","priority":5,"tags":["warning",
# "neutral_face"]}\n'
# ```

# %%
# Practice rewrite for source example 20.13
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# #### Source example 20.14
#
# Checklist note: captured from section **Push Notifications**.
#
# **Context**
#
# 1. This example focuses on data-interchange files such as CSV, JSON, or XML.
# 2. These formats let programs exchange structured data using plain files.
# 3. This chapter connects earlier automation to people: once a script finishes or fails, it can send a message with the result.
# 4. They appear in exports, APIs, configuration files, logs, and integrations between tools.
# 5. Use parsers instead of manual string splitting when the format has quoting, nesting, or special characters.
#
# **Concept Flow**
#
# ```text
# script result -> format message -> authenticate service -> send notification
# ```
#
# **Code Preview**
#
# ```python
# >>>
# import json
#
# >>>
# notifications = []
#
# >>>
# for json_text in resp.text.splitlines():
#
# ...
# notifications.append(json.loads(json_text))
#
# ...
# >>>
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# >>>
# import json
#
# >>>
# notifications = []
#
# >>>
# for json_text in resp.text.splitlines():
#
# ...
# notifications.append(json.loads(json_text))
#
# ...
# >>>
# notifications[0]['message']
#
# 'Hello, world!'
# >>>
# notifications[1]['message']
#
# 'The rent is too high!'
# ```

# %%
# Practice rewrite for source example 20.14
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Practice Programs

# %% [markdown]
# #### Source example 20.15
#
# Checklist note: captured from section **Practice Programs**.
#
# **Context**
#
# 1. This example belongs to the chapter on sending email, texts, and push notifications, and shows one small building block from the section `Practice Programs`.
# 2. Pay attention to the library calls, the data type being passed in, and what the code returns or changes.
# 3. This chapter connects earlier automation to people: once a script finishes or fails, it can send a message with the result.
# 4. In real automation work, this kind of pattern lets you replace repeated manual steps with a script you can rerun.
# 5. Run it carefully: later chapters often touch real files, websites, accounts, or installed applications.
#
# **Concept Flow**
#
# ```text
# script result -> format message -> authenticate service -> send notification
# ```
#
# **Code Preview**
#
# ```python
# qbProcess = subprocess.Popen(['C:\\Program Files (x86)\\qBittorrent\\
# qbittorrent.exe', 'shakespeare_complete_works.torrent'])
# ```

# %% [markdown]
# Study transcript or context-dependent example:
#
# ```python
# qbProcess = subprocess.Popen(['C:\\Program Files (x86)\\qBittorrent\\
# qbittorrent.exe', 'shakespeare_complete_works.torrent'])
# ```

# %%
# Practice rewrite for source example 20.15
# Goal: recreate the idea using safe sample data before using real files/accounts.

# %% [markdown]
# ### Chapter 20 Practice Checkpoint

# %%
# Chapter 20 checkpoint
# Choose three source examples from this chapter.
# For each one:
# 1. Explain what input it expects.
# 2. Explain what output or side effect it creates.
# 3. Rewrite it with safe sample data.

# %% [markdown]
# ### Extra Practice for Chapter 20

# %% [markdown]
# #### Practice: notification message builder

# %%
def build_status_message(job_name, success, details):
    status = "SUCCESS" if success else "NEEDS ATTENTION"
    return f"[{status}] {job_name}: {details}"

print(build_status_message("Nightly backup", True, "12 files archived."))
print(build_status_message("Invoice scan", False, "Missing March invoice."))

# %% [markdown]
# ## Capstone: Office Automation Pipeline
#
# This project combines the next-ten-chapter skills without requiring real email,
# Google credentials, Excel files, or web access. It simulates a practical workflow:
# collect records, store them in SQLite, export JSON/CSV, and build a notification
# message.

# %%
raw_csv = '''name,department,hours,rate
Ada,Engineering,6,75
Grace,Operations,8,65
Linus,Infrastructure,5,80
'''

records = list(csv.DictReader(io.StringIO(raw_csv)))
for record in records:
    record["hours"] = int(record["hours"])
    record["rate"] = int(record["rate"])
    record["pay"] = record["hours"] * record["rate"]

pprint(records)

# %%
database = sqlite3.connect(":memory:")
cursor = database.cursor()
cursor.execute(
    "CREATE TABLE payroll (name TEXT, department TEXT, hours INTEGER, rate INTEGER, pay INTEGER)"
)
cursor.executemany(
    "INSERT INTO payroll VALUES (:name, :department, :hours, :rate, :pay)",
    records,
)

cursor.execute("SELECT department, SUM(pay) FROM payroll GROUP BY department")
pprint(cursor.fetchall())

# %%
output_dir = Path(tempfile.gettempdir()) / "atsbs_ch11_20_capstone"
output_dir.mkdir(exist_ok=True)

json_path = output_dir / "payroll.json"
csv_path = output_dir / "payroll.csv"

json_path.write_text(json.dumps(records, indent=2), encoding="utf-8")

with csv_path.open("w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=["name", "department", "hours", "rate", "pay"])
    writer.writeheader()
    writer.writerows(records)

print(json_path)
print(csv_path)

# %%
total_pay = sum(record["pay"] for record in records)
message = f"[SUCCESS] Payroll export complete: {len(records)} records, total ${total_pay:,.2f}."
print(message)

# Real-world next step:
# Send this message through email, SMS, Slack, or a push notification service.
