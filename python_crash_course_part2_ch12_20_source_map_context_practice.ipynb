# %% [markdown]
# # Python Crash Course Part II: Chapters 12-20 Source Map, Context, and Practice
#
# Source PDF: `C:\Users\jag\Downloads\Python Crash Course - 3rd Edition - Eric Matthes.pdf`
# Official script source: `https://github.com/ehmatthes/pcc_3e`
#
# This notebook follows the same study format as the Automate the Boring Stuff
# notebooks: source-map order, readable context, link to earlier ideas, ASCII
# concept flow, clean code preview, and safe practice/rewrite cells.
#
# Extraction note: chapter examples come from the official GitHub source files,
# with the PDF outline used for chapter titles and context. Appendix examples
# still come from PDF monospace snippets because the source repository does not
# provide matching appendix scripts. Use the coverage index to audit every block.

# %%
import json
import random
import re
import tempfile
from pathlib import Path
from pprint import pprint

print("Setup complete.")

# %% [markdown]
# ## Coverage Summary

# %% [markdown]
# - Chapter 12: A Ship That Fires Bullets: 15 captured source block(s) from official GitHub files under chapter_12
# - Chapter 13: Aliens!: 26 captured source block(s) from official GitHub files under chapter_13
# - Chapter 14: Scoring: 22 captured source block(s) from official GitHub files under chapter_14
# - Chapter 15: Generating Data: 33 captured source block(s) from official GitHub files under chapter_15
# - Chapter 16: Downloading Data: 24 captured source block(s) from official GitHub files under chapter_16
# - Chapter 17: Working with APIs: 15 captured source block(s) from official GitHub files under chapter_17
# - Chapter 18: Getting Started with Django: 48 captured source block(s) from official GitHub files under chapter_18
# - Chapter 19: User Accounts: 80 captured source block(s) from official GitHub files under chapter_19
# - Chapter 20: Styling and Deploying an App: 69 captured source block(s) from official GitHub files under chapter_20

# %% [markdown]
# ## Chapter 12: A Ship That Fires Bullets
#
# PDF pages: 380-421

# %% [markdown]
# ### Adding Ship Image

# %% [markdown]
# #### Source example 12.1
#
# Checklist note: captured from **Chapter 12: A Ship That Fires Bullets**, official GitHub source `chapter_12/adding_ship_image/alien_invasion.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This begins the project phase by combining classes, functions, loops, conditionals, and external libraries.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game class -> event loop -> draw/update screen -> repeat
# ```
#
# **Code Preview**
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
# from ship import Ship
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
#         pygame.init()
# # ... 30 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
# from ship import Ship
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
#         pygame.init()
#         self.clock = pygame.time.Clock()
#         self.settings = Settings()
#
#         self.screen = pygame.display.set_mode(
#             (self.settings.screen_width, self.settings.screen_height))
#         pygame.display.set_caption("Alien Invasion")
#
#         self.ship = Ship(self)
#
#     def run_game(self):
#         """Start the main loop for the game."""
#         while True:
#             # Watch for keyboard and mouse events.
#             for event in pygame.event.get():
#                 if event.type == pygame.QUIT:
#                     sys.exit()
#
#             # Redraw the screen during each pass through the loop.
#             self.screen.fill(self.settings.bg_color)
#             self.ship.blitme()
#
#             # Make the most recently drawn screen visible.
#             pygame.display.flip()
#             self.clock.tick(60)
#
#
# if __name__ == '__main__':
#     # Make a game instance, and run the game.
#     ai = AlienInvasion()
#     ai.run_game()
# ```

# %%
# Practice rewrite for source example 12.1
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 12.2
#
# Checklist note: captured from **Chapter 12: A Ship That Fires Bullets**, official GitHub source `chapter_12/adding_ship_image/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This begins the project phase by combining classes, functions, loops, conditionals, and external libraries.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game class -> event loop -> draw/update screen -> repeat
# ```
#
# **Code Preview**
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
# ```

# %%
# Practice rewrite for source example 12.2
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 12.3
#
# Checklist note: captured from **Chapter 12: A Ship That Fires Bullets**, official GitHub source `chapter_12/adding_ship_image/ship.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This begins the project phase by combining classes, functions, loops, conditionals, and external libraries.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game class -> event loop -> draw/update screen -> repeat
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
#         self.rect = self.image.get_rect()
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new ship at the bottom center of the screen.
#         self.rect.midbottom = self.screen_rect.midbottom
#
#     def blitme(self):
#         """Draw the ship at its current location."""
#         self.screen.blit(self.image, self.rect)
# ```

# %%
# Practice rewrite for source example 12.3
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Piloting The Ship

# %% [markdown]
# #### Source example 12.4
#
# Checklist note: captured from **Chapter 12: A Ship That Fires Bullets**, official GitHub source `chapter_12/piloting_the_ship/alien_invasion.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This begins the project phase by combining classes, functions, loops, conditionals, and external libraries.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game class -> event loop -> draw/update screen -> repeat
# ```
#
# **Code Preview**
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
# from ship import Ship
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
#         pygame.init()
# # ... 55 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
# from ship import Ship
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
#         pygame.init()
#         self.clock = pygame.time.Clock()
#         self.settings = Settings()
#
#         self.screen = pygame.display.set_mode(
#             (self.settings.screen_width, self.settings.screen_height))
#         pygame.display.set_caption("Alien Invasion")
#
#         self.ship = Ship(self)
#
#     def run_game(self):
#         """Start the main loop for the game."""
#         while True:
#             self._check_events()
#             self.ship.update()
#             self._update_screen()
#             self.clock.tick(60)
#
#     def _check_events(self):
#         """Respond to keypresses and mouse events."""
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 sys.exit()
#             elif event.type == pygame.KEYDOWN:
#                 self._check_keydown_events(event)
#             elif event.type == pygame.KEYUP:
#                 self._check_keyup_events(event)
#
#     def _check_keydown_events(self, event):
#         """Respond to keypresses."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = True
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = True
#         elif event.key == pygame.K_q:
#             sys.exit()
#
#     def _check_keyup_events(self, event):
#         """Respond to key releases."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = False
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = False
#
#     def _update_screen(self):
#         """Update images on the screen, and flip to the new screen."""
#         self.screen.fill(self.settings.bg_color)
#         self.ship.blitme()
#
#         pygame.display.flip()
#
#
# if __name__ == '__main__':
#     # Make a game instance, and run the game.
#     ai = AlienInvasion()
#     ai.run_game()
# ```

# %%
# Practice rewrite for source example 12.4
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 12.5
#
# Checklist note: captured from **Chapter 12: A Ship That Fires Bullets**, official GitHub source `chapter_12/piloting_the_ship/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This begins the project phase by combining classes, functions, loops, conditionals, and external libraries.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game class -> event loop -> draw/update screen -> repeat
# ```
#
# **Code Preview**
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_speed = 1.5
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_speed = 1.5
# ```

# %%
# Practice rewrite for source example 12.5
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 12.6
#
# Checklist note: captured from **Chapter 12: A Ship That Fires Bullets**, official GitHub source `chapter_12/piloting_the_ship/ship.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This begins the project phase by combining classes, functions, loops, conditionals, and external libraries.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game class -> event loop -> draw/update screen -> repeat
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
# # ... 26 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new ship at the bottom center of the screen.
#         self.rect.midbottom = self.screen_rect.midbottom
#
#         # Store a float for the ship's exact horizontal position.
#         self.x = float(self.rect.x)
#
#         # Movement flags; start with a ship that's not moving.
#         self.moving_right = False
#         self.moving_left = False
#
#     def update(self):
#         """Update the ship's position based on movement flags."""
#         # Update the ship's x value, not the rect.
#         if self.moving_right and self.rect.right < self.screen_rect.right:
#             self.x += self.settings.ship_speed
#         if self.moving_left and self.rect.left > 0:
#             self.x -= self.settings.ship_speed
#
#         # Update rect object from self.x.
#         self.rect.x = self.x
#
#     def blitme(self):
#         """Draw the ship at its current location."""
#         self.screen.blit(self.image, self.rect)
# ```

# %%
# Practice rewrite for source example 12.6
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Refactoring

# %% [markdown]
# #### Source example 12.7
#
# Checklist note: captured from **Chapter 12: A Ship That Fires Bullets**, official GitHub source `chapter_12/refactoring/alien_invasion.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This begins the project phase by combining classes, functions, loops, conditionals, and external libraries.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game class -> event loop -> draw/update screen -> repeat
# ```
#
# **Code Preview**
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
# from ship import Ship
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
#         pygame.init()
# # ... 33 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
# from ship import Ship
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
#         pygame.init()
#         self.clock = pygame.time.Clock()
#         self.settings = Settings()
#
#         self.screen = pygame.display.set_mode(
#             (self.settings.screen_width, self.settings.screen_height))
#         pygame.display.set_caption("Alien Invasion")
#
#         self.ship = Ship(self)
#
#     def run_game(self):
#         """Start the main loop for the game."""
#         while True:
#             self._check_events()
#             self._update_screen()
#             self.clock.tick(60)
#
#     def _check_events(self):
#         """Respond to keypresses and mouse events."""
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 sys.exit()
#
#     def _update_screen(self):
#         """Update images on the screen, and flip to the new screen."""
#         self.screen.fill(self.settings.bg_color)
#         self.ship.blitme()
#         pygame.display.flip()
#
#
# if __name__ == '__main__':
#     # Make a game instance, and run the game.
#     ai = AlienInvasion()
#     ai.run_game()
# ```

# %%
# Practice rewrite for source example 12.7
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 12.8
#
# Checklist note: captured from **Chapter 12: A Ship That Fires Bullets**, official GitHub source `chapter_12/refactoring/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This begins the project phase by combining classes, functions, loops, conditionals, and external libraries.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game class -> event loop -> draw/update screen -> repeat
# ```
#
# **Code Preview**
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
# ```

# %%
# Practice rewrite for source example 12.8
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 12.9
#
# Checklist note: captured from **Chapter 12: A Ship That Fires Bullets**, official GitHub source `chapter_12/refactoring/ship.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This begins the project phase by combining classes, functions, loops, conditionals, and external libraries.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game class -> event loop -> draw/update screen -> repeat
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
#         self.rect = self.image.get_rect()
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new ship at the bottom center of the screen.
#         self.rect.midbottom = self.screen_rect.midbottom
#
#     def blitme(self):
#         """Draw the ship at its current location."""
#         self.screen.blit(self.image, self.rect)
# ```

# %%
# Practice rewrite for source example 12.9
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Shooting Bullets

# %% [markdown]
# #### Source example 12.10
#
# Checklist note: captured from **Chapter 12: A Ship That Fires Bullets**, official GitHub source `chapter_12/shooting_bullets/alien_invasion.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This begins the project phase by combining classes, functions, loops, conditionals, and external libraries.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game class -> event loop -> draw/update screen -> repeat
# ```
#
# **Code Preview**
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
# from ship import Ship
# from bullet import Bullet
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
# # ... 78 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
# from ship import Ship
# from bullet import Bullet
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
#         pygame.init()
#         self.clock = pygame.time.Clock()
#         self.settings = Settings()
#
#         self.screen = pygame.display.set_mode(
#             (self.settings.screen_width, self.settings.screen_height))
#         pygame.display.set_caption("Alien Invasion")
#
#         self.ship = Ship(self)
#         self.bullets = pygame.sprite.Group()
#
#     def run_game(self):
#         """Start the main loop for the game."""
#         while True:
#             self._check_events()
#             self.ship.update()
#             self._update_bullets()
#             self._update_screen()
#             self.clock.tick(60)
#
#     def _check_events(self):
#         """Respond to keypresses and mouse events."""
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 sys.exit()
#             elif event.type == pygame.KEYDOWN:
#                 self._check_keydown_events(event)
#             elif event.type == pygame.KEYUP:
#                 self._check_keyup_events(event)
#
#     def _check_keydown_events(self, event):
#         """Respond to keypresses."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = True
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = True
#         elif event.key == pygame.K_q:
#             sys.exit()
#         elif event.key == pygame.K_SPACE:
#             self._fire_bullet()
#
#     def _check_keyup_events(self, event):
#         """Respond to key releases."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = False
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = False
#
#     def _fire_bullet(self):
#         """Create a new bullet and add it to the bullets group."""
#         if len(self.bullets) < self.settings.bullets_allowed:
#             new_bullet = Bullet(self)
#             self.bullets.add(new_bullet)
#
#     def _update_bullets(self):
#         """Update position of bullets and get rid of old bullets."""
#         # Update bullet positions.
#         self.bullets.update()
#
#         # Get rid of bullets that have disappeared.
#         for bullet in self.bullets.copy():
#             if bullet.rect.bottom <= 0:
#                 self.bullets.remove(bullet)
#
#     def _update_screen(self):
#         """Update images on the screen, and flip to the new screen."""
#         self.screen.fill(self.settings.bg_color)
#         for bullet in self.bullets.sprites():
#             bullet.draw_bullet()
#         self.ship.blitme()
#
#         pygame.display.flip()
#
#
# if __name__ == '__main__':
#     # Make a game instance, and run the game.
#     ai = AlienInvasion()
#     ai.run_game()
# ```

# %%
# Practice rewrite for source example 12.10
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 12.11
#
# Checklist note: captured from **Chapter 12: A Ship That Fires Bullets**, official GitHub source `chapter_12/shooting_bullets/bullet.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This begins the project phase by combining classes, functions, loops, conditionals, and external libraries.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game class -> event loop -> draw/update screen -> repeat
# ```
#
# **Code Preview**
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
# # ... 17 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
#         self.rect = pygame.Rect(0, 0, self.settings.bullet_width,
#             self.settings.bullet_height)
#         self.rect.midtop = ai_game.ship.rect.midtop
#
#         # Store the bullet's position as a float.
#         self.y = float(self.rect.y)
#
#     def update(self):
#         """Move the bullet up the screen."""
#         # Update the exact position of the bullet.
#         self.y -= self.settings.bullet_speed
#         # Update the rect position.
#         self.rect.y = self.y
#
#     def draw_bullet(self):
#         """Draw the bullet to the screen."""
#         pygame.draw.rect(self.screen, self.color, self.rect)
# ```

# %%
# Practice rewrite for source example 12.11
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 12.12
#
# Checklist note: captured from **Chapter 12: A Ship That Fires Bullets**, official GitHub source `chapter_12/shooting_bullets/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This begins the project phase by combining classes, functions, loops, conditionals, and external libraries.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game class -> event loop -> draw/update screen -> repeat
# ```
#
# **Code Preview**
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_speed = 1.5
#
#         # Bullet settings
# # ... 5 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_speed = 1.5
#
#         # Bullet settings
#         self.bullet_speed = 2.0
#         self.bullet_width = 3
#         self.bullet_height = 15
#         self.bullet_color = (60, 60, 60)
#         self.bullets_allowed = 3
# ```

# %%
# Practice rewrite for source example 12.12
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 12.13
#
# Checklist note: captured from **Chapter 12: A Ship That Fires Bullets**, official GitHub source `chapter_12/shooting_bullets/ship.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This begins the project phase by combining classes, functions, loops, conditionals, and external libraries.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game class -> event loop -> draw/update screen -> repeat
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
# # ... 26 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new ship at the bottom center of the screen.
#         self.rect.midbottom = self.screen_rect.midbottom
#
#         # Store a float for the ship's exact horizontal position.
#         self.x = float(self.rect.x)
#
#         # Movement flags; start with a ship that's not moving.
#         self.moving_right = False
#         self.moving_left = False
#
#     def update(self):
#         """Update the ship's position based on movement flags."""
#         # Update the ship's x value, not the rect.
#         if self.moving_right and self.rect.right < self.screen_rect.right:
#             self.x += self.settings.ship_speed
#         if self.moving_left and self.rect.left > 0:
#             self.x -= self.settings.ship_speed
#
#         # Update rect object from self.x.
#         self.rect.x = self.x
#
#     def blitme(self):
#         """Draw the ship at its current location."""
#         self.screen.blit(self.image, self.rect)
# ```

# %%
# Practice rewrite for source example 12.13
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Starting The Game Project

# %% [markdown]
# #### Source example 12.14
#
# Checklist note: captured from **Chapter 12: A Ship That Fires Bullets**, official GitHub source `chapter_12/starting_the_game_project/alien_invasion.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This begins the project phase by combining classes, functions, loops, conditionals, and external libraries.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game class -> event loop -> draw/update screen -> repeat
# ```
#
# **Code Preview**
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
#         pygame.init()
#         self.clock = pygame.time.Clock()
# # ... 26 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
#         pygame.init()
#         self.clock = pygame.time.Clock()
#         self.settings = Settings()
#
#         self.screen = pygame.display.set_mode(
#             (self.settings.screen_width, self.settings.screen_height))
#         pygame.display.set_caption("Alien Invasion")
#
#     def run_game(self):
#         """Start the main loop for the game."""
#         while True:
#             # Watch for keyboard and mouse events.
#             for event in pygame.event.get():
#                 if event.type == pygame.QUIT:
#                     sys.exit()
#
#             # Redraw the screen during each pass through the loop.
#             self.screen.fill(self.settings.bg_color)
#
#             # Make the most recently drawn screen visible.
#             pygame.display.flip()
#             self.clock.tick(60)
#
#
# if __name__ == '__main__':
#     # Make a game instance, and run the game.
#     ai = AlienInvasion()
#     ai.run_game()
# ```

# %%
# Practice rewrite for source example 12.14
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 12.15
#
# Checklist note: captured from **Chapter 12: A Ship That Fires Bullets**, official GitHub source `chapter_12/starting_the_game_project/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This begins the project phase by combining classes, functions, loops, conditionals, and external libraries.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game class -> event loop -> draw/update screen -> repeat
# ```
#
# **Code Preview**
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
# ```

# %%
# Practice rewrite for source example 12.15
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Chapter 12: A Ship That Fires Bullets Practice Checkpoint

# %% [markdown]
# #### Practice: project-safe rewrite

# %%
# Project chapters often depend on installed packages, files, servers, or assets.
# Rewrite one source example with fake data first:
# - replace file/API/game/web inputs with a small list or dictionary
# - print the planned action
# - only then connect it back to the real project
planned_steps = ["identify input", "transform state", "show or save result"]
for step in planned_steps:
    print(step)

# %% [markdown]
# ## Chapter 13: Aliens!
#
# PDF pages: 422-455

# %% [markdown]
# ### Building Alien Fleet

# %% [markdown]
# #### Source example 13.1
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/building_alien_fleet/alien.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
# from pygame.sprite import Sprite
#
#
# class Alien(Sprite):
#     """A class to represent a single alien in the fleet."""
#
#     def __init__(self, ai_game):
#         """Initialize the alien and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#
#         # Load the alien image and set its rect attribute.
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
# from pygame.sprite import Sprite
#
#
# class Alien(Sprite):
#     """A class to represent a single alien in the fleet."""
#
#     def __init__(self, ai_game):
#         """Initialize the alien and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#
#         # Load the alien image and set its rect attribute.
#         self.image = pygame.image.load('images/alien.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new alien near the top left of the screen.
#         self.rect.x = self.rect.width
#         self.rect.y = self.rect.height
#
#         # Store the alien's exact horizontal position.
#         self.x = float(self.rect.x)
# ```

# %%
# Practice rewrite for source example 13.1
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.2
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/building_alien_fleet/alien_invasion.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
# from ship import Ship
# from bullet import Bullet
# from alien import Alien
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
# # ... 108 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
# from ship import Ship
# from bullet import Bullet
# from alien import Alien
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
#         pygame.init()
#         self.clock = pygame.time.Clock()
#         self.settings = Settings()
#
#         self.screen = pygame.display.set_mode(
#             (self.settings.screen_width, self.settings.screen_height))
#         pygame.display.set_caption("Alien Invasion")
#
#         self.ship = Ship(self)
#         self.bullets = pygame.sprite.Group()
#         self.aliens = pygame.sprite.Group()
#
#         self._create_fleet()
#
#     def run_game(self):
#         """Start the main loop for the game."""
#         while True:
#             self._check_events()
#             self.ship.update()
#             self._update_bullets()
#             self._update_screen()
#             self.clock.tick(60)
#
#     def _check_events(self):
#         """Respond to keypresses and mouse events."""
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 sys.exit()
#             elif event.type == pygame.KEYDOWN:
#                 self._check_keydown_events(event)
#             elif event.type == pygame.KEYUP:
#                 self._check_keyup_events(event)
#
#     def _check_keydown_events(self, event):
#         """Respond to keypresses."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = True
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = True
#         elif event.key == pygame.K_q:
#             sys.exit()
#         elif event.key == pygame.K_SPACE:
#             self._fire_bullet()
#
#     def _check_keyup_events(self, event):
#         """Respond to key releases."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = False
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = False
#
#     def _fire_bullet(self):
#         """Create a new bullet and add it to the bullets group."""
#         if len(self.bullets) < self.settings.bullets_allowed:
#             new_bullet = Bullet(self)
#             self.bullets.add(new_bullet)
#
#     def _update_bullets(self):
#         """Update position of bullets and get rid of old bullets."""
#         # Update bullet positions.
#         self.bullets.update()
#
#         # Get rid of bullets that have disappeared.
#         for bullet in self.bullets.copy():
#             if bullet.rect.bottom <= 0:
#                 self.bullets.remove(bullet)
#
#     def _create_fleet(self):
#         """Create the fleet of aliens."""
#         # Create an alien and keep adding aliens until there's no room left.
#         # Spacing between aliens is one alien width and one alien height.
#         alien = Alien(self)
#         alien_width, alien_height = alien.rect.size
#
#         current_x, current_y = alien_width, alien_height
#         while current_y < (self.settings.screen_height - 3 * alien_height):
#             while current_x < (self.settings.screen_width - 2 * alien_width):
#                 self._create_alien(current_x, current_y)
#                 current_x += 2 * alien_width
#
#             # Finished a row; reset x value, and increment y value.
#             current_x = alien_width
#             current_y += 2 * alien_height
#
#     def _create_alien(self, x_position, y_position):
#         """Create an alien and place it in the fleet."""
#         new_alien = Alien(self)
#         new_alien.x = x_position
#         new_alien.rect.x = x_position
#         new_alien.rect.y = y_position
#         self.aliens.add(new_alien)
#
#     def _update_screen(self):
#         """Update images on the screen, and flip to the new screen."""
#         self.screen.fill(self.settings.bg_color)
#         for bullet in self.bullets.sprites():
#             bullet.draw_bullet()
#         self.ship.blitme()
#         self.aliens.draw(self.screen)
#
#         pygame.display.flip()
#
#
# if __name__ == '__main__':
#     # Make a game instance, and run the game.
#     ai = AlienInvasion()
#     ai.run_game()
# ```

# %%
# Practice rewrite for source example 13.2
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.3
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/building_alien_fleet/bullet.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
# # ... 17 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
#         self.rect = pygame.Rect(0, 0, self.settings.bullet_width,
#             self.settings.bullet_height)
#         self.rect.midtop = ai_game.ship.rect.midtop
#
#         # Store the bullet's position as a float.
#         self.y = float(self.rect.y)
#
#     def update(self):
#         """Move the bullet up the screen."""
#         # Update the exact position of the bullet.
#         self.y -= self.settings.bullet_speed
#         # Update the rect position.
#         self.rect.y = self.y
#
#     def draw_bullet(self):
#         """Draw the bullet to the screen."""
#         pygame.draw.rect(self.screen, self.color, self.rect)
# ```

# %%
# Practice rewrite for source example 13.3
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.4
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/building_alien_fleet/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_speed = 1.5
#
#         # Bullet settings
# # ... 5 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_speed = 1.5
#
#         # Bullet settings
#         self.bullet_speed = 2.0
#         self.bullet_width = 3
#         self.bullet_height = 15
#         self.bullet_color = (60, 60, 60)
#         self.bullets_allowed = 3
# ```

# %%
# Practice rewrite for source example 13.4
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.5
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/building_alien_fleet/ship.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
# # ... 26 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new ship at the bottom center of the screen.
#         self.rect.midbottom = self.screen_rect.midbottom
#
#         # Store a float for the ship's exact horizontal position.
#         self.x = float(self.rect.x)
#
#         # Movement flags; start with a ship that's not moving.
#         self.moving_right = False
#         self.moving_left = False
#
#     def update(self):
#         """Update the ship's position based on movement flags."""
#         # Update the ship's x value, not the rect.
#         if self.moving_right and self.rect.right < self.screen_rect.right:
#             self.x += self.settings.ship_speed
#         if self.moving_left and self.rect.left > 0:
#             self.x -= self.settings.ship_speed
#
#         # Update rect object from self.x.
#         self.rect.x = self.x
#
#     def blitme(self):
#         """Draw the ship at its current location."""
#         self.screen.blit(self.image, self.rect)
# ```

# %%
# Practice rewrite for source example 13.5
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Creating First Alien

# %% [markdown]
# #### Source example 13.6
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/creating_first_alien/alien.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
# from pygame.sprite import Sprite
#
#
# class Alien(Sprite):
#     """A class to represent a single alien in the fleet."""
#
#     def __init__(self, ai_game):
#         """Initialize the alien and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#
#         # Load the alien image and set its rect attribute.
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
# from pygame.sprite import Sprite
#
#
# class Alien(Sprite):
#     """A class to represent a single alien in the fleet."""
#
#     def __init__(self, ai_game):
#         """Initialize the alien and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#
#         # Load the alien image and set its rect attribute.
#         self.image = pygame.image.load('images/alien.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new alien near the top left of the screen.
#         self.rect.x = self.rect.width
#         self.rect.y = self.rect.height
#
#         # Store the alien's exact horizontal position.
#         self.x = float(self.rect.x)
# ```

# %%
# Practice rewrite for source example 13.6
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.7
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/creating_first_alien/alien_invasion.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
# from ship import Ship
# from bullet import Bullet
# from alien import Alien
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
# # ... 89 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
# from ship import Ship
# from bullet import Bullet
# from alien import Alien
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
#         pygame.init()
#         self.clock = pygame.time.Clock()
#         self.settings = Settings()
#
#         self.screen = pygame.display.set_mode(
#             (self.settings.screen_width, self.settings.screen_height))
#         pygame.display.set_caption("Alien Invasion")
#
#         self.ship = Ship(self)
#         self.bullets = pygame.sprite.Group()
#         self.aliens = pygame.sprite.Group()
#
#         self._create_fleet()
#
#     def run_game(self):
#         """Start the main loop for the game."""
#         while True:
#             self._check_events()
#             self.ship.update()
#             self._update_bullets()
#             self._update_screen()
#             self.clock.tick(60)
#
#     def _check_events(self):
#         """Respond to keypresses and mouse events."""
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 sys.exit()
#             elif event.type == pygame.KEYDOWN:
#                 self._check_keydown_events(event)
#             elif event.type == pygame.KEYUP:
#                 self._check_keyup_events(event)
#
#     def _check_keydown_events(self, event):
#         """Respond to keypresses."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = True
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = True
#         elif event.key == pygame.K_q:
#             sys.exit()
#         elif event.key == pygame.K_SPACE:
#             self._fire_bullet()
#
#     def _check_keyup_events(self, event):
#         """Respond to key releases."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = False
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = False
#
#     def _fire_bullet(self):
#         """Create a new bullet and add it to the bullets group."""
#         if len(self.bullets) < self.settings.bullets_allowed:
#             new_bullet = Bullet(self)
#             self.bullets.add(new_bullet)
#
#     def _update_bullets(self):
#         """Update position of bullets and get rid of old bullets."""
#         # Update bullet positions.
#         self.bullets.update()
#
#         # Get rid of bullets that have disappeared.
#         for bullet in self.bullets.copy():
#             if bullet.rect.bottom <= 0:
#                 self.bullets.remove(bullet)
#
#     def _create_fleet(self):
#         """Create the fleet of aliens."""
#         # Make an alien.
#         alien = Alien(self)
#         self.aliens.add(alien)
#
#     def _update_screen(self):
#         """Update images on the screen, and flip to the new screen."""
#         self.screen.fill(self.settings.bg_color)
#         for bullet in self.bullets.sprites():
#             bullet.draw_bullet()
#         self.ship.blitme()
#         self.aliens.draw(self.screen)
#
#         pygame.display.flip()
#
#
# if __name__ == '__main__':
#     # Make a game instance, and run the game.
#     ai = AlienInvasion()
#     ai.run_game()
# ```

# %%
# Practice rewrite for source example 13.7
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.8
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/creating_first_alien/bullet.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
# # ... 17 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
#         self.rect = pygame.Rect(0, 0, self.settings.bullet_width,
#             self.settings.bullet_height)
#         self.rect.midtop = ai_game.ship.rect.midtop
#
#         # Store the bullet's position as a float.
#         self.y = float(self.rect.y)
#
#     def update(self):
#         """Move the bullet up the screen."""
#         # Update the exact position of the bullet.
#         self.y -= self.settings.bullet_speed
#         # Update the rect position.
#         self.rect.y = self.y
#
#     def draw_bullet(self):
#         """Draw the bullet to the screen."""
#         pygame.draw.rect(self.screen, self.color, self.rect)
# ```

# %%
# Practice rewrite for source example 13.8
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.9
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/creating_first_alien/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_speed = 1.5
#
#         # Bullet settings
# # ... 5 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_speed = 1.5
#
#         # Bullet settings
#         self.bullet_speed = 2.0
#         self.bullet_width = 3
#         self.bullet_height = 15
#         self.bullet_color = (60, 60, 60)
#         self.bullets_allowed = 3
# ```

# %%
# Practice rewrite for source example 13.9
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.10
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/creating_first_alien/ship.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
# # ... 26 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new ship at the bottom center of the screen.
#         self.rect.midbottom = self.screen_rect.midbottom
#
#         # Store a float for the ship's exact horizontal position.
#         self.x = float(self.rect.x)
#
#         # Movement flags; start with a ship that's not moving.
#         self.moving_right = False
#         self.moving_left = False
#
#     def update(self):
#         """Update the ship's position based on movement flags."""
#         # Update the ship's x value, not the rect.
#         if self.moving_right and self.rect.right < self.screen_rect.right:
#             self.x += self.settings.ship_speed
#         if self.moving_left and self.rect.left > 0:
#             self.x -= self.settings.ship_speed
#
#         # Update rect object from self.x.
#         self.rect.x = self.x
#
#     def blitme(self):
#         """Draw the ship at its current location."""
#         self.screen.blit(self.image, self.rect)
# ```

# %%
# Practice rewrite for source example 13.10
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Ending The Game

# %% [markdown]
# #### Source example 13.11
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/ending_the_game/alien.py`.
#
# **Context**
#
# 1. This example demonstrates decision-making, where the program chooses a path based on data.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
# from pygame.sprite import Sprite
#
#
# class Alien(Sprite):
#     """A class to represent a single alien in the fleet."""
#
#     def __init__(self, ai_game):
#         """Initialize the alien and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#
# # ... 20 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
# from pygame.sprite import Sprite
#
#
# class Alien(Sprite):
#     """A class to represent a single alien in the fleet."""
#
#     def __init__(self, ai_game):
#         """Initialize the alien and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#
#         # Load the alien image and set its rect attribute.
#         self.image = pygame.image.load('images/alien.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new alien near the top left of the screen.
#         self.rect.x = self.rect.width
#         self.rect.y = self.rect.height
#
#         # Store the alien's exact horizontal position.
#         self.x = float(self.rect.x)
#
#     def check_edges(self):
#         """Return True if alien is at edge of screen."""
#         screen_rect = self.screen.get_rect()
#         return (self.rect.right >= screen_rect.right) or (self.rect.left <= 0)
#
#     def update(self):
#         """Move the alien right or left."""
#         self.x += self.settings.alien_speed * self.settings.fleet_direction
#         self.rect.x = self.x
# ```

# %%
# Practice rewrite for source example 13.11
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.12
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/ending_the_game/alien_invasion.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import sys
# from time import sleep
#
# import pygame
#
# from settings import Settings
# from game_stats import GameStats
# from ship import Ship
# from bullet import Bullet
# from alien import Alien
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
# # ... 187 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import sys
# from time import sleep
#
# import pygame
#
# from settings import Settings
# from game_stats import GameStats
# from ship import Ship
# from bullet import Bullet
# from alien import Alien
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
#         pygame.init()
#         self.clock = pygame.time.Clock()
#         self.settings = Settings()
#
#         self.screen = pygame.display.set_mode(
#             (self.settings.screen_width, self.settings.screen_height))
#         pygame.display.set_caption("Alien Invasion")
#
#         # Create an instance to store game statistics.
#         self.stats = GameStats(self)
#
#         self.ship = Ship(self)
#         self.bullets = pygame.sprite.Group()
#         self.aliens = pygame.sprite.Group()
#
#         self._create_fleet()
#
#         # Start Alien Invasion in an active state.
#         self.game_active = True
#
#     def run_game(self):
#         """Start the main loop for the game."""
#         while True:
#             self._check_events()
#
#             if self.game_active:
#                 self.ship.update()
#                 self._update_bullets()
#                 self._update_aliens()
#
#             self._update_screen()
#             self.clock.tick(60)
#
#     def _check_events(self):
#         """Respond to keypresses and mouse events."""
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 sys.exit()
#             elif event.type == pygame.KEYDOWN:
#                 self._check_keydown_events(event)
#             elif event.type == pygame.KEYUP:
#                 self._check_keyup_events(event)
#
#     def _check_keydown_events(self, event):
#         """Respond to keypresses."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = True
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = True
#         elif event.key == pygame.K_q:
#             sys.exit()
#         elif event.key == pygame.K_SPACE:
#             self._fire_bullet()
#
#     def _check_keyup_events(self, event):
#         """Respond to key releases."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = False
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = False
#
#     def _fire_bullet(self):
#         """Create a new bullet and add it to the bullets group."""
#         if len(self.bullets) < self.settings.bullets_allowed:
#             new_bullet = Bullet(self)
#             self.bullets.add(new_bullet)
#
#     def _update_bullets(self):
#         """Update position of bullets and get rid of old bullets."""
#         # Update bullet positions.
#         self.bullets.update()
#
#         # Get rid of bullets that have disappeared.
#         for bullet in self.bullets.copy():
#             if bullet.rect.bottom <= 0:
#                 self.bullets.remove(bullet)
#
#         self._check_bullet_alien_collisions()
#
#
#     def _check_bullet_alien_collisions(self):
#         """Respond to bullet-alien collisions."""
#         # Remove any bullets and aliens that have collided.
#         collisions = pygame.sprite.groupcollide(
#                 self.bullets, self.aliens, True, True)
#
#         if not self.aliens:
#             # Destroy existing bullets and create new fleet.
#             self.bullets.empty()
#             self._create_fleet()
#
#     def _ship_hit(self):
#         """Respond to the ship being hit by an alien."""
#         if self.stats.ships_left > 0:
#             # Decrement ships_left.
#             self.stats.ships_left -= 1
#
#             # Get rid of any remaining bullets and aliens.
#             self.bullets.empty()
#             self.aliens.empty()
#
#             # Create a new fleet and center the ship.
#             self._create_fleet()
#             self.ship.center_ship()
#
#             # Pause.
#             sleep(0.5)
#         else:
#             self.game_active = False
#
#     def _update_aliens(self):
#         """Update the positions of all aliens in the fleet."""
#         """Check if the fleet is at an edge, then update positions."""
#         self._check_fleet_edges()
#         self.aliens.update()
#
#         # Look for alien-ship collisions.
#         if pygame.sprite.spritecollideany(self.ship, self.aliens):
#             self._ship_hit()
#
#         # Look for aliens hitting the bottom of the screen.
#         self._check_aliens_bottom()
#
#     def _check_aliens_bottom(self):
#         """Check if any aliens have reached the bottom of the screen."""
#         for alien in self.aliens.sprites():
#             if alien.rect.bottom >= self.settings.screen_height:
#                 # Treat this the same as if the ship got hit.
#                 self._ship_hit()
#                 break
#
#     def _create_fleet(self):
#         """Create the fleet of aliens."""
#         # Create an alien and keep adding aliens until there's no room left.
#         # Spacing between aliens is one alien width and one alien height.
#         alien = Alien(self)
#         alien_width, alien_height = alien.rect.size
#
#         current_x, current_y = alien_width, alien_height
#         while current_y < (self.settings.screen_height - 3 * alien_height):
#             while current_x < (self.settings.screen_width - 2 * alien_width):
#                 self._create_alien(current_x, current_y)
#                 current_x += 2 * alien_width
#
#             # Finished a row; reset x value, and increment y value.
#             current_x = alien_width
#             current_y += 2 * alien_height
#
#     def _create_alien(self, x_position, y_position):
#         """Create an alien and place it in the fleet."""
#         new_alien = Alien(self)
#         new_alien.x = x_position
#         new_alien.rect.x = x_position
#         new_alien.rect.y = y_position
#         self.aliens.add(new_alien)
#
#     def _check_fleet_edges(self):
#         """Respond appropriately if any aliens have reached an edge."""
#         for alien in self.aliens.sprites():
#             if alien.check_edges():
#                 self._change_fleet_direction()
#                 break
#
#     def _change_fleet_direction(self):
#         """Drop the entire fleet and change the fleet's direction."""
#         for alien in self.aliens.sprites():
#             alien.rect.y += self.settings.fleet_drop_speed
#         self.settings.fleet_direction *= -1
#
#     def _update_screen(self):
#         """Update images on the screen, and flip to the new screen."""
#         self.screen.fill(self.settings.bg_color)
#         for bullet in self.bullets.sprites():
#             bullet.draw_bullet()
#         self.ship.blitme()
#         self.aliens.draw(self.screen)
#
#         pygame.display.flip()
#
#
# if __name__ == '__main__':
#     # Make a game instance, and run the game.
#     ai = AlienInvasion()
#     ai.run_game()
# ```

# %%
# Practice rewrite for source example 13.12
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.13
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/ending_the_game/bullet.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
# # ... 17 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
#         self.rect = pygame.Rect(0, 0, self.settings.bullet_width,
#             self.settings.bullet_height)
#         self.rect.midtop = ai_game.ship.rect.midtop
#
#         # Store the bullet's position as a float.
#         self.y = float(self.rect.y)
#
#     def update(self):
#         """Move the bullet up the screen."""
#         # Update the exact position of the bullet.
#         self.y -= self.settings.bullet_speed
#         # Update the rect position.
#         self.rect.y = self.y
#
#     def draw_bullet(self):
#         """Draw the bullet to the screen."""
#         pygame.draw.rect(self.screen, self.color, self.rect)
# ```

# %%
# Practice rewrite for source example 13.13
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.14
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/ending_the_game/game_stats.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# class GameStats:
#     """Track statistics for Alien Invasion."""
#
#     def __init__(self, ai_game):
#         """Initialize statistics."""
#         self.settings = ai_game.settings
#         self.reset_stats()
#
#     def reset_stats(self):
#         """Initialize statistics that can change during the game."""
#         self.ships_left = self.settings.ship_limit
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# class GameStats:
#     """Track statistics for Alien Invasion."""
#
#     def __init__(self, ai_game):
#         """Initialize statistics."""
#         self.settings = ai_game.settings
#         self.reset_stats()
#
#     def reset_stats(self):
#         """Initialize statistics that can change during the game."""
#         self.ships_left = self.settings.ship_limit
# ```

# %%
# Practice rewrite for source example 13.14
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.15
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/ending_the_game/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_speed = 1.5
#         self.ship_limit = 3
#
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_speed = 1.5
#         self.ship_limit = 3
#
#         # Bullet settings
#         self.bullet_speed = 2.5
#         self.bullet_width = 3
#         self.bullet_height = 15
#         self.bullet_color = (60, 60, 60)
#         self.bullets_allowed = 3
#
#         # Alien settings.
#         self.alien_speed = 1.0
#         self.fleet_drop_speed = 10
#         # fleet_direction of 1 represents right; -1 represents left.
#         self.fleet_direction = 1
# ```

# %%
# Practice rewrite for source example 13.15
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.16
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/ending_the_game/ship.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
# # ... 31 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new ship at the bottom center of the screen.
#         self.rect.midbottom = self.screen_rect.midbottom
#
#         # Store a float for the ship's exact horizontal position.
#         self.x = float(self.rect.x)
#
#         # Movement flags; start with a ship that's not moving.
#         self.moving_right = False
#         self.moving_left = False
#
#     def center_ship(self):
#         """Center the ship on the screen."""
#         self.rect.midbottom = self.screen_rect.midbottom
#         self.x = float(self.rect.x)
#
#     def update(self):
#         """Update the ship's position based on movement flags."""
#         # Update the ship's x value, not the rect.
#         if self.moving_right and self.rect.right < self.screen_rect.right:
#             self.x += self.settings.ship_speed
#         if self.moving_left and self.rect.left > 0:
#             self.x -= self.settings.ship_speed
#
#         # Update rect object from self.x.
#         self.rect.x = self.x
#
#     def blitme(self):
#         """Draw the ship at its current location."""
#         self.screen.blit(self.image, self.rect)
# ```

# %%
# Practice rewrite for source example 13.16
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Making Fleet Move

# %% [markdown]
# #### Source example 13.17
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/making_fleet_move/alien.py`.
#
# **Context**
#
# 1. This example demonstrates decision-making, where the program chooses a path based on data.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
# from pygame.sprite import Sprite
#
#
# class Alien(Sprite):
#     """A class to represent a single alien in the fleet."""
#
#     def __init__(self, ai_game):
#         """Initialize the alien and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#
# # ... 20 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
# from pygame.sprite import Sprite
#
#
# class Alien(Sprite):
#     """A class to represent a single alien in the fleet."""
#
#     def __init__(self, ai_game):
#         """Initialize the alien and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#
#         # Load the alien image and set its rect attribute.
#         self.image = pygame.image.load('images/alien.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new alien near the top left of the screen.
#         self.rect.x = self.rect.width
#         self.rect.y = self.rect.height
#
#         # Store the alien's exact horizontal position.
#         self.x = float(self.rect.x)
#
#     def check_edges(self):
#         """Return True if alien is at edge of screen."""
#         screen_rect = self.screen.get_rect()
#         return (self.rect.right >= screen_rect.right) or (self.rect.left <= 0)
#
#     def update(self):
#         """Move the alien right or left."""
#         self.x += self.settings.alien_speed * self.settings.fleet_direction
#         self.rect.x = self.x
# ```

# %%
# Practice rewrite for source example 13.17
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.18
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/making_fleet_move/alien_invasion.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
# from ship import Ship
# from bullet import Bullet
# from alien import Alien
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
# # ... 128 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
# from ship import Ship
# from bullet import Bullet
# from alien import Alien
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
#         pygame.init()
#         self.clock = pygame.time.Clock()
#         self.settings = Settings()
#
#         self.screen = pygame.display.set_mode(
#             (self.settings.screen_width, self.settings.screen_height))
#         pygame.display.set_caption("Alien Invasion")
#
#         self.ship = Ship(self)
#         self.bullets = pygame.sprite.Group()
#         self.aliens = pygame.sprite.Group()
#
#         self._create_fleet()
#
#     def run_game(self):
#         """Start the main loop for the game."""
#         while True:
#             self._check_events()
#             self.ship.update()
#             self._update_bullets()
#             self._update_aliens()
#             self._update_screen()
#             self.clock.tick(60)
#
#     def _check_events(self):
#         """Respond to keypresses and mouse events."""
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 sys.exit()
#             elif event.type == pygame.KEYDOWN:
#                 self._check_keydown_events(event)
#             elif event.type == pygame.KEYUP:
#                 self._check_keyup_events(event)
#
#     def _check_keydown_events(self, event):
#         """Respond to keypresses."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = True
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = True
#         elif event.key == pygame.K_q:
#             sys.exit()
#         elif event.key == pygame.K_SPACE:
#             self._fire_bullet()
#
#     def _check_keyup_events(self, event):
#         """Respond to key releases."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = False
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = False
#
#     def _fire_bullet(self):
#         """Create a new bullet and add it to the bullets group."""
#         if len(self.bullets) < self.settings.bullets_allowed:
#             new_bullet = Bullet(self)
#             self.bullets.add(new_bullet)
#
#     def _update_bullets(self):
#         """Update position of bullets and get rid of old bullets."""
#         # Update bullet positions.
#         self.bullets.update()
#
#         # Get rid of bullets that have disappeared.
#         for bullet in self.bullets.copy():
#             if bullet.rect.bottom <= 0:
#                 self.bullets.remove(bullet)
#
#     def _update_aliens(self):
#         """Update the positions of all aliens in the fleet."""
#         """Check if the fleet is at an edge, then update positions."""
#         self._check_fleet_edges()
#         self.aliens.update()
#
#     def _create_fleet(self):
#         """Create the fleet of aliens."""
#         # Create an alien and keep adding aliens until there's no room left.
#         # Spacing between aliens is one alien width and one alien height.
#         alien = Alien(self)
#         alien_width, alien_height = alien.rect.size
#
#         current_x, current_y = alien_width, alien_height
#         while current_y < (self.settings.screen_height - 3 * alien_height):
#             while current_x < (self.settings.screen_width - 2 * alien_width):
#                 self._create_alien(current_x, current_y)
#                 current_x += 2 * alien_width
#
#             # Finished a row; reset x value, and increment y value.
#             current_x = alien_width
#             current_y += 2 * alien_height
#
#     def _create_alien(self, x_position, y_position):
#         """Create an alien and place it in the fleet."""
#         new_alien = Alien(self)
#         new_alien.x = x_position
#         new_alien.rect.x = x_position
#         new_alien.rect.y = y_position
#         self.aliens.add(new_alien)
#
#     def _check_fleet_edges(self):
#         """Respond appropriately if any aliens have reached an edge."""
#         for alien in self.aliens.sprites():
#             if alien.check_edges():
#                 self._change_fleet_direction()
#                 break
#
#     def _change_fleet_direction(self):
#         """Drop the entire fleet and change the fleet's direction."""
#         for alien in self.aliens.sprites():
#             alien.rect.y += self.settings.fleet_drop_speed
#         self.settings.fleet_direction *= -1
#
#     def _update_screen(self):
#         """Update images on the screen, and flip to the new screen."""
#         self.screen.fill(self.settings.bg_color)
#         for bullet in self.bullets.sprites():
#             bullet.draw_bullet()
#         self.ship.blitme()
#         self.aliens.draw(self.screen)
#
#         pygame.display.flip()
#
#
# if __name__ == '__main__':
#     # Make a game instance, and run the game.
#     ai = AlienInvasion()
#     ai.run_game()
# ```

# %%
# Practice rewrite for source example 13.18
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.19
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/making_fleet_move/bullet.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
# # ... 17 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
#         self.rect = pygame.Rect(0, 0, self.settings.bullet_width,
#             self.settings.bullet_height)
#         self.rect.midtop = ai_game.ship.rect.midtop
#
#         # Store the bullet's position as a float.
#         self.y = float(self.rect.y)
#
#     def update(self):
#         """Move the bullet up the screen."""
#         # Update the exact position of the bullet.
#         self.y -= self.settings.bullet_speed
#         # Update the rect position.
#         self.rect.y = self.y
#
#     def draw_bullet(self):
#         """Draw the bullet to the screen."""
#         pygame.draw.rect(self.screen, self.color, self.rect)
# ```

# %%
# Practice rewrite for source example 13.19
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.20
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/making_fleet_move/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_speed = 1.5
#
#         # Bullet settings
# # ... 11 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_speed = 1.5
#
#         # Bullet settings
#         self.bullet_speed = 2.0
#         self.bullet_width = 3
#         self.bullet_height = 15
#         self.bullet_color = (60, 60, 60)
#         self.bullets_allowed = 3
#
#         # Alien settings.
#         self.alien_speed = 1.0
#         self.fleet_drop_speed = 10
#         # fleet_direction of 1 represents right; -1 represents left.
#         self.fleet_direction = 1
# ```

# %%
# Practice rewrite for source example 13.20
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.21
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/making_fleet_move/ship.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
# # ... 26 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new ship at the bottom center of the screen.
#         self.rect.midbottom = self.screen_rect.midbottom
#
#         # Store a float for the ship's exact horizontal position.
#         self.x = float(self.rect.x)
#
#         # Movement flags; start with a ship that's not moving.
#         self.moving_right = False
#         self.moving_left = False
#
#     def update(self):
#         """Update the ship's position based on movement flags."""
#         # Update the ship's x value, not the rect.
#         if self.moving_right and self.rect.right < self.screen_rect.right:
#             self.x += self.settings.ship_speed
#         if self.moving_left and self.rect.left > 0:
#             self.x -= self.settings.ship_speed
#
#         # Update rect object from self.x.
#         self.rect.x = self.x
#
#     def blitme(self):
#         """Draw the ship at its current location."""
#         self.screen.blit(self.image, self.rect)
# ```

# %%
# Practice rewrite for source example 13.21
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Shooting Aliens

# %% [markdown]
# #### Source example 13.22
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/shooting_aliens/alien.py`.
#
# **Context**
#
# 1. This example demonstrates decision-making, where the program chooses a path based on data.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
# from pygame.sprite import Sprite
#
#
# class Alien(Sprite):
#     """A class to represent a single alien in the fleet."""
#
#     def __init__(self, ai_game):
#         """Initialize the alien and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#
# # ... 20 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
# from pygame.sprite import Sprite
#
#
# class Alien(Sprite):
#     """A class to represent a single alien in the fleet."""
#
#     def __init__(self, ai_game):
#         """Initialize the alien and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#
#         # Load the alien image and set its rect attribute.
#         self.image = pygame.image.load('images/alien.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new alien near the top left of the screen.
#         self.rect.x = self.rect.width
#         self.rect.y = self.rect.height
#
#         # Store the alien's exact horizontal position.
#         self.x = float(self.rect.x)
#
#     def check_edges(self):
#         """Return True if alien is at edge of screen."""
#         screen_rect = self.screen.get_rect()
#         return (self.rect.right >= screen_rect.right) or (self.rect.left <= 0)
#
#     def update(self):
#         """Move the alien right or left."""
#         self.x += self.settings.alien_speed * self.settings.fleet_direction
#         self.rect.x = self.x
# ```

# %%
# Practice rewrite for source example 13.22
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.23
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/shooting_aliens/alien_invasion.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
# from ship import Ship
# from bullet import Bullet
# from alien import Alien
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
# # ... 142 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import sys
#
# import pygame
#
# from settings import Settings
# from ship import Ship
# from bullet import Bullet
# from alien import Alien
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
#         pygame.init()
#         self.clock = pygame.time.Clock()
#         self.settings = Settings()
#
#         self.screen = pygame.display.set_mode(
#             (self.settings.screen_width, self.settings.screen_height))
#         pygame.display.set_caption("Alien Invasion")
#
#         self.ship = Ship(self)
#         self.bullets = pygame.sprite.Group()
#         self.aliens = pygame.sprite.Group()
#
#         self._create_fleet()
#
#     def run_game(self):
#         """Start the main loop for the game."""
#         while True:
#             self._check_events()
#             self.ship.update()
#             self._update_bullets()
#             self._update_aliens()
#             self._update_screen()
#             self.clock.tick(60)
#
#     def _check_events(self):
#         """Respond to keypresses and mouse events."""
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 sys.exit()
#             elif event.type == pygame.KEYDOWN:
#                 self._check_keydown_events(event)
#             elif event.type == pygame.KEYUP:
#                 self._check_keyup_events(event)
#
#     def _check_keydown_events(self, event):
#         """Respond to keypresses."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = True
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = True
#         elif event.key == pygame.K_q:
#             sys.exit()
#         elif event.key == pygame.K_SPACE:
#             self._fire_bullet()
#
#     def _check_keyup_events(self, event):
#         """Respond to key releases."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = False
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = False
#
#     def _fire_bullet(self):
#         """Create a new bullet and add it to the bullets group."""
#         if len(self.bullets) < self.settings.bullets_allowed:
#             new_bullet = Bullet(self)
#             self.bullets.add(new_bullet)
#
#     def _update_bullets(self):
#         """Update position of bullets and get rid of old bullets."""
#         # Update bullet positions.
#         self.bullets.update()
#
#         # Get rid of bullets that have disappeared.
#         for bullet in self.bullets.copy():
#             if bullet.rect.bottom <= 0:
#                 self.bullets.remove(bullet)
#
#         self._check_bullet_alien_collisions()
#
#
#     def _check_bullet_alien_collisions(self):
#         """Respond to bullet-alien collisions."""
#         # Remove any bullets and aliens that have collided.
#         collisions = pygame.sprite.groupcollide(
#                 self.bullets, self.aliens, True, True)
#
#         if not self.aliens:
#             # Destroy existing bullets and create new fleet.
#             self.bullets.empty()
#             self._create_fleet()
#
#     def _update_aliens(self):
#         """Update the positions of all aliens in the fleet."""
#         """Check if the fleet is at an edge, then update positions."""
#         self._check_fleet_edges()
#         self.aliens.update()
#
#     def _create_fleet(self):
#         """Create the fleet of aliens."""
#         # Create an alien and keep adding aliens until there's no room left.
#         # Spacing between aliens is one alien width and one alien height.
#         alien = Alien(self)
#         alien_width, alien_height = alien.rect.size
#
#         current_x, current_y = alien_width, alien_height
#         while current_y < (self.settings.screen_height - 3 * alien_height):
#             while current_x < (self.settings.screen_width - 2 * alien_width):
#                 self._create_alien(current_x, current_y)
#                 current_x += 2 * alien_width
#
#             # Finished a row; reset x value, and increment y value.
#             current_x = alien_width
#             current_y += 2 * alien_height
#
#     def _create_alien(self, x_position, y_position):
#         """Create an alien and place it in the fleet."""
#         new_alien = Alien(self)
#         new_alien.x = x_position
#         new_alien.rect.x = x_position
#         new_alien.rect.y = y_position
#         self.aliens.add(new_alien)
#
#     def _check_fleet_edges(self):
#         """Respond appropriately if any aliens have reached an edge."""
#         for alien in self.aliens.sprites():
#             if alien.check_edges():
#                 self._change_fleet_direction()
#                 break
#
#     def _change_fleet_direction(self):
#         """Drop the entire fleet and change the fleet's direction."""
#         for alien in self.aliens.sprites():
#             alien.rect.y += self.settings.fleet_drop_speed
#         self.settings.fleet_direction *= -1
#
#     def _update_screen(self):
#         """Update images on the screen, and flip to the new screen."""
#         self.screen.fill(self.settings.bg_color)
#         for bullet in self.bullets.sprites():
#             bullet.draw_bullet()
#         self.ship.blitme()
#         self.aliens.draw(self.screen)
#
#         pygame.display.flip()
#
#
# if __name__ == '__main__':
#     # Make a game instance, and run the game.
#     ai = AlienInvasion()
#     ai.run_game()
# ```

# %%
# Practice rewrite for source example 13.23
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.24
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/shooting_aliens/bullet.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
# # ... 17 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
#         self.rect = pygame.Rect(0, 0, self.settings.bullet_width,
#             self.settings.bullet_height)
#         self.rect.midtop = ai_game.ship.rect.midtop
#
#         # Store the bullet's position as a float.
#         self.y = float(self.rect.y)
#
#     def update(self):
#         """Move the bullet up the screen."""
#         # Update the exact position of the bullet.
#         self.y -= self.settings.bullet_speed
#         # Update the rect position.
#         self.rect.y = self.y
#
#     def draw_bullet(self):
#         """Draw the bullet to the screen."""
#         pygame.draw.rect(self.screen, self.color, self.rect)
# ```

# %%
# Practice rewrite for source example 13.24
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.25
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/shooting_aliens/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_speed = 1.5
#
#         # Bullet settings
# # ... 11 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_speed = 1.5
#
#         # Bullet settings
#         self.bullet_speed = 2.5
#         self.bullet_width = 3
#         self.bullet_height = 15
#         self.bullet_color = (60, 60, 60)
#         self.bullets_allowed = 3
#
#         # Alien settings.
#         self.alien_speed = 1.0
#         self.fleet_drop_speed = 10
#         # fleet_direction of 1 represents right; -1 represents left.
#         self.fleet_direction = 1
# ```

# %%
# Practice rewrite for source example 13.25
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 13.26
#
# Checklist note: captured from **Chapter 13: Aliens!**, official GitHub source `chapter_13/shooting_aliens/ship.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This grows the game by adding repeated objects, collision checks, and state changes.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# fleet/list of sprites -> update positions -> detect collisions -> respond
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
# # ... 26 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new ship at the bottom center of the screen.
#         self.rect.midbottom = self.screen_rect.midbottom
#
#         # Store a float for the ship's exact horizontal position.
#         self.x = float(self.rect.x)
#
#         # Movement flags; start with a ship that's not moving.
#         self.moving_right = False
#         self.moving_left = False
#
#     def update(self):
#         """Update the ship's position based on movement flags."""
#         # Update the ship's x value, not the rect.
#         if self.moving_right and self.rect.right < self.screen_rect.right:
#             self.x += self.settings.ship_speed
#         if self.moving_left and self.rect.left > 0:
#             self.x -= self.settings.ship_speed
#
#         # Update rect object from self.x.
#         self.rect.x = self.x
#
#     def blitme(self):
#         """Draw the ship at its current location."""
#         self.screen.blit(self.image, self.rect)
# ```

# %%
# Practice rewrite for source example 13.26
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Chapter 13: Aliens! Practice Checkpoint

# %% [markdown]
# #### Practice: project-safe rewrite

# %%
# Project chapters often depend on installed packages, files, servers, or assets.
# Rewrite one source example with fake data first:
# - replace file/API/game/web inputs with a small list or dictionary
# - print the planned action
# - only then connect it back to the real project
planned_steps = ["identify input", "transform state", "show or save result"]
for step in planned_steps:
    print(step)

# %% [markdown]
# ## Chapter 14: Scoring
#
# PDF pages: 456-491

# %% [markdown]
# ### Adding Play Button

# %% [markdown]
# #### Source example 14.1
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/adding_play_button/alien.py`.
#
# **Context**
#
# 1. This example demonstrates decision-making, where the program chooses a path based on data.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
# from pygame.sprite import Sprite
#
#
# class Alien(Sprite):
#     """A class to represent a single alien in the fleet."""
#
#     def __init__(self, ai_game):
#         """Initialize the alien and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#
# # ... 20 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
# from pygame.sprite import Sprite
#
#
# class Alien(Sprite):
#     """A class to represent a single alien in the fleet."""
#
#     def __init__(self, ai_game):
#         """Initialize the alien and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#
#         # Load the alien image and set its rect attribute.
#         self.image = pygame.image.load('images/alien.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new alien near the top left of the screen.
#         self.rect.x = self.rect.width
#         self.rect.y = self.rect.height
#
#         # Store the alien's exact horizontal position.
#         self.x = float(self.rect.x)
#
#     def check_edges(self):
#         """Return True if alien is at edge of screen."""
#         screen_rect = self.screen.get_rect()
#         return (self.rect.right >= screen_rect.right) or (self.rect.left <= 0)
#
#     def update(self):
#         """Move the alien right or left."""
#         self.x += self.settings.alien_speed * self.settings.fleet_direction
#         self.rect.x = self.x
# ```

# %%
# Practice rewrite for source example 14.1
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.2
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/adding_play_button/alien_invasion.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# import sys
# from time import sleep
#
# import pygame
#
# from settings import Settings
# from game_stats import GameStats
# from button import Button
# from ship import Ship
# from bullet import Bullet
# from alien import Alien
#
#
# class AlienInvasion:
# # ... 218 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import sys
# from time import sleep
#
# import pygame
#
# from settings import Settings
# from game_stats import GameStats
# from button import Button
# from ship import Ship
# from bullet import Bullet
# from alien import Alien
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
#         pygame.init()
#         self.clock = pygame.time.Clock()
#         self.settings = Settings()
#
#         self.screen = pygame.display.set_mode(
#             (self.settings.screen_width, self.settings.screen_height))
#         pygame.display.set_caption("Alien Invasion")
#
#         # Create an instance to store game statistics.
#         self.stats = GameStats(self)
#
#         self.ship = Ship(self)
#         self.bullets = pygame.sprite.Group()
#         self.aliens = pygame.sprite.Group()
#
#         self._create_fleet()
#
#         # Start Alien Invasion in an inactive state.
#         self.game_active = False
#
#         # Make the Play button.
#         self.play_button = Button(self, "Play")
#
#     def run_game(self):
#         """Start the main loop for the game."""
#         while True:
#             self._check_events()
#
#             if self.game_active:
#                 self.ship.update()
#                 self._update_bullets()
#                 self._update_aliens()
#
#             self._update_screen()
#             self.clock.tick(60)
#
#     def _check_events(self):
#         """Respond to keypresses and mouse events."""
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 sys.exit()
#             elif event.type == pygame.KEYDOWN:
#                 self._check_keydown_events(event)
#             elif event.type == pygame.KEYUP:
#                 self._check_keyup_events(event)
#             elif event.type == pygame.MOUSEBUTTONDOWN:
#                 mouse_pos = pygame.mouse.get_pos()
#                 self._check_play_button(mouse_pos)
#
#     def _check_play_button(self, mouse_pos):
#         """Start a new game when the player clicks Play."""
#         button_clicked = self.play_button.rect.collidepoint(mouse_pos)
#         if button_clicked and not self.game_active:
#             # Reset the game statistics.
#             self.stats.reset_stats()
#             self.game_active = True
#
#             # Get rid of any remaining bullets and aliens.
#             self.bullets.empty()
#             self.aliens.empty()
#
#             # Create a new fleet and center the ship.
#             self._create_fleet()
#             self.ship.center_ship()
#
#             # Hide the mouse cursor.
#             pygame.mouse.set_visible(False)
#
#     def _check_keydown_events(self, event):
#         """Respond to keypresses."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = True
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = True
#         elif event.key == pygame.K_q:
#             sys.exit()
#         elif event.key == pygame.K_SPACE:
#             self._fire_bullet()
#
#     def _check_keyup_events(self, event):
#         """Respond to key releases."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = False
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = False
#
#     def _fire_bullet(self):
#         """Create a new bullet and add it to the bullets group."""
#         if len(self.bullets) < self.settings.bullets_allowed:
#             new_bullet = Bullet(self)
#             self.bullets.add(new_bullet)
#
#     def _update_bullets(self):
#         """Update position of bullets and get rid of old bullets."""
#         # Update bullet positions.
#         self.bullets.update()
#
#         # Get rid of bullets that have disappeared.
#         for bullet in self.bullets.copy():
#             if bullet.rect.bottom <= 0:
#                 self.bullets.remove(bullet)
#
#         self._check_bullet_alien_collisions()
#
#
#     def _check_bullet_alien_collisions(self):
#         """Respond to bullet-alien collisions."""
#         # Remove any bullets and aliens that have collided.
#         collisions = pygame.sprite.groupcollide(
#                 self.bullets, self.aliens, True, True)
#
#         if not self.aliens:
#             # Destroy existing bullets and create new fleet.
#             self.bullets.empty()
#             self._create_fleet()
#
#     def _ship_hit(self):
#         """Respond to the ship being hit by an alien."""
#         if self.stats.ships_left > 0:
#             # Decrement ships_left.
#             self.stats.ships_left -= 1
#
#             # Get rid of any remaining bullets and aliens.
#             self.bullets.empty()
#             self.aliens.empty()
#
#             # Create a new fleet and center the ship.
#             self._create_fleet()
#             self.ship.center_ship()
#
#             # Pause.
#             sleep(0.5)
#         else:
#             self.game_active = False
#             pygame.mouse.set_visible(True)
#
#     def _update_aliens(self):
#         """Update the positions of all aliens in the fleet."""
#         """Check if the fleet is at an edge, then update positions."""
#         self._check_fleet_edges()
#         self.aliens.update()
#
#         # Look for alien-ship collisions.
#         if pygame.sprite.spritecollideany(self.ship, self.aliens):
#             self._ship_hit()
#
#         # Look for aliens hitting the bottom of the screen.
#         self._check_aliens_bottom()
#
#     def _check_aliens_bottom(self):
#         """Check if any aliens have reached the bottom of the screen."""
#         for alien in self.aliens.sprites():
#             if alien.rect.bottom >= self.settings.screen_height:
#                 # Treat this the same as if the ship got hit.
#                 self._ship_hit()
#                 break
#
#     def _create_fleet(self):
#         """Create the fleet of aliens."""
#         # Create an alien and keep adding aliens until there's no room left.
#         # Spacing between aliens is one alien width and one alien height.
#         alien = Alien(self)
#         alien_width, alien_height = alien.rect.size
#
#         current_x, current_y = alien_width, alien_height
#         while current_y < (self.settings.screen_height - 3 * alien_height):
#             while current_x < (self.settings.screen_width - 2 * alien_width):
#                 self._create_alien(current_x, current_y)
#                 current_x += 2 * alien_width
#
#             # Finished a row; reset x value, and increment y value.
#             current_x = alien_width
#             current_y += 2 * alien_height
#
#     def _create_alien(self, x_position, y_position):
#         """Create an alien and place it in the fleet."""
#         new_alien = Alien(self)
#         new_alien.x = x_position
#         new_alien.rect.x = x_position
#         new_alien.rect.y = y_position
#         self.aliens.add(new_alien)
#
#     def _check_fleet_edges(self):
#         """Respond appropriately if any aliens have reached an edge."""
#         for alien in self.aliens.sprites():
#             if alien.check_edges():
#                 self._change_fleet_direction()
#                 break
#
#     def _change_fleet_direction(self):
#         """Drop the entire fleet and change the fleet's direction."""
#         for alien in self.aliens.sprites():
#             alien.rect.y += self.settings.fleet_drop_speed
#         self.settings.fleet_direction *= -1
#
#     def _update_screen(self):
#         """Update images on the screen, and flip to the new screen."""
#         self.screen.fill(self.settings.bg_color)
#         for bullet in self.bullets.sprites():
#             bullet.draw_bullet()
#         self.ship.blitme()
#         self.aliens.draw(self.screen)
#
#         # Draw the play button if the game is inactive.
#         if not self.game_active:
#             self.play_button.draw_button()
#
#         pygame.display.flip()
#
#
# if __name__ == '__main__':
#     # Make a game instance, and run the game.
#     ai = AlienInvasion()
#     ai.run_game()
# ```

# %%
# Practice rewrite for source example 14.2
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.3
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/adding_play_button/bullet.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
# # ... 17 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
#         self.rect = pygame.Rect(0, 0, self.settings.bullet_width,
#             self.settings.bullet_height)
#         self.rect.midtop = ai_game.ship.rect.midtop
#
#         # Store the bullet's position as a float.
#         self.y = float(self.rect.y)
#
#     def update(self):
#         """Move the bullet up the screen."""
#         # Update the exact position of the bullet.
#         self.y -= self.settings.bullet_speed
#         # Update the rect position.
#         self.rect.y = self.y
#
#     def draw_bullet(self):
#         """Draw the bullet to the screen."""
#         pygame.draw.rect(self.screen, self.color, self.rect)
# ```

# %%
# Practice rewrite for source example 14.3
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.4
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/adding_play_button/button.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# import pygame.font
#
#
# class Button:
#     """A class to build buttons for the game."""
#
#     def __init__(self, ai_game, msg):
#         """Initialize button attributes."""
#         self.screen = ai_game.screen
#         self.screen_rect = self.screen.get_rect()
#
#         # Set the dimensions and properties of the button.
#         self.width, self.height = 200, 50
#         self.button_color = (0, 135, 0)
# # ... 21 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame.font
#
#
# class Button:
#     """A class to build buttons for the game."""
#
#     def __init__(self, ai_game, msg):
#         """Initialize button attributes."""
#         self.screen = ai_game.screen
#         self.screen_rect = self.screen.get_rect()
#
#         # Set the dimensions and properties of the button.
#         self.width, self.height = 200, 50
#         self.button_color = (0, 135, 0)
#         self.text_color = (255, 255, 255)
#         self.font = pygame.font.SysFont(None, 48)
#
#         # Build the button's rect object and center it.
#         self.rect = pygame.Rect(0, 0, self.width, self.height)
#         self.rect.center = self.screen_rect.center
#
#         # The button message needs to be prepped only once.
#         self._prep_msg(msg)
#
#     def _prep_msg(self, msg):
#         """Turn msg into a rendered image and center text on the button."""
#         self.msg_image = self.font.render(msg, True, self.text_color,
#                 self.button_color)
#         self.msg_image_rect = self.msg_image.get_rect()
#         self.msg_image_rect.center = self.rect.center
#
#     def draw_button(self):
#         """Draw blank button and then draw message."""
#         self.screen.fill(self.button_color, self.rect)
#         self.screen.blit(self.msg_image, self.msg_image_rect)
# ```

# %%
# Practice rewrite for source example 14.4
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.5
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/adding_play_button/game_stats.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# class GameStats:
#     """Track statistics for Alien Invasion."""
#
#     def __init__(self, ai_game):
#         """Initialize statistics."""
#         self.settings = ai_game.settings
#         self.reset_stats()
#
#     def reset_stats(self):
#         """Initialize statistics that can change during the game."""
#         self.ships_left = self.settings.ship_limit
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# class GameStats:
#     """Track statistics for Alien Invasion."""
#
#     def __init__(self, ai_game):
#         """Initialize statistics."""
#         self.settings = ai_game.settings
#         self.reset_stats()
#
#     def reset_stats(self):
#         """Initialize statistics that can change during the game."""
#         self.ships_left = self.settings.ship_limit
# ```

# %%
# Practice rewrite for source example 14.5
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.6
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/adding_play_button/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_speed = 1.5
#         self.ship_limit = 3
#
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_speed = 1.5
#         self.ship_limit = 3
#
#         # Bullet settings
#         self.bullet_speed = 2.5
#         self.bullet_width = 3
#         self.bullet_height = 15
#         self.bullet_color = (60, 60, 60)
#         self.bullets_allowed = 3
#
#         # Alien settings.
#         self.alien_speed = 1.0
#         self.fleet_drop_speed = 10
#         # fleet_direction of 1 represents right; -1 represents left.
#         self.fleet_direction = 1
# ```

# %%
# Practice rewrite for source example 14.6
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.7
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/adding_play_button/ship.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
# # ... 31 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new ship at the bottom center of the screen.
#         self.rect.midbottom = self.screen_rect.midbottom
#
#         # Store a float for the ship's exact horizontal position.
#         self.x = float(self.rect.x)
#
#         # Movement flags; start with a ship that's not moving.
#         self.moving_right = False
#         self.moving_left = False
#
#     def center_ship(self):
#         """Center the ship on the screen."""
#         self.rect.midbottom = self.screen_rect.midbottom
#         self.x = float(self.rect.x)
#
#     def update(self):
#         """Update the ship's position based on movement flags."""
#         # Update the ship's x value, not the rect.
#         if self.moving_right and self.rect.right < self.screen_rect.right:
#             self.x += self.settings.ship_speed
#         if self.moving_left and self.rect.left > 0:
#             self.x -= self.settings.ship_speed
#
#         # Update rect object from self.x.
#         self.rect.x = self.x
#
#     def blitme(self):
#         """Draw the ship at its current location."""
#         self.screen.blit(self.image, self.rect)
# ```

# %%
# Practice rewrite for source example 14.7
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Leveling Up

# %% [markdown]
# #### Source example 14.8
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/leveling_up/alien.py`.
#
# **Context**
#
# 1. This example demonstrates decision-making, where the program chooses a path based on data.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
# from pygame.sprite import Sprite
#
#
# class Alien(Sprite):
#     """A class to represent a single alien in the fleet."""
#
#     def __init__(self, ai_game):
#         """Initialize the alien and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#
# # ... 20 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
# from pygame.sprite import Sprite
#
#
# class Alien(Sprite):
#     """A class to represent a single alien in the fleet."""
#
#     def __init__(self, ai_game):
#         """Initialize the alien and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#
#         # Load the alien image and set its rect attribute.
#         self.image = pygame.image.load('images/alien.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new alien near the top left of the screen.
#         self.rect.x = self.rect.width
#         self.rect.y = self.rect.height
#
#         # Store the alien's exact horizontal position.
#         self.x = float(self.rect.x)
#
#     def check_edges(self):
#         """Return True if alien is at edge of screen."""
#         screen_rect = self.screen.get_rect()
#         return (self.rect.right >= screen_rect.right) or (self.rect.left <= 0)
#
#     def update(self):
#         """Move the alien right or left."""
#         self.x += self.settings.alien_speed * self.settings.fleet_direction
#         self.rect.x = self.x
# ```

# %%
# Practice rewrite for source example 14.8
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.9
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/leveling_up/alien_invasion.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# import sys
# from time import sleep
#
# import pygame
#
# from settings import Settings
# from game_stats import GameStats
# from button import Button
# from ship import Ship
# from bullet import Bullet
# from alien import Alien
#
#
# class AlienInvasion:
# # ... 222 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import sys
# from time import sleep
#
# import pygame
#
# from settings import Settings
# from game_stats import GameStats
# from button import Button
# from ship import Ship
# from bullet import Bullet
# from alien import Alien
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
#         pygame.init()
#         self.clock = pygame.time.Clock()
#         self.settings = Settings()
#
#         self.screen = pygame.display.set_mode(
#             (self.settings.screen_width, self.settings.screen_height))
#         pygame.display.set_caption("Alien Invasion")
#
#         # Create an instance to store game statistics.
#         self.stats = GameStats(self)
#
#         self.ship = Ship(self)
#         self.bullets = pygame.sprite.Group()
#         self.aliens = pygame.sprite.Group()
#
#         self._create_fleet()
#
#         # Start Alien Invasion in an inactive state.
#         self.game_active = False
#
#         # Make the Play button.
#         self.play_button = Button(self, "Play")
#
#     def run_game(self):
#         """Start the main loop for the game."""
#         while True:
#             self._check_events()
#
#             if self.game_active:
#                 self.ship.update()
#                 self._update_bullets()
#                 self._update_aliens()
#
#             self._update_screen()
#             self.clock.tick(60)
#
#     def _check_events(self):
#         """Respond to keypresses and mouse events."""
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 sys.exit()
#             elif event.type == pygame.KEYDOWN:
#                 self._check_keydown_events(event)
#             elif event.type == pygame.KEYUP:
#                 self._check_keyup_events(event)
#             elif event.type == pygame.MOUSEBUTTONDOWN:
#                 mouse_pos = pygame.mouse.get_pos()
#                 self._check_play_button(mouse_pos)
#
#     def _check_play_button(self, mouse_pos):
#         """Start a new game when the player clicks Play."""
#         button_clicked = self.play_button.rect.collidepoint(mouse_pos)
#         if button_clicked and not self.game_active:
#             # Reset the game settings.
#             self.settings.initialize_dynamic_settings()
#
#             # Reset the game statistics.
#             self.stats.reset_stats()
#             self.game_active = True
#
#             # Get rid of any remaining bullets and aliens.
#             self.bullets.empty()
#             self.aliens.empty()
#
#             # Create a new fleet and center the ship.
#             self._create_fleet()
#             self.ship.center_ship()
#
#             # Hide the mouse cursor.
#             pygame.mouse.set_visible(False)
#
#     def _check_keydown_events(self, event):
#         """Respond to keypresses."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = True
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = True
#         elif event.key == pygame.K_q:
#             sys.exit()
#         elif event.key == pygame.K_SPACE:
#             self._fire_bullet()
#
#     def _check_keyup_events(self, event):
#         """Respond to key releases."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = False
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = False
#
#     def _fire_bullet(self):
#         """Create a new bullet and add it to the bullets group."""
#         if len(self.bullets) < self.settings.bullets_allowed:
#             new_bullet = Bullet(self)
#             self.bullets.add(new_bullet)
#
#     def _update_bullets(self):
#         """Update position of bullets and get rid of old bullets."""
#         # Update bullet positions.
#         self.bullets.update()
#
#         # Get rid of bullets that have disappeared.
#         for bullet in self.bullets.copy():
#             if bullet.rect.bottom <= 0:
#                 self.bullets.remove(bullet)
#
#         self._check_bullet_alien_collisions()
#
#
#     def _check_bullet_alien_collisions(self):
#         """Respond to bullet-alien collisions."""
#         # Remove any bullets and aliens that have collided.
#         collisions = pygame.sprite.groupcollide(
#                 self.bullets, self.aliens, True, True)
#
#         if not self.aliens:
#             # Destroy existing bullets and create new fleet.
#             self.bullets.empty()
#             self._create_fleet()
#             self.settings.increase_speed()
#
#     def _ship_hit(self):
#         """Respond to the ship being hit by an alien."""
#         if self.stats.ships_left > 0:
#             # Decrement ships_left.
#             self.stats.ships_left -= 1
#
#             # Get rid of any remaining bullets and aliens.
#             self.bullets.empty()
#             self.aliens.empty()
#
#             # Create a new fleet and center the ship.
#             self._create_fleet()
#             self.ship.center_ship()
#
#             # Pause.
#             sleep(0.5)
#         else:
#             self.game_active = False
#             pygame.mouse.set_visible(True)
#
#     def _update_aliens(self):
#         """Update the positions of all aliens in the fleet."""
#         """Check if the fleet is at an edge, then update positions."""
#         self._check_fleet_edges()
#         self.aliens.update()
#
#         # Look for alien-ship collisions.
#         if pygame.sprite.spritecollideany(self.ship, self.aliens):
#             self._ship_hit()
#
#         # Look for aliens hitting the bottom of the screen.
#         self._check_aliens_bottom()
#
#     def _check_aliens_bottom(self):
#         """Check if any aliens have reached the bottom of the screen."""
#         for alien in self.aliens.sprites():
#             if alien.rect.bottom >= self.settings.screen_height:
#                 # Treat this the same as if the ship got hit.
#                 self._ship_hit()
#                 break
#
#     def _create_fleet(self):
#         """Create the fleet of aliens."""
#         # Create an alien and keep adding aliens until there's no room left.
#         # Spacing between aliens is one alien width and one alien height.
#         alien = Alien(self)
#         alien_width, alien_height = alien.rect.size
#
#         current_x, current_y = alien_width, alien_height
#         while current_y < (self.settings.screen_height - 3 * alien_height):
#             while current_x < (self.settings.screen_width - 2 * alien_width):
#                 self._create_alien(current_x, current_y)
#                 current_x += 2 * alien_width
#
#             # Finished a row; reset x value, and increment y value.
#             current_x = alien_width
#             current_y += 2 * alien_height
#
#     def _create_alien(self, x_position, y_position):
#         """Create an alien and place it in the fleet."""
#         new_alien = Alien(self)
#         new_alien.x = x_position
#         new_alien.rect.x = x_position
#         new_alien.rect.y = y_position
#         self.aliens.add(new_alien)
#
#     def _check_fleet_edges(self):
#         """Respond appropriately if any aliens have reached an edge."""
#         for alien in self.aliens.sprites():
#             if alien.check_edges():
#                 self._change_fleet_direction()
#                 break
#
#     def _change_fleet_direction(self):
#         """Drop the entire fleet and change the fleet's direction."""
#         for alien in self.aliens.sprites():
#             alien.rect.y += self.settings.fleet_drop_speed
#         self.settings.fleet_direction *= -1
#
#     def _update_screen(self):
#         """Update images on the screen, and flip to the new screen."""
#         self.screen.fill(self.settings.bg_color)
#         for bullet in self.bullets.sprites():
#             bullet.draw_bullet()
#         self.ship.blitme()
#         self.aliens.draw(self.screen)
#
#         # Draw the play button if the game is inactive.
#         if not self.game_active:
#             self.play_button.draw_button()
#
#         pygame.display.flip()
#
#
# if __name__ == '__main__':
#     # Make a game instance, and run the game.
#     ai = AlienInvasion()
#     ai.run_game()
# ```

# %%
# Practice rewrite for source example 14.9
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.10
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/leveling_up/bullet.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
# # ... 17 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
#         self.rect = pygame.Rect(0, 0, self.settings.bullet_width,
#             self.settings.bullet_height)
#         self.rect.midtop = ai_game.ship.rect.midtop
#
#         # Store the bullet's position as a float.
#         self.y = float(self.rect.y)
#
#     def update(self):
#         """Move the bullet up the screen."""
#         # Update the exact position of the bullet.
#         self.y -= self.settings.bullet_speed
#         # Update the rect position.
#         self.rect.y = self.y
#
#     def draw_bullet(self):
#         """Draw the bullet to the screen."""
#         pygame.draw.rect(self.screen, self.color, self.rect)
# ```

# %%
# Practice rewrite for source example 14.10
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.11
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/leveling_up/button.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# import pygame.font
#
#
# class Button:
#     """A class to build buttons for the game."""
#
#     def __init__(self, ai_game, msg):
#         """Initialize button attributes."""
#         self.screen = ai_game.screen
#         self.screen_rect = self.screen.get_rect()
#
#         # Set the dimensions and properties of the button.
#         self.width, self.height = 200, 50
#         self.button_color = (0, 135, 0)
# # ... 21 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame.font
#
#
# class Button:
#     """A class to build buttons for the game."""
#
#     def __init__(self, ai_game, msg):
#         """Initialize button attributes."""
#         self.screen = ai_game.screen
#         self.screen_rect = self.screen.get_rect()
#
#         # Set the dimensions and properties of the button.
#         self.width, self.height = 200, 50
#         self.button_color = (0, 135, 0)
#         self.text_color = (255, 255, 255)
#         self.font = pygame.font.SysFont(None, 48)
#
#         # Build the button's rect object and center it.
#         self.rect = pygame.Rect(0, 0, self.width, self.height)
#         self.rect.center = self.screen_rect.center
#
#         # The button message needs to be prepped only once.
#         self._prep_msg(msg)
#
#     def _prep_msg(self, msg):
#         """Turn msg into a rendered image and center text on the button."""
#         self.msg_image = self.font.render(msg, True, self.text_color,
#                 self.button_color)
#         self.msg_image_rect = self.msg_image.get_rect()
#         self.msg_image_rect.center = self.rect.center
#
#     def draw_button(self):
#         """Draw blank button and then draw message."""
#         self.screen.fill(self.button_color, self.rect)
#         self.screen.blit(self.msg_image, self.msg_image_rect)
# ```

# %%
# Practice rewrite for source example 14.11
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.12
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/leveling_up/game_stats.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# class GameStats:
#     """Track statistics for Alien Invasion."""
#
#     def __init__(self, ai_game):
#         """Initialize statistics."""
#         self.settings = ai_game.settings
#         self.reset_stats()
#
#     def reset_stats(self):
#         """Initialize statistics that can change during the game."""
#         self.ships_left = self.settings.ship_limit
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# class GameStats:
#     """Track statistics for Alien Invasion."""
#
#     def __init__(self, ai_game):
#         """Initialize statistics."""
#         self.settings = ai_game.settings
#         self.reset_stats()
#
#     def reset_stats(self):
#         """Initialize statistics that can change during the game."""
#         self.ships_left = self.settings.ship_limit
# ```

# %%
# Practice rewrite for source example 14.12
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.13
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/leveling_up/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's static settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_limit = 3
#
#         # Bullet settings
# # ... 27 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's static settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings.
#         self.ship_limit = 3
#
#         # Bullet settings
#         self.bullet_width = 3
#         self.bullet_height = 15
#         self.bullet_color = (60, 60, 60)
#         self.bullets_allowed = 3
#
#         # Alien settings.
#         self.fleet_drop_speed = 10
#
#         # How quickly the game speeds up
#         self.speedup_scale = 1.1
#
#         self.initialize_dynamic_settings()
#
#     def initialize_dynamic_settings(self):
#         """Initialize settings that change throughout the game."""
#         self.ship_speed = 1.5
#         self.bullet_speed = 2.5
#         self.alien_speed = 1.0
#
#         # fleet_direction of 1 represents right; -1 represents left.
#         self.fleet_direction = 1
#
#     def increase_speed(self):
#         """Increase speed settings."""
#         self.ship_speed *= self.speedup_scale
#         self.bullet_speed *= self.speedup_scale
#         self.alien_speed *= self.speedup_scale
# ```

# %%
# Practice rewrite for source example 14.13
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.14
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/leveling_up/ship.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
# # ... 31 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
#
# class Ship:
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new ship at the bottom center of the screen.
#         self.rect.midbottom = self.screen_rect.midbottom
#
#         # Store a float for the ship's exact horizontal position.
#         self.x = float(self.rect.x)
#
#         # Movement flags; start with a ship that's not moving.
#         self.moving_right = False
#         self.moving_left = False
#
#     def center_ship(self):
#         """Center the ship on the screen."""
#         self.rect.midbottom = self.screen_rect.midbottom
#         self.x = float(self.rect.x)
#
#     def update(self):
#         """Update the ship's position based on movement flags."""
#         # Update the ship's x value, not the rect.
#         if self.moving_right and self.rect.right < self.screen_rect.right:
#             self.x += self.settings.ship_speed
#         if self.moving_left and self.rect.left > 0:
#             self.x -= self.settings.ship_speed
#
#         # Update rect object from self.x.
#         self.rect.x = self.x
#
#     def blitme(self):
#         """Draw the ship at its current location."""
#         self.screen.blit(self.image, self.rect)
# ```

# %%
# Practice rewrite for source example 14.14
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Scoring

# %% [markdown]
# #### Source example 14.15
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/scoring/alien.py`.
#
# **Context**
#
# 1. This example demonstrates decision-making, where the program chooses a path based on data.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# import pygame
#
# from pygame.sprite import Sprite
#
#
# class Alien(Sprite):
#     """A class to represent a single alien in the fleet."""
#
#     def __init__(self, ai_game):
#         """Initialize the alien and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#
# # ... 20 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
#
# from pygame.sprite import Sprite
#
#
# class Alien(Sprite):
#     """A class to represent a single alien in the fleet."""
#
#     def __init__(self, ai_game):
#         """Initialize the alien and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#
#         # Load the alien image and set its rect attribute.
#         self.image = pygame.image.load('images/alien.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new alien near the top left of the screen.
#         self.rect.x = self.rect.width
#         self.rect.y = self.rect.height
#
#         # Store the alien's exact horizontal position.
#         self.x = float(self.rect.x)
#
#     def check_edges(self):
#         """Return True if alien is at edge of screen."""
#         screen_rect = self.screen.get_rect()
#         return (self.rect.right >= screen_rect.right) or (self.rect.left <= 0)
#
#     def update(self):
#         """Move the alien right or left."""
#         self.x += self.settings.alien_speed * self.settings.fleet_direction
#         self.rect.x = self.x
# ```

# %%
# Practice rewrite for source example 14.15
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.16
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/scoring/alien_invasion.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# import sys
# from time import sleep
#
# import pygame
#
# from settings import Settings
# from game_stats import GameStats
# from scoreboard import Scoreboard
# from button import Button
# from ship import Ship
# from bullet import Bullet
# from alien import Alien
#
#
# # ... 240 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import sys
# from time import sleep
#
# import pygame
#
# from settings import Settings
# from game_stats import GameStats
# from scoreboard import Scoreboard
# from button import Button
# from ship import Ship
# from bullet import Bullet
# from alien import Alien
#
#
# class AlienInvasion:
#     """Overall class to manage game assets and behavior."""
#
#     def __init__(self):
#         """Initialize the game, and create game resources."""
#         pygame.init()
#         self.clock = pygame.time.Clock()
#         self.settings = Settings()
#
#         self.screen = pygame.display.set_mode(
#             (self.settings.screen_width, self.settings.screen_height))
#         pygame.display.set_caption("Alien Invasion")
#
#         # Create an instance to store game statistics,
#         #   and create a scoreboard.
#         self.stats = GameStats(self)
#         self.sb = Scoreboard(self)
#
#         self.ship = Ship(self)
#         self.bullets = pygame.sprite.Group()
#         self.aliens = pygame.sprite.Group()
#
#         self._create_fleet()
#
#         # Start Alien Invasion in an inactive state.
#         self.game_active = False
#
#         # Make the Play button.
#         self.play_button = Button(self, "Play")
#
#     def run_game(self):
#         """Start the main loop for the game."""
#         while True:
#             self._check_events()
#
#             if self.game_active:
#                 self.ship.update()
#                 self._update_bullets()
#                 self._update_aliens()
#
#             self._update_screen()
#             self.clock.tick(60)
#
#     def _check_events(self):
#         """Respond to keypresses and mouse events."""
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 sys.exit()
#             elif event.type == pygame.KEYDOWN:
#                 self._check_keydown_events(event)
#             elif event.type == pygame.KEYUP:
#                 self._check_keyup_events(event)
#             elif event.type == pygame.MOUSEBUTTONDOWN:
#                 mouse_pos = pygame.mouse.get_pos()
#                 self._check_play_button(mouse_pos)
#
#     def _check_play_button(self, mouse_pos):
#         """Start a new game when the player clicks Play."""
#         button_clicked = self.play_button.rect.collidepoint(mouse_pos)
#         if button_clicked and not self.game_active:
#             # Reset the game settings.
#             self.settings.initialize_dynamic_settings()
#
#             # Reset the game statistics.
#             self.stats.reset_stats()
#             self.sb.prep_score()
#             self.sb.prep_level()
#             self.sb.prep_ships()
#             self.game_active = True
#
#             # Get rid of any remaining bullets and aliens.
#             self.bullets.empty()
#             self.aliens.empty()
#
#             # Create a new fleet and center the ship.
#             self._create_fleet()
#             self.ship.center_ship()
#
#             # Hide the mouse cursor.
#             pygame.mouse.set_visible(False)
#
#     def _check_keydown_events(self, event):
#         """Respond to keypresses."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = True
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = True
#         elif event.key == pygame.K_q:
#             sys.exit()
#         elif event.key == pygame.K_SPACE:
#             self._fire_bullet()
#
#     def _check_keyup_events(self, event):
#         """Respond to key releases."""
#         if event.key == pygame.K_RIGHT:
#             self.ship.moving_right = False
#         elif event.key == pygame.K_LEFT:
#             self.ship.moving_left = False
#
#     def _fire_bullet(self):
#         """Create a new bullet and add it to the bullets group."""
#         if len(self.bullets) < self.settings.bullets_allowed:
#             new_bullet = Bullet(self)
#             self.bullets.add(new_bullet)
#
#     def _update_bullets(self):
#         """Update position of bullets and get rid of old bullets."""
#         # Update bullet positions.
#         self.bullets.update()
#
#         # Get rid of bullets that have disappeared.
#         for bullet in self.bullets.copy():
#             if bullet.rect.bottom <= 0:
#                 self.bullets.remove(bullet)
#
#         self._check_bullet_alien_collisions()
#
#     def _check_bullet_alien_collisions(self):
#         """Respond to bullet-alien collisions."""
#         # Remove any bullets and aliens that have collided.
#         collisions = pygame.sprite.groupcollide(
#                 self.bullets, self.aliens, True, True)
#
#         if collisions:
#             for aliens in collisions.values():
#                 self.stats.score += self.settings.alien_points * len(aliens)
#             self.sb.prep_score()
#             self.sb.check_high_score()
#
#         if not self.aliens:
#             # Destroy existing bullets and create new fleet.
#             self.bullets.empty()
#             self._create_fleet()
#             self.settings.increase_speed()
#
#             # Increase level.
#             self.stats.level += 1
#             self.sb.prep_level()
#
#     def _ship_hit(self):
#         """Respond to the ship being hit by an alien."""
#         if self.stats.ships_left > 0:
#             # Decrement ships_left, and update scoreboard.
#             self.stats.ships_left -= 1
#             self.sb.prep_ships()
#
#             # Get rid of any remaining bullets and aliens.
#             self.bullets.empty()
#             self.aliens.empty()
#
#             # Create a new fleet and center the ship.
#             self._create_fleet()
#             self.ship.center_ship()
#
#             # Pause.
#             sleep(0.5)
#         else:
#             self.game_active = False
#             pygame.mouse.set_visible(True)
#
#     def _update_aliens(self):
#         """Check if the fleet is at an edge, then update positions."""
#         self._check_fleet_edges()
#         self.aliens.update()
#
#         # Look for alien-ship collisions.
#         if pygame.sprite.spritecollideany(self.ship, self.aliens):
#             self._ship_hit()
#
#         # Look for aliens hitting the bottom of the screen.
#         self._check_aliens_bottom()
#
#     def _check_aliens_bottom(self):
#         """Check if any aliens have reached the bottom of the screen."""
#         for alien in self.aliens.sprites():
#             if alien.rect.bottom >= self.settings.screen_height:
#                 # Treat this the same as if the ship got hit.
#                 self._ship_hit()
#                 break
#
#     def _create_fleet(self):
#         """Create the fleet of aliens."""
#         # Create an alien and keep adding aliens until there's no room left.
#         # Spacing between aliens is one alien width and one alien height.
#         alien = Alien(self)
#         alien_width, alien_height = alien.rect.size
#
#         current_x, current_y = alien_width, alien_height
#         while current_y < (self.settings.screen_height - 3 * alien_height):
#             while current_x < (self.settings.screen_width - 2 * alien_width):
#                 self._create_alien(current_x, current_y)
#                 current_x += 2 * alien_width
#
#             # Finished a row; reset x value, and increment y value.
#             current_x = alien_width
#             current_y += 2 * alien_height
#
#     def _create_alien(self, x_position, y_position):
#         """Create an alien and place it in the fleet."""
#         new_alien = Alien(self)
#         new_alien.x = x_position
#         new_alien.rect.x = x_position
#         new_alien.rect.y = y_position
#         self.aliens.add(new_alien)
#
#     def _check_fleet_edges(self):
#         """Respond appropriately if any aliens have reached an edge."""
#         for alien in self.aliens.sprites():
#             if alien.check_edges():
#                 self._change_fleet_direction()
#                 break
#
#     def _change_fleet_direction(self):
#         """Drop the entire fleet and change the fleet's direction."""
#         for alien in self.aliens.sprites():
#             alien.rect.y += self.settings.fleet_drop_speed
#         self.settings.fleet_direction *= -1
#
#     def _update_screen(self):
#         """Update images on the screen, and flip to the new screen."""
#         self.screen.fill(self.settings.bg_color)
#         for bullet in self.bullets.sprites():
#             bullet.draw_bullet()
#         self.ship.blitme()
#         self.aliens.draw(self.screen)
#
#         # Draw the score information.
#         self.sb.show_score()
#
#         # Draw the play button if the game is inactive.
#         if not self.game_active:
#             self.play_button.draw_button()
#
#         pygame.display.flip()
#
#
# if __name__ == '__main__':
#     # Make a game instance, and run the game.
#     ai = AlienInvasion()
#     ai.run_game()
# ```

# %%
# Practice rewrite for source example 14.16
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.17
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/scoring/bullet.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
# # ... 17 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
# class Bullet(Sprite):
#     """A class to manage bullets fired from the ship."""
#
#     def __init__(self, ai_game):
#         """Create a bullet object at the ship's current position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.color = self.settings.bullet_color
#
#         # Create a bullet rect at (0, 0) and then set correct position.
#         self.rect = pygame.Rect(0, 0, self.settings.bullet_width,
#             self.settings.bullet_height)
#         self.rect.midtop = ai_game.ship.rect.midtop
#
#         # Store the bullet's position as a float.
#         self.y = float(self.rect.y)
#
#     def update(self):
#         """Move the bullet up the screen."""
#         # Update the exact position of the bullet.
#         self.y -= self.settings.bullet_speed
#         # Update the rect position.
#         self.rect.y = self.y
#
#     def draw_bullet(self):
#         """Draw the bullet to the screen."""
#         pygame.draw.rect(self.screen, self.color, self.rect)
# ```

# %%
# Practice rewrite for source example 14.17
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.18
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/scoring/button.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# import pygame.font
#
#
# class Button:
#     """A class to build buttons for the game."""
#
#     def __init__(self, ai_game, msg):
#         """Initialize button attributes."""
#         self.screen = ai_game.screen
#         self.screen_rect = self.screen.get_rect()
#
#         # Set the dimensions and properties of the button.
#         self.width, self.height = 200, 50
#         self.button_color = (0, 135, 0)
# # ... 21 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame.font
#
#
# class Button:
#     """A class to build buttons for the game."""
#
#     def __init__(self, ai_game, msg):
#         """Initialize button attributes."""
#         self.screen = ai_game.screen
#         self.screen_rect = self.screen.get_rect()
#
#         # Set the dimensions and properties of the button.
#         self.width, self.height = 200, 50
#         self.button_color = (0, 135, 0)
#         self.text_color = (255, 255, 255)
#         self.font = pygame.font.SysFont(None, 48)
#
#         # Build the button's rect object and center it.
#         self.rect = pygame.Rect(0, 0, self.width, self.height)
#         self.rect.center = self.screen_rect.center
#
#         # The button message needs to be prepped only once.
#         self._prep_msg(msg)
#
#     def _prep_msg(self, msg):
#         """Turn msg into a rendered image and center text on the button."""
#         self.msg_image = self.font.render(msg, True, self.text_color,
#                 self.button_color)
#         self.msg_image_rect = self.msg_image.get_rect()
#         self.msg_image_rect.center = self.rect.center
#
#     def draw_button(self):
#         """Draw blank button and then draw message."""
#         self.screen.fill(self.button_color, self.rect)
#         self.screen.blit(self.msg_image, self.msg_image_rect)
# ```

# %%
# Practice rewrite for source example 14.18
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.19
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/scoring/game_stats.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# class GameStats:
#     """Track statistics for Alien Invasion."""
#
#     def __init__(self, ai_game):
#         """Initialize statistics."""
#         self.settings = ai_game.settings
#         self.reset_stats()
#
#         # High score should never be reset.
#         self.high_score = 0
#
#     def reset_stats(self):
#         """Initialize statistics that can change during the game."""
#         self.ships_left = self.settings.ship_limit
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# class GameStats:
#     """Track statistics for Alien Invasion."""
#
#     def __init__(self, ai_game):
#         """Initialize statistics."""
#         self.settings = ai_game.settings
#         self.reset_stats()
#
#         # High score should never be reset.
#         self.high_score = 0
#
#     def reset_stats(self):
#         """Initialize statistics that can change during the game."""
#         self.ships_left = self.settings.ship_limit
#         self.score = 0
#         self.level = 1
# ```

# %%
# Practice rewrite for source example 14.19
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.20
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/scoring/scoreboard.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# import pygame.font
# from pygame.sprite import Group
#
# from ship import Ship
#
#
# class Scoreboard:
#     """A class to report scoring information."""
#
#     def __init__(self, ai_game):
#         """Initialize scorekeeping attributes."""
#         self.ai_game = ai_game
#         self.screen = ai_game.screen
#         self.screen_rect = self.screen.get_rect()
# # ... 69 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame.font
# from pygame.sprite import Group
#
# from ship import Ship
#
#
# class Scoreboard:
#     """A class to report scoring information."""
#
#     def __init__(self, ai_game):
#         """Initialize scorekeeping attributes."""
#         self.ai_game = ai_game
#         self.screen = ai_game.screen
#         self.screen_rect = self.screen.get_rect()
#         self.settings = ai_game.settings
#         self.stats = ai_game.stats
#
#         # Font settings for scoring information.
#         self.text_color = (30, 30, 30)
#         self.font = pygame.font.SysFont(None, 48)
#
#         # Prepare the initial score images.
#         self.prep_score()
#         self.prep_high_score()
#         self.prep_level()
#         self.prep_ships()
#
#     def prep_score(self):
#         """Turn the score into a rendered image."""
#         rounded_score = round(self.stats.score, -1)
#         score_str = f"{rounded_score:,}"
#         self.score_image = self.font.render(score_str, True,
#                 self.text_color, self.settings.bg_color)
#
#         # Display the score at the top right of the screen.
#         self.score_rect = self.score_image.get_rect()
#         self.score_rect.right = self.screen_rect.right - 20
#         self.score_rect.top = 20
#
#     def prep_high_score(self):
#         """Turn the high score into a rendered image."""
#         high_score = round(self.stats.high_score, -1)
#         high_score_str = f"{high_score:,}"
#         self.high_score_image = self.font.render(high_score_str, True,
#                 self.text_color, self.settings.bg_color)
#
#         # Center the high score at the top of the screen.
#         self.high_score_rect = self.high_score_image.get_rect()
#         self.high_score_rect.centerx = self.screen_rect.centerx
#         self.high_score_rect.top = self.score_rect.top
#
#     def prep_level(self):
#         """Turn the level into a rendered image."""
#         level_str = str(self.stats.level)
#         self.level_image = self.font.render(level_str, True,
#                 self.text_color, self.settings.bg_color)
#
#         # Position the level below the score.
#         self.level_rect = self.level_image.get_rect()
#         self.level_rect.right = self.score_rect.right
#         self.level_rect.top = self.score_rect.bottom + 10
#
#     def prep_ships(self):
#         """Show how many ships are left."""
#         self.ships = Group()
#         for ship_number in range(self.stats.ships_left):
#             ship = Ship(self.ai_game)
#             ship.rect.x = 10 + ship_number * ship.rect.width
#             ship.rect.y = 10
#             self.ships.add(ship)
#
#     def check_high_score(self):
#         """Check to see if there's a new high score."""
#         if self.stats.score > self.stats.high_score:
#             self.stats.high_score = self.stats.score
#             self.prep_high_score()
#
#     def show_score(self):
#         """Draw scores, level, and ships to the screen."""
#         self.screen.blit(self.score_image, self.score_rect)
#         self.screen.blit(self.high_score_image, self.high_score_rect)
#         self.screen.blit(self.level_image, self.level_rect)
#         self.ships.draw(self.screen)
# ```

# %%
# Practice rewrite for source example 14.20
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.21
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/scoring/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's static settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings
#         self.ship_limit = 3
#
#         # Bullet settings
# # ... 34 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# class Settings:
#     """A class to store all settings for Alien Invasion."""
#
#     def __init__(self):
#         """Initialize the game's static settings."""
#         # Screen settings
#         self.screen_width = 1200
#         self.screen_height = 800
#         self.bg_color = (230, 230, 230)
#
#         # Ship settings
#         self.ship_limit = 3
#
#         # Bullet settings
#         self.bullet_width = 3
#         self.bullet_height = 15
#         self.bullet_color = (60, 60, 60)
#         self.bullets_allowed = 3
#
#         # Alien settings
#         self.fleet_drop_speed = 10
#
#         # How quickly the game speeds up
#         self.speedup_scale = 1.1
#         # How quickly the alien point values increase
#         self.score_scale = 1.5
#
#         self.initialize_dynamic_settings()
#
#     def initialize_dynamic_settings(self):
#         """Initialize settings that change throughout the game."""
#         self.ship_speed = 1.5
#         self.bullet_speed = 2.5
#         self.alien_speed = 1.0
#
#         # fleet_direction of 1 represents right; -1 represents left.
#         self.fleet_direction = 1
#
#         # Scoring settings
#         self.alien_points = 50
#
#     def increase_speed(self):
#         """Increase speed settings and alien point values."""
#         self.ship_speed *= self.speedup_scale
#         self.bullet_speed *= self.speedup_scale
#         self.alien_speed *= self.speedup_scale
#
#         self.alien_points = int(self.alien_points * self.score_scale)
# ```

# %%
# Practice rewrite for source example 14.21
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 14.22
#
# Checklist note: captured from **Chapter 14: Scoring**, official GitHub source `chapter_14/scoring/ship.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This adds user experience and game state, connecting classes, conditionals, and persistent scores.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# game state -> button/score/level -> update display -> continue/reset
# ```
#
# **Code Preview**
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
#
# class Ship(Sprite):
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
# # ... 33 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import pygame
# from pygame.sprite import Sprite
#
#
# class Ship(Sprite):
#     """A class to manage the ship."""
#
#     def __init__(self, ai_game):
#         """Initialize the ship and set its starting position."""
#         super().__init__()
#         self.screen = ai_game.screen
#         self.settings = ai_game.settings
#         self.screen_rect = ai_game.screen.get_rect()
#
#         # Load the ship image and get its rect.
#         self.image = pygame.image.load('images/ship.bmp')
#         self.rect = self.image.get_rect()
#
#         # Start each new ship at the bottom center of the screen.
#         self.rect.midbottom = self.screen_rect.midbottom
#
#         # Store a float for the ship's exact horizontal position.
#         self.x = float(self.rect.x)
#
#         # Movement flags; start with a ship that's not moving.
#         self.moving_right = False
#         self.moving_left = False
#
#     def center_ship(self):
#         """Center the ship on the screen."""
#         self.rect.midbottom = self.screen_rect.midbottom
#         self.x = float(self.rect.x)
#
#     def update(self):
#         """Update the ship's position based on movement flags."""
#         # Update the ship's x value, not the rect.
#         if self.moving_right and self.rect.right < self.screen_rect.right:
#             self.x += self.settings.ship_speed
#         if self.moving_left and self.rect.left > 0:
#             self.x -= self.settings.ship_speed
#
#         # Update rect object from self.x.
#         self.rect.x = self.x
#
#     def blitme(self):
#         """Draw the ship at its current location."""
#         self.screen.blit(self.image, self.rect)
# ```

# %%
# Practice rewrite for source example 14.22
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Chapter 14: Scoring Practice Checkpoint

# %% [markdown]
# #### Practice: project-safe rewrite

# %%
# Project chapters often depend on installed packages, files, servers, or assets.
# Rewrite one source example with fake data first:
# - replace file/API/game/web inputs with a small list or dictionary
# - print the planned action
# - only then connect it back to the real project
planned_steps = ["identify input", "transform state", "show or save result"]
for step in planned_steps:
    print(step)

# %% [markdown]
# ## Chapter 15: Generating Data
#
# PDF pages: 492-535

# %% [markdown]
# ### Plotting Simple Line Graph

# %% [markdown]
# #### Source example 15.1
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/plotting_simple_line_graph/mpl_squares.py`.
#
# **Context**
#
# 1. This example demonstrates turning data into a readable report or visualization.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# input_values = [1, 2, 3, 4, 5]
# squares = [1, 4, 9, 16, 25]
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.plot(input_values, squares, linewidth=3)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # ... 4 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# input_values = [1, 2, 3, 4, 5]
# squares = [1, 4, 9, 16, 25]
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.plot(input_values, squares, linewidth=3)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # Set size of tick labels.
# ax.tick_params(labelsize=14)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 15.1
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.2
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/plotting_simple_line_graph/scatter_squares.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# x_values = range(1, 1001)
# y_values = [x**2 for x in x_values]
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues, s=10)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# x_values = range(1, 1001)
# y_values = [x**2 for x in x_values]
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues, s=10)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # Set size of tick labels.
# ax.tick_params(labelsize=14)
#
# # Set the range for each axis.
# ax.axis([0, 1100, 0, 1_100_000])
# ax.ticklabel_format(style='plain')
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 15.2
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Random Walks

# %% [markdown]
# #### Source example 15.3
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/random_walks/random_walk.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# from random import choice
#
#
# class RandomWalk:
#     """A class to generate random walks."""
#
#     def __init__(self, num_points=5000):
#         """Initialize attributes of a walk."""
#         self.num_points = num_points
#
#         # All walks start at (0, 0).
#         self.x_values = [0]
#         self.y_values = [0]
#
# # ... 24 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from random import choice
#
#
# class RandomWalk:
#     """A class to generate random walks."""
#
#     def __init__(self, num_points=5000):
#         """Initialize attributes of a walk."""
#         self.num_points = num_points
#
#         # All walks start at (0, 0).
#         self.x_values = [0]
#         self.y_values = [0]
#
#     def fill_walk(self):
#         """Calculate all the points in the walk."""
#         # Keep taking steps until the walk reaches the desired length.
#         while len(self.x_values) < self.num_points:
#
#             # Decide which direction to go, and how far to go.
#             x_direction = choice([1, -1])
#             x_distance = choice([0, 1, 2, 3, 4])
#             x_step = x_direction * x_distance
#
#             y_direction = choice([1, -1])
#             y_distance = choice([0, 1, 2, 3, 4])
#             y_step = y_direction * y_distance
#
#             # Reject moves that go nowhere.
#             if x_step == 0 and y_step == 0:
#                 continue
#
#             # Calculate the new position.
#             x = self.x_values[-1] + x_step
#             y = self.y_values[-1] + y_step
#
#             self.x_values.append(x)
#             self.y_values.append(y)
# ```

# %%
# Practice rewrite for source example 15.3
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.4
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/random_walks/rw_visual.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# from random_walk import RandomWalk
#
# # Keep making new walks, as long as the program is active.
# while True:
#     # Make a random walk.
#     rw = RandomWalk(50_000)
#     rw.fill_walk()
#
#     # Plot the points in the walk.
#     plt.style.use('classic')
#     fig, ax = plt.subplots()
#     point_numbers = range(rw.num_points)
# # ... 18 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# from random_walk import RandomWalk
#
# # Keep making new walks, as long as the program is active.
# while True:
#     # Make a random walk.
#     rw = RandomWalk(50_000)
#     rw.fill_walk()
#
#     # Plot the points in the walk.
#     plt.style.use('classic')
#     fig, ax = plt.subplots()
#     point_numbers = range(rw.num_points)
#     ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Blues,
#        edgecolors='none', s=1)
#     ax.set_aspect('equal')
#
#     # Emphasize the first and last points.
#     ax.scatter(0, 0, c='green', edgecolors='none', s=100)
#     ax.scatter(rw.x_values[-1], rw.y_values[-1], c='red', edgecolors='none',
#         s=100)
#
#     # Remove the axes.
#     ax.get_xaxis().set_visible(False)
#     ax.get_yaxis().set_visible(False)
#
#     plt.show()
#
#     keep_running = input("Make another walk? (y/n): ")
#     if keep_running == 'n':
#         break
# ```

# %%
# Practice rewrite for source example 15.4
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Rolling Dice

# %% [markdown]
# #### Source example 15.5
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/rolling_dice/dice_visual.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import plotly.express as px
#
# from die import Die
#
#
# # Create two D6 dice.
# die_1 = Die()
# die_2 = Die()
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(1000):
#     result = die_1.roll() + die_2.roll()
#     results.append(result)
# # ... 18 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import plotly.express as px
#
# from die import Die
#
#
# # Create two D6 dice.
# die_1 = Die()
# die_2 = Die()
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(1000):
#     result = die_1.roll() + die_2.roll()
#     results.append(result)
#
# # Analyze the results.
# frequencies = []
# max_result = die_1.num_sides + die_2.num_sides
# poss_results = range(2, max_result+1)
# for value in poss_results:
#     frequency = results.count(value)
#     frequencies.append(frequency)
#
# # Visualize the results.
# title = "Results of Rolling Two D6 Dice 1,000 Times"
# labels = {'x': 'Result', 'y': 'Frequency of Result'}
# fig = px.bar(x=poss_results, y=frequencies, title=title, labels=labels)
#
# # Further customize chart.
# fig.update_layout(xaxis_dtick=1)
#
# fig.show()
# ```

# %%
# Practice rewrite for source example 15.5
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.6
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/rolling_dice/dice_visual_d6d10.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import plotly.express as px
#
# from die import Die
#
#
# # Create a D6 and a D10.
# die_1 = Die()
# die_2 = Die(10)
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(50_000):
#     result = die_1.roll() + die_2.roll()
#     results.append(result)
# # ... 18 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import plotly.express as px
#
# from die import Die
#
#
# # Create a D6 and a D10.
# die_1 = Die()
# die_2 = Die(10)
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(50_000):
#     result = die_1.roll() + die_2.roll()
#     results.append(result)
#
# # Analyze the results.
# frequencies = []
# max_result = die_1.num_sides + die_2.num_sides
# poss_results = range(2, max_result+1)
# for value in poss_results:
#     frequency = results.count(value)
#     frequencies.append(frequency)
#
# # Visualize the results.
# title = "Results of Rolling a D6 and a D10 50,000 Times"
# labels = {'x': 'Result', 'y': 'Frequency of Result'}
# fig = px.bar(x=poss_results, y=frequencies, title=title, labels=labels)
#
# # Further customize chart.
# fig.update_layout(xaxis_dtick=1)
#
# fig.show()
# ```

# %%
# Practice rewrite for source example 15.6
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.7
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/rolling_dice/die.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# from random import randint
#
# class Die:
#     """A class representing a single die."""
#
#     def __init__(self, num_sides=6):
#         """Assume a six-sided die."""
#         self.num_sides = num_sides
#
#     def roll(self):
#         """"Return a random value between 1 and number of sides."""
#         return randint(1, self.num_sides)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from random import randint
#
# class Die:
#     """A class representing a single die."""
#
#     def __init__(self, num_sides=6):
#         """Assume a six-sided die."""
#         self.num_sides = num_sides
#
#     def roll(self):
#         """"Return a random value between 1 and number of sides."""
#         return randint(1, self.num_sides)
# ```

# %%
# Practice rewrite for source example 15.7
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.8
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/rolling_dice/die_visual.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import plotly.express as px
#
# from die import Die
#
#
# # Create a D6.
# die = Die()
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(1000):
#     result = die.roll()
#     results.append(result)
#
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import plotly.express as px
#
# from die import Die
#
#
# # Create a D6.
# die = Die()
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(1000):
#     result = die.roll()
#     results.append(result)
#
# # Analyze the results.
# frequencies = []
# poss_results = range(1, die.num_sides+1)
# for value in poss_results:
#     frequency = results.count(value)
#     frequencies.append(frequency)
#
# # Visualize the results.
# title = "Results of Rolling One D6 1,000 Times"
# labels = {'x': 'Result', 'y': 'Frequency of Result'}
# fig = px.bar(x=poss_results, y=frequencies, title=title, labels=labels)
# fig.show()
# ```

# %%
# Practice rewrite for source example 15.8
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Plotting Simple Line Graph / Partial Programs

# %% [markdown]
# #### Source example 15.9
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/plotting_simple_line_graph/partial_programs/mpl_squares_0_first_version.py`.
#
# **Context**
#
# 1. This example demonstrates turning data into a readable report or visualization.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# squares = [1, 4, 9, 16, 25]
#
# fig, ax = plt.subplots()
# ax.plot(squares)
#
# plt.show()
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# squares = [1, 4, 9, 16, 25]
#
# fig, ax = plt.subplots()
# ax.plot(squares)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 15.9
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.10
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/plotting_simple_line_graph/partial_programs/mpl_squares_1_labeled.py`.
#
# **Context**
#
# 1. This example demonstrates turning data into a readable report or visualization.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# squares = [1, 4, 9, 16, 25]
#
# fig, ax = plt.subplots()
# ax.plot(squares, linewidth=3)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # Set size of tick labels.
# ax.tick_params(labelsize=14)
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# squares = [1, 4, 9, 16, 25]
#
# fig, ax = plt.subplots()
# ax.plot(squares, linewidth=3)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # Set size of tick labels.
# ax.tick_params(labelsize=14)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 15.10
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.11
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/plotting_simple_line_graph/partial_programs/mpl_squares_2_corrected_plot.py`.
#
# **Context**
#
# 1. This example demonstrates turning data into a readable report or visualization.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# input_values = [1, 2, 3, 4, 5]
# squares = [1, 4, 9, 16, 25]
#
# fig, ax = plt.subplots()
# ax.plot(input_values, squares, linewidth=3)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # Set size of tick labels.
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# input_values = [1, 2, 3, 4, 5]
# squares = [1, 4, 9, 16, 25]
#
# fig, ax = plt.subplots()
# ax.plot(input_values, squares, linewidth=3)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # Set size of tick labels.
# ax.tick_params(labelsize=14)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 15.11
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.12
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/plotting_simple_line_graph/partial_programs/mpl_squares_3_style_seaborn.py`.
#
# **Context**
#
# 1. This example demonstrates turning data into a readable report or visualization.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# input_values = [1, 2, 3, 4, 5]
# squares = [1, 4, 9, 16, 25]
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.plot(input_values, squares, linewidth=3)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # ... 4 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# input_values = [1, 2, 3, 4, 5]
# squares = [1, 4, 9, 16, 25]
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.plot(input_values, squares, linewidth=3)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # Set size of tick labels.
# ax.tick_params(labelsize=14)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 15.12
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.13
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/plotting_simple_line_graph/partial_programs/scatter_squares_0_first_version.py`.
#
# **Context**
#
# 1. This example demonstrates turning data into a readable report or visualization.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.scatter(2, 4)
#
# plt.show()
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.scatter(2, 4)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 15.13
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.14
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/plotting_simple_line_graph/partial_programs/scatter_squares_1_labeled.py`.
#
# **Context**
#
# 1. This example demonstrates turning data into a readable report or visualization.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.scatter(2, 4, s=200)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # Set size of tick labels.
# ax.tick_params(labelsize=14)
#
# # ... 1 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.scatter(2, 4, s=200)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # Set size of tick labels.
# ax.tick_params(labelsize=14)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 15.14
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.15
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/plotting_simple_line_graph/partial_programs/scatter_squares_2_series_of_points.py`.
#
# **Context**
#
# 1. This example demonstrates turning data into a readable report or visualization.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# x_values = [1, 2, 3, 4, 5]
# y_values = [1, 4, 9, 16, 25]
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.scatter(x_values, y_values, s=100)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # ... 4 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# x_values = [1, 2, 3, 4, 5]
# y_values = [1, 4, 9, 16, 25]
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.scatter(x_values, y_values, s=100)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # Set size of tick labels.
# ax.tick_params(labelsize=14)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 15.15
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.16
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/plotting_simple_line_graph/partial_programs/scatter_squares_3_calculating_automatically.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# x_values = range(1, 1001)
# y_values = [x**2 for x in x_values]
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.scatter(x_values, y_values, s=10)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# x_values = range(1, 1001)
# y_values = [x**2 for x in x_values]
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.scatter(x_values, y_values, s=10)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # Set size of tick labels.
# ax.tick_params(labelsize=14)
#
# # Set the range for each axis.
# ax.axis([0, 1100, 0, 1_100_000])
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 15.16
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.17
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/plotting_simple_line_graph/partial_programs/scatter_squares_4_custom_tick_labels.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# x_values = range(1, 1001)
# y_values = [x**2 for x in x_values]
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.scatter(x_values, y_values, s=10)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# x_values = range(1, 1001)
# y_values = [x**2 for x in x_values]
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.scatter(x_values, y_values, s=10)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # Set size of tick labels.
# ax.tick_params(labelsize=14)
#
# # Set the range for each axis.
# ax.axis([0, 1100, 0, 1_100_000])
# ax.ticklabel_format(style='plain')
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 15.17
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.18
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/plotting_simple_line_graph/partial_programs/scatter_squares_5_colormap.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# x_values = range(1, 1001)
# y_values = [x**2 for x in x_values]
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues, s=10)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# x_values = range(1, 1001)
# y_values = [x**2 for x in x_values]
#
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues, s=10)
#
# # Set chart title and label axes.
# ax.set_title("Square Numbers", fontsize=24)
# ax.set_xlabel("Value", fontsize=14)
# ax.set_ylabel("Square of Value", fontsize=14)
#
# # Set size of tick labels.
# ax.tick_params(labelsize=14)
#
# # Set the range for each axis.
# ax.axis([0, 1100, 0, 1_100_000])
# ax.ticklabel_format(style='plain')
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 15.18
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Random Walks / Partial Programs

# %% [markdown]
# #### Source example 15.19
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/random_walks/partial_programs/random_walk.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# from random import choice
#
#
# class RandomWalk:
#     """A class to generate random walks."""
#
#     def __init__(self, num_points=5000):
#         """Initialize attributes of a walk."""
#         self.num_points = num_points
#
#         # All walks start at (0, 0).
#         self.x_values = [0]
#         self.y_values = [0]
#
# # ... 24 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from random import choice
#
#
# class RandomWalk:
#     """A class to generate random walks."""
#
#     def __init__(self, num_points=5000):
#         """Initialize attributes of a walk."""
#         self.num_points = num_points
#
#         # All walks start at (0, 0).
#         self.x_values = [0]
#         self.y_values = [0]
#
#     def fill_walk(self):
#         """Calculate all the points in the walk."""
#         # Keep taking steps until the walk reaches the desired length.
#         while len(self.x_values) < self.num_points:
#
#             # Decide which direction to go, and how far to go.
#             x_direction = choice([1, -1])
#             x_distance = choice([0, 1, 2, 3, 4])
#             x_step = x_direction * x_distance
#
#             y_direction = choice([1, -1])
#             y_distance = choice([0, 1, 2, 3, 4])
#             y_step = y_direction * y_distance
#
#             # Reject moves that go nowhere.
#             if x_step == 0 and y_step == 0:
#                 continue
#
#             # Calculate the new position.
#             x = self.x_values[-1] + x_step
#             y = self.y_values[-1] + y_step
#
#             self.x_values.append(x)
#             self.y_values.append(y)
# ```

# %%
# Practice rewrite for source example 15.19
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.20
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/random_walks/partial_programs/rw_visual_0_first_version.py`.
#
# **Context**
#
# 1. This example demonstrates turning data into a readable report or visualization.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# from random_walk import RandomWalk
#
# # Make a random walk.
# rw = RandomWalk()
# rw.fill_walk()
#
# # Plot the points in the walk.
# plt.style.use('classic')
# fig, ax = plt.subplots()
# ax.scatter(rw.x_values, rw.y_values, s=15)
# ax.set_aspect('equal')
# plt.show()
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# from random_walk import RandomWalk
#
# # Make a random walk.
# rw = RandomWalk()
# rw.fill_walk()
#
# # Plot the points in the walk.
# plt.style.use('classic')
# fig, ax = plt.subplots()
# ax.scatter(rw.x_values, rw.y_values, s=15)
# ax.set_aspect('equal')
# plt.show()
# ```

# %%
# Practice rewrite for source example 15.20
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.21
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/random_walks/partial_programs/rw_visual_1_multiple_walks.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# from random_walk import RandomWalk
#
# # Keep making new walks, as long as the program is active.
# while True:
#     # Make a random walk.
#     rw = RandomWalk()
#     rw.fill_walk()
#
#     # Plot the points in the walk.
#     plt.style.use('classic')
#     fig, ax = plt.subplots()
#     ax.scatter(rw.x_values, rw.y_values, s=15)
# # ... 6 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# from random_walk import RandomWalk
#
# # Keep making new walks, as long as the program is active.
# while True:
#     # Make a random walk.
#     rw = RandomWalk()
#     rw.fill_walk()
#
#     # Plot the points in the walk.
#     plt.style.use('classic')
#     fig, ax = plt.subplots()
#     ax.scatter(rw.x_values, rw.y_values, s=15)
#     ax.set_aspect('equal')
#     plt.show()
#
#     keep_running = input("Make another walk? (y/n): ")
#     if keep_running == 'n':
#         break
# ```

# %%
# Practice rewrite for source example 15.21
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.22
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/random_walks/partial_programs/rw_visual_2_coloring_points.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# from random_walk import RandomWalk
#
# # Keep making new walks, as long as the program is active.
# while True:
#     # Make a random walk.
#     rw = RandomWalk()
#     rw.fill_walk()
#
#     # Plot the points in the walk.
#     plt.style.use('classic')
#     fig, ax = plt.subplots()
#     point_numbers = range(rw.num_points)
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# from random_walk import RandomWalk
#
# # Keep making new walks, as long as the program is active.
# while True:
#     # Make a random walk.
#     rw = RandomWalk()
#     rw.fill_walk()
#
#     # Plot the points in the walk.
#     plt.style.use('classic')
#     fig, ax = plt.subplots()
#     point_numbers = range(rw.num_points)
#     ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Blues,
#         edgecolors='none', s=15)
#     ax.set_aspect('equal')
#     plt.show()
#
#     keep_running = input("Make another walk? (y/n): ")
#     if keep_running == 'n':
#         break
# ```

# %%
# Practice rewrite for source example 15.22
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.23
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/random_walks/partial_programs/rw_visual_3_starting_ending_points.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# from random_walk import RandomWalk
#
# # Keep making new walks, as long as the program is active.
# while True:
#     # Make a random walk.
#     rw = RandomWalk()
#     rw.fill_walk()
#
#     # Plot the points in the walk.
#     plt.style.use('classic')
#     fig, ax = plt.subplots()
#     point_numbers = range(rw.num_points)
# # ... 14 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# from random_walk import RandomWalk
#
# # Keep making new walks, as long as the program is active.
# while True:
#     # Make a random walk.
#     rw = RandomWalk()
#     rw.fill_walk()
#
#     # Plot the points in the walk.
#     plt.style.use('classic')
#     fig, ax = plt.subplots()
#     point_numbers = range(rw.num_points)
#     ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Blues,
#         edgecolors='none', s=15)
#     ax.set_aspect('equal')
#
#     # Emphasize the first and last points.
#     ax.scatter(0, 0, c='green', edgecolors='none', s=100)
#     ax.scatter(rw.x_values[-1], rw.y_values[-1], c='red', edgecolors='none',
#         s=100)
#
#     plt.show()
#
#     keep_running = input("Make another walk? (y/n): ")
#     if keep_running == 'n':
#         break
# ```

# %%
# Practice rewrite for source example 15.23
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.24
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/random_walks/partial_programs/rw_visual_4_cleaning_axes.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# from random_walk import RandomWalk
#
# # Keep making new walks, as long as the program is active.
# while True:
#     # Make a random walk.
#     rw = RandomWalk()
#     rw.fill_walk()
#
#     # Plot the points in the walk.
#     plt.style.use('classic')
#     fig, ax = plt.subplots()
#     point_numbers = range(rw.num_points)
# # ... 18 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# from random_walk import RandomWalk
#
# # Keep making new walks, as long as the program is active.
# while True:
#     # Make a random walk.
#     rw = RandomWalk()
#     rw.fill_walk()
#
#     # Plot the points in the walk.
#     plt.style.use('classic')
#     fig, ax = plt.subplots()
#     point_numbers = range(rw.num_points)
#     ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Blues,
#         edgecolors='none', s=15)
#     ax.set_aspect('equal')
#
#     # Emphasize the first and last points.
#     ax.scatter(0, 0, c='green', edgecolors='none', s=100)
#     ax.scatter(rw.x_values[-1], rw.y_values[-1], c='red', edgecolors='none',
#         s=100)
#
#     # Remove the axes.
#     ax.get_xaxis().set_visible(False)
#     ax.get_yaxis().set_visible(False)
#
#     plt.show()
#
#     keep_running = input("Make another walk? (y/n): ")
#     if keep_running == 'n':
#         break
# ```

# %%
# Practice rewrite for source example 15.24
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.25
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/random_walks/partial_programs/rw_visual_5_adding_plot_points.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import matplotlib.pyplot as plt
#
# from random_walk import RandomWalk
#
# # Keep making new walks, as long as the program is active.
# while True:
#     # Make a random walk.
#     rw = RandomWalk(50_000)
#     rw.fill_walk()
#
#     # Plot the points in the walk.
#     plt.style.use('classic')
#     fig, ax = plt.subplots()
#     point_numbers = range(rw.num_points)
# # ... 18 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import matplotlib.pyplot as plt
#
# from random_walk import RandomWalk
#
# # Keep making new walks, as long as the program is active.
# while True:
#     # Make a random walk.
#     rw = RandomWalk(50_000)
#     rw.fill_walk()
#
#     # Plot the points in the walk.
#     plt.style.use('classic')
#     fig, ax = plt.subplots()
#     point_numbers = range(rw.num_points)
#     ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Blues,
#        edgecolors='none', s=1)
#     ax.set_aspect('equal')
#
#     # Emphasize the first and last points.
#     ax.scatter(0, 0, c='green', edgecolors='none', s=100)
#     ax.scatter(rw.x_values[-1], rw.y_values[-1], c='red', edgecolors='none',
#         s=100)
#
#     # Remove the axes.
#     ax.get_xaxis().set_visible(False)
#     ax.get_yaxis().set_visible(False)
#
#     plt.show()
#
#     keep_running = input("Make another walk? (y/n): ")
#     if keep_running == 'n':
#         break
# ```

# %%
# Practice rewrite for source example 15.25
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Rolling Dice / Partial Programs

# %% [markdown]
# #### Source example 15.26
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/rolling_dice/partial_programs/dice_visual_0_first_version.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import plotly.express as px
#
# from die import Die
#
#
# # Create two D6 dice.
# die_1 = Die()
# die_2 = Die()
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(1000):
#     result = die_1.roll() + die_2.roll()
#     results.append(result)
# # ... 14 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import plotly.express as px
#
# from die import Die
#
#
# # Create two D6 dice.
# die_1 = Die()
# die_2 = Die()
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(1000):
#     result = die_1.roll() + die_2.roll()
#     results.append(result)
#
# # Analyze the results.
# frequencies = []
# max_result = die_1.num_sides + die_2.num_sides
# poss_results = range(2, max_result+1)
# for value in poss_results:
#     frequency = results.count(value)
#     frequencies.append(frequency)
#
# # Visualize the results.
# title = "Results of Rolling Two D6 Dice 1,000 Times"
# labels = {'x': 'Result', 'y': 'Frequency of Result'}
# fig = px.bar(x=poss_results, y=frequencies, title=title, labels=labels)
# fig.show()
# ```

# %%
# Practice rewrite for source example 15.26
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.27
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/rolling_dice/partial_programs/dice_visual_1_further_customizations.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import plotly.express as px
#
# from die import Die
#
#
# # Create two D6 dice.
# die_1 = Die()
# die_2 = Die()
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(1000):
#     result = die_1.roll() + die_2.roll()
#     results.append(result)
# # ... 18 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import plotly.express as px
#
# from die import Die
#
#
# # Create two D6 dice.
# die_1 = Die()
# die_2 = Die()
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(1000):
#     result = die_1.roll() + die_2.roll()
#     results.append(result)
#
# # Analyze the results.
# frequencies = []
# max_result = die_1.num_sides + die_2.num_sides
# poss_results = range(2, max_result+1)
# for value in poss_results:
#     frequency = results.count(value)
#     frequencies.append(frequency)
#
# # Visualize the results.
# title = "Results of Rolling Two D6 Dice 1,000 Times"
# labels = {'x': 'Result', 'y': 'Frequency of Result'}
# fig = px.bar(x=poss_results, y=frequencies, title=title, labels=labels)
#
# # Further customize chart.
# fig.update_layout(xaxis_dtick=1)
#
# fig.show()
# ```

# %%
# Practice rewrite for source example 15.27
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.28
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/rolling_dice/partial_programs/dice_visual_d6d10.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import plotly.express as px
#
# from die import Die
#
#
# # Create a D6 and a D10.
# die_1 = Die()
# die_2 = Die(10)
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(50_000):
#     result = die_1.roll() + die_2.roll()
#     results.append(result)
# # ... 18 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import plotly.express as px
#
# from die import Die
#
#
# # Create a D6 and a D10.
# die_1 = Die()
# die_2 = Die(10)
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(50_000):
#     result = die_1.roll() + die_2.roll()
#     results.append(result)
#
# # Analyze the results.
# frequencies = []
# max_result = die_1.num_sides + die_2.num_sides
# poss_results = range(2, max_result+1)
# for value in poss_results:
#     frequency = results.count(value)
#     frequencies.append(frequency)
#
# # Visualize the results.
# title = "Results of Rolling a D6 and a D10 50,000 Times"
# labels = {'x': 'Result', 'y': 'Frequency of Result'}
# fig = px.bar(x=poss_results, y=frequencies, title=title, labels=labels)
#
# # Further customize chart.
# fig.update_layout(xaxis_dtick=1)
#
# fig.show()
# ```

# %%
# Practice rewrite for source example 15.28
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.29
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/rolling_dice/partial_programs/die.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# from random import randint
#
# class Die:
#     """A class representing a single die."""
#
#     def __init__(self, num_sides=6):
#         """Assume a six-sided die."""
#         self.num_sides = num_sides
#
#     def roll(self):
#         """"Return a random value between 1 and number of sides."""
#         return randint(1, self.num_sides)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from random import randint
#
# class Die:
#     """A class representing a single die."""
#
#     def __init__(self, num_sides=6):
#         """Assume a six-sided die."""
#         self.num_sides = num_sides
#
#     def roll(self):
#         """"Return a random value between 1 and number of sides."""
#         return randint(1, self.num_sides)
# ```

# %%
# Practice rewrite for source example 15.29
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.30
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/rolling_dice/partial_programs/die_visual_0_first_version.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# from die import Die
#
# # Create a D6.
# die = Die()
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(100):
#     result = die.roll()
#     results.append(result)
#
# print(results)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from die import Die
#
# # Create a D6.
# die = Die()
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(100):
#     result = die.roll()
#     results.append(result)
#
# print(results)
# ```

# %%
# Practice rewrite for source example 15.30
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.31
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/rolling_dice/partial_programs/die_visual_1_analyzing_results.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# from die import Die
#
# # Create a D6.
# die = Die()
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(1000):
#     result = die.roll()
#     results.append(result)
#
# # Analyze the results.
# frequencies = []
# poss_results = range(1, die.num_sides+1)
# # ... 5 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from die import Die
#
# # Create a D6.
# die = Die()
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(1000):
#     result = die.roll()
#     results.append(result)
#
# # Analyze the results.
# frequencies = []
# poss_results = range(1, die.num_sides+1)
# for value in poss_results:
#     frequency = results.count(value)
#     frequencies.append(frequency)
#
# print(frequencies)
# ```

# %%
# Practice rewrite for source example 15.31
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.32
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/rolling_dice/partial_programs/die_visual_2_making_histogram.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import plotly.express as px
#
# from die import Die
#
#
# # Create a D6.
# die = Die()
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(1000):
#     result = die.roll()
#     results.append(result)
#
# # ... 10 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import plotly.express as px
#
# from die import Die
#
#
# # Create a D6.
# die = Die()
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(1000):
#     result = die.roll()
#     results.append(result)
#
# # Analyze the results.
# frequencies = []
# poss_results = range(1, die.num_sides+1)
# for value in poss_results:
#     frequency = results.count(value)
#     frequencies.append(frequency)
#
# # Visualize the results.
# fig = px.bar(x=poss_results, y=frequencies)
# fig.show()
# ```

# %%
# Practice rewrite for source example 15.32
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 15.33
#
# Checklist note: captured from **Chapter 15: Generating Data**, official GitHub source `chapter_15/rolling_dice/partial_programs/die_visual_3_customizing_plot.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This reuses lists, loops, dictionaries, and files to turn data into visual insight.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# generated data -> list/dict -> chart library -> visualization
# ```
#
# **Code Preview**
#
# ```python
# import plotly.express as px
#
# from die import Die
#
#
# # Create a D6.
# die = Die()
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(1000):
#     result = die.roll()
#     results.append(result)
#
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import plotly.express as px
#
# from die import Die
#
#
# # Create a D6.
# die = Die()
#
# # Make some rolls, and store results in a list.
# results = []
# for roll_num in range(1000):
#     result = die.roll()
#     results.append(result)
#
# # Analyze the results.
# frequencies = []
# poss_results = range(1, die.num_sides+1)
# for value in poss_results:
#     frequency = results.count(value)
#     frequencies.append(frequency)
#
# # Visualize the results.
# title = "Results of Rolling One D6 1,000 Times"
# labels = {'x': 'Result', 'y': 'Frequency of Result'}
# fig = px.bar(x=poss_results, y=frequencies, title=title, labels=labels)
# fig.show()
# ```

# %%
# Practice rewrite for source example 15.33
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Chapter 15: Generating Data Practice Checkpoint

# %% [markdown]
# #### Practice: project-safe rewrite

# %%
# Project chapters often depend on installed packages, files, servers, or assets.
# Rewrite one source example with fake data first:
# - replace file/API/game/web inputs with a small list or dictionary
# - print the planned action
# - only then connect it back to the real project
planned_steps = ["identify input", "transform state", "show or save result"]
for step in planned_steps:
    print(step)

# %% [markdown]
# ## Chapter 16: Downloading Data
#
# PDF pages: 536-573

# %% [markdown]
# ### Mapping Global Datasets

# %% [markdown]
# #### Source example 16.1
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/mapping_global_datasets/eq_explore_data.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import json
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_1_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
#
# mags, lons, lats = [], [], []
# for eq_dict in all_eq_dicts:
# # ... 10 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import json
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_1_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
#
# mags, lons, lats = [], [], []
# for eq_dict in all_eq_dicts:
#     mag = eq_dict['properties']['mag']
#     lon = eq_dict['geometry']['coordinates'][0]
#     lat = eq_dict['geometry']['coordinates'][1]
#     mags.append(mag)
#     lons.append(lon)
#     lats.append(lat)
#
# print(mags[:10])
# print(lons[:5])
# print(lats[:5])
# ```

# %%
# Practice rewrite for source example 16.1
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.2
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/mapping_global_datasets/eq_world_map.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import json
#
# import plotly.express as px
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_30_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
#
# # ... 20 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import json
#
# import plotly.express as px
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_30_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
#
# mags, lons, lats, eq_titles = [], [], [], []
# for eq_dict in all_eq_dicts:
#     mag = eq_dict['properties']['mag']
#     lon = eq_dict['geometry']['coordinates'][0]
#     lat = eq_dict['geometry']['coordinates'][1]
#     eq_title = eq_dict['properties']['title']
#     mags.append(mag)
#     lons.append(lon)
#     lats.append(lat)
#     eq_titles.append(eq_title)
#
# title = 'Global Earthquakes'
# fig = px.scatter_geo(lat=lats, lon=lons, size=mags, title=title,
#         color=mags,
#         color_continuous_scale='Viridis',
#         labels={'color':'Magnitude'},
#         projection='natural earth',
#         hover_name=eq_titles,
#     )
# fig.show()
# ```

# %%
# Practice rewrite for source example 16.2
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### The Csv File Format

# %% [markdown]
# #### Source example 16.3
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/the_csv_file_format/death_valley_highs_lows.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/death_valley_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates, and high and low temperatures.
# # ... 28 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/death_valley_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates, and high and low temperatures.
# dates, highs, lows = [], [], []
# for row in reader:
#     current_date = datetime.strptime(row[2], '%Y-%m-%d')
#     try:
#         high = int(row[3])
#         low = int(row[4])
#     except ValueError:
#         print(f"Missing data for {current_date}")
#     else:
#         dates.append(current_date)
#         highs.append(high)
#         lows.append(low)
#
# # Plot the high and low temperatures.
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.plot(dates, highs, color='red', alpha=0.5)
# ax.plot(dates, lows, color='blue', alpha=0.5)
# ax.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1)
#
# # Format plot.
# title = "Daily High and Low Temperatures, 2021\nDeath Valley, CA"
# ax.set_title(title, fontsize=20)
# fig.autofmt_xdate()
# ax.set_ylabel("Temperature (F)", fontsize=16)
# ax.tick_params(labelsize=16)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 16.3
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.4
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/the_csv_file_format/sitka_highs.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/sitka_weather_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates and high temperatures.
# # ... 20 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/sitka_weather_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates and high temperatures.
# dates, highs = [], []
# for row in reader:
#     current_date = datetime.strptime(row[2], '%Y-%m-%d')
#     high = int(row[4])
#     dates.append(current_date)
#     highs.append(high)
#
# # Plot the high temperatures.
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.plot(dates, highs, color='red')
#
# # Format plot.
# ax.set_title("Daily High Temperatures, 2021", fontsize=24)
# ax.set_xlabel('', fontsize=16)
# fig.autofmt_xdate()
# ax.set_ylabel("Temperature (F)", fontsize=16)
# ax.tick_params(labelsize=16)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 16.4
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.5
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/the_csv_file_format/sitka_highs_lows.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/sitka_weather_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates, and high and low temperatures.
# # ... 24 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/sitka_weather_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates, and high and low temperatures.
# dates, highs, lows = [], [], []
# for row in reader:
#     current_date = datetime.strptime(row[2], '%Y-%m-%d')
#     high = int(row[4])
#     low = int(row[5])
#     dates.append(current_date)
#     highs.append(high)
#     lows.append(low)
#
# # Plot the high and low temperatures.
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.plot(dates, highs, color='red', alpha=0.5)
# ax.plot(dates, lows, color='blue', alpha=0.5)
# ax.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1)
#
# # Format plot.
# ax.set_title("Daily High and Low Temperatures, 2021", fontsize=24)
# ax.set_xlabel('', fontsize=16)
# fig.autofmt_xdate()
# ax.set_ylabel("Temperature (F)", fontsize=16)
# ax.tick_params(labelsize=16)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 16.5
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Mapping Global Datasets / Partial Programs

# %% [markdown]
# #### Source example 16.6
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/mapping_global_datasets/partial_programs/eq_explore_data_0_first_version.py`.
#
# **Context**
#
# 1. This example demonstrates working with outside data and handling things that can go wrong.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import json
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_1_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Create a more readable version of the data file.
# path = Path('eq_data/readable_eq_data.geojson')
# readable_contents = json.dumps(all_eq_data, indent=4)
# path.write_text(readable_contents)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import json
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_1_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Create a more readable version of the data file.
# path = Path('eq_data/readable_eq_data.geojson')
# readable_contents = json.dumps(all_eq_data, indent=4)
# path.write_text(readable_contents)
# ```

# %%
# Practice rewrite for source example 16.6
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.7
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/mapping_global_datasets/partial_programs/eq_explore_data_1_list_all_earthquakes.py`.
#
# **Context**
#
# 1. This example demonstrates working with outside data and handling things that can go wrong.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import json
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_1_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
# print(len(all_eq_dicts))
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import json
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_1_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
# print(len(all_eq_dicts))
# ```

# %%
# Practice rewrite for source example 16.7
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.8
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/mapping_global_datasets/partial_programs/eq_explore_data_2_extract_magnitudes.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import json
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_1_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
#
# mags = []
# for eq_dict in all_eq_dicts:
# # ... 4 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import json
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_1_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
#
# mags = []
# for eq_dict in all_eq_dicts:
#     mag = eq_dict['properties']['mag']
#     mags.append(mag)
#
# print(mags[:10])
# ```

# %%
# Practice rewrite for source example 16.8
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.9
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/mapping_global_datasets/partial_programs/eq_explore_data_3_extract_location_data.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import json
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_1_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
#
# mags, lons, lats = [], [], []
# for eq_dict in all_eq_dicts:
# # ... 10 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import json
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_1_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
#
# mags, lons, lats = [], [], []
# for eq_dict in all_eq_dicts:
#     mag = eq_dict['properties']['mag']
#     lon = eq_dict['geometry']['coordinates'][0]
#     lat = eq_dict['geometry']['coordinates'][1]
#     mags.append(mag)
#     lons.append(lon)
#     lats.append(lat)
#
# print(mags[:10])
# print(lons[:5])
# print(lats[:5])
# ```

# %%
# Practice rewrite for source example 16.9
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.10
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/mapping_global_datasets/partial_programs/eq_world_map_0_first_version.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import json
#
# import plotly.express as px
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_1_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
#
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import json
#
# import plotly.express as px
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_1_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
#
# mags, lons, lats = [], [], []
# for eq_dict in all_eq_dicts:
#     mag = eq_dict['properties']['mag']
#     lon = eq_dict['geometry']['coordinates'][0]
#     lat = eq_dict['geometry']['coordinates'][1]
#     mags.append(mag)
#     lons.append(lon)
#     lats.append(lat)
#
# title = 'Global Earthquakes'
# fig = px.scatter_geo(lat=lats, lon=lons, title=title)
# fig.show()
# ```

# %%
# Practice rewrite for source example 16.10
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.11
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/mapping_global_datasets/partial_programs/eq_world_map_1_representing_magnitudes.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import json
#
# import plotly.express as px
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_30_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
#
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import json
#
# import plotly.express as px
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_30_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
#
# mags, lons, lats = [], [], []
# for eq_dict in all_eq_dicts:
#     mag = eq_dict['properties']['mag']
#     lon = eq_dict['geometry']['coordinates'][0]
#     lat = eq_dict['geometry']['coordinates'][1]
#     mags.append(mag)
#     lons.append(lon)
#     lats.append(lat)
#
# title = 'Global Earthquakes'
# fig = px.scatter_geo(lat=lats, lon=lons, size=mags, title=title)
# fig.show()
# ```

# %%
# Practice rewrite for source example 16.11
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.12
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/mapping_global_datasets/partial_programs/eq_world_map_2_custom_marker_colors.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import json
#
# import plotly.express as px
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_30_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
#
# # ... 17 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import json
#
# import plotly.express as px
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_30_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
#
# mags, lons, lats = [], [], []
# for eq_dict in all_eq_dicts:
#     mag = eq_dict['properties']['mag']
#     lon = eq_dict['geometry']['coordinates'][0]
#     lat = eq_dict['geometry']['coordinates'][1]
#     mags.append(mag)
#     lons.append(lon)
#     lats.append(lat)
#
# title = 'Global Earthquakes'
# fig = px.scatter_geo(lat=lats, lon=lons, size=mags, title=title,
#         color=mags,
#         color_continuous_scale='Viridis',
#         labels={'color':'Magnitude'},
#         projection='natural earth',
#     )
# fig.show()
# ```

# %%
# Practice rewrite for source example 16.12
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.13
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/mapping_global_datasets/partial_programs/eq_world_map_3_adding_hover_text.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import json
#
# import plotly.express as px
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_30_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
#
# # ... 20 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import json
#
# import plotly.express as px
#
#
# # Read data as a string and convert to a Python object.
# path = Path('eq_data/eq_data_30_day_m1.geojson')
# contents = path.read_text(encoding='utf-8')
# all_eq_data = json.loads(contents)
#
# # Examine all earthquakes in the dataset.
# all_eq_dicts = all_eq_data['features']
#
# mags, lons, lats, eq_titles = [], [], [], []
# for eq_dict in all_eq_dicts:
#     mag = eq_dict['properties']['mag']
#     lon = eq_dict['geometry']['coordinates'][0]
#     lat = eq_dict['geometry']['coordinates'][1]
#     eq_title = eq_dict['properties']['title']
#     mags.append(mag)
#     lons.append(lon)
#     lats.append(lat)
#     eq_titles.append(eq_title)
#
# title = 'Global Earthquakes'
# fig = px.scatter_geo(lat=lats, lon=lons, size=mags, title=title,
#         color=mags,
#         color_continuous_scale='Viridis',
#         labels={'color':'Magnitude'},
#         projection='natural earth',
#         hover_name=eq_titles,
#     )
# fig.show()
# ```

# %%
# Practice rewrite for source example 16.13
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### The Csv File Format / Partial Programs

# %% [markdown]
# #### Source example 16.14
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/the_csv_file_format/partial_programs/death_valley_highs_lows_0_first_version.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import csv
#
#
# path = Path('weather_data/death_valley_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# for index, column_header in enumerate(header_row):
#     print(index, column_header)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import csv
#
#
# path = Path('weather_data/death_valley_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# for index, column_header in enumerate(header_row):
#     print(index, column_header)
# ```

# %%
# Practice rewrite for source example 16.14
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.15
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/the_csv_file_format/partial_programs/death_valley_highs_lows_1_no_try_catch.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/death_valley_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates, and high and low temperatures.
# # ... 24 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/death_valley_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates, and high and low temperatures.
# dates, highs, lows = [], [], []
# for row in reader:
#     current_date = datetime.strptime(row[2], '%Y-%m-%d')
#     high = int(row[3])
#     low = int(row[4])
#     dates.append(current_date)
#     highs.append(high)
#     lows.append(low)
#
# # Plot the high and low temperatures.
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.plot(dates, highs, color='red', alpha=0.5)
# ax.plot(dates, lows, color='blue', alpha=0.5)
# ax.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1)
#
# # Format plot.
# ax.set_title("Daily High and Low Temperatures, 2021", fontsize=24)
# ax.set_xlabel('', fontsize=16)
# fig.autofmt_xdate()
# ax.set_ylabel("Temperature (F)", fontsize=16)
# ax.tick_params(labelsize=16)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 16.15
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.16
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/the_csv_file_format/partial_programs/death_valley_highs_lows_2_with_try_catch.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/death_valley_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates, and high and low temperatures.
# # ... 28 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/death_valley_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates, and high and low temperatures.
# dates, highs, lows = [], [], []
# for row in reader:
#     current_date = datetime.strptime(row[2], '%Y-%m-%d')
#     try:
#         high = int(row[3])
#         low = int(row[4])
#     except ValueError:
#         print(f"Missing data for {current_date}")
#     else:
#         dates.append(current_date)
#         highs.append(high)
#         lows.append(low)
#
# # Plot the high and low temperatures.
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.plot(dates, highs, color='red', alpha=0.5)
# ax.plot(dates, lows, color='blue', alpha=0.5)
# ax.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1)
#
# # Format plot.
# title = "Daily High and Low Temperatures, 2021\nDeath Valley, CA"
# ax.set_title(title, fontsize=20)
# fig.autofmt_xdate()
# ax.set_ylabel("Temperature (F)", fontsize=16)
# ax.tick_params(labelsize=16)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 16.16
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.17
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/the_csv_file_format/partial_programs/sitka_highs_0_first_version.py`.
#
# **Context**
#
# 1. This example demonstrates turning data into a readable report or visualization.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import csv
#
#
# path = Path('weather_data/sitka_weather_07-2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# print(header_row)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import csv
#
#
# path = Path('weather_data/sitka_weather_07-2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# print(header_row)
# ```

# %%
# Practice rewrite for source example 16.17
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.18
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/the_csv_file_format/partial_programs/sitka_highs_1_headers_positions.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import csv
#
#
# path = Path('weather_data/sitka_weather_07-2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# for index, column_header in enumerate(header_row):
#     print(index, column_header)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import csv
#
#
# path = Path('weather_data/sitka_weather_07-2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# for index, column_header in enumerate(header_row):
#     print(index, column_header)
# ```

# %%
# Practice rewrite for source example 16.18
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.19
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/the_csv_file_format/partial_programs/sitka_highs_2_extracting_reading_data.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import csv
#
#
# path = Path('weather_data/sitka_weather_07-2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract high temperatures.
# highs = []
# for row in reader:
#     high = int(row[4])
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import csv
#
#
# path = Path('weather_data/sitka_weather_07-2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract high temperatures.
# highs = []
# for row in reader:
#     high = int(row[4])
#     highs.append(high)
#
# print(highs)
# ```

# %%
# Practice rewrite for source example 16.19
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.20
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/the_csv_file_format/partial_programs/sitka_highs_3_plotting_data.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import csv
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/sitka_weather_07-2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract high temperatures.
# highs = []
# # ... 16 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import csv
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/sitka_weather_07-2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract high temperatures.
# highs = []
# for row in reader:
#     high = int(row[4])
#     highs.append(high)
#
# # Plot the high temperatures.
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.plot(highs, color='red')
#
# # Format plot.
# ax.set_title("Daily High Temperatures, July 2021", fontsize=24)
# ax.set_xlabel('', fontsize=16)
# ax.set_ylabel("Temperature (F)", fontsize=16)
# ax.tick_params(labelsize=16)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 16.20
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.21
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/the_csv_file_format/partial_programs/sitka_highs_4_plotting_dates.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/sitka_weather_07-2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates and high temperatures.
# # ... 20 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/sitka_weather_07-2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates and high temperatures.
# dates, highs = [], []
# for row in reader:
#     current_date = datetime.strptime(row[2], '%Y-%m-%d')
#     high = int(row[4])
#     dates.append(current_date)
#     highs.append(high)
#
# # Plot the high temperatures.
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.plot(dates, highs, color='red')
#
# # Format plot.
# ax.set_title("Daily High Temperatures, July 2021", fontsize=24)
# ax.set_xlabel('', fontsize=16)
# fig.autofmt_xdate()
# ax.set_ylabel("Temperature (F)", fontsize=16)
# ax.tick_params(labelsize=16)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 16.21
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.22
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/the_csv_file_format/partial_programs/sitka_highs_5_longer_timeframe.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/sitka_weather_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates and high temperatures.
# # ... 20 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/sitka_weather_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates and high temperatures.
# dates, highs = [], []
# for row in reader:
#     current_date = datetime.strptime(row[2], '%Y-%m-%d')
#     high = int(row[4])
#     dates.append(current_date)
#     highs.append(high)
#
# # Plot the high temperatures.
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.plot(dates, highs, color='red')
#
# # Format plot.
# ax.set_title("Daily High Temperatures, 2021", fontsize=24)
# ax.set_xlabel('', fontsize=16)
# fig.autofmt_xdate()
# ax.set_ylabel("Temperature (F)", fontsize=16)
# ax.tick_params(labelsize=16)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 16.22
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.23
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/the_csv_file_format/partial_programs/sitka_highs_lows_0_first_version.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/sitka_weather_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates, and high and low temperatures.
# # ... 23 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/sitka_weather_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates, and high and low temperatures.
# dates, highs, lows = [], [], []
# for row in reader:
#     current_date = datetime.strptime(row[2], '%Y-%m-%d')
#     high = int(row[4])
#     low = int(row[5])
#     dates.append(current_date)
#     highs.append(high)
#     lows.append(low)
#
# # Plot the high and low temperatures.
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.plot(dates, highs, color='red')
# ax.plot(dates, lows, color='blue')
#
# # Format plot.
# ax.set_title("Daily High and Low Temperatures, 2021", fontsize=24)
# ax.set_xlabel('', fontsize=16)
# fig.autofmt_xdate()
# ax.set_ylabel("Temperature (F)", fontsize=16)
# ax.tick_params(labelsize=16)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 16.23
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 16.24
#
# Checklist note: captured from **Chapter 16: Downloading Data**, official GitHub source `chapter_16/the_csv_file_format/partial_programs/sitka_highs_lows_1_shading_area.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on data visualization by pulling in real-world datasets from files and online sources.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# downloaded/file data -> parse -> clean -> plot/map
# ```
#
# **Code Preview**
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/sitka_weather_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates, and high and low temperatures.
# # ... 24 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from pathlib import Path
# import csv
# from datetime import datetime
#
# import matplotlib.pyplot as plt
#
#
# path = Path('weather_data/sitka_weather_2021_simple.csv')
# lines = path.read_text().splitlines()
#
# reader = csv.reader(lines)
# header_row = next(reader)
#
# # Extract dates, and high and low temperatures.
# dates, highs, lows = [], [], []
# for row in reader:
#     current_date = datetime.strptime(row[2], '%Y-%m-%d')
#     high = int(row[4])
#     low = int(row[5])
#     dates.append(current_date)
#     highs.append(high)
#     lows.append(low)
#
# # Plot the high and low temperatures.
# plt.style.use('seaborn-v0_8')
# fig, ax = plt.subplots()
# ax.plot(dates, highs, color='red', alpha=0.5)
# ax.plot(dates, lows, color='blue', alpha=0.5)
# ax.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1)
#
# # Format plot.
# ax.set_title("Daily High and Low Temperatures, 2021", fontsize=24)
# ax.set_xlabel('', fontsize=16)
# fig.autofmt_xdate()
# ax.set_ylabel("Temperature (F)", fontsize=16)
# ax.tick_params(labelsize=16)
#
# plt.show()
# ```

# %%
# Practice rewrite for source example 16.24
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Chapter 16: Downloading Data Practice Checkpoint

# %% [markdown]
# #### Practice: project-safe rewrite

# %%
# Project chapters often depend on installed packages, files, servers, or assets.
# Rewrite one source example with fake data first:
# - replace file/API/game/web inputs with a small list or dictionary
# - print the planned action
# - only then connect it back to the real project
planned_steps = ["identify input", "transform state", "show or save result"]
for step in planned_steps:
    print(step)

# %% [markdown]
# ## Chapter 17: Working with APIs
#
# PDF pages: 574-601

# %% [markdown]
# ### Official source files

# %% [markdown]
# #### Source example 17.1
#
# Checklist note: captured from **Chapter 17: Working with APIs**, official GitHub source `chapter_17/hn_article.py`.
#
# **Context**
#
# 1. This example demonstrates working with outside data and handling things that can go wrong.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on dictionaries, JSON, requests, and error handling to work with live web APIs.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# API endpoint -> request -> JSON/dicts -> process/display
# ```
#
# **Code Preview**
#
# ```python
# import requests
# import json
#
#
# # Make an API call, and store the response.
# url = "https://hacker-news.firebaseio.com/v0/item/31353677.json"
# r = requests.get(url)
# print(f"Status code: {r.status_code}")
#
# # Explore the structure of the data.
# response_dict = r.json()
# response_string = json.dumps(response_dict, indent=4)
# print(response_string)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import requests
# import json
#
#
# # Make an API call, and store the response.
# url = "https://hacker-news.firebaseio.com/v0/item/31353677.json"
# r = requests.get(url)
# print(f"Status code: {r.status_code}")
#
# # Explore the structure of the data.
# response_dict = r.json()
# response_string = json.dumps(response_dict, indent=4)
# print(response_string)
# ```

# %%
# Practice rewrite for source example 17.1
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 17.2
#
# Checklist note: captured from **Chapter 17: Working with APIs**, official GitHub source `chapter_17/hn_submissions.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on dictionaries, JSON, requests, and error handling to work with live web APIs.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# API endpoint -> request -> JSON/dicts -> process/display
# ```
#
# **Code Preview**
#
# ```python
# from operator import itemgetter
#
# import requests
#
#
# # Make an API call and check the response.
# url = 'https://hacker-news.firebaseio.com/v0/topstories.json'
# r = requests.get(url)
# print(f"Status code: {r.status_code}")
#
# # Process information about each submission.
# submission_ids = r.json()
#
# submission_dicts = []
# # ... 22 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from operator import itemgetter
#
# import requests
#
#
# # Make an API call and check the response.
# url = 'https://hacker-news.firebaseio.com/v0/topstories.json'
# r = requests.get(url)
# print(f"Status code: {r.status_code}")
#
# # Process information about each submission.
# submission_ids = r.json()
#
# submission_dicts = []
# for submission_id in submission_ids[:30]:
#     # Make a new API call for each submission.
#     url = f"https://hacker-news.firebaseio.com/v0/item/{submission_id}.json"
#     r = requests.get(url)
#     print(f"id: {submission_id}\tstatus: {r.status_code}")
#     response_dict = r.json()
#
#     # Build a dictionary for each article.
#     submission_dict = {
#         'title': response_dict['title'],
#         'hn_link': f"https://news.ycombinator.com/item?id={submission_id}",
#         'comments': response_dict['descendants'],
#     }
#     submission_dicts.append(submission_dict)
#
# submission_dicts = sorted(submission_dicts, key=itemgetter('comments'),
#                             reverse=True)
#
# for submission_dict in submission_dicts:
#     print(f"\nTitle: {submission_dict['title']}")
#     print(f"Discussion link: {submission_dict['hn_link']}")
#     print(f"Comments: {submission_dict['comments']}")
# ```

# %%
# Practice rewrite for source example 17.2
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 17.3
#
# Checklist note: captured from **Chapter 17: Working with APIs**, official GitHub source `chapter_17/python_repos.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on dictionaries, JSON, requests, and error handling to work with live web APIs.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# API endpoint -> request -> JSON/dicts -> process/display
# ```
#
# **Code Preview**
#
# ```python
# import requests
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Convert the response object to a dictionary.
# response_dict = r.json()
#
# # ... 16 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import requests
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Convert the response object to a dictionary.
# response_dict = r.json()
#
# print(f"Total repositories: {response_dict['total_count']}")
# print(f"Complete results: {not response_dict['incomplete_results']}")
#
# # Explore information about the repositories.
# repo_dicts = response_dict['items']
# print(f"Repositories returned: {len(repo_dicts)}")
#
# print("\nSelected information about each repository:")
# for repo_dict in repo_dicts:
#     print(f"Name: {repo_dict['name']}")
#     print(f"Owner: {repo_dict['owner']['login']}")
#     print(f"Stars: {repo_dict['stargazers_count']}")
#     print(f"Repository: {repo_dict['html_url']}")
#     print(f"Created: {repo_dict['created_at']}")
#     print(f"Updated: {repo_dict['updated_at']}")
#     print(f"Description: {repo_dict['description']}")
# ```

# %%
# Practice rewrite for source example 17.3
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 17.4
#
# Checklist note: captured from **Chapter 17: Working with APIs**, official GitHub source `chapter_17/python_repos_visual.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on dictionaries, JSON, requests, and error handling to work with live web APIs.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# API endpoint -> request -> JSON/dicts -> process/display
# ```
#
# **Code Preview**
#
# ```python
# import requests
# import plotly.express as px
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Process overall results.
# response_dict = r.json()
# # ... 32 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import requests
# import plotly.express as px
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Process overall results.
# response_dict = r.json()
# print(f"Complete results: {not response_dict['incomplete_results']}")
#
# # Process repository information.
# repo_dicts = response_dict['items']
# repo_links, stars, hover_texts = [], [], []
# for repo_dict in repo_dicts:
#     # Turn repo names into active links.
#     repo_name = repo_dict['name']
#     repo_url = repo_dict['html_url']
#     repo_link = f"<a href='{repo_url}'>{repo_name}</a>"
#     repo_links.append(repo_link)
#
#     stars.append(repo_dict['stargazers_count'])
#
#     # Build hover texts.
#     owner = repo_dict['owner']['login']
#     description = repo_dict['description']
#     hover_text = f"{owner}<br />{description}"
#     hover_texts.append(hover_text)
#
# # Make visualization.
# title = "Most-Starred Python Projects on GitHub"
# labels = {'x': 'Repository', 'y': 'Stars'}
# fig = px.bar(x=repo_links, y=stars, title=title, labels=labels,
#         hover_name=hover_texts)
#
# fig.update_layout(title_font_size=28, xaxis_title_font_size=20,
#         yaxis_title_font_size=20)
#
# fig.update_traces(marker_color='SteelBlue', marker_opacity=0.6)
#
# fig.show()
# ```

# %%
# Practice rewrite for source example 17.4
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Partial Programs

# %% [markdown]
# #### Source example 17.5
#
# Checklist note: captured from **Chapter 17: Working with APIs**, official GitHub source `chapter_17/partial_programs/hn_article.py`.
#
# **Context**
#
# 1. This example demonstrates working with outside data and handling things that can go wrong.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on dictionaries, JSON, requests, and error handling to work with live web APIs.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# API endpoint -> request -> JSON/dicts -> process/display
# ```
#
# **Code Preview**
#
# ```python
# import requests
# import json
#
#
# # Make an API call, and store the response.
# url = "https://hacker-news.firebaseio.com/v0/item/31353677.json"
# r = requests.get(url)
# print(f"Status code: {r.status_code}")
#
# # Explore the structure of the data.
# response_dict = r.json()
# response_string = json.dumps(response_dict, indent=4)
# print(response_string)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import requests
# import json
#
#
# # Make an API call, and store the response.
# url = "https://hacker-news.firebaseio.com/v0/item/31353677.json"
# r = requests.get(url)
# print(f"Status code: {r.status_code}")
#
# # Explore the structure of the data.
# response_dict = r.json()
# response_string = json.dumps(response_dict, indent=4)
# print(response_string)
# ```

# %%
# Practice rewrite for source example 17.5
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 17.6
#
# Checklist note: captured from **Chapter 17: Working with APIs**, official GitHub source `chapter_17/partial_programs/hn_submissions.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on dictionaries, JSON, requests, and error handling to work with live web APIs.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# API endpoint -> request -> JSON/dicts -> process/display
# ```
#
# **Code Preview**
#
# ```python
# from operator import itemgetter
#
# import requests
#
#
# # Make an API call and check the response.
# url = 'https://hacker-news.firebaseio.com/v0/topstories.json'
# r = requests.get(url)
# print(f"Status code: {r.status_code}")
#
# # Process information about each submission.
# submission_ids = r.json()
#
# submission_dicts = []
# # ... 22 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from operator import itemgetter
#
# import requests
#
#
# # Make an API call and check the response.
# url = 'https://hacker-news.firebaseio.com/v0/topstories.json'
# r = requests.get(url)
# print(f"Status code: {r.status_code}")
#
# # Process information about each submission.
# submission_ids = r.json()
#
# submission_dicts = []
# for submission_id in submission_ids[:5]:
#     # Make a new API call for each submission.
#     url = f"https://hacker-news.firebaseio.com/v0/item/{submission_id}.json"
#     r = requests.get(url)
#     print(f"id: {submission_id}\tstatus: {r.status_code}")
#     response_dict = r.json()
#
#     # Build a dictionary for each article.
#     submission_dict = {
#         'title': response_dict['title'],
#         'hn_link': f"https://news.ycombinator.com/item?id={submission_id}",
#         'comments': response_dict['descendants'],
#     }
#     submission_dicts.append(submission_dict)
#
# submission_dicts = sorted(submission_dicts, key=itemgetter('comments'),
#                             reverse=True)
#
# for submission_dict in submission_dicts:
#     print(f"\nTitle: {submission_dict['title']}")
#     print(f"Discussion link: {submission_dict['hn_link']}")
#     print(f"Comments: {submission_dict['comments']}")
# ```

# %%
# Practice rewrite for source example 17.6
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 17.7
#
# Checklist note: captured from **Chapter 17: Working with APIs**, official GitHub source `chapter_17/partial_programs/python_repos_0_first_version.py`.
#
# **Context**
#
# 1. This example demonstrates working with outside data and handling things that can go wrong.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on dictionaries, JSON, requests, and error handling to work with live web APIs.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# API endpoint -> request -> JSON/dicts -> process/display
# ```
#
# **Code Preview**
#
# ```python
# import requests
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Convert the response object to a dictionary.
# response_dict = r.json()
#
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import requests
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Convert the response object to a dictionary.
# response_dict = r.json()
#
# # Process results.
# print(response_dict.keys())
# ```

# %%
# Practice rewrite for source example 17.7
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 17.8
#
# Checklist note: captured from **Chapter 17: Working with APIs**, official GitHub source `chapter_17/partial_programs/python_repos_1_working_with_response_dict.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on dictionaries, JSON, requests, and error handling to work with live web APIs.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# API endpoint -> request -> JSON/dicts -> process/display
# ```
#
# **Code Preview**
#
# ```python
# import requests
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Convert the response object to a dictionary.
# response_dict = r.json()
#
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import requests
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Convert the response object to a dictionary.
# response_dict = r.json()
#
# print(f"Total repositories: {response_dict['total_count']}")
# print(f"Complete results: {not response_dict['incomplete_results']}")
#
# # Explore information about the repositories.
# repo_dicts = response_dict['items']
# print(f"Repositories returned: {len(repo_dicts)}")
#
# # Examine the first repository.
# repo_dict = repo_dicts[0]
# print(f"\nKeys: {len(repo_dict)}")
# for key in sorted(repo_dict.keys()):
#   print(key)
# ```

# %%
# Practice rewrite for source example 17.8
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 17.9
#
# Checklist note: captured from **Chapter 17: Working with APIs**, official GitHub source `chapter_17/partial_programs/python_repos_2_examine_first_repo.py`.
#
# **Context**
#
# 1. This example demonstrates working with outside data and handling things that can go wrong.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on dictionaries, JSON, requests, and error handling to work with live web APIs.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# API endpoint -> request -> JSON/dicts -> process/display
# ```
#
# **Code Preview**
#
# ```python
# import requests
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Convert the response object to a dictionary.
# response_dict = r.json()
#
# # ... 18 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import requests
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Convert the response object to a dictionary.
# response_dict = r.json()
#
# print(f"Total repositories: {response_dict['total_count']}")
# print(f"Complete results: {not response_dict['incomplete_results']}")
#
# # Explore information about the repositories.
# repo_dicts = response_dict['items']
# print(f"Repositories returned: {len(repo_dicts)}")
#
# # Examine the first repository.
# repo_dict = repo_dicts[0]
#
# print("\nSelected information about first repository:")
# print(f"Name: {repo_dict['name']}")
# print(f"Owner: {repo_dict['owner']['login']}")
# print(f"Stars: {repo_dict['stargazers_count']}")
# print(f"Repository: {repo_dict['html_url']}")
# print(f"Created: {repo_dict['created_at']}")
# print(f"Updated: {repo_dict['updated_at']}")
# print(f"Description: {repo_dict['description']}")
# ```

# %%
# Practice rewrite for source example 17.9
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 17.10
#
# Checklist note: captured from **Chapter 17: Working with APIs**, official GitHub source `chapter_17/partial_programs/python_repos_3_summarizing_top_repos.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on dictionaries, JSON, requests, and error handling to work with live web APIs.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# API endpoint -> request -> JSON/dicts -> process/display
# ```
#
# **Code Preview**
#
# ```python
# import requests
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Convert the response object to a dictionary.
# response_dict = r.json()
#
# # ... 17 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import requests
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Convert the response object to a dictionary.
# response_dict = r.json()
#
# print(f"Total repositories: {response_dict['total_count']}")
# print(f"Complete results: {not response_dict['incomplete_results']}")
#
# # Explore information about the repositories.
# repo_dicts = response_dict['items']
# print(f"Repositories returned: {len(repo_dicts)}")
#
# print("\nSelected information about each repository:")
# for repo_dict in repo_dicts:
#     print("\nSelected information about first repository:")
#     print(f"Name: {repo_dict['name']}")
#     print(f"Owner: {repo_dict['owner']['login']}")
#     print(f"Stars: {repo_dict['stargazers_count']}")
#     print(f"Repository: {repo_dict['html_url']}")
#     print(f"Created: {repo_dict['created_at']}")
#     print(f"Updated: {repo_dict['updated_at']}")
#     print(f"Description: {repo_dict['description']}")
# ```

# %%
# Practice rewrite for source example 17.10
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 17.11
#
# Checklist note: captured from **Chapter 17: Working with APIs**, official GitHub source `chapter_17/partial_programs/python_repos_visual_0_first_version.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on dictionaries, JSON, requests, and error handling to work with live web APIs.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# API endpoint -> request -> JSON/dicts -> process/display
# ```
#
# **Code Preview**
#
# ```python
# import requests
# import plotly.express as px
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Process overall results.
# response_dict = r.json()
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import requests
# import plotly.express as px
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Process overall results.
# response_dict = r.json()
# print(f"Complete results: {not response_dict['incomplete_results']}")
#
# # Process repository information.
# repo_dicts = response_dict['items']
# repo_names, stars = [], []
# for repo_dict in repo_dicts:
#     repo_names.append(repo_dict['name'])
#     stars.append(repo_dict['stargazers_count'])
#
# # Make visualization.
# fig = px.bar(x=repo_names, y=stars)
# fig.show()
# ```

# %%
# Practice rewrite for source example 17.11
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 17.12
#
# Checklist note: captured from **Chapter 17: Working with APIs**, official GitHub source `chapter_17/partial_programs/python_repos_visual_1_styling_chart.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on dictionaries, JSON, requests, and error handling to work with live web APIs.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# API endpoint -> request -> JSON/dicts -> process/display
# ```
#
# **Code Preview**
#
# ```python
# import requests
# import plotly.express as px
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Process overall results.
# response_dict = r.json()
# # ... 18 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import requests
# import plotly.express as px
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Process overall results.
# response_dict = r.json()
# print(f"Complete results: {not response_dict['incomplete_results']}")
#
# # Process repository information.
# repo_dicts = response_dict['items']
# repo_names, stars = [], []
# for repo_dict in repo_dicts:
#     repo_names.append(repo_dict['name'])
#     stars.append(repo_dict['stargazers_count'])
#
# # Make visualization.
# title = "Most-Starred Python Projects on GitHub"
# labels = {'x': 'Repository', 'y': 'Stars'}
# fig = px.bar(x=repo_names, y=stars, title=title, labels=labels)
#
# fig.update_layout(title_font_size=28, xaxis_title_font_size=20,
#         yaxis_title_font_size=20)
#
# fig.show()
# ```

# %%
# Practice rewrite for source example 17.12
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 17.13
#
# Checklist note: captured from **Chapter 17: Working with APIs**, official GitHub source `chapter_17/partial_programs/python_repos_visual_2_custom_tooltips.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on dictionaries, JSON, requests, and error handling to work with live web APIs.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# API endpoint -> request -> JSON/dicts -> process/display
# ```
#
# **Code Preview**
#
# ```python
# import requests
# import plotly.express as px
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Process overall results.
# response_dict = r.json()
# # ... 25 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import requests
# import plotly.express as px
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Process overall results.
# response_dict = r.json()
# print(f"Complete results: {not response_dict['incomplete_results']}")
#
# # Process repository information.
# repo_dicts = response_dict['items']
# repo_names, stars, hover_texts = [], [], []
# for repo_dict in repo_dicts:
#     repo_names.append(repo_dict['name'])
#     stars.append(repo_dict['stargazers_count'])
#
#     # Build hover texts.
#     owner = repo_dict['owner']['login']
#     description = repo_dict['description']
#     hover_text = f"{owner}<br />{description}"
#     hover_texts.append(hover_text)
#
# # Make visualization.
# title = "Most-Starred Python Projects on GitHub"
# labels = {'x': 'Repository', 'y': 'Stars'}
# fig = px.bar(x=repo_names, y=stars, title=title, labels=labels,
#         hover_name=hover_texts)
#
# fig.update_layout(title_font_size=28, xaxis_title_font_size=20,
#         yaxis_title_font_size=20)
#
# fig.show()
# ```

# %%
# Practice rewrite for source example 17.13
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 17.14
#
# Checklist note: captured from **Chapter 17: Working with APIs**, official GitHub source `chapter_17/partial_programs/python_repos_visual_3_clickable_links.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on dictionaries, JSON, requests, and error handling to work with live web APIs.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# API endpoint -> request -> JSON/dicts -> process/display
# ```
#
# **Code Preview**
#
# ```python
# import requests
# import plotly.express as px
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Process overall results.
# response_dict = r.json()
# # ... 30 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import requests
# import plotly.express as px
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Process overall results.
# response_dict = r.json()
# print(f"Complete results: {not response_dict['incomplete_results']}")
#
# # Process repository information.
# repo_dicts = response_dict['items']
# repo_links, stars, hover_texts = [], [], []
# for repo_dict in repo_dicts:
#     # Turn repo names into active links.
#     repo_name = repo_dict['name']
#     repo_url = repo_dict['html_url']
#     repo_link = f"<a href='{repo_url}'>{repo_name}</a>"
#     repo_links.append(repo_link)
#
#     stars.append(repo_dict['stargazers_count'])
#
#     # Build hover texts.
#     owner = repo_dict['owner']['login']
#     description = repo_dict['description']
#     hover_text = f"{owner}<br />{description}"
#     hover_texts.append(hover_text)
#
# # Make visualization.
# title = "Most-Starred Python Projects on GitHub"
# labels = {'x': 'Repository', 'y': 'Stars'}
# fig = px.bar(x=repo_links, y=stars, title=title, labels=labels,
#         hover_name=hover_texts)
#
# fig.update_layout(title_font_size=28, xaxis_title_font_size=20,
#         yaxis_title_font_size=20)
#
# fig.show()
# ```

# %%
# Practice rewrite for source example 17.14
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 17.15
#
# Checklist note: captured from **Chapter 17: Working with APIs**, official GitHub source `chapter_17/partial_programs/python_repos_visual_4_custom_marker_colors.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on dictionaries, JSON, requests, and error handling to work with live web APIs.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# API endpoint -> request -> JSON/dicts -> process/display
# ```
#
# **Code Preview**
#
# ```python
# import requests
# import plotly.express as px
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Process overall results.
# response_dict = r.json()
# # ... 32 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# import requests
# import plotly.express as px
#
#
# # Make an API call and check the response.
# url = "https://api.github.com/search/repositories"
# url += "?q=language:python+sort:stars+stars:>10000"
#
# headers = {"Accept": "application/vnd.github.v3+json"}
# r = requests.get(url, headers=headers)
# print(f"Status code: {r.status_code}")
#
# # Process overall results.
# response_dict = r.json()
# print(f"Complete results: {not response_dict['incomplete_results']}")
#
# # Process repository information.
# repo_dicts = response_dict['items']
# repo_links, stars, hover_texts = [], [], []
# for repo_dict in repo_dicts:
#     # Turn repo names into active links.
#     repo_name = repo_dict['name']
#     repo_url = repo_dict['html_url']
#     repo_link = f"<a href='{repo_url}'>{repo_name}</a>"
#     repo_links.append(repo_link)
#
#     stars.append(repo_dict['stargazers_count'])
#
#     # Build hover texts.
#     owner = repo_dict['owner']['login']
#     description = repo_dict['description']
#     hover_text = f"{owner}<br />{description}"
#     hover_texts.append(hover_text)
#
# # Make visualization.
# title = "Most-Starred Python Projects on GitHub"
# labels = {'x': 'Repository', 'y': 'Stars'}
# fig = px.bar(x=repo_links, y=stars, title=title, labels=labels,
#         hover_name=hover_texts)
#
# fig.update_layout(title_font_size=28, xaxis_title_font_size=20,
#         yaxis_title_font_size=20)
#
# fig.update_traces(marker_color='SteelBlue', marker_opacity=0.6)
#
# fig.show()
# ```

# %%
# Practice rewrite for source example 17.15
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Chapter 17: Working with APIs Practice Checkpoint

# %% [markdown]
# #### Practice: project-safe rewrite

# %%
# Project chapters often depend on installed packages, files, servers, or assets.
# Rewrite one source example with fake data first:
# - replace file/API/game/web inputs with a small list or dictionary
# - print the planned action
# - only then connect it back to the real project
planned_steps = ["identify input", "transform state", "show or save result"]
for step in planned_steps:
    print(step)

# %% [markdown]
# ## Chapter 18: Getting Started with Django
#
# PDF pages: 602-648

# %% [markdown]
# ### Building Additional Pages / Learning Logs

# %% [markdown]
# #### Source example 18.1
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/building_additional_pages/learning_logs/admin.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# from django.contrib import admin
#
# from .models import Topic, Entry
#
#
# admin.site.register(Topic)
# admin.site.register(Entry)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.contrib import admin
#
# from .models import Topic, Entry
#
#
# admin.site.register(Topic)
# admin.site.register(Entry)
# ```

# %%
# Practice rewrite for source example 18.1
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.2
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/building_additional_pages/learning_logs/apps.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# from django.apps import AppConfig
#
#
# class LearningLogsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'learning_logs'
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.apps import AppConfig
#
#
# class LearningLogsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'learning_logs'
# ```

# %%
# Practice rewrite for source example 18.2
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Building Additional Pages / Learning Logs / Migrations

# %% [markdown]
# #### Source example 18.3
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/building_additional_pages/learning_logs/migrations/0001_initial.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:24
#
# from django.db import migrations, models
#
#
# class Migration(migrations.Migration):
#
#     initial = True
#
#     dependencies = [
#     ]
#
#     operations = [
#         migrations.CreateModel(
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:24
#
# from django.db import migrations, models
#
#
# class Migration(migrations.Migration):
#
#     initial = True
#
#     dependencies = [
#     ]
#
#     operations = [
#         migrations.CreateModel(
#             name='Topic',
#             fields=[
#                 ('id', models.BigAutoField(auto_created=True, primary_key=True, serialize=False, verbose_name='ID')),
#                 ('text', models.CharField(max_length=200)),
#                 ('date_added', models.DateTimeField(auto_now_add=True)),
#             ],
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 18.3
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.4
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/building_additional_pages/learning_logs/migrations/0002_entry.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:28
#
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         ('learning_logs', '0001_initial'),
#     ]
#
#     operations = [
#         migrations.CreateModel(
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:28
#
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         ('learning_logs', '0001_initial'),
#     ]
#
#     operations = [
#         migrations.CreateModel(
#             name='Entry',
#             fields=[
#                 ('id', models.BigAutoField(auto_created=True, primary_key=True, serialize=False, verbose_name='ID')),
#                 ('text', models.TextField()),
#                 ('date_added', models.DateTimeField(auto_now_add=True)),
#                 ('topic', models.ForeignKey(on_delete=django.db.models.deletion.CASCADE, to='learning_logs.topic')),
#             ],
#             options={
#                 'verbose_name_plural': 'entries',
#             },
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 18.4
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Building Additional Pages / Learning Logs

# %% [markdown]
# #### Source example 18.5
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/building_additional_pages/learning_logs/models.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# from django.db import models
#
# class Topic(models.Model):
#     """A topic the user is learning about."""
#     text = models.CharField(max_length=200)
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     def __str__(self):
#         """Return a string representation of the model."""
#         return self.text
#
#
# class Entry(models.Model):
#     """Something specific learned about a topic."""
# # ... 10 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.db import models
#
# class Topic(models.Model):
#     """A topic the user is learning about."""
#     text = models.CharField(max_length=200)
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     def __str__(self):
#         """Return a string representation of the model."""
#         return self.text
#
#
# class Entry(models.Model):
#     """Something specific learned about a topic."""
#     topic = models.ForeignKey(Topic, on_delete=models.CASCADE)
#     text = models.TextField()
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     class Meta:
#         verbose_name_plural = 'entries'
#
#     def __str__(self):
#         """Return a simple string representing the entry."""
#         return f"{self.text[:50]}..."
# ```

# %%
# Practice rewrite for source example 18.5
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Building Additional Pages / Learning Logs / Templates / Learning Logs

# %% [markdown]
# #### Source example 18.6
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/building_additional_pages/learning_logs/templates/learning_logs/base.html`.
#
# **Context**
#
# 1. This example belongs to starting a Django web app, from the section `Building Additional Pages / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```html
# <p>
#   <a href="{% url 'learning_logs:index' %}">Learning Log</a> -
#   <a href="{% url 'learning_logs:topics' %}">Topics</a>
# </p>
#
# {% block content %}{% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# <p>
#   <a href="{% url 'learning_logs:index' %}">Learning Log</a> -
#   <a href="{% url 'learning_logs:topics' %}">Topics</a>
# </p>
#
# {% block content %}{% endblock content %}
# ```

# %%
# Practice rewrite for source example 18.6
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.7
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/building_additional_pages/learning_logs/templates/learning_logs/index.html`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#   <p>Learning Log helps you keep track of your learning, for any topic you're
#   interested in.</p>
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#   <p>Learning Log helps you keep track of your learning, for any topic you're
#   interested in.</p>
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 18.7
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.8
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/building_additional_pages/learning_logs/templates/learning_logs/topic.html`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   <p>Topic: {{ topic.text }}</p>
#
#   <p>Entries:</p>
#   <ul>
#     {% for entry in entries %}
#       <li>
#         <p>{{ entry.date_added|date:'M d, Y H:i' }}</p>
#         <p>{{ entry.text|linebreaks }}</p>
#       </li>
#     {% empty %}
# # ... 5 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   <p>Topic: {{ topic.text }}</p>
#
#   <p>Entries:</p>
#   <ul>
#     {% for entry in entries %}
#       <li>
#         <p>{{ entry.date_added|date:'M d, Y H:i' }}</p>
#         <p>{{ entry.text|linebreaks }}</p>
#       </li>
#     {% empty %}
#       <li>There are no entries for this topic yet.</li>
#     {% endfor %}
#   </ul>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 18.8
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.9
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/building_additional_pages/learning_logs/templates/learning_logs/topics.html`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   <p>Topics</p>
#   <ul>
#     {% for topic in topics %}
#       <li>
#         <a href="{% url 'learning_logs:topic' topic.id %}">
#           {{ topic.text }}</a>
#       </li>
#     {% empty %}
#       <li>No topics have been added yet.</li>
#     {% endfor %}
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   <p>Topics</p>
#   <ul>
#     {% for topic in topics %}
#       <li>
#         <a href="{% url 'learning_logs:topic' topic.id %}">
#           {{ topic.text }}</a>
#       </li>
#     {% empty %}
#       <li>No topics have been added yet.</li>
#     {% endfor %}
#   </ul>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 18.9
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Building Additional Pages / Learning Logs

# %% [markdown]
# #### Source example 18.10
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/building_additional_pages/learning_logs/tests.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %%
# Practice rewrite for source example 18.10
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.11
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/building_additional_pages/learning_logs/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """Defines URL patterns for learning_logs."""
#
# from django.urls import path
#
# from . import views
#
# app_name = 'learning_logs'
# urlpatterns = [
#     # Home page
#     path('', views.index, name='index'),
#     # Page that shows all topics.
#     path('topics/', views.topics, name='topics'),
#     # Detail page for a single topic.
#     path('topics/<int:topic_id>/', views.topic, name='topic'),
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """Defines URL patterns for learning_logs."""
#
# from django.urls import path
#
# from . import views
#
# app_name = 'learning_logs'
# urlpatterns = [
#     # Home page
#     path('', views.index, name='index'),
#     # Page that shows all topics.
#     path('topics/', views.topics, name='topics'),
#     # Detail page for a single topic.
#     path('topics/<int:topic_id>/', views.topic, name='topic'),
#
# ]
# ```

# %%
# Practice rewrite for source example 18.11
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.12
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/building_additional_pages/learning_logs/views.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# from django.shortcuts import render
#
# from .models import Topic
#
#
# def index(request):
#     """The home page for Learning Log."""
#     return render(request, 'learning_logs/index.html')
#
# def topics(request):
#     """Show all topics."""
#     topics = Topic.objects.order_by('date_added')
#     context = {'topics': topics}
#     return render(request, 'learning_logs/topics.html', context)
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.shortcuts import render
#
# from .models import Topic
#
#
# def index(request):
#     """The home page for Learning Log."""
#     return render(request, 'learning_logs/index.html')
#
# def topics(request):
#     """Show all topics."""
#     topics = Topic.objects.order_by('date_added')
#     context = {'topics': topics}
#     return render(request, 'learning_logs/topics.html', context)
#
# def topic(request, topic_id):
#     """Show a single topic and all its entries."""
#     topic = Topic.objects.get(id=topic_id)
#     entries = topic.entry_set.order_by('-date_added')
#     context = {'topic': topic, 'entries': entries}
#     return render(request, 'learning_logs/topic.html', context)
# ```

# %%
# Practice rewrite for source example 18.12
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Building Additional Pages / Ll Project

# %% [markdown]
# #### Source example 18.13
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/building_additional_pages/ll_project/asgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_asgi_application()
# ```

# %%
# Practice rewrite for source example 18.13
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.14
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/building_additional_pages/ll_project/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # ... 112 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # Build paths inside the project like this: BASE_DIR / 'subdir'.
# BASE_DIR = Path(__file__).resolve().parent.parent
#
#
# # Quick-start development settings - unsuitable for production
# # See https://docs.djangoproject.com/en/dev/howto/deployment/checklist/
#
# # SECURITY WARNING: keep the secret key used in production secret!
# SECRET_KEY = 'django-insecure-mibxt7sboxg%r)9t6z=a6@weyo(thgbknfcwgyowgx9$5s4&=!'
#
# # SECURITY WARNING: don't run with debug turned on in production!
# DEBUG = True
#
# ALLOWED_HOSTS = []
#
# # Application definition
#
# INSTALLED_APPS = [
#     # My apps.
#     'learning_logs',
#
#     # Default django apps.
#     'django.contrib.admin',
#     'django.contrib.auth',
#     'django.contrib.contenttypes',
#     'django.contrib.sessions',
#     'django.contrib.messages',
#     'django.contrib.staticfiles',
# ]
#
# MIDDLEWARE = [
#     'django.middleware.security.SecurityMiddleware',
#     'django.contrib.sessions.middleware.SessionMiddleware',
#     'django.middleware.common.CommonMiddleware',
#     'django.middleware.csrf.CsrfViewMiddleware',
#     'django.contrib.auth.middleware.AuthenticationMiddleware',
#     'django.contrib.messages.middleware.MessageMiddleware',
#     'django.middleware.clickjacking.XFrameOptionsMiddleware',
# ]
#
# ROOT_URLCONF = 'll_project.urls'
#
# TEMPLATES = [
#     {
#         'BACKEND': 'django.template.backends.django.DjangoTemplates',
#         'DIRS': [],
#         'APP_DIRS': True,
#         'OPTIONS': {
#             'context_processors': [
#                 'django.template.context_processors.debug',
#                 'django.template.context_processors.request',
#                 'django.contrib.auth.context_processors.auth',
#                 'django.contrib.messages.context_processors.messages',
#             ],
#         },
#     },
# ]
#
# WSGI_APPLICATION = 'll_project.wsgi.application'
#
#
# # Database
# # https://docs.djangoproject.com/en/dev/ref/settings/#databases
#
# DATABASES = {
#     'default': {
#         'ENGINE': 'django.db.backends.sqlite3',
#         'NAME': BASE_DIR / 'db.sqlite3',
#     }
# }
#
#
# # Password validation
# # https://docs.djangoproject.com/en/dev/ref/settings/#auth-password-validators
#
# AUTH_PASSWORD_VALIDATORS = [
#     {
#         'NAME': 'django.contrib.auth.password_validation.UserAttributeSimilarityValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.MinimumLengthValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.CommonPasswordValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.NumericPasswordValidator',
#     },
# ]
#
#
# # Internationalization
# # https://docs.djangoproject.com/en/dev/topics/i18n/
#
# LANGUAGE_CODE = 'en-us'
#
# TIME_ZONE = 'UTC'
#
# USE_I18N = True
#
# USE_TZ = True
#
#
# # Static files (CSS, JavaScript, Images)
# # https://docs.djangoproject.com/en/dev/howto/static-files/
#
# STATIC_URL = 'static/'
#
# # Default primary key field type
# # https://docs.djangoproject.com/en/dev/ref/settings/#default-auto-field
#
# DEFAULT_AUTO_FIELD = 'django.db.models.BigAutoField'
# ```

# %%
# Practice rewrite for source example 18.14
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.15
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/building_additional_pages/ll_project/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# """
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('', include('learning_logs.urls')),
# ]
# ```

# %%
# Practice rewrite for source example 18.15
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.16
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/building_additional_pages/ll_project/wsgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_wsgi_application()
# ```

# %%
# Practice rewrite for source example 18.16
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Building Additional Pages

# %% [markdown]
# #### Source example 18.17
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/building_additional_pages/manage.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
#             "available on your PYTHONPATH environment variable? Did you "
#             "forget to activate a virtual environment?"
#         ) from exc
#     execute_from_command_line(sys.argv)
#
#
# if __name__ == '__main__':
#     main()
# ```

# %%
# Practice rewrite for source example 18.17
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Making Pages / Learning Logs

# %% [markdown]
# #### Source example 18.18
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/making_pages/learning_logs/admin.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# from django.contrib import admin
#
# from .models import Topic, Entry
#
#
# admin.site.register(Topic)
# admin.site.register(Entry)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.contrib import admin
#
# from .models import Topic, Entry
#
#
# admin.site.register(Topic)
# admin.site.register(Entry)
# ```

# %%
# Practice rewrite for source example 18.18
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.19
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/making_pages/learning_logs/apps.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# from django.apps import AppConfig
#
#
# class LearningLogsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'learning_logs'
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.apps import AppConfig
#
#
# class LearningLogsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'learning_logs'
# ```

# %%
# Practice rewrite for source example 18.19
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Making Pages / Learning Logs / Migrations

# %% [markdown]
# #### Source example 18.20
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/making_pages/learning_logs/migrations/0001_initial.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:24
#
# from django.db import migrations, models
#
#
# class Migration(migrations.Migration):
#
#     initial = True
#
#     dependencies = [
#     ]
#
#     operations = [
#         migrations.CreateModel(
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:24
#
# from django.db import migrations, models
#
#
# class Migration(migrations.Migration):
#
#     initial = True
#
#     dependencies = [
#     ]
#
#     operations = [
#         migrations.CreateModel(
#             name='Topic',
#             fields=[
#                 ('id', models.BigAutoField(auto_created=True, primary_key=True, serialize=False, verbose_name='ID')),
#                 ('text', models.CharField(max_length=200)),
#                 ('date_added', models.DateTimeField(auto_now_add=True)),
#             ],
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 18.20
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.21
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/making_pages/learning_logs/migrations/0002_entry.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:28
#
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         ('learning_logs', '0001_initial'),
#     ]
#
#     operations = [
#         migrations.CreateModel(
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:28
#
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         ('learning_logs', '0001_initial'),
#     ]
#
#     operations = [
#         migrations.CreateModel(
#             name='Entry',
#             fields=[
#                 ('id', models.BigAutoField(auto_created=True, primary_key=True, serialize=False, verbose_name='ID')),
#                 ('text', models.TextField()),
#                 ('date_added', models.DateTimeField(auto_now_add=True)),
#                 ('topic', models.ForeignKey(on_delete=django.db.models.deletion.CASCADE, to='learning_logs.topic')),
#             ],
#             options={
#                 'verbose_name_plural': 'entries',
#             },
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 18.21
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Making Pages / Learning Logs

# %% [markdown]
# #### Source example 18.22
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/making_pages/learning_logs/models.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# from django.db import models
#
# class Topic(models.Model):
#     """A topic the user is learning about."""
#     text = models.CharField(max_length=200)
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     def __str__(self):
#         """Return a string representation of the model."""
#         return self.text
#
#
# class Entry(models.Model):
#     """Something specific learned about a topic."""
# # ... 10 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.db import models
#
# class Topic(models.Model):
#     """A topic the user is learning about."""
#     text = models.CharField(max_length=200)
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     def __str__(self):
#         """Return a string representation of the model."""
#         return self.text
#
#
# class Entry(models.Model):
#     """Something specific learned about a topic."""
#     topic = models.ForeignKey(Topic, on_delete=models.CASCADE)
#     text = models.TextField()
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     class Meta:
#         verbose_name_plural = 'entries'
#
#     def __str__(self):
#         """Return a simple string representing the entry."""
#         return f"{self.text[:50]}..."
# ```

# %%
# Practice rewrite for source example 18.22
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Making Pages / Learning Logs / Templates / Learning Logs

# %% [markdown]
# #### Source example 18.23
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/making_pages/learning_logs/templates/learning_logs/index.html`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```html
# <p>Learning Log</p>
#
# <p>Learning Log helps you keep track of your learning, for any topic you're
# interested in.</p>
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# <p>Learning Log</p>
#
# <p>Learning Log helps you keep track of your learning, for any topic you're
# interested in.</p>
# ```

# %%
# Practice rewrite for source example 18.23
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Making Pages / Learning Logs

# %% [markdown]
# #### Source example 18.24
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/making_pages/learning_logs/tests.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %%
# Practice rewrite for source example 18.24
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.25
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/making_pages/learning_logs/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """Defines URL patterns for learning_logs."""
#
# from django.urls import path
#
# from . import views
#
# app_name = 'learning_logs'
# urlpatterns = [
#     # Home page
#     path('', views.index, name='index'),
# ]
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """Defines URL patterns for learning_logs."""
#
# from django.urls import path
#
# from . import views
#
# app_name = 'learning_logs'
# urlpatterns = [
#     # Home page
#     path('', views.index, name='index'),
# ]
# ```

# %%
# Practice rewrite for source example 18.25
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.26
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/making_pages/learning_logs/views.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# from django.shortcuts import render
#
#
# def index(request):
#     """The home page for Learning Log."""
#     return render(request, 'learning_logs/index.html')
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.shortcuts import render
#
#
# def index(request):
#     """The home page for Learning Log."""
#     return render(request, 'learning_logs/index.html')
# ```

# %%
# Practice rewrite for source example 18.26
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Making Pages / Ll Project

# %% [markdown]
# #### Source example 18.27
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/making_pages/ll_project/asgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_asgi_application()
# ```

# %%
# Practice rewrite for source example 18.27
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.28
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/making_pages/ll_project/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # ... 112 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # Build paths inside the project like this: BASE_DIR / 'subdir'.
# BASE_DIR = Path(__file__).resolve().parent.parent
#
#
# # Quick-start development settings - unsuitable for production
# # See https://docs.djangoproject.com/en/dev/howto/deployment/checklist/
#
# # SECURITY WARNING: keep the secret key used in production secret!
# SECRET_KEY = 'django-insecure-mibxt7sboxg%r)9t6z=a6@weyo(thgbknfcwgyowgx9$5s4&=!'
#
# # SECURITY WARNING: don't run with debug turned on in production!
# DEBUG = True
#
# ALLOWED_HOSTS = []
#
# # Application definition
#
# INSTALLED_APPS = [
#     # My apps.
#     'learning_logs',
#
#     # Default django apps.
#     'django.contrib.admin',
#     'django.contrib.auth',
#     'django.contrib.contenttypes',
#     'django.contrib.sessions',
#     'django.contrib.messages',
#     'django.contrib.staticfiles',
# ]
#
# MIDDLEWARE = [
#     'django.middleware.security.SecurityMiddleware',
#     'django.contrib.sessions.middleware.SessionMiddleware',
#     'django.middleware.common.CommonMiddleware',
#     'django.middleware.csrf.CsrfViewMiddleware',
#     'django.contrib.auth.middleware.AuthenticationMiddleware',
#     'django.contrib.messages.middleware.MessageMiddleware',
#     'django.middleware.clickjacking.XFrameOptionsMiddleware',
# ]
#
# ROOT_URLCONF = 'll_project.urls'
#
# TEMPLATES = [
#     {
#         'BACKEND': 'django.template.backends.django.DjangoTemplates',
#         'DIRS': [],
#         'APP_DIRS': True,
#         'OPTIONS': {
#             'context_processors': [
#                 'django.template.context_processors.debug',
#                 'django.template.context_processors.request',
#                 'django.contrib.auth.context_processors.auth',
#                 'django.contrib.messages.context_processors.messages',
#             ],
#         },
#     },
# ]
#
# WSGI_APPLICATION = 'll_project.wsgi.application'
#
#
# # Database
# # https://docs.djangoproject.com/en/dev/ref/settings/#databases
#
# DATABASES = {
#     'default': {
#         'ENGINE': 'django.db.backends.sqlite3',
#         'NAME': BASE_DIR / 'db.sqlite3',
#     }
# }
#
#
# # Password validation
# # https://docs.djangoproject.com/en/dev/ref/settings/#auth-password-validators
#
# AUTH_PASSWORD_VALIDATORS = [
#     {
#         'NAME': 'django.contrib.auth.password_validation.UserAttributeSimilarityValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.MinimumLengthValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.CommonPasswordValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.NumericPasswordValidator',
#     },
# ]
#
#
# # Internationalization
# # https://docs.djangoproject.com/en/dev/topics/i18n/
#
# LANGUAGE_CODE = 'en-us'
#
# TIME_ZONE = 'UTC'
#
# USE_I18N = True
#
# USE_TZ = True
#
#
# # Static files (CSS, JavaScript, Images)
# # https://docs.djangoproject.com/en/dev/howto/static-files/
#
# STATIC_URL = 'static/'
#
# # Default primary key field type
# # https://docs.djangoproject.com/en/dev/ref/settings/#default-auto-field
#
# DEFAULT_AUTO_FIELD = 'django.db.models.BigAutoField'
# ```

# %%
# Practice rewrite for source example 18.28
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.29
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/making_pages/ll_project/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# """
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('', include('learning_logs.urls')),
# ]
# ```

# %%
# Practice rewrite for source example 18.29
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.30
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/making_pages/ll_project/wsgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_wsgi_application()
# ```

# %%
# Practice rewrite for source example 18.30
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Making Pages

# %% [markdown]
# #### Source example 18.31
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/making_pages/manage.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
#             "available on your PYTHONPATH environment variable? Did you "
#             "forget to activate a virtual environment?"
#         ) from exc
#     execute_from_command_line(sys.argv)
#
#
# if __name__ == '__main__':
#     main()
# ```

# %%
# Practice rewrite for source example 18.31
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Setting Up Project / Ll Project

# %% [markdown]
# #### Source example 18.32
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/setting_up_project/ll_project/asgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_asgi_application()
# ```

# %%
# Practice rewrite for source example 18.32
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.33
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/setting_up_project/ll_project/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # ... 109 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # Build paths inside the project like this: BASE_DIR / 'subdir'.
# BASE_DIR = Path(__file__).resolve().parent.parent
#
#
# # Quick-start development settings - unsuitable for production
# # See https://docs.djangoproject.com/en/dev/howto/deployment/checklist/
#
# # SECURITY WARNING: keep the secret key used in production secret!
# SECRET_KEY = 'django-insecure-mibxt7sboxg%r)9t6z=a6@weyo(thgbknfcwgyowgx9$5s4&=!'
#
# # SECURITY WARNING: don't run with debug turned on in production!
# DEBUG = True
#
# ALLOWED_HOSTS = []
#
#
# # Application definition
#
# INSTALLED_APPS = [
#     'django.contrib.admin',
#     'django.contrib.auth',
#     'django.contrib.contenttypes',
#     'django.contrib.sessions',
#     'django.contrib.messages',
#     'django.contrib.staticfiles',
# ]
#
# MIDDLEWARE = [
#     'django.middleware.security.SecurityMiddleware',
#     'django.contrib.sessions.middleware.SessionMiddleware',
#     'django.middleware.common.CommonMiddleware',
#     'django.middleware.csrf.CsrfViewMiddleware',
#     'django.contrib.auth.middleware.AuthenticationMiddleware',
#     'django.contrib.messages.middleware.MessageMiddleware',
#     'django.middleware.clickjacking.XFrameOptionsMiddleware',
# ]
#
# ROOT_URLCONF = 'll_project.urls'
#
# TEMPLATES = [
#     {
#         'BACKEND': 'django.template.backends.django.DjangoTemplates',
#         'DIRS': [],
#         'APP_DIRS': True,
#         'OPTIONS': {
#             'context_processors': [
#                 'django.template.context_processors.debug',
#                 'django.template.context_processors.request',
#                 'django.contrib.auth.context_processors.auth',
#                 'django.contrib.messages.context_processors.messages',
#             ],
#         },
#     },
# ]
#
# WSGI_APPLICATION = 'll_project.wsgi.application'
#
#
# # Database
# # https://docs.djangoproject.com/en/dev/ref/settings/#databases
#
# DATABASES = {
#     'default': {
#         'ENGINE': 'django.db.backends.sqlite3',
#         'NAME': BASE_DIR / 'db.sqlite3',
#     }
# }
#
#
# # Password validation
# # https://docs.djangoproject.com/en/dev/ref/settings/#auth-password-validators
#
# AUTH_PASSWORD_VALIDATORS = [
#     {
#         'NAME': 'django.contrib.auth.password_validation.UserAttributeSimilarityValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.MinimumLengthValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.CommonPasswordValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.NumericPasswordValidator',
#     },
# ]
#
#
# # Internationalization
# # https://docs.djangoproject.com/en/dev/topics/i18n/
#
# LANGUAGE_CODE = 'en-us'
#
# TIME_ZONE = 'UTC'
#
# USE_I18N = True
#
# USE_TZ = True
#
#
# # Static files (CSS, JavaScript, Images)
# # https://docs.djangoproject.com/en/dev/howto/static-files/
#
# STATIC_URL = 'static/'
#
# # Default primary key field type
# # https://docs.djangoproject.com/en/dev/ref/settings/#default-auto-field
#
# DEFAULT_AUTO_FIELD = 'django.db.models.BigAutoField'
# ```

# %%
# Practice rewrite for source example 18.33
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.34
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/setting_up_project/ll_project/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# """
# from django.contrib import admin
# from django.urls import path
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
# ]
# ```

# %%
# Practice rewrite for source example 18.34
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.35
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/setting_up_project/ll_project/wsgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_wsgi_application()
# ```

# %%
# Practice rewrite for source example 18.35
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Setting Up Project

# %% [markdown]
# #### Source example 18.36
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/setting_up_project/manage.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
#             "available on your PYTHONPATH environment variable? Did you "
#             "forget to activate a virtual environment?"
#         ) from exc
#     execute_from_command_line(sys.argv)
#
#
# if __name__ == '__main__':
#     main()
# ```

# %%
# Practice rewrite for source example 18.36
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Starting An App / Learning Logs

# %% [markdown]
# #### Source example 18.37
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/starting_an_app/learning_logs/admin.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# from django.contrib import admin
#
# from .models import Topic, Entry
#
#
# admin.site.register(Topic)
# admin.site.register(Entry)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.contrib import admin
#
# from .models import Topic, Entry
#
#
# admin.site.register(Topic)
# admin.site.register(Entry)
# ```

# %%
# Practice rewrite for source example 18.37
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.38
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/starting_an_app/learning_logs/apps.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# from django.apps import AppConfig
#
#
# class LearningLogsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'learning_logs'
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.apps import AppConfig
#
#
# class LearningLogsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'learning_logs'
# ```

# %%
# Practice rewrite for source example 18.38
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Starting An App / Learning Logs / Migrations

# %% [markdown]
# #### Source example 18.39
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/starting_an_app/learning_logs/migrations/0001_initial.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:24
#
# from django.db import migrations, models
#
#
# class Migration(migrations.Migration):
#
#     initial = True
#
#     dependencies = [
#     ]
#
#     operations = [
#         migrations.CreateModel(
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:24
#
# from django.db import migrations, models
#
#
# class Migration(migrations.Migration):
#
#     initial = True
#
#     dependencies = [
#     ]
#
#     operations = [
#         migrations.CreateModel(
#             name='Topic',
#             fields=[
#                 ('id', models.BigAutoField(auto_created=True, primary_key=True, serialize=False, verbose_name='ID')),
#                 ('text', models.CharField(max_length=200)),
#                 ('date_added', models.DateTimeField(auto_now_add=True)),
#             ],
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 18.39
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.40
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/starting_an_app/learning_logs/migrations/0002_entry.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:28
#
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         ('learning_logs', '0001_initial'),
#     ]
#
#     operations = [
#         migrations.CreateModel(
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:28
#
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         ('learning_logs', '0001_initial'),
#     ]
#
#     operations = [
#         migrations.CreateModel(
#             name='Entry',
#             fields=[
#                 ('id', models.BigAutoField(auto_created=True, primary_key=True, serialize=False, verbose_name='ID')),
#                 ('text', models.TextField()),
#                 ('date_added', models.DateTimeField(auto_now_add=True)),
#                 ('topic', models.ForeignKey(on_delete=django.db.models.deletion.CASCADE, to='learning_logs.topic')),
#             ],
#             options={
#                 'verbose_name_plural': 'entries',
#             },
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 18.40
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Starting An App / Learning Logs

# %% [markdown]
# #### Source example 18.41
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/starting_an_app/learning_logs/models.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# from django.db import models
#
# class Topic(models.Model):
#     """A topic the user is learning about."""
#     text = models.CharField(max_length=200)
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     def __str__(self):
#         """Return a string representation of the model."""
#         return self.text
#
#
# class Entry(models.Model):
#     """Something specific learned about a topic."""
# # ... 10 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.db import models
#
# class Topic(models.Model):
#     """A topic the user is learning about."""
#     text = models.CharField(max_length=200)
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     def __str__(self):
#         """Return a string representation of the model."""
#         return self.text
#
#
# class Entry(models.Model):
#     """Something specific learned about a topic."""
#     topic = models.ForeignKey(Topic, on_delete=models.CASCADE)
#     text = models.TextField()
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     class Meta:
#         verbose_name_plural = 'entries'
#
#     def __str__(self):
#         """Return a simple string representing the entry."""
#         return f"{self.text[:50]}..."
# ```

# %%
# Practice rewrite for source example 18.41
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.42
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/starting_an_app/learning_logs/tests.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %%
# Practice rewrite for source example 18.42
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.43
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/starting_an_app/learning_logs/views.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# from django.shortcuts import render
#
# # Create your views here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.shortcuts import render
#
# # Create your views here.
# ```

# %%
# Practice rewrite for source example 18.43
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Starting An App / Ll Project

# %% [markdown]
# #### Source example 18.44
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/starting_an_app/ll_project/asgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_asgi_application()
# ```

# %%
# Practice rewrite for source example 18.44
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.45
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/starting_an_app/ll_project/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # ... 112 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # Build paths inside the project like this: BASE_DIR / 'subdir'.
# BASE_DIR = Path(__file__).resolve().parent.parent
#
#
# # Quick-start development settings - unsuitable for production
# # See https://docs.djangoproject.com/en/dev/howto/deployment/checklist/
#
# # SECURITY WARNING: keep the secret key used in production secret!
# SECRET_KEY = 'django-insecure-mibxt7sboxg%r)9t6z=a6@weyo(thgbknfcwgyowgx9$5s4&=!'
#
# # SECURITY WARNING: don't run with debug turned on in production!
# DEBUG = True
#
# ALLOWED_HOSTS = []
#
# # Application definition
#
# INSTALLED_APPS = [
#     # My apps.
#     'learning_logs',
#
#     # Default django apps.
#     'django.contrib.admin',
#     'django.contrib.auth',
#     'django.contrib.contenttypes',
#     'django.contrib.sessions',
#     'django.contrib.messages',
#     'django.contrib.staticfiles',
# ]
#
# MIDDLEWARE = [
#     'django.middleware.security.SecurityMiddleware',
#     'django.contrib.sessions.middleware.SessionMiddleware',
#     'django.middleware.common.CommonMiddleware',
#     'django.middleware.csrf.CsrfViewMiddleware',
#     'django.contrib.auth.middleware.AuthenticationMiddleware',
#     'django.contrib.messages.middleware.MessageMiddleware',
#     'django.middleware.clickjacking.XFrameOptionsMiddleware',
# ]
#
# ROOT_URLCONF = 'll_project.urls'
#
# TEMPLATES = [
#     {
#         'BACKEND': 'django.template.backends.django.DjangoTemplates',
#         'DIRS': [],
#         'APP_DIRS': True,
#         'OPTIONS': {
#             'context_processors': [
#                 'django.template.context_processors.debug',
#                 'django.template.context_processors.request',
#                 'django.contrib.auth.context_processors.auth',
#                 'django.contrib.messages.context_processors.messages',
#             ],
#         },
#     },
# ]
#
# WSGI_APPLICATION = 'll_project.wsgi.application'
#
#
# # Database
# # https://docs.djangoproject.com/en/dev/ref/settings/#databases
#
# DATABASES = {
#     'default': {
#         'ENGINE': 'django.db.backends.sqlite3',
#         'NAME': BASE_DIR / 'db.sqlite3',
#     }
# }
#
#
# # Password validation
# # https://docs.djangoproject.com/en/dev/ref/settings/#auth-password-validators
#
# AUTH_PASSWORD_VALIDATORS = [
#     {
#         'NAME': 'django.contrib.auth.password_validation.UserAttributeSimilarityValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.MinimumLengthValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.CommonPasswordValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.NumericPasswordValidator',
#     },
# ]
#
#
# # Internationalization
# # https://docs.djangoproject.com/en/dev/topics/i18n/
#
# LANGUAGE_CODE = 'en-us'
#
# TIME_ZONE = 'UTC'
#
# USE_I18N = True
#
# USE_TZ = True
#
#
# # Static files (CSS, JavaScript, Images)
# # https://docs.djangoproject.com/en/dev/howto/static-files/
#
# STATIC_URL = 'static/'
#
# # Default primary key field type
# # https://docs.djangoproject.com/en/dev/ref/settings/#default-auto-field
#
# DEFAULT_AUTO_FIELD = 'django.db.models.BigAutoField'
# ```

# %%
# Practice rewrite for source example 18.45
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.46
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/starting_an_app/ll_project/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# """
# from django.contrib import admin
# from django.urls import path
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
# ]
# ```

# %%
# Practice rewrite for source example 18.46
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 18.47
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/starting_an_app/ll_project/wsgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_wsgi_application()
# ```

# %%
# Practice rewrite for source example 18.47
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Starting An App

# %% [markdown]
# #### Source example 18.48
#
# Checklist note: captured from **Chapter 18: Getting Started with Django**, official GitHub source `chapter_18/starting_an_app/manage.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This starts the web project by applying functions, classes, files, and databases inside Django's structure.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# Django project -> app/model/view/template -> web page
# ```
#
# **Code Preview**
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
#             "available on your PYTHONPATH environment variable? Did you "
#             "forget to activate a virtual environment?"
#         ) from exc
#     execute_from_command_line(sys.argv)
#
#
# if __name__ == '__main__':
#     main()
# ```

# %%
# Practice rewrite for source example 18.48
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Chapter 18: Getting Started with Django Practice Checkpoint

# %% [markdown]
# #### Practice: project-safe rewrite

# %%
# Project chapters often depend on installed packages, files, servers, or assets.
# Rewrite one source example with fake data first:
# - replace file/API/game/web inputs with a small list or dictionary
# - print the planned action
# - only then connect it back to the real project
planned_steps = ["identify input", "transform state", "show or save result"]
for step in planned_steps:
    print(step)

# %% [markdown]
# ## Chapter 19: User Accounts
#
# PDF pages: 649-692

# %% [markdown]
# ### Allowing Users To Enter Data / Learning Logs

# %% [markdown]
# #### Source example 19.1
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/learning_logs/admin.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.contrib import admin
#
# from .models import Topic, Entry
#
#
# admin.site.register(Topic)
# admin.site.register(Entry)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.contrib import admin
#
# from .models import Topic, Entry
#
#
# admin.site.register(Topic)
# admin.site.register(Entry)
# ```

# %%
# Practice rewrite for source example 19.1
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.2
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/learning_logs/apps.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.apps import AppConfig
#
#
# class LearningLogsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'learning_logs'
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.apps import AppConfig
#
#
# class LearningLogsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'learning_logs'
# ```

# %%
# Practice rewrite for source example 19.2
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.3
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/learning_logs/forms.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django import forms
#
# from .models import Topic, Entry
#
#
# class TopicForm(forms.ModelForm):
#     class Meta:
#         model = Topic
#         fields = ['text']
#         labels = {'text': ''}
#
# class EntryForm(forms.ModelForm):
#     class Meta:
#         model = Entry
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django import forms
#
# from .models import Topic, Entry
#
#
# class TopicForm(forms.ModelForm):
#     class Meta:
#         model = Topic
#         fields = ['text']
#         labels = {'text': ''}
#
# class EntryForm(forms.ModelForm):
#     class Meta:
#         model = Entry
#         fields = ['text']
#         labels = {'text': ''}
#         widgets = {'text': forms.Textarea(attrs={'cols': 80})}
# ```

# %%
# Practice rewrite for source example 19.3
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Allowing Users To Enter Data / Learning Logs / Migrations

# %% [markdown]
# #### Source example 19.4
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/learning_logs/migrations/0001_initial.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:24
#
# from django.db import migrations, models
#
#
# class Migration(migrations.Migration):
#
#     initial = True
#
#     dependencies = [
#     ]
#
#     operations = [
#         migrations.CreateModel(
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:24
#
# from django.db import migrations, models
#
#
# class Migration(migrations.Migration):
#
#     initial = True
#
#     dependencies = [
#     ]
#
#     operations = [
#         migrations.CreateModel(
#             name='Topic',
#             fields=[
#                 ('id', models.BigAutoField(auto_created=True, primary_key=True, serialize=False, verbose_name='ID')),
#                 ('text', models.CharField(max_length=200)),
#                 ('date_added', models.DateTimeField(auto_now_add=True)),
#             ],
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 19.4
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.5
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/learning_logs/migrations/0002_entry.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:28
#
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         ('learning_logs', '0001_initial'),
#     ]
#
#     operations = [
#         migrations.CreateModel(
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:28
#
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         ('learning_logs', '0001_initial'),
#     ]
#
#     operations = [
#         migrations.CreateModel(
#             name='Entry',
#             fields=[
#                 ('id', models.BigAutoField(auto_created=True, primary_key=True, serialize=False, verbose_name='ID')),
#                 ('text', models.TextField()),
#                 ('date_added', models.DateTimeField(auto_now_add=True)),
#                 ('topic', models.ForeignKey(on_delete=django.db.models.deletion.CASCADE, to='learning_logs.topic')),
#             ],
#             options={
#                 'verbose_name_plural': 'entries',
#             },
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 19.5
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Allowing Users To Enter Data / Learning Logs

# %% [markdown]
# #### Source example 19.6
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/learning_logs/models.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.db import models
#
# class Topic(models.Model):
#     """A topic the user is learning about."""
#     text = models.CharField(max_length=200)
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     def __str__(self):
#         """Return a string representation of the model."""
#         return self.text
#
#
# class Entry(models.Model):
#     """Something specific learned about a topic."""
# # ... 10 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.db import models
#
# class Topic(models.Model):
#     """A topic the user is learning about."""
#     text = models.CharField(max_length=200)
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     def __str__(self):
#         """Return a string representation of the model."""
#         return self.text
#
#
# class Entry(models.Model):
#     """Something specific learned about a topic."""
#     topic = models.ForeignKey(Topic, on_delete=models.CASCADE)
#     text = models.TextField()
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     class Meta:
#         verbose_name_plural = 'entries'
#
#     def __str__(self):
#         """Return a simple string representing the entry."""
#         return f"{self.text[:50]}..."
# ```

# %%
# Practice rewrite for source example 19.6
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Allowing Users To Enter Data / Learning Logs / Templates / Learning Logs

# %% [markdown]
# #### Source example 19.7
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/learning_logs/templates/learning_logs/base.html`.
#
# **Context**
#
# 1. This example belongs to adding user accounts and protected data, from the section `Allowing Users To Enter Data / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# <p>
#   <a href="{% url 'learning_logs:index' %}">Learning Log</a> -
#   <a href="{% url 'learning_logs:topics' %}">Topics</a>
# </p>
#
# {% block content %}{% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# <p>
#   <a href="{% url 'learning_logs:index' %}">Learning Log</a> -
#   <a href="{% url 'learning_logs:topics' %}">Topics</a>
# </p>
#
# {% block content %}{% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.7
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.8
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/learning_logs/templates/learning_logs/edit_entry.html`.
#
# **Context**
#
# 1. This example belongs to adding user accounts and protected data, from the section `Allowing Users To Enter Data / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Edit entry:</p>
#
#   <form action="{% url 'learning_logs:edit_entry' entry.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Save changes</button>
#   </form>
#
# # ... 1 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Edit entry:</p>
#
#   <form action="{% url 'learning_logs:edit_entry' entry.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Save changes</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.8
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.9
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/learning_logs/templates/learning_logs/index.html`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#   <p>Learning Log helps you keep track of your learning, for any topic you're
#   interested in.</p>
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#   <p>Learning Log helps you keep track of your learning, for any topic you're
#   interested in.</p>
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.9
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.10
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/learning_logs/templates/learning_logs/new_entry.html`.
#
# **Context**
#
# 1. This example belongs to adding user accounts and protected data, from the section `Allowing Users To Enter Data / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Add a new entry:</p>
#   <form action="{% url 'learning_logs:new_entry' topic.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name='submit'>Add entry</button>
#   </form>
#
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Add a new entry:</p>
#   <form action="{% url 'learning_logs:new_entry' topic.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name='submit'>Add entry</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.10
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.11
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/learning_logs/templates/learning_logs/new_topic.html`.
#
# **Context**
#
# 1. This example belongs to adding user accounts and protected data, from the section `Allowing Users To Enter Data / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#   <p>Add a new topic:</p>
#
#   <form action="{% url 'learning_logs:new_topic' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Add topic</button>
#   </form>
#
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#   <p>Add a new topic:</p>
#
#   <form action="{% url 'learning_logs:new_topic' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Add topic</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.11
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.12
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/learning_logs/templates/learning_logs/topic.html`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   <p>Topic: {{ topic.text }}</p>
#
#   <p>Entries:</p>
#   <p>
#     <a href="{% url 'learning_logs:new_entry' topic.id %}">Add new entry</a>
#   </p>
#
#   <ul>
#     {% for entry in entries %}
#       <li>
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   <p>Topic: {{ topic.text }}</p>
#
#   <p>Entries:</p>
#   <p>
#     <a href="{% url 'learning_logs:new_entry' topic.id %}">Add new entry</a>
#   </p>
#
#   <ul>
#     {% for entry in entries %}
#       <li>
#         <p>{{ entry.date_added|date:'M d, Y H:i' }}</p>
#         <p>{{ entry.text|linebreaks }}</p>
#         <p>
#           <a href="{% url 'learning_logs:edit_entry' entry.id %}">
#             Edit entry</a></p>
#       </li>
#     {% empty %}
#       <li>There are no entries for this topic yet.</li>
#     {% endfor %}
#   </ul>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.12
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.13
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/learning_logs/templates/learning_logs/topics.html`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   <p>Topics</p>
#   <ul>
#     {% for topic in topics %}
#       <li>
#         <a href="{% url 'learning_logs:topic' topic.id %}">
#           {{ topic.text }}</a>
#       </li>
#     {% empty %}
#       <li>No topics have been added yet.</li>
#     {% endfor %}
# # ... 5 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   <p>Topics</p>
#   <ul>
#     {% for topic in topics %}
#       <li>
#         <a href="{% url 'learning_logs:topic' topic.id %}">
#           {{ topic.text }}</a>
#       </li>
#     {% empty %}
#       <li>No topics have been added yet.</li>
#     {% endfor %}
#   </ul>
#
#   <a href="{% url 'learning_logs:new_topic' %}">Add a new topic</a>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.13
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Allowing Users To Enter Data / Learning Logs

# %% [markdown]
# #### Source example 19.14
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/learning_logs/tests.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %%
# Practice rewrite for source example 19.14
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.15
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/learning_logs/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# """Defines URL patterns for learning_logs."""
#
# from django.urls import path
#
# from . import views
#
# app_name = 'learning_logs'
# urlpatterns = [
#     # Home page
#     path('', views.index, name='index'),
#     # Page that shows all topics.
#     path('topics/', views.topics, name='topics'),
#     # Detail page for a single topic.
#     path('topics/<int:topic_id>/', views.topic, name='topic'),
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """Defines URL patterns for learning_logs."""
#
# from django.urls import path
#
# from . import views
#
# app_name = 'learning_logs'
# urlpatterns = [
#     # Home page
#     path('', views.index, name='index'),
#     # Page that shows all topics.
#     path('topics/', views.topics, name='topics'),
#     # Detail page for a single topic.
#     path('topics/<int:topic_id>/', views.topic, name='topic'),
#     # Page for adding a new topic.
#     path('new_topic/', views.new_topic, name='new_topic'),
#     # Page for adding a new entry.
#     path('new_entry/<int:topic_id>/', views.new_entry, name='new_entry'),
#     # Page for editing an entry.
#     path('edit_entry/<int:entry_id>/', views.edit_entry, name='edit_entry'),
# ]
# ```

# %%
# Practice rewrite for source example 19.15
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.16
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/learning_logs/views.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.shortcuts import render, redirect
#
# from .models import Topic, Entry
# from .forms import TopicForm, EntryForm
#
#
# def index(request):
#     """The home page for Learning Log."""
#     return render(request, 'learning_logs/index.html')
#
# def topics(request):
#     """Show all topics."""
#     topics = Topic.objects.order_by('date_added')
#     context = {'topics': topics}
# # ... 62 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.shortcuts import render, redirect
#
# from .models import Topic, Entry
# from .forms import TopicForm, EntryForm
#
#
# def index(request):
#     """The home page for Learning Log."""
#     return render(request, 'learning_logs/index.html')
#
# def topics(request):
#     """Show all topics."""
#     topics = Topic.objects.order_by('date_added')
#     context = {'topics': topics}
#     return render(request, 'learning_logs/topics.html', context)
#
# def topic(request, topic_id):
#     """Show a single topic and all its entries."""
#     topic = Topic.objects.get(id=topic_id)
#     entries = topic.entry_set.order_by('-date_added')
#     context = {'topic': topic, 'entries': entries}
#     return render(request, 'learning_logs/topic.html', context)
#
# def new_topic(request):
#     """Add a new topic."""
#     if request.method != 'POST':
#         # No data submitted; create a blank form.
#         form = TopicForm()
#     else:
#         # POST data submitted; process data.
#         form = TopicForm(data=request.POST)
#         if form.is_valid():
#             form.save()
#             return redirect('learning_logs:topics')
#
#     # Display a blank or invalid form.
#     context = {'form': form}
#     return render(request, 'learning_logs/new_topic.html', context)
#
# def new_entry(request, topic_id):
#     """Add a new entry for a particular topic."""
#     topic = Topic.objects.get(id=topic_id)
#
#     if request.method != 'POST':
#         # No data submitted; create a blank form.
#         form = EntryForm()
#     else:
#         # POST data submitted; process data.
#         form = EntryForm(data=request.POST)
#         if form.is_valid():
#             new_entry = form.save(commit=False)
#             new_entry.topic = topic
#             new_entry.save()
#             return redirect('learning_logs:topic', topic_id=topic_id)
#
#     # Display a blank or invalid form.
#     context = {'topic': topic, 'form': form}
#     return render(request, 'learning_logs/new_entry.html', context)
#
# def edit_entry(request, entry_id):
#     """Edit an existing entry."""
#     entry = Entry.objects.get(id=entry_id)
#     topic = entry.topic
#
#     if request.method != 'POST':
#         # Initial request; pre-fill form with the current entry.
#         form = EntryForm(instance=entry)
#     else:
#         # POST data submitted; process data.
#         form = EntryForm(instance=entry, data=request.POST)
#         if form.is_valid():
#             form.save()
#             return redirect('learning_logs:topic', topic_id=topic.id)
#
#     context = {'entry': entry, 'topic': topic, 'form': form}
#     return render(request, 'learning_logs/edit_entry.html', context)
# ```

# %%
# Practice rewrite for source example 19.16
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Allowing Users To Enter Data / Ll Project

# %% [markdown]
# #### Source example 19.17
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/ll_project/asgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_asgi_application()
# ```

# %%
# Practice rewrite for source example 19.17
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.18
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/ll_project/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # ... 112 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # Build paths inside the project like this: BASE_DIR / 'subdir'.
# BASE_DIR = Path(__file__).resolve().parent.parent
#
#
# # Quick-start development settings - unsuitable for production
# # See https://docs.djangoproject.com/en/dev/howto/deployment/checklist/
#
# # SECURITY WARNING: keep the secret key used in production secret!
# SECRET_KEY = 'django-insecure-mibxt7sboxg%r)9t6z=a6@weyo(thgbknfcwgyowgx9$5s4&=!'
#
# # SECURITY WARNING: don't run with debug turned on in production!
# DEBUG = True
#
# ALLOWED_HOSTS = []
#
# # Application definition
#
# INSTALLED_APPS = [
#     # My apps.
#     'learning_logs',
#
#     # Default django apps.
#     'django.contrib.admin',
#     'django.contrib.auth',
#     'django.contrib.contenttypes',
#     'django.contrib.sessions',
#     'django.contrib.messages',
#     'django.contrib.staticfiles',
# ]
#
# MIDDLEWARE = [
#     'django.middleware.security.SecurityMiddleware',
#     'django.contrib.sessions.middleware.SessionMiddleware',
#     'django.middleware.common.CommonMiddleware',
#     'django.middleware.csrf.CsrfViewMiddleware',
#     'django.contrib.auth.middleware.AuthenticationMiddleware',
#     'django.contrib.messages.middleware.MessageMiddleware',
#     'django.middleware.clickjacking.XFrameOptionsMiddleware',
# ]
#
# ROOT_URLCONF = 'll_project.urls'
#
# TEMPLATES = [
#     {
#         'BACKEND': 'django.template.backends.django.DjangoTemplates',
#         'DIRS': [],
#         'APP_DIRS': True,
#         'OPTIONS': {
#             'context_processors': [
#                 'django.template.context_processors.debug',
#                 'django.template.context_processors.request',
#                 'django.contrib.auth.context_processors.auth',
#                 'django.contrib.messages.context_processors.messages',
#             ],
#         },
#     },
# ]
#
# WSGI_APPLICATION = 'll_project.wsgi.application'
#
#
# # Database
# # https://docs.djangoproject.com/en/dev/ref/settings/#databases
#
# DATABASES = {
#     'default': {
#         'ENGINE': 'django.db.backends.sqlite3',
#         'NAME': BASE_DIR / 'db.sqlite3',
#     }
# }
#
#
# # Password validation
# # https://docs.djangoproject.com/en/dev/ref/settings/#auth-password-validators
#
# AUTH_PASSWORD_VALIDATORS = [
#     {
#         'NAME': 'django.contrib.auth.password_validation.UserAttributeSimilarityValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.MinimumLengthValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.CommonPasswordValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.NumericPasswordValidator',
#     },
# ]
#
#
# # Internationalization
# # https://docs.djangoproject.com/en/dev/topics/i18n/
#
# LANGUAGE_CODE = 'en-us'
#
# TIME_ZONE = 'UTC'
#
# USE_I18N = True
#
# USE_TZ = True
#
#
# # Static files (CSS, JavaScript, Images)
# # https://docs.djangoproject.com/en/dev/howto/static-files/
#
# STATIC_URL = 'static/'
#
# # Default primary key field type
# # https://docs.djangoproject.com/en/dev/ref/settings/#default-auto-field
#
# DEFAULT_AUTO_FIELD = 'django.db.models.BigAutoField'
# ```

# %%
# Practice rewrite for source example 19.18
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.19
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/ll_project/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# """
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('', include('learning_logs.urls')),
# ]
# ```

# %%
# Practice rewrite for source example 19.19
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.20
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/ll_project/wsgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_wsgi_application()
# ```

# %%
# Practice rewrite for source example 19.20
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Allowing Users To Enter Data

# %% [markdown]
# #### Source example 19.21
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_enter_data/manage.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
#             "available on your PYTHONPATH environment variable? Did you "
#             "forget to activate a virtual environment?"
#         ) from exc
#     execute_from_command_line(sys.argv)
#
#
# if __name__ == '__main__':
#     main()
# ```

# %%
# Practice rewrite for source example 19.21
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Allowing Users To Own Their Data / Accounts

# %% [markdown]
# #### Source example 19.22
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/accounts/admin.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.contrib import admin
#
# # Register your models here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.contrib import admin
#
# # Register your models here.
# ```

# %%
# Practice rewrite for source example 19.22
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.23
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/accounts/apps.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.apps import AppConfig
#
#
# class AccountsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'accounts'
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.apps import AppConfig
#
#
# class AccountsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'accounts'
# ```

# %%
# Practice rewrite for source example 19.23
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.24
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/accounts/models.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.db import models
#
# # Create your models here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.db import models
#
# # Create your models here.
# ```

# %%
# Practice rewrite for source example 19.24
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Allowing Users To Own Their Data / Accounts / Templates / Registration

# %% [markdown]
# #### Source example 19.25
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/accounts/templates/registration/login.html`.
#
# **Context**
#
# 1. This example demonstrates decision-making, where the program chooses a path based on data.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   {% if form.errors %}
#     <p>Your username and password didn't match. Please try again.</p>
#   {% endif %}
#
#   <form action="{% url 'accounts:login' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#
#     <button name="submit">Log in</button>
#   </form>
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   {% if form.errors %}
#     <p>Your username and password didn't match. Please try again.</p>
#   {% endif %}
#
#   <form action="{% url 'accounts:login' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#
#     <button name="submit">Log in</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.25
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.26
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/accounts/templates/registration/register.html`.
#
# **Context**
#
# 1. This example belongs to adding user accounts and protected data, from the section `Allowing Users To Own Their Data / Accounts / Templates / Registration`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <form action="{% url 'accounts:register' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#
#     <button name="submit">Register</button>
#   </form>
#
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <form action="{% url 'accounts:register' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#
#     <button name="submit">Register</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.26
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Allowing Users To Own Their Data / Accounts

# %% [markdown]
# #### Source example 19.27
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/accounts/tests.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %%
# Practice rewrite for source example 19.27
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.28
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/accounts/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# """Defines URL patterns for accounts."""
#
# from django.urls import path, include
#
# from . import views
#
#
# app_name = 'accounts'
# urlpatterns = [
#     # Include default auth urls.
#     path('', include('django.contrib.auth.urls')),
#     # Registration page.
#     path('register/', views.register, name='register'),
# ]
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """Defines URL patterns for accounts."""
#
# from django.urls import path, include
#
# from . import views
#
#
# app_name = 'accounts'
# urlpatterns = [
#     # Include default auth urls.
#     path('', include('django.contrib.auth.urls')),
#     # Registration page.
#     path('register/', views.register, name='register'),
# ]
# ```

# %%
# Practice rewrite for source example 19.28
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.29
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/accounts/views.py`.
#
# **Context**
#
# 1. This example demonstrates decision-making, where the program chooses a path based on data.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.shortcuts import render, redirect
# from django.contrib.auth import login
# from django.contrib.auth.forms import UserCreationForm
#
#
# def register(request):
#     """Register a new user."""
#     if request.method != 'POST':
#         # Display blank registration form.
#         form = UserCreationForm()
#     else:
#         # Process completed form.
#         form = UserCreationForm(data=request.POST)
#
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.shortcuts import render, redirect
# from django.contrib.auth import login
# from django.contrib.auth.forms import UserCreationForm
#
#
# def register(request):
#     """Register a new user."""
#     if request.method != 'POST':
#         # Display blank registration form.
#         form = UserCreationForm()
#     else:
#         # Process completed form.
#         form = UserCreationForm(data=request.POST)
#
#         if form.is_valid():
#             new_user = form.save()
#             # Log the user in and then redirect to home page.
#             login(request, new_user)
#             return redirect('learning_logs:index')
#
#     # Display a blank or invalid form.
#     context = {'form': form}
#     return render(request, 'registration/register.html', context)
# ```

# %%
# Practice rewrite for source example 19.29
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Allowing Users To Own Their Data / Learning Logs

# %% [markdown]
# #### Source example 19.30
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/learning_logs/admin.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.contrib import admin
#
# from .models import Topic, Entry
#
#
# admin.site.register(Topic)
# admin.site.register(Entry)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.contrib import admin
#
# from .models import Topic, Entry
#
#
# admin.site.register(Topic)
# admin.site.register(Entry)
# ```

# %%
# Practice rewrite for source example 19.30
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.31
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/learning_logs/apps.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.apps import AppConfig
#
#
# class LearningLogsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'learning_logs'
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.apps import AppConfig
#
#
# class LearningLogsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'learning_logs'
# ```

# %%
# Practice rewrite for source example 19.31
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.32
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/learning_logs/forms.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django import forms
#
# from .models import Topic, Entry
#
#
# class TopicForm(forms.ModelForm):
#     class Meta:
#         model = Topic
#         fields = ['text']
#         labels = {'text': ''}
#
# class EntryForm(forms.ModelForm):
#     class Meta:
#         model = Entry
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django import forms
#
# from .models import Topic, Entry
#
#
# class TopicForm(forms.ModelForm):
#     class Meta:
#         model = Topic
#         fields = ['text']
#         labels = {'text': ''}
#
# class EntryForm(forms.ModelForm):
#     class Meta:
#         model = Entry
#         fields = ['text']
#         labels = {'text': ''}
#         widgets = {'text': forms.Textarea(attrs={'cols': 80})}
# ```

# %%
# Practice rewrite for source example 19.32
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Allowing Users To Own Their Data / Learning Logs / Migrations

# %% [markdown]
# #### Source example 19.33
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/learning_logs/migrations/0001_initial.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:24
#
# from django.db import migrations, models
#
#
# class Migration(migrations.Migration):
#
#     initial = True
#
#     dependencies = [
#     ]
#
#     operations = [
#         migrations.CreateModel(
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:24
#
# from django.db import migrations, models
#
#
# class Migration(migrations.Migration):
#
#     initial = True
#
#     dependencies = [
#     ]
#
#     operations = [
#         migrations.CreateModel(
#             name='Topic',
#             fields=[
#                 ('id', models.BigAutoField(auto_created=True, primary_key=True, serialize=False, verbose_name='ID')),
#                 ('text', models.CharField(max_length=200)),
#                 ('date_added', models.DateTimeField(auto_now_add=True)),
#             ],
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 19.33
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.34
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/learning_logs/migrations/0002_entry.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:28
#
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         ('learning_logs', '0001_initial'),
#     ]
#
#     operations = [
#         migrations.CreateModel(
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:28
#
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         ('learning_logs', '0001_initial'),
#     ]
#
#     operations = [
#         migrations.CreateModel(
#             name='Entry',
#             fields=[
#                 ('id', models.BigAutoField(auto_created=True, primary_key=True, serialize=False, verbose_name='ID')),
#                 ('text', models.TextField()),
#                 ('date_added', models.DateTimeField(auto_now_add=True)),
#                 ('topic', models.ForeignKey(on_delete=django.db.models.deletion.CASCADE, to='learning_logs.topic')),
#             ],
#             options={
#                 'verbose_name_plural': 'entries',
#             },
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 19.34
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.35
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/learning_logs/migrations/0003_topic_owner.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 23:58
#
# from django.conf import settings
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         migrations.swappable_dependency(settings.AUTH_USER_MODEL),
#         ('learning_logs', '0002_entry'),
#     ]
#
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 23:58
#
# from django.conf import settings
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         migrations.swappable_dependency(settings.AUTH_USER_MODEL),
#         ('learning_logs', '0002_entry'),
#     ]
#
#     operations = [
#         migrations.AddField(
#             model_name='topic',
#             name='owner',
#             field=models.ForeignKey(default=1, on_delete=django.db.models.deletion.CASCADE, to=settings.AUTH_USER_MODEL),
#             preserve_default=False,
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 19.35
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Allowing Users To Own Their Data / Learning Logs

# %% [markdown]
# #### Source example 19.36
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/learning_logs/models.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.db import models
# from django.contrib.auth.models import User
#
#
# class Topic(models.Model):
#     """A topic the user is learning about."""
#     text = models.CharField(max_length=200)
#     date_added = models.DateTimeField(auto_now_add=True)
#     owner = models.ForeignKey(User, on_delete=models.CASCADE)
#
#     def __str__(self):
#         """Return a string representation of the model."""
#         return self.text
#
# # ... 13 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.db import models
# from django.contrib.auth.models import User
#
#
# class Topic(models.Model):
#     """A topic the user is learning about."""
#     text = models.CharField(max_length=200)
#     date_added = models.DateTimeField(auto_now_add=True)
#     owner = models.ForeignKey(User, on_delete=models.CASCADE)
#
#     def __str__(self):
#         """Return a string representation of the model."""
#         return self.text
#
#
# class Entry(models.Model):
#     """Something specific learned about a topic."""
#     topic = models.ForeignKey(Topic, on_delete=models.CASCADE)
#     text = models.TextField()
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     class Meta:
#         verbose_name_plural = 'entries'
#
#     def __str__(self):
#         """Return a simple string representing the entry."""
#         return f"{self.text[:50]}..."
# ```

# %%
# Practice rewrite for source example 19.36
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Allowing Users To Own Their Data / Learning Logs / Templates / Learning Logs

# %% [markdown]
# #### Source example 19.37
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/learning_logs/templates/learning_logs/base.html`.
#
# **Context**
#
# 1. This example demonstrates decision-making, where the program chooses a path based on data.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# <p>
#   <a href="{% url 'learning_logs:index' %}">Learning Log</a> -
#   <a href="{% url 'learning_logs:topics' %}">Topics</a> -
#   {% if user.is_authenticated %}
#     Hello, {{ user.username }}.
#   {% else %}
#     <a href="{% url 'accounts:register' %}">Register</a> -
#     <a href="{% url 'accounts:login' %}">Log in</a>
#   {% endif %}
# </p>
#
# {% block content %}{% endblock content %}
#
# {% if user.is_authenticated %}
# # ... 6 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# <p>
#   <a href="{% url 'learning_logs:index' %}">Learning Log</a> -
#   <a href="{% url 'learning_logs:topics' %}">Topics</a> -
#   {% if user.is_authenticated %}
#     Hello, {{ user.username }}.
#   {% else %}
#     <a href="{% url 'accounts:register' %}">Register</a> -
#     <a href="{% url 'accounts:login' %}">Log in</a>
#   {% endif %}
# </p>
#
# {% block content %}{% endblock content %}
#
# {% if user.is_authenticated %}
#   <hr />
#   <form action="{% url 'accounts:logout' %}" method='post'>
#     {% csrf_token %}
#     <button name='submit'>Log out</button>
#   </form>
# {% endif %}
# ```

# %%
# Practice rewrite for source example 19.37
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.38
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/learning_logs/templates/learning_logs/edit_entry.html`.
#
# **Context**
#
# 1. This example belongs to adding user accounts and protected data, from the section `Allowing Users To Own Their Data / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Edit entry:</p>
#
#   <form action="{% url 'learning_logs:edit_entry' entry.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Save changes</button>
#   </form>
#
# # ... 1 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Edit entry:</p>
#
#   <form action="{% url 'learning_logs:edit_entry' entry.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Save changes</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.38
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.39
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/learning_logs/templates/learning_logs/index.html`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#   <p>Learning Log helps you keep track of your learning, for any topic you're
#   interested in.</p>
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#   <p>Learning Log helps you keep track of your learning, for any topic you're
#   interested in.</p>
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.39
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.40
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/learning_logs/templates/learning_logs/new_entry.html`.
#
# **Context**
#
# 1. This example belongs to adding user accounts and protected data, from the section `Allowing Users To Own Their Data / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Add a new entry:</p>
#   <form action="{% url 'learning_logs:new_entry' topic.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name='submit'>Add entry</button>
#   </form>
#
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Add a new entry:</p>
#   <form action="{% url 'learning_logs:new_entry' topic.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name='submit'>Add entry</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.40
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.41
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/learning_logs/templates/learning_logs/new_topic.html`.
#
# **Context**
#
# 1. This example belongs to adding user accounts and protected data, from the section `Allowing Users To Own Their Data / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#   <p>Add a new topic:</p>
#
#   <form action="{% url 'learning_logs:new_topic' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Add topic</button>
#   </form>
#
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#   <p>Add a new topic:</p>
#
#   <form action="{% url 'learning_logs:new_topic' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Add topic</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.41
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.42
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/learning_logs/templates/learning_logs/topic.html`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   <p>Topic: {{ topic.text }}</p>
#
#   <p>Entries:</p>
#   <p>
#     <a href="{% url 'learning_logs:new_entry' topic.id %}">Add new entry</a>
#   </p>
#
#   <ul>
#     {% for entry in entries %}
#       <li>
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   <p>Topic: {{ topic.text }}</p>
#
#   <p>Entries:</p>
#   <p>
#     <a href="{% url 'learning_logs:new_entry' topic.id %}">Add new entry</a>
#   </p>
#
#   <ul>
#     {% for entry in entries %}
#       <li>
#         <p>{{ entry.date_added|date:'M d, Y H:i' }}</p>
#         <p>{{ entry.text|linebreaks }}</p>
#         <p>
#           <a href="{% url 'learning_logs:edit_entry' entry.id %}">
#             Edit entry</a></p>
#       </li>
#     {% empty %}
#       <li>There are no entries for this topic yet.</li>
#     {% endfor %}
#   </ul>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.42
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.43
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/learning_logs/templates/learning_logs/topics.html`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   <p>Topics</p>
#   <ul>
#     {% for topic in topics %}
#       <li>
#         <a href="{% url 'learning_logs:topic' topic.id %}">
#           {{ topic.text }}</a>
#       </li>
#     {% empty %}
#       <li>No topics have been added yet.</li>
#     {% endfor %}
# # ... 5 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   <p>Topics</p>
#   <ul>
#     {% for topic in topics %}
#       <li>
#         <a href="{% url 'learning_logs:topic' topic.id %}">
#           {{ topic.text }}</a>
#       </li>
#     {% empty %}
#       <li>No topics have been added yet.</li>
#     {% endfor %}
#   </ul>
#
#   <a href="{% url 'learning_logs:new_topic' %}">Add a new topic</a>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.43
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Allowing Users To Own Their Data / Learning Logs

# %% [markdown]
# #### Source example 19.44
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/learning_logs/tests.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %%
# Practice rewrite for source example 19.44
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.45
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/learning_logs/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# """Defines URL patterns for learning_logs."""
#
# from django.urls import path
#
# from . import views
#
# app_name = 'learning_logs'
# urlpatterns = [
#     # Home page
#     path('', views.index, name='index'),
#     # Page that shows all topics.
#     path('topics/', views.topics, name='topics'),
#     # Detail page for a single topic.
#     path('topics/<int:topic_id>/', views.topic, name='topic'),
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """Defines URL patterns for learning_logs."""
#
# from django.urls import path
#
# from . import views
#
# app_name = 'learning_logs'
# urlpatterns = [
#     # Home page
#     path('', views.index, name='index'),
#     # Page that shows all topics.
#     path('topics/', views.topics, name='topics'),
#     # Detail page for a single topic.
#     path('topics/<int:topic_id>/', views.topic, name='topic'),
#     # Page for adding a new topic.
#     path('new_topic/', views.new_topic, name='new_topic'),
#     # Page for adding a new entry.
#     path('new_entry/<int:topic_id>/', views.new_entry, name='new_entry'),
#     # Page for editing an entry.
#     path('edit_entry/<int:entry_id>/', views.edit_entry, name='edit_entry'),
# ]
# ```

# %%
# Practice rewrite for source example 19.45
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.46
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/learning_logs/views.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.shortcuts import render, redirect
# from django.contrib.auth.decorators import login_required
# from django.http import Http404
#
# from .models import Topic, Entry
# from .forms import TopicForm, EntryForm
#
#
# def index(request):
#     """The home page for Learning Log."""
#     return render(request, 'learning_logs/index.html')
#
# @login_required
# def topics(request):
# # ... 77 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.shortcuts import render, redirect
# from django.contrib.auth.decorators import login_required
# from django.http import Http404
#
# from .models import Topic, Entry
# from .forms import TopicForm, EntryForm
#
#
# def index(request):
#     """The home page for Learning Log."""
#     return render(request, 'learning_logs/index.html')
#
# @login_required
# def topics(request):
#     """Show all topics."""
#     topics = Topic.objects.filter(owner=request.user).order_by('date_added')
#     context = {'topics': topics}
#     return render(request, 'learning_logs/topics.html', context)
#
# @login_required
# def topic(request, topic_id):
#     """Show a single topic and all its entries."""
#     topic = Topic.objects.get(id=topic_id)
#     # Make sure the topic belongs to the current user.
#     if topic.owner != request.user:
#         raise Http404
#
#     entries = topic.entry_set.order_by('-date_added')
#     context = {'topic': topic, 'entries': entries}
#     return render(request, 'learning_logs/topic.html', context)
#
# @login_required
# def new_topic(request):
#     """Add a new topic."""
#     if request.method != 'POST':
#         # No data submitted; create a blank form.
#         form = TopicForm()
#     else:
#         # POST data submitted; process data.
#         form = TopicForm(data=request.POST)
#         if form.is_valid():
#             new_topic = form.save(commit=False)
#             new_topic.owner = request.user
#             new_topic.save()
#             return redirect('learning_logs:topics')
#
#     # Display a blank or invalid form.
#     context = {'form': form}
#     return render(request, 'learning_logs/new_topic.html', context)
#
# @login_required
# def new_entry(request, topic_id):
#     """Add a new entry for a particular topic."""
#     topic = Topic.objects.get(id=topic_id)
#
#     if request.method != 'POST':
#         # No data submitted; create a blank form.
#         form = EntryForm()
#     else:
#         # POST data submitted; process data.
#         form = EntryForm(data=request.POST)
#         if form.is_valid():
#             new_entry = form.save(commit=False)
#             new_entry.topic = topic
#             new_entry.save()
#             return redirect('learning_logs:topic', topic_id=topic_id)
#
#     # Display a blank or invalid form.
#     context = {'topic': topic, 'form': form}
#     return render(request, 'learning_logs/new_entry.html', context)
#
# @login_required
# def edit_entry(request, entry_id):
#     """Edit an existing entry."""
#     entry = Entry.objects.get(id=entry_id)
#     topic = entry.topic
#     if topic.owner != request.user:
#         raise Http404
#
#     if request.method != 'POST':
#         # Initial request; pre-fill form with the current entry.
#         form = EntryForm(instance=entry)
#     else:
#         # POST data submitted; process data.
#         form = EntryForm(instance=entry, data=request.POST)
#         if form.is_valid():
#             form.save()
#             return redirect('learning_logs:topic', topic_id=topic.id)
#
#     context = {'entry': entry, 'topic': topic, 'form': form}
#     return render(request, 'learning_logs/edit_entry.html', context)
# ```

# %%
# Practice rewrite for source example 19.46
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Allowing Users To Own Their Data / Ll Project

# %% [markdown]
# #### Source example 19.47
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/ll_project/asgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_asgi_application()
# ```

# %%
# Practice rewrite for source example 19.47
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.48
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/ll_project/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # ... 118 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # Build paths inside the project like this: BASE_DIR / 'subdir'.
# BASE_DIR = Path(__file__).resolve().parent.parent
#
#
# # Quick-start development settings - unsuitable for production
# # See https://docs.djangoproject.com/en/dev/howto/deployment/checklist/
#
# # SECURITY WARNING: keep the secret key used in production secret!
# SECRET_KEY = 'django-insecure-mibxt7sboxg%r)9t6z=a6@weyo(thgbknfcwgyowgx9$5s4&=!'
#
# # SECURITY WARNING: don't run with debug turned on in production!
# DEBUG = True
#
# ALLOWED_HOSTS = []
#
# # Application definition
#
# INSTALLED_APPS = [
#     # My apps.
#     'learning_logs',
#     'accounts',
#
#     # Default django apps.
#     'django.contrib.admin',
#     'django.contrib.auth',
#     'django.contrib.contenttypes',
#     'django.contrib.sessions',
#     'django.contrib.messages',
#     'django.contrib.staticfiles',
# ]
#
# MIDDLEWARE = [
#     'django.middleware.security.SecurityMiddleware',
#     'django.contrib.sessions.middleware.SessionMiddleware',
#     'django.middleware.common.CommonMiddleware',
#     'django.middleware.csrf.CsrfViewMiddleware',
#     'django.contrib.auth.middleware.AuthenticationMiddleware',
#     'django.contrib.messages.middleware.MessageMiddleware',
#     'django.middleware.clickjacking.XFrameOptionsMiddleware',
# ]
#
# ROOT_URLCONF = 'll_project.urls'
#
# TEMPLATES = [
#     {
#         'BACKEND': 'django.template.backends.django.DjangoTemplates',
#         'DIRS': [],
#         'APP_DIRS': True,
#         'OPTIONS': {
#             'context_processors': [
#                 'django.template.context_processors.debug',
#                 'django.template.context_processors.request',
#                 'django.contrib.auth.context_processors.auth',
#                 'django.contrib.messages.context_processors.messages',
#             ],
#         },
#     },
# ]
#
# WSGI_APPLICATION = 'll_project.wsgi.application'
#
#
# # Database
# # https://docs.djangoproject.com/en/dev/ref/settings/#databases
#
# DATABASES = {
#     'default': {
#         'ENGINE': 'django.db.backends.sqlite3',
#         'NAME': BASE_DIR / 'db.sqlite3',
#     }
# }
#
#
# # Password validation
# # https://docs.djangoproject.com/en/dev/ref/settings/#auth-password-validators
#
# AUTH_PASSWORD_VALIDATORS = [
#     {
#         'NAME': 'django.contrib.auth.password_validation.UserAttributeSimilarityValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.MinimumLengthValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.CommonPasswordValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.NumericPasswordValidator',
#     },
# ]
#
#
# # Internationalization
# # https://docs.djangoproject.com/en/dev/topics/i18n/
#
# LANGUAGE_CODE = 'en-us'
#
# TIME_ZONE = 'UTC'
#
# USE_I18N = True
#
# USE_TZ = True
#
#
# # Static files (CSS, JavaScript, Images)
# # https://docs.djangoproject.com/en/dev/howto/static-files/
#
# STATIC_URL = 'static/'
#
# # Default primary key field type
# # https://docs.djangoproject.com/en/dev/ref/settings/#default-auto-field
#
# DEFAULT_AUTO_FIELD = 'django.db.models.BigAutoField'
#
# # My settings.
# LOGIN_REDIRECT_URL = 'learning_logs:index'
# LOGOUT_REDIRECT_URL = 'learning_logs:index'
# LOGIN_URL = 'accounts:login'
# ```

# %%
# Practice rewrite for source example 19.48
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.49
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/ll_project/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# """
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('accounts/', include('accounts.urls')),
#     path('', include('learning_logs.urls')),
# ]
# ```

# %%
# Practice rewrite for source example 19.49
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.50
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/ll_project/wsgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_wsgi_application()
# ```

# %%
# Practice rewrite for source example 19.50
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Allowing Users To Own Their Data

# %% [markdown]
# #### Source example 19.51
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/allowing_users_to_own_their_data/manage.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
#             "available on your PYTHONPATH environment variable? Did you "
#             "forget to activate a virtual environment?"
#         ) from exc
#     execute_from_command_line(sys.argv)
#
#
# if __name__ == '__main__':
#     main()
# ```

# %%
# Practice rewrite for source example 19.51
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Setting Up User Accounts / Accounts

# %% [markdown]
# #### Source example 19.52
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/accounts/admin.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.contrib import admin
#
# # Register your models here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.contrib import admin
#
# # Register your models here.
# ```

# %%
# Practice rewrite for source example 19.52
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.53
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/accounts/apps.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.apps import AppConfig
#
#
# class AccountsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'accounts'
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.apps import AppConfig
#
#
# class AccountsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'accounts'
# ```

# %%
# Practice rewrite for source example 19.53
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.54
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/accounts/models.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.db import models
#
# # Create your models here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.db import models
#
# # Create your models here.
# ```

# %%
# Practice rewrite for source example 19.54
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Setting Up User Accounts / Accounts / Templates / Registration

# %% [markdown]
# #### Source example 19.55
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/accounts/templates/registration/login.html`.
#
# **Context**
#
# 1. This example demonstrates decision-making, where the program chooses a path based on data.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   {% if form.errors %}
#     <p>Your username and password didn't match. Please try again.</p>
#   {% endif %}
#
#   <form action="{% url 'accounts:login' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#
#     <button name="submit">Log in</button>
#   </form>
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   {% if form.errors %}
#     <p>Your username and password didn't match. Please try again.</p>
#   {% endif %}
#
#   <form action="{% url 'accounts:login' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#
#     <button name="submit">Log in</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.55
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.56
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/accounts/templates/registration/register.html`.
#
# **Context**
#
# 1. This example belongs to adding user accounts and protected data, from the section `Setting Up User Accounts / Accounts / Templates / Registration`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <form action="{% url 'accounts:register' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#
#     <button name="submit">Register</button>
#   </form>
#
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <form action="{% url 'accounts:register' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#
#     <button name="submit">Register</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.56
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Setting Up User Accounts / Accounts

# %% [markdown]
# #### Source example 19.57
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/accounts/tests.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %%
# Practice rewrite for source example 19.57
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.58
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/accounts/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# """Defines URL patterns for accounts."""
#
# from django.urls import path, include
#
# from . import views
#
#
# app_name = 'accounts'
# urlpatterns = [
#     # Include default auth urls.
#     path('', include('django.contrib.auth.urls')),
#     # Registration page.
#     path('register/', views.register, name='register'),
# ]
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """Defines URL patterns for accounts."""
#
# from django.urls import path, include
#
# from . import views
#
#
# app_name = 'accounts'
# urlpatterns = [
#     # Include default auth urls.
#     path('', include('django.contrib.auth.urls')),
#     # Registration page.
#     path('register/', views.register, name='register'),
# ]
# ```

# %%
# Practice rewrite for source example 19.58
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.59
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/accounts/views.py`.
#
# **Context**
#
# 1. This example demonstrates decision-making, where the program chooses a path based on data.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.shortcuts import render, redirect
# from django.contrib.auth import login
# from django.contrib.auth.forms import UserCreationForm
#
#
# def register(request):
#     """Register a new user."""
#     if request.method != 'POST':
#         # Display blank registration form.
#         form = UserCreationForm()
#     else:
#         # Process completed form.
#         form = UserCreationForm(data=request.POST)
#
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.shortcuts import render, redirect
# from django.contrib.auth import login
# from django.contrib.auth.forms import UserCreationForm
#
#
# def register(request):
#     """Register a new user."""
#     if request.method != 'POST':
#         # Display blank registration form.
#         form = UserCreationForm()
#     else:
#         # Process completed form.
#         form = UserCreationForm(data=request.POST)
#
#         if form.is_valid():
#             new_user = form.save()
#             # Log the user in and then redirect to home page.
#             login(request, new_user)
#             return redirect('learning_logs:index')
#
#     # Display a blank or invalid form.
#     context = {'form': form}
#     return render(request, 'registration/register.html', context)
# ```

# %%
# Practice rewrite for source example 19.59
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Setting Up User Accounts / Learning Logs

# %% [markdown]
# #### Source example 19.60
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/learning_logs/admin.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.contrib import admin
#
# from .models import Topic, Entry
#
#
# admin.site.register(Topic)
# admin.site.register(Entry)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.contrib import admin
#
# from .models import Topic, Entry
#
#
# admin.site.register(Topic)
# admin.site.register(Entry)
# ```

# %%
# Practice rewrite for source example 19.60
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.61
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/learning_logs/apps.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.apps import AppConfig
#
#
# class LearningLogsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'learning_logs'
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.apps import AppConfig
#
#
# class LearningLogsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'learning_logs'
# ```

# %%
# Practice rewrite for source example 19.61
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.62
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/learning_logs/forms.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django import forms
#
# from .models import Topic, Entry
#
#
# class TopicForm(forms.ModelForm):
#     class Meta:
#         model = Topic
#         fields = ['text']
#         labels = {'text': ''}
#
# class EntryForm(forms.ModelForm):
#     class Meta:
#         model = Entry
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django import forms
#
# from .models import Topic, Entry
#
#
# class TopicForm(forms.ModelForm):
#     class Meta:
#         model = Topic
#         fields = ['text']
#         labels = {'text': ''}
#
# class EntryForm(forms.ModelForm):
#     class Meta:
#         model = Entry
#         fields = ['text']
#         labels = {'text': ''}
#         widgets = {'text': forms.Textarea(attrs={'cols': 80})}
# ```

# %%
# Practice rewrite for source example 19.62
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Setting Up User Accounts / Learning Logs / Migrations

# %% [markdown]
# #### Source example 19.63
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/learning_logs/migrations/0001_initial.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:24
#
# from django.db import migrations, models
#
#
# class Migration(migrations.Migration):
#
#     initial = True
#
#     dependencies = [
#     ]
#
#     operations = [
#         migrations.CreateModel(
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:24
#
# from django.db import migrations, models
#
#
# class Migration(migrations.Migration):
#
#     initial = True
#
#     dependencies = [
#     ]
#
#     operations = [
#         migrations.CreateModel(
#             name='Topic',
#             fields=[
#                 ('id', models.BigAutoField(auto_created=True, primary_key=True, serialize=False, verbose_name='ID')),
#                 ('text', models.CharField(max_length=200)),
#                 ('date_added', models.DateTimeField(auto_now_add=True)),
#             ],
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 19.63
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.64
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/learning_logs/migrations/0002_entry.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:28
#
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         ('learning_logs', '0001_initial'),
#     ]
#
#     operations = [
#         migrations.CreateModel(
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:28
#
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         ('learning_logs', '0001_initial'),
#     ]
#
#     operations = [
#         migrations.CreateModel(
#             name='Entry',
#             fields=[
#                 ('id', models.BigAutoField(auto_created=True, primary_key=True, serialize=False, verbose_name='ID')),
#                 ('text', models.TextField()),
#                 ('date_added', models.DateTimeField(auto_now_add=True)),
#                 ('topic', models.ForeignKey(on_delete=django.db.models.deletion.CASCADE, to='learning_logs.topic')),
#             ],
#             options={
#                 'verbose_name_plural': 'entries',
#             },
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 19.64
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Setting Up User Accounts / Learning Logs

# %% [markdown]
# #### Source example 19.65
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/learning_logs/models.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.db import models
#
# class Topic(models.Model):
#     """A topic the user is learning about."""
#     text = models.CharField(max_length=200)
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     def __str__(self):
#         """Return a string representation of the model."""
#         return self.text
#
#
# class Entry(models.Model):
#     """Something specific learned about a topic."""
# # ... 10 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.db import models
#
# class Topic(models.Model):
#     """A topic the user is learning about."""
#     text = models.CharField(max_length=200)
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     def __str__(self):
#         """Return a string representation of the model."""
#         return self.text
#
#
# class Entry(models.Model):
#     """Something specific learned about a topic."""
#     topic = models.ForeignKey(Topic, on_delete=models.CASCADE)
#     text = models.TextField()
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     class Meta:
#         verbose_name_plural = 'entries'
#
#     def __str__(self):
#         """Return a simple string representing the entry."""
#         return f"{self.text[:50]}..."
# ```

# %%
# Practice rewrite for source example 19.65
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Setting Up User Accounts / Learning Logs / Templates / Learning Logs

# %% [markdown]
# #### Source example 19.66
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/learning_logs/templates/learning_logs/base.html`.
#
# **Context**
#
# 1. This example demonstrates decision-making, where the program chooses a path based on data.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# <p>
#   <a href="{% url 'learning_logs:index' %}">Learning Log</a> -
#   <a href="{% url 'learning_logs:topics' %}">Topics</a> -
#   {% if user.is_authenticated %}
#     Hello, {{ user.username }}.
#   {% else %}
#     <a href="{% url 'accounts:register' %}">Register</a> -
#     <a href="{% url 'accounts:login' %}">Log in</a>
#   {% endif %}
# </p>
#
# {% block content %}{% endblock content %}
#
# {% if user.is_authenticated %}
# # ... 6 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# <p>
#   <a href="{% url 'learning_logs:index' %}">Learning Log</a> -
#   <a href="{% url 'learning_logs:topics' %}">Topics</a> -
#   {% if user.is_authenticated %}
#     Hello, {{ user.username }}.
#   {% else %}
#     <a href="{% url 'accounts:register' %}">Register</a> -
#     <a href="{% url 'accounts:login' %}">Log in</a>
#   {% endif %}
# </p>
#
# {% block content %}{% endblock content %}
#
# {% if user.is_authenticated %}
#   <hr />
#   <form action="{% url 'accounts:logout' %}" method='post'>
#     {% csrf_token %}
#     <button name='submit'>Log out</button>
#   </form>
# {% endif %}
# ```

# %%
# Practice rewrite for source example 19.66
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.67
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/learning_logs/templates/learning_logs/edit_entry.html`.
#
# **Context**
#
# 1. This example belongs to adding user accounts and protected data, from the section `Setting Up User Accounts / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Edit entry:</p>
#
#   <form action="{% url 'learning_logs:edit_entry' entry.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Save changes</button>
#   </form>
#
# # ... 1 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Edit entry:</p>
#
#   <form action="{% url 'learning_logs:edit_entry' entry.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Save changes</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.67
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.68
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/learning_logs/templates/learning_logs/index.html`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#   <p>Learning Log helps you keep track of your learning, for any topic you're
#   interested in.</p>
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#   <p>Learning Log helps you keep track of your learning, for any topic you're
#   interested in.</p>
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.68
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.69
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/learning_logs/templates/learning_logs/new_entry.html`.
#
# **Context**
#
# 1. This example belongs to adding user accounts and protected data, from the section `Setting Up User Accounts / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Add a new entry:</p>
#   <form action="{% url 'learning_logs:new_entry' topic.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name='submit'>Add entry</button>
#   </form>
#
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Add a new entry:</p>
#   <form action="{% url 'learning_logs:new_entry' topic.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name='submit'>Add entry</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.69
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.70
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/learning_logs/templates/learning_logs/new_topic.html`.
#
# **Context**
#
# 1. This example belongs to adding user accounts and protected data, from the section `Setting Up User Accounts / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#   <p>Add a new topic:</p>
#
#   <form action="{% url 'learning_logs:new_topic' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Add topic</button>
#   </form>
#
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#   <p>Add a new topic:</p>
#
#   <form action="{% url 'learning_logs:new_topic' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Add topic</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.70
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.71
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/learning_logs/templates/learning_logs/topic.html`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   <p>Topic: {{ topic.text }}</p>
#
#   <p>Entries:</p>
#   <p>
#     <a href="{% url 'learning_logs:new_entry' topic.id %}">Add new entry</a>
#   </p>
#
#   <ul>
#     {% for entry in entries %}
#       <li>
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   <p>Topic: {{ topic.text }}</p>
#
#   <p>Entries:</p>
#   <p>
#     <a href="{% url 'learning_logs:new_entry' topic.id %}">Add new entry</a>
#   </p>
#
#   <ul>
#     {% for entry in entries %}
#       <li>
#         <p>{{ entry.date_added|date:'M d, Y H:i' }}</p>
#         <p>{{ entry.text|linebreaks }}</p>
#         <p>
#           <a href="{% url 'learning_logs:edit_entry' entry.id %}">
#             Edit entry</a></p>
#       </li>
#     {% empty %}
#       <li>There are no entries for this topic yet.</li>
#     {% endfor %}
#   </ul>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.71
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.72
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/learning_logs/templates/learning_logs/topics.html`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   <p>Topics</p>
#   <ul>
#     {% for topic in topics %}
#       <li>
#         <a href="{% url 'learning_logs:topic' topic.id %}">
#           {{ topic.text }}</a>
#       </li>
#     {% empty %}
#       <li>No topics have been added yet.</li>
#     {% endfor %}
# # ... 5 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block content %}
#
#   <p>Topics</p>
#   <ul>
#     {% for topic in topics %}
#       <li>
#         <a href="{% url 'learning_logs:topic' topic.id %}">
#           {{ topic.text }}</a>
#       </li>
#     {% empty %}
#       <li>No topics have been added yet.</li>
#     {% endfor %}
#   </ul>
#
#   <a href="{% url 'learning_logs:new_topic' %}">Add a new topic</a>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 19.72
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Setting Up User Accounts / Learning Logs

# %% [markdown]
# #### Source example 19.73
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/learning_logs/tests.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %%
# Practice rewrite for source example 19.73
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.74
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/learning_logs/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# """Defines URL patterns for learning_logs."""
#
# from django.urls import path
#
# from . import views
#
# app_name = 'learning_logs'
# urlpatterns = [
#     # Home page
#     path('', views.index, name='index'),
#     # Page that shows all topics.
#     path('topics/', views.topics, name='topics'),
#     # Detail page for a single topic.
#     path('topics/<int:topic_id>/', views.topic, name='topic'),
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """Defines URL patterns for learning_logs."""
#
# from django.urls import path
#
# from . import views
#
# app_name = 'learning_logs'
# urlpatterns = [
#     # Home page
#     path('', views.index, name='index'),
#     # Page that shows all topics.
#     path('topics/', views.topics, name='topics'),
#     # Detail page for a single topic.
#     path('topics/<int:topic_id>/', views.topic, name='topic'),
#     # Page for adding a new topic.
#     path('new_topic/', views.new_topic, name='new_topic'),
#     # Page for adding a new entry.
#     path('new_entry/<int:topic_id>/', views.new_entry, name='new_entry'),
#     # Page for editing an entry.
#     path('edit_entry/<int:entry_id>/', views.edit_entry, name='edit_entry'),
# ]
# ```

# %%
# Practice rewrite for source example 19.74
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.75
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/learning_logs/views.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# from django.shortcuts import render, redirect
#
# from .models import Topic, Entry
# from .forms import TopicForm, EntryForm
#
#
# def index(request):
#     """The home page for Learning Log."""
#     return render(request, 'learning_logs/index.html')
#
# def topics(request):
#     """Show all topics."""
#     topics = Topic.objects.order_by('date_added')
#     context = {'topics': topics}
# # ... 62 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.shortcuts import render, redirect
#
# from .models import Topic, Entry
# from .forms import TopicForm, EntryForm
#
#
# def index(request):
#     """The home page for Learning Log."""
#     return render(request, 'learning_logs/index.html')
#
# def topics(request):
#     """Show all topics."""
#     topics = Topic.objects.order_by('date_added')
#     context = {'topics': topics}
#     return render(request, 'learning_logs/topics.html', context)
#
# def topic(request, topic_id):
#     """Show a single topic and all its entries."""
#     topic = Topic.objects.get(id=topic_id)
#     entries = topic.entry_set.order_by('-date_added')
#     context = {'topic': topic, 'entries': entries}
#     return render(request, 'learning_logs/topic.html', context)
#
# def new_topic(request):
#     """Add a new topic."""
#     if request.method != 'POST':
#         # No data submitted; create a blank form.
#         form = TopicForm()
#     else:
#         # POST data submitted; process data.
#         form = TopicForm(data=request.POST)
#         if form.is_valid():
#             form.save()
#             return redirect('learning_logs:topics')
#
#     # Display a blank or invalid form.
#     context = {'form': form}
#     return render(request, 'learning_logs/new_topic.html', context)
#
# def new_entry(request, topic_id):
#     """Add a new entry for a particular topic."""
#     topic = Topic.objects.get(id=topic_id)
#
#     if request.method != 'POST':
#         # No data submitted; create a blank form.
#         form = EntryForm()
#     else:
#         # POST data submitted; process data.
#         form = EntryForm(data=request.POST)
#         if form.is_valid():
#             new_entry = form.save(commit=False)
#             new_entry.topic = topic
#             new_entry.save()
#             return redirect('learning_logs:topic', topic_id=topic_id)
#
#     # Display a blank or invalid form.
#     context = {'topic': topic, 'form': form}
#     return render(request, 'learning_logs/new_entry.html', context)
#
# def edit_entry(request, entry_id):
#     """Edit an existing entry."""
#     entry = Entry.objects.get(id=entry_id)
#     topic = entry.topic
#
#     if request.method != 'POST':
#         # Initial request; pre-fill form with the current entry.
#         form = EntryForm(instance=entry)
#     else:
#         # POST data submitted; process data.
#         form = EntryForm(instance=entry, data=request.POST)
#         if form.is_valid():
#             form.save()
#             return redirect('learning_logs:topic', topic_id=topic.id)
#
#     context = {'entry': entry, 'topic': topic, 'form': form}
#     return render(request, 'learning_logs/edit_entry.html', context)
# ```

# %%
# Practice rewrite for source example 19.75
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Setting Up User Accounts / Ll Project

# %% [markdown]
# #### Source example 19.76
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/ll_project/asgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_asgi_application()
# ```

# %%
# Practice rewrite for source example 19.76
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.77
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/ll_project/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # ... 117 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # Build paths inside the project like this: BASE_DIR / 'subdir'.
# BASE_DIR = Path(__file__).resolve().parent.parent
#
#
# # Quick-start development settings - unsuitable for production
# # See https://docs.djangoproject.com/en/dev/howto/deployment/checklist/
#
# # SECURITY WARNING: keep the secret key used in production secret!
# SECRET_KEY = 'django-insecure-mibxt7sboxg%r)9t6z=a6@weyo(thgbknfcwgyowgx9$5s4&=!'
#
# # SECURITY WARNING: don't run with debug turned on in production!
# DEBUG = True
#
# ALLOWED_HOSTS = []
#
# # Application definition
#
# INSTALLED_APPS = [
#     # My apps.
#     'learning_logs',
#     'accounts',
#
#     # Default django apps.
#     'django.contrib.admin',
#     'django.contrib.auth',
#     'django.contrib.contenttypes',
#     'django.contrib.sessions',
#     'django.contrib.messages',
#     'django.contrib.staticfiles',
# ]
#
# MIDDLEWARE = [
#     'django.middleware.security.SecurityMiddleware',
#     'django.contrib.sessions.middleware.SessionMiddleware',
#     'django.middleware.common.CommonMiddleware',
#     'django.middleware.csrf.CsrfViewMiddleware',
#     'django.contrib.auth.middleware.AuthenticationMiddleware',
#     'django.contrib.messages.middleware.MessageMiddleware',
#     'django.middleware.clickjacking.XFrameOptionsMiddleware',
# ]
#
# ROOT_URLCONF = 'll_project.urls'
#
# TEMPLATES = [
#     {
#         'BACKEND': 'django.template.backends.django.DjangoTemplates',
#         'DIRS': [],
#         'APP_DIRS': True,
#         'OPTIONS': {
#             'context_processors': [
#                 'django.template.context_processors.debug',
#                 'django.template.context_processors.request',
#                 'django.contrib.auth.context_processors.auth',
#                 'django.contrib.messages.context_processors.messages',
#             ],
#         },
#     },
# ]
#
# WSGI_APPLICATION = 'll_project.wsgi.application'
#
#
# # Database
# # https://docs.djangoproject.com/en/dev/ref/settings/#databases
#
# DATABASES = {
#     'default': {
#         'ENGINE': 'django.db.backends.sqlite3',
#         'NAME': BASE_DIR / 'db.sqlite3',
#     }
# }
#
#
# # Password validation
# # https://docs.djangoproject.com/en/dev/ref/settings/#auth-password-validators
#
# AUTH_PASSWORD_VALIDATORS = [
#     {
#         'NAME': 'django.contrib.auth.password_validation.UserAttributeSimilarityValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.MinimumLengthValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.CommonPasswordValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.NumericPasswordValidator',
#     },
# ]
#
#
# # Internationalization
# # https://docs.djangoproject.com/en/dev/topics/i18n/
#
# LANGUAGE_CODE = 'en-us'
#
# TIME_ZONE = 'UTC'
#
# USE_I18N = True
#
# USE_TZ = True
#
#
# # Static files (CSS, JavaScript, Images)
# # https://docs.djangoproject.com/en/dev/howto/static-files/
#
# STATIC_URL = 'static/'
#
# # Default primary key field type
# # https://docs.djangoproject.com/en/dev/ref/settings/#default-auto-field
#
# DEFAULT_AUTO_FIELD = 'django.db.models.BigAutoField'
#
# # My settings.
# LOGIN_REDIRECT_URL = 'learning_logs:index'
# LOGOUT_REDIRECT_URL = 'learning_logs:index'
# ```

# %%
# Practice rewrite for source example 19.77
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.78
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/ll_project/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# """
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('accounts/', include('accounts.urls')),
#     path('', include('learning_logs.urls')),
# ]
# ```

# %%
# Practice rewrite for source example 19.78
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 19.79
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/ll_project/wsgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_wsgi_application()
# ```

# %%
# Practice rewrite for source example 19.79
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Setting Up User Accounts

# %% [markdown]
# #### Source example 19.80
#
# Checklist note: captured from **Chapter 19: User Accounts**, official GitHub source `chapter_19/setting_up_user_accounts/manage.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This builds on Django basics by adding authentication, ownership, forms, and user-specific records.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# user account -> form/authentication -> owned data -> protected view
# ```
#
# **Code Preview**
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
#             "available on your PYTHONPATH environment variable? Did you "
#             "forget to activate a virtual environment?"
#         ) from exc
#     execute_from_command_line(sys.argv)
#
#
# if __name__ == '__main__':
#     main()
# ```

# %%
# Practice rewrite for source example 19.80
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Chapter 19: User Accounts Practice Checkpoint

# %% [markdown]
# #### Practice: project-safe rewrite

# %%
# Project chapters often depend on installed packages, files, servers, or assets.
# Rewrite one source example with fake data first:
# - replace file/API/game/web inputs with a small list or dictionary
# - print the planned action
# - only then connect it back to the real project
planned_steps = ["identify input", "transform state", "show or save result"]
for step in planned_steps:
    print(step)

# %% [markdown]
# ## Chapter 20: Styling and Deploying an App
#
# PDF pages: 693-740

# %% [markdown]
# ### Deploying Learning Log / .Platform / Local

# %% [markdown]
# #### Source example 20.1
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/.platform/local/project.yaml`.
#
# **Context**
#
# 1. This example demonstrates asking another web service for data and turning the response into Python objects.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```yaml
# id: 7hzn2gjzsf6qs
# host: api.platform.sh
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```yaml
# id: 7hzn2gjzsf6qs
# host: api.platform.sh
# ```

# %%
# Practice rewrite for source example 20.1
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.2
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/.platform/local/README.txt`.
#
# **Context**
#
# 1. This example belongs to styling and deploying a Django app, from the section `Deploying Learning Log / .Platform / Local`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```text
# .platform/local
# ===============
#
# This directory is where the Platform.sh CLI stores configuration files, builds, and
# other data to help work with your project locally.
#
# It is not used on remote environments at all - the directory is excluded from
# your Git repository (via .git/info/exclude).
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```text
# .platform/local
# ===============
#
# This directory is where the Platform.sh CLI stores configuration files, builds, and
# other data to help work with your project locally.
#
# It is not used on remote environments at all - the directory is excluded from
# your Git repository (via .git/info/exclude).
# ```

# %%
# Practice rewrite for source example 20.2
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Deploying Learning Log / .Platform

# %% [markdown]
# #### Source example 20.3
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/.platform/routes.yaml`.
#
# **Context**
#
# 1. This example belongs to styling and deploying a Django app, from the section `Deploying Learning Log / .Platform`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```yaml
# # Each route describes how an incoming URL will be processed by Platform.sh.
#
# "https://{default}/":
#     type: upstream
#     upstream: "ll_project:http"
#
# "https://www.{default}/":
#     type: redirect
#     to: "https://{default}/"
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```yaml
# # Each route describes how an incoming URL will be processed by Platform.sh.
#
# "https://{default}/":
#     type: upstream
#     upstream: "ll_project:http"
#
# "https://www.{default}/":
#     type: redirect
#     to: "https://{default}/"
# ```

# %%
# Practice rewrite for source example 20.3
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.4
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/.platform/services.yaml`.
#
# **Context**
#
# 1. This example belongs to styling and deploying a Django app, from the section `Deploying Learning Log / .Platform`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```yaml
# # Each service listed will be deployed in its own container as part of your
# #   Platform.sh project.
#
# db:
#     type: postgresql:12
#     disk: 1024
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```yaml
# # Each service listed will be deployed in its own container as part of your
# #   Platform.sh project.
#
# db:
#     type: postgresql:12
#     disk: 1024
# ```

# %%
# Practice rewrite for source example 20.4
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Deploying Learning Log

# %% [markdown]
# #### Source example 20.5
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/.platform.app.yaml`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```yaml
# name: "ll_project"
# type: "python:3.10"
#
# relationships:
#     database: "db:postgresql"
#
# # The configuration of the app when it's exposed to the web.
# web:
#     upstream:
#         socket_family: unix
#     commands:
#         start: "gunicorn -w 4 -b unix:$SOCKET ll_project.wsgi:application"
#     locations:
#         "/":
# # ... 27 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```yaml
# name: "ll_project"
# type: "python:3.10"
#
# relationships:
#     database: "db:postgresql"
#
# # The configuration of the app when it's exposed to the web.
# web:
#     upstream:
#         socket_family: unix
#     commands:
#         start: "gunicorn -w 4 -b unix:$SOCKET ll_project.wsgi:application"
#     locations:
#         "/":
#             passthru: true
#         "/static":
#             root: "static"
#             expires: 1h
#             allow: true
#
# # The size of the persistent disk of the application (in MB).
# disk: 512
#
# # Set a local read/write mount for logs.
# mounts:
#     "logs":
#         source: local
#         source_path: logs
#
# # The hooks executed at various points in the lifecycle of the application.
# hooks:
#     build: |
#         pip install --upgrade pip
#         pip install -r requirements.txt
#         pip install -r requirements_remote.txt
#
#         mkdir logs
#         python manage.py collectstatic
#         rm -rf logs
#     deploy: |
#         python manage.py migrate
# ```

# %%
# Practice rewrite for source example 20.5
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Deploying Learning Log / Accounts

# %% [markdown]
# #### Source example 20.6
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/accounts/admin.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.contrib import admin
#
# # Register your models here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.contrib import admin
#
# # Register your models here.
# ```

# %%
# Practice rewrite for source example 20.6
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.7
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/accounts/apps.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.apps import AppConfig
#
#
# class AccountsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'accounts'
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.apps import AppConfig
#
#
# class AccountsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'accounts'
# ```

# %%
# Practice rewrite for source example 20.7
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.8
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/accounts/models.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.db import models
#
# # Create your models here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.db import models
#
# # Create your models here.
# ```

# %%
# Practice rewrite for source example 20.8
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Deploying Learning Log / Accounts / Templates / Registration

# %% [markdown]
# #### Source example 20.9
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/accounts/templates/registration/login.html`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
# {% load django_bootstrap5 %}
#
# {% block page_header %}
#   <h2>Log in to your account.</h2>
# {% endblock page_header %}
#
# {% block content %}
#
#   <form action="{% url 'accounts:login' %}" method='post'>
#     {% csrf_token %}
#     {% bootstrap_form form %}
#     {% bootstrap_button button_type="submit" content="Log in" %}
#   </form>
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
# {% load django_bootstrap5 %}
#
# {% block page_header %}
#   <h2>Log in to your account.</h2>
# {% endblock page_header %}
#
# {% block content %}
#
#   <form action="{% url 'accounts:login' %}" method='post'>
#     {% csrf_token %}
#     {% bootstrap_form form %}
#     {% bootstrap_button button_type="submit" content="Log in" %}
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 20.9
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.10
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/accounts/templates/registration/register.html`.
#
# **Context**
#
# 1. This example belongs to styling and deploying a Django app, from the section `Deploying Learning Log / Accounts / Templates / Registration`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <form action="{% url 'accounts:register' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#
#     <button name="submit">Register</button>
#   </form>
#
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <form action="{% url 'accounts:register' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#
#     <button name="submit">Register</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 20.10
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Deploying Learning Log / Accounts

# %% [markdown]
# #### Source example 20.11
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/accounts/tests.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %%
# Practice rewrite for source example 20.11
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.12
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/accounts/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# """Defines URL patterns for accounts."""
#
# from django.urls import path, include
#
# from . import views
#
#
# app_name = 'accounts'
# urlpatterns = [
#     # Include default auth urls.
#     path('', include('django.contrib.auth.urls')),
#     # Registration page.
#     path('register/', views.register, name='register'),
# ]
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """Defines URL patterns for accounts."""
#
# from django.urls import path, include
#
# from . import views
#
#
# app_name = 'accounts'
# urlpatterns = [
#     # Include default auth urls.
#     path('', include('django.contrib.auth.urls')),
#     # Registration page.
#     path('register/', views.register, name='register'),
# ]
# ```

# %%
# Practice rewrite for source example 20.12
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.13
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/accounts/views.py`.
#
# **Context**
#
# 1. This example demonstrates decision-making, where the program chooses a path based on data.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.shortcuts import render, redirect
# from django.contrib.auth import login
# from django.contrib.auth.forms import UserCreationForm
#
#
# def register(request):
#     """Register a new user."""
#     if request.method != 'POST':
#         # Display blank registration form.
#         form = UserCreationForm()
#     else:
#         # Process completed form.
#         form = UserCreationForm(data=request.POST)
#
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.shortcuts import render, redirect
# from django.contrib.auth import login
# from django.contrib.auth.forms import UserCreationForm
#
#
# def register(request):
#     """Register a new user."""
#     if request.method != 'POST':
#         # Display blank registration form.
#         form = UserCreationForm()
#     else:
#         # Process completed form.
#         form = UserCreationForm(data=request.POST)
#
#         if form.is_valid():
#             new_user = form.save()
#             # Log the user in and then redirect to home page.
#             login(request, new_user)
#             return redirect('learning_logs:index')
#
#     # Display a blank or invalid form.
#     context = {'form': form}
#     return render(request, 'registration/register.html', context)
# ```

# %%
# Practice rewrite for source example 20.13
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Deploying Learning Log / Learning Logs

# %% [markdown]
# #### Source example 20.14
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/learning_logs/admin.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.contrib import admin
#
# from .models import Topic, Entry
#
#
# admin.site.register(Topic)
# admin.site.register(Entry)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.contrib import admin
#
# from .models import Topic, Entry
#
#
# admin.site.register(Topic)
# admin.site.register(Entry)
# ```

# %%
# Practice rewrite for source example 20.14
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.15
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/learning_logs/apps.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.apps import AppConfig
#
#
# class LearningLogsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'learning_logs'
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.apps import AppConfig
#
#
# class LearningLogsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'learning_logs'
# ```

# %%
# Practice rewrite for source example 20.15
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.16
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/learning_logs/forms.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django import forms
#
# from .models import Topic, Entry
#
#
# class TopicForm(forms.ModelForm):
#     class Meta:
#         model = Topic
#         fields = ['text']
#         labels = {'text': ''}
#
# class EntryForm(forms.ModelForm):
#     class Meta:
#         model = Entry
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django import forms
#
# from .models import Topic, Entry
#
#
# class TopicForm(forms.ModelForm):
#     class Meta:
#         model = Topic
#         fields = ['text']
#         labels = {'text': ''}
#
# class EntryForm(forms.ModelForm):
#     class Meta:
#         model = Entry
#         fields = ['text']
#         labels = {'text': ''}
#         widgets = {'text': forms.Textarea(attrs={'cols': 80})}
# ```

# %%
# Practice rewrite for source example 20.16
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Deploying Learning Log / Learning Logs / Migrations

# %% [markdown]
# #### Source example 20.17
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/learning_logs/migrations/0001_initial.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:24
#
# from django.db import migrations, models
#
#
# class Migration(migrations.Migration):
#
#     initial = True
#
#     dependencies = [
#     ]
#
#     operations = [
#         migrations.CreateModel(
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:24
#
# from django.db import migrations, models
#
#
# class Migration(migrations.Migration):
#
#     initial = True
#
#     dependencies = [
#     ]
#
#     operations = [
#         migrations.CreateModel(
#             name='Topic',
#             fields=[
#                 ('id', models.BigAutoField(auto_created=True, primary_key=True, serialize=False, verbose_name='ID')),
#                 ('text', models.CharField(max_length=200)),
#                 ('date_added', models.DateTimeField(auto_now_add=True)),
#             ],
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 20.17
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.18
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/learning_logs/migrations/0002_entry.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:28
#
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         ('learning_logs', '0001_initial'),
#     ]
#
#     operations = [
#         migrations.CreateModel(
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:28
#
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         ('learning_logs', '0001_initial'),
#     ]
#
#     operations = [
#         migrations.CreateModel(
#             name='Entry',
#             fields=[
#                 ('id', models.BigAutoField(auto_created=True, primary_key=True, serialize=False, verbose_name='ID')),
#                 ('text', models.TextField()),
#                 ('date_added', models.DateTimeField(auto_now_add=True)),
#                 ('topic', models.ForeignKey(on_delete=django.db.models.deletion.CASCADE, to='learning_logs.topic')),
#             ],
#             options={
#                 'verbose_name_plural': 'entries',
#             },
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 20.18
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.19
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/learning_logs/migrations/0003_topic_owner.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 23:58
#
# from django.conf import settings
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         migrations.swappable_dependency(settings.AUTH_USER_MODEL),
#         ('learning_logs', '0002_entry'),
#     ]
#
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 23:58
#
# from django.conf import settings
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         migrations.swappable_dependency(settings.AUTH_USER_MODEL),
#         ('learning_logs', '0002_entry'),
#     ]
#
#     operations = [
#         migrations.AddField(
#             model_name='topic',
#             name='owner',
#             field=models.ForeignKey(default=1, on_delete=django.db.models.deletion.CASCADE, to=settings.AUTH_USER_MODEL),
#             preserve_default=False,
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 20.19
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Deploying Learning Log / Learning Logs

# %% [markdown]
# #### Source example 20.20
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/learning_logs/models.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.db import models
# from django.contrib.auth.models import User
#
#
# class Topic(models.Model):
#     """A topic the user is learning about."""
#     text = models.CharField(max_length=200)
#     date_added = models.DateTimeField(auto_now_add=True)
#     owner = models.ForeignKey(User, on_delete=models.CASCADE)
#
#     def __str__(self):
#         """Return a string representation of the model."""
#         return self.text
#
# # ... 13 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.db import models
# from django.contrib.auth.models import User
#
#
# class Topic(models.Model):
#     """A topic the user is learning about."""
#     text = models.CharField(max_length=200)
#     date_added = models.DateTimeField(auto_now_add=True)
#     owner = models.ForeignKey(User, on_delete=models.CASCADE)
#
#     def __str__(self):
#         """Return a string representation of the model."""
#         return self.text
#
#
# class Entry(models.Model):
#     """Something specific learned about a topic."""
#     topic = models.ForeignKey(Topic, on_delete=models.CASCADE)
#     text = models.TextField()
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     class Meta:
#         verbose_name_plural = 'entries'
#
#     def __str__(self):
#         """Return a simple string representing the entry."""
#         return f"{self.text[:50]}..."
# ```

# %%
# Practice rewrite for source example 20.20
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Deploying Learning Log / Learning Logs / Templates / Learning Logs

# %% [markdown]
# #### Source example 20.21
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/learning_logs/templates/learning_logs/base.html`.
#
# **Context**
#
# 1. This example demonstrates decision-making, where the program chooses a path based on data.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# <!doctype html>
# <html lang="en">
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <title>Learning Log</title>
#
#   {% load django_bootstrap5 %}
#   {% bootstrap_css %}
#   {% bootstrap_javascript %}
#
# </head>
# <body>
#   <nav class="navbar navbar-expand-md navbar-light bg-light mb-4 border">
# # ... 60 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# <!doctype html>
# <html lang="en">
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <title>Learning Log</title>
#
#   {% load django_bootstrap5 %}
#   {% bootstrap_css %}
#   {% bootstrap_javascript %}
#
# </head>
# <body>
#   <nav class="navbar navbar-expand-md navbar-light bg-light mb-4 border">
#     <div class="container-fluid">
#       <a class="navbar-brand" href="{% url 'learning_logs:index' %}">
#           Learning Log</a>
#
#       <button class="navbar-toggler" type="button" data-bs-toggle="collapse"
#         data-bs-target="#navbarCollapse" aria-controls="navbarCollapse"
#         aria-expanded="false" aria-label="Toggle navigation">
#         <span class="navbar-toggler-icon"></span>
#       </button>
#
#       <div class="collapse navbar-collapse" id="navbarCollapse">
#         <ul class="navbar-nav me-auto mb-2 mb-md-0">
#           <li class="nav-item">
#             <a class="nav-link" href="{% url 'learning_logs:topics' %}">
#               Topics</a></li>
#         </ul> <!-- End of links on left side of navbar -->
#
#         <!-- Account-related links -->
#         <ul class="navbar-nav ms-auto mb-2 mb-md-0">
#
#           {% if user.is_authenticated %}
#             <li class="nav-item">
#               <span class="navbar-text me-2">Hello, {{ user.username }}.
#                 </span></li>
#           {% else %}
#             <li class="nav-item">
#               <a class="nav-link" href="{% url 'accounts:register' %}">
#                   Register</a></li>
#             <li class="nav-item">
#               <a class="nav-link" href="{% url 'accounts:login' %}">
#                   Log in</a></li>
#           {% endif %}
#
#         </ul> <!-- End of account-related links -->
#
#         {% if user.is_authenticated %}
#           <form action="{% url 'accounts:logout' %}" method='post'>
#             {% csrf_token %}
#             <button name='submit' class='btn btn-outline-secondary btn-sm'>
#               Log out</button>
#           </form>
#         {% endif %}
#
#       </div> <!-- Closes collapsible parts of navbar -->
#
#     </div> <!-- Closes navbar's container -->
#   </nav> <!-- End of navbar -->
#
#   <main class="container">
#     <div class="pb-2 mb-2 border-bottom">
#       {% block page_header %}{% endblock page_header %}
#     </div>
#
#     <div>
#       {% block content %}{% endblock content %}
#     </div>
#   </main>
#
# </body>
# </html>
# ```

# %%
# Practice rewrite for source example 20.21
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.22
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/learning_logs/templates/learning_logs/edit_entry.html`.
#
# **Context**
#
# 1. This example belongs to styling and deploying a Django app, from the section `Deploying Learning Log / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Edit entry:</p>
#
#   <form action="{% url 'learning_logs:edit_entry' entry.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Save changes</button>
#   </form>
#
# # ... 1 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Edit entry:</p>
#
#   <form action="{% url 'learning_logs:edit_entry' entry.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Save changes</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 20.22
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.23
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/learning_logs/templates/learning_logs/index.html`.
#
# **Context**
#
# 1. This example belongs to styling and deploying a Django app, from the section `Deploying Learning Log / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block page_header %}
#   <div class="p-3 mb-4 bg-light border rounded-3">
#     <div class="container-fluid py-4">
#       <h1 class="display-3">Track your learning.</h1>
#
#       <p class="lead">Make your own Learning Log, and keep a list of the
#       topics you're learning about. Whenever you learn something new
#       about a topic, make an entry summarizing what you've learned.</p>
#
#       <a class="btn btn-primary btn-lg mt-1"
#           href="{% url 'accounts:register' %}">Register &raquo;</a>
#     </div>
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block page_header %}
#   <div class="p-3 mb-4 bg-light border rounded-3">
#     <div class="container-fluid py-4">
#       <h1 class="display-3">Track your learning.</h1>
#
#       <p class="lead">Make your own Learning Log, and keep a list of the
#       topics you're learning about. Whenever you learn something new
#       about a topic, make an entry summarizing what you've learned.</p>
#
#       <a class="btn btn-primary btn-lg mt-1"
#           href="{% url 'accounts:register' %}">Register &raquo;</a>
#     </div>
#   </div>
# {% endblock page_header %}
# ```

# %%
# Practice rewrite for source example 20.23
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.24
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/learning_logs/templates/learning_logs/new_entry.html`.
#
# **Context**
#
# 1. This example belongs to styling and deploying a Django app, from the section `Deploying Learning Log / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Add a new entry:</p>
#   <form action="{% url 'learning_logs:new_entry' topic.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name='submit'>Add entry</button>
#   </form>
#
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Add a new entry:</p>
#   <form action="{% url 'learning_logs:new_entry' topic.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name='submit'>Add entry</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 20.24
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.25
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/learning_logs/templates/learning_logs/new_topic.html`.
#
# **Context**
#
# 1. This example belongs to styling and deploying a Django app, from the section `Deploying Learning Log / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#   <p>Add a new topic:</p>
#
#   <form action="{% url 'learning_logs:new_topic' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Add topic</button>
#   </form>
#
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#   <p>Add a new topic:</p>
#
#   <form action="{% url 'learning_logs:new_topic' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Add topic</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 20.25
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.26
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/learning_logs/templates/learning_logs/topic.html`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block page_header %}
#   <h1>{{ topic.text }}</h1>
# {% endblock page_header %}
#
# {% block content %}
#
#   <p>
#     <a href="{% url 'learning_logs:new_entry' topic.id %}">Add new entry</a>
#   </p>
#
#   {% for entry in entries %}
#     <div class="card mb-3">
# # ... 14 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block page_header %}
#   <h1>{{ topic.text }}</h1>
# {% endblock page_header %}
#
# {% block content %}
#
#   <p>
#     <a href="{% url 'learning_logs:new_entry' topic.id %}">Add new entry</a>
#   </p>
#
#   {% for entry in entries %}
#     <div class="card mb-3">
#       <!-- Card header with timestamp and edit link -->
#       <h4 class="card-header">
#         {{ entry.date_added|date:'M d, Y H:i' }}
#         <small><a href="{% url 'learning_logs:edit_entry' entry.id %}">
#           edit entry</a></small>
#       </h4>
#       <!-- Card body with entry text -->
#       <div class="card-body">{{ entry.text|linebreaks }}</div>
#     </div>
#   {% empty %}
#     <p>There are no entries for this topic yet.</p>
#   {% endfor %}
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 20.26
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.27
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/learning_logs/templates/learning_logs/topics.html`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block page_header %}
#   <h1>Topics</h1>
# {% endblock page_header %}
#
# {% block content %}
#
#   <ul class="list-group border-bottom pb-2 mb-4">
#     {% for topic in topics %}
#       <li class="list-group-item border-0">
#         <a href="{% url 'learning_logs:topic' topic.id %}">
#           {{ topic.text }}</a>
#       </li>
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block page_header %}
#   <h1>Topics</h1>
# {% endblock page_header %}
#
# {% block content %}
#
#   <ul class="list-group border-bottom pb-2 mb-4">
#     {% for topic in topics %}
#       <li class="list-group-item border-0">
#         <a href="{% url 'learning_logs:topic' topic.id %}">
#           {{ topic.text }}</a>
#       </li>
#     {% empty %}
#       <li class="list-group-item border-0">No topics have been added yet.</li>
#     {% endfor %}
#   </ul>
#
#   <a href="{% url 'learning_logs:new_topic' %}">Add a new topic</a>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 20.27
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Deploying Learning Log / Learning Logs

# %% [markdown]
# #### Source example 20.28
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/learning_logs/tests.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %%
# Practice rewrite for source example 20.28
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.29
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/learning_logs/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# """Defines URL patterns for learning_logs."""
#
# from django.urls import path
#
# from . import views
#
# app_name = 'learning_logs'
# urlpatterns = [
#     # Home page
#     path('', views.index, name='index'),
#     # Page that shows all topics.
#     path('topics/', views.topics, name='topics'),
#     # Detail page for a single topic.
#     path('topics/<int:topic_id>/', views.topic, name='topic'),
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """Defines URL patterns for learning_logs."""
#
# from django.urls import path
#
# from . import views
#
# app_name = 'learning_logs'
# urlpatterns = [
#     # Home page
#     path('', views.index, name='index'),
#     # Page that shows all topics.
#     path('topics/', views.topics, name='topics'),
#     # Detail page for a single topic.
#     path('topics/<int:topic_id>/', views.topic, name='topic'),
#     # Page for adding a new topic.
#     path('new_topic/', views.new_topic, name='new_topic'),
#     # Page for adding a new entry.
#     path('new_entry/<int:topic_id>/', views.new_entry, name='new_entry'),
#     # Page for editing an entry.
#     path('edit_entry/<int:entry_id>/', views.edit_entry, name='edit_entry'),
# ]
# ```

# %%
# Practice rewrite for source example 20.29
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.30
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/learning_logs/views.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.shortcuts import render, redirect
# from django.contrib.auth.decorators import login_required
# from django.http import Http404
#
# from .models import Topic, Entry
# from .forms import TopicForm, EntryForm
#
#
# def index(request):
#     """The home page for Learning Log."""
#     return render(request, 'learning_logs/index.html')
#
# @login_required
# def topics(request):
# # ... 77 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.shortcuts import render, redirect
# from django.contrib.auth.decorators import login_required
# from django.http import Http404
#
# from .models import Topic, Entry
# from .forms import TopicForm, EntryForm
#
#
# def index(request):
#     """The home page for Learning Log."""
#     return render(request, 'learning_logs/index.html')
#
# @login_required
# def topics(request):
#     """Show all topics."""
#     topics = Topic.objects.filter(owner=request.user).order_by('date_added')
#     context = {'topics': topics}
#     return render(request, 'learning_logs/topics.html', context)
#
# @login_required
# def topic(request, topic_id):
#     """Show a single topic and all its entries."""
#     topic = Topic.objects.get(id=topic_id)
#     # Make sure the topic belongs to the current user.
#     if topic.owner != request.user:
#         raise Http404
#
#     entries = topic.entry_set.order_by('-date_added')
#     context = {'topic': topic, 'entries': entries}
#     return render(request, 'learning_logs/topic.html', context)
#
# @login_required
# def new_topic(request):
#     """Add a new topic."""
#     if request.method != 'POST':
#         # No data submitted; create a blank form.
#         form = TopicForm()
#     else:
#         # POST data submitted; process data.
#         form = TopicForm(data=request.POST)
#         if form.is_valid():
#             new_topic = form.save(commit=False)
#             new_topic.owner = request.user
#             new_topic.save()
#             return redirect('learning_logs:topics')
#
#     # Display a blank or invalid form.
#     context = {'form': form}
#     return render(request, 'learning_logs/new_topic.html', context)
#
# @login_required
# def new_entry(request, topic_id):
#     """Add a new entry for a particular topic."""
#     topic = Topic.objects.get(id=topic_id)
#
#     if request.method != 'POST':
#         # No data submitted; create a blank form.
#         form = EntryForm()
#     else:
#         # POST data submitted; process data.
#         form = EntryForm(data=request.POST)
#         if form.is_valid():
#             new_entry = form.save(commit=False)
#             new_entry.topic = topic
#             new_entry.save()
#             return redirect('learning_logs:topic', topic_id=topic_id)
#
#     # Display a blank or invalid form.
#     context = {'topic': topic, 'form': form}
#     return render(request, 'learning_logs/new_entry.html', context)
#
# @login_required
# def edit_entry(request, entry_id):
#     """Edit an existing entry."""
#     entry = Entry.objects.get(id=entry_id)
#     topic = entry.topic
#     if topic.owner != request.user:
#         raise Http404
#
#     if request.method != 'POST':
#         # Initial request; pre-fill form with the current entry.
#         form = EntryForm(instance=entry)
#     else:
#         # POST data submitted; process data.
#         form = EntryForm(instance=entry, data=request.POST)
#         if form.is_valid():
#             form.save()
#             return redirect('learning_logs:topic', topic_id=topic.id)
#
#     context = {'entry': entry, 'topic': topic, 'form': form}
#     return render(request, 'learning_logs/edit_entry.html', context)
# ```

# %%
# Practice rewrite for source example 20.30
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Deploying Learning Log / Ll Project

# %% [markdown]
# #### Source example 20.31
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/ll_project/asgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_asgi_application()
# ```

# %%
# Practice rewrite for source example 20.31
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.32
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/ll_project/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # ... 147 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # Build paths inside the project like this: BASE_DIR / 'subdir'.
# BASE_DIR = Path(__file__).resolve().parent.parent
#
#
# # Quick-start development settings - unsuitable for production
# # See https://docs.djangoproject.com/en/dev/howto/deployment/checklist/
#
# # SECURITY WARNING: keep the secret key used in production secret!
# SECRET_KEY = 'django-insecure-mibxt7sboxg%r)9t6z=a6@weyo(thgbknfcwgyowgx9$5s4&=!'
#
# # SECURITY WARNING: don't run with debug turned on in production!
# DEBUG = True
#
# ALLOWED_HOSTS = []
#
# # Application definition
#
# INSTALLED_APPS = [
#     # My apps.
#     'learning_logs',
#     'accounts',
#
#     # Third party apps.
#     'django_bootstrap5',
#
#     # Default django apps.
#     'django.contrib.admin',
#     'django.contrib.auth',
#     'django.contrib.contenttypes',
#     'django.contrib.sessions',
#     'django.contrib.messages',
#     'django.contrib.staticfiles',
# ]
#
# MIDDLEWARE = [
#     'django.middleware.security.SecurityMiddleware',
#     'django.contrib.sessions.middleware.SessionMiddleware',
#     'django.middleware.common.CommonMiddleware',
#     'django.middleware.csrf.CsrfViewMiddleware',
#     'django.contrib.auth.middleware.AuthenticationMiddleware',
#     'django.contrib.messages.middleware.MessageMiddleware',
#     'django.middleware.clickjacking.XFrameOptionsMiddleware',
# ]
#
# ROOT_URLCONF = 'll_project.urls'
#
# TEMPLATES = [
#     {
#         'BACKEND': 'django.template.backends.django.DjangoTemplates',
#         'DIRS': [BASE_DIR / 'templates'],
#         'APP_DIRS': True,
#         'OPTIONS': {
#             'context_processors': [
#                 'django.template.context_processors.debug',
#                 'django.template.context_processors.request',
#                 'django.contrib.auth.context_processors.auth',
#                 'django.contrib.messages.context_processors.messages',
#             ],
#         },
#     },
# ]
#
# WSGI_APPLICATION = 'll_project.wsgi.application'
#
#
# # Database
# # https://docs.djangoproject.com/en/dev/ref/settings/#databases
#
# DATABASES = {
#     'default': {
#         'ENGINE': 'django.db.backends.sqlite3',
#         'NAME': BASE_DIR / 'db.sqlite3',
#     }
# }
#
#
# # Password validation
# # https://docs.djangoproject.com/en/dev/ref/settings/#auth-password-validators
#
# AUTH_PASSWORD_VALIDATORS = [
#     {
#         'NAME': 'django.contrib.auth.password_validation.UserAttributeSimilarityValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.MinimumLengthValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.CommonPasswordValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.NumericPasswordValidator',
#     },
# ]
#
#
# # Internationalization
# # https://docs.djangoproject.com/en/dev/topics/i18n/
#
# LANGUAGE_CODE = 'en-us'
#
# TIME_ZONE = 'UTC'
#
# USE_I18N = True
#
# USE_TZ = True
#
#
# # Static files (CSS, JavaScript, Images)
# # https://docs.djangoproject.com/en/dev/howto/static-files/
#
# STATIC_URL = 'static/'
#
# # Default primary key field type
# # https://docs.djangoproject.com/en/dev/ref/settings/#default-auto-field
#
# DEFAULT_AUTO_FIELD = 'django.db.models.BigAutoField'
#
# # My settings.
# LOGIN_REDIRECT_URL = 'learning_logs:index'
# LOGOUT_REDIRECT_URL = 'learning_logs:index'
# LOGIN_URL = 'accounts:login'
#
# # Platform.sh settings.
# from platformshconfig import Config
#
# config = Config()
# if config.is_valid_platform():
#     ALLOWED_HOSTS.append('.platformsh.site')
#     DEBUG = False
#
#     if config.appDir:
#         STATIC_ROOT = Path(config.appDir) / 'static'
#     if config.projectEntropy:
#         SECRET_KEY = config.projectEntropy
#
#     if not config.in_build():
#         db_settings = config.credentials('database')
#         DATABASES = {
#             'default': {
#                 'ENGINE': 'django.db.backends.postgresql',
#                 'NAME': db_settings['path'],
#                 'USER': db_settings['username'],
#                 'PASSWORD': db_settings['password'],
#                 'HOST': db_settings['host'],
#                 'PORT': db_settings['port'],
#     },
# }
# ```

# %%
# Practice rewrite for source example 20.32
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.33
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/ll_project/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# """
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('accounts/', include('accounts.urls')),
#     path('', include('learning_logs.urls')),
# ]
# ```

# %%
# Practice rewrite for source example 20.33
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.34
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/ll_project/wsgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_wsgi_application()
# ```

# %%
# Practice rewrite for source example 20.34
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Deploying Learning Log

# %% [markdown]
# #### Source example 20.35
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/manage.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
#             "available on your PYTHONPATH environment variable? Did you "
#             "forget to activate a virtual environment?"
#         ) from exc
#     execute_from_command_line(sys.argv)
#
#
# if __name__ == '__main__':
#     main()
# ```

# %%
# Practice rewrite for source example 20.35
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.36
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/requirements.txt`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```text
# asgiref==3.5.2
# beautifulsoup4==4.11.1
# Django==4.1b1
# django-bootstrap5==21.3
# platformshconfig==2.4.0
# soupsieve==2.3.2.post1
# sqlparse==0.4.2
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```text
# asgiref==3.5.2
# beautifulsoup4==4.11.1
# Django==4.1b1
# django-bootstrap5==21.3
# platformshconfig==2.4.0
# soupsieve==2.3.2.post1
# sqlparse==0.4.2
# ```

# %%
# Practice rewrite for source example 20.36
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.37
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/requirements_remote.txt`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```text
# # Requirements for live project.
# gunicorn
# psycopg2
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```text
# # Requirements for live project.
# gunicorn
# psycopg2
# ```

# %%
# Practice rewrite for source example 20.37
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Deploying Learning Log / Templates

# %% [markdown]
# #### Source example 20.38
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/templates/404.html`.
#
# **Context**
#
# 1. This example belongs to styling and deploying a Django app, from the section `Deploying Learning Log / Templates`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block page_header %}
#   <h2>The item you requested is not available. (404)</h2>
# {% endblock page_header %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block page_header %}
#   <h2>The item you requested is not available. (404)</h2>
# {% endblock page_header %}
# ```

# %%
# Practice rewrite for source example 20.38
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.39
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/deploying_learning_log/templates/500.html`.
#
# **Context**
#
# 1. This example belongs to styling and deploying a Django app, from the section `Deploying Learning Log / Templates`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block page_header %}
#   <h2>There has been an internal error. (500)</h2>
# {% endblock page_header %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block page_header %}
#   <h2>There has been an internal error. (500)</h2>
# {% endblock page_header %}
# ```

# %%
# Practice rewrite for source example 20.39
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Styling Learning Log / Accounts

# %% [markdown]
# #### Source example 20.40
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/accounts/admin.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.contrib import admin
#
# # Register your models here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.contrib import admin
#
# # Register your models here.
# ```

# %%
# Practice rewrite for source example 20.40
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.41
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/accounts/apps.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.apps import AppConfig
#
#
# class AccountsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'accounts'
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.apps import AppConfig
#
#
# class AccountsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'accounts'
# ```

# %%
# Practice rewrite for source example 20.41
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.42
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/accounts/models.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.db import models
#
# # Create your models here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.db import models
#
# # Create your models here.
# ```

# %%
# Practice rewrite for source example 20.42
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Styling Learning Log / Accounts / Templates / Registration

# %% [markdown]
# #### Source example 20.43
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/accounts/templates/registration/login.html`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
# {% load django_bootstrap5 %}
#
# {% block page_header %}
#   <h2>Log in to your account.</h2>
# {% endblock page_header %}
#
# {% block content %}
#
#   <form action="{% url 'accounts:login' %}" method='post'>
#     {% csrf_token %}
#     {% bootstrap_form form %}
#     {% bootstrap_button button_type="submit" content="Log in" %}
#   </form>
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
# {% load django_bootstrap5 %}
#
# {% block page_header %}
#   <h2>Log in to your account.</h2>
# {% endblock page_header %}
#
# {% block content %}
#
#   <form action="{% url 'accounts:login' %}" method='post'>
#     {% csrf_token %}
#     {% bootstrap_form form %}
#     {% bootstrap_button button_type="submit" content="Log in" %}
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 20.43
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.44
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/accounts/templates/registration/register.html`.
#
# **Context**
#
# 1. This example belongs to styling and deploying a Django app, from the section `Styling Learning Log / Accounts / Templates / Registration`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <form action="{% url 'accounts:register' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#
#     <button name="submit">Register</button>
#   </form>
#
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <form action="{% url 'accounts:register' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#
#     <button name="submit">Register</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 20.44
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Styling Learning Log / Accounts

# %% [markdown]
# #### Source example 20.45
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/accounts/tests.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %%
# Practice rewrite for source example 20.45
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.46
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/accounts/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# """Defines URL patterns for accounts."""
#
# from django.urls import path, include
#
# from . import views
#
#
# app_name = 'accounts'
# urlpatterns = [
#     # Include default auth urls.
#     path('', include('django.contrib.auth.urls')),
#     # Registration page.
#     path('register/', views.register, name='register'),
# ]
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """Defines URL patterns for accounts."""
#
# from django.urls import path, include
#
# from . import views
#
#
# app_name = 'accounts'
# urlpatterns = [
#     # Include default auth urls.
#     path('', include('django.contrib.auth.urls')),
#     # Registration page.
#     path('register/', views.register, name='register'),
# ]
# ```

# %%
# Practice rewrite for source example 20.46
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.47
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/accounts/views.py`.
#
# **Context**
#
# 1. This example demonstrates decision-making, where the program chooses a path based on data.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.shortcuts import render, redirect
# from django.contrib.auth import login
# from django.contrib.auth.forms import UserCreationForm
#
#
# def register(request):
#     """Register a new user."""
#     if request.method != 'POST':
#         # Display blank registration form.
#         form = UserCreationForm()
#     else:
#         # Process completed form.
#         form = UserCreationForm(data=request.POST)
#
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.shortcuts import render, redirect
# from django.contrib.auth import login
# from django.contrib.auth.forms import UserCreationForm
#
#
# def register(request):
#     """Register a new user."""
#     if request.method != 'POST':
#         # Display blank registration form.
#         form = UserCreationForm()
#     else:
#         # Process completed form.
#         form = UserCreationForm(data=request.POST)
#
#         if form.is_valid():
#             new_user = form.save()
#             # Log the user in and then redirect to home page.
#             login(request, new_user)
#             return redirect('learning_logs:index')
#
#     # Display a blank or invalid form.
#     context = {'form': form}
#     return render(request, 'registration/register.html', context)
# ```

# %%
# Practice rewrite for source example 20.47
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Styling Learning Log / Learning Logs

# %% [markdown]
# #### Source example 20.48
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/learning_logs/admin.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.contrib import admin
#
# from .models import Topic, Entry
#
#
# admin.site.register(Topic)
# admin.site.register(Entry)
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.contrib import admin
#
# from .models import Topic, Entry
#
#
# admin.site.register(Topic)
# admin.site.register(Entry)
# ```

# %%
# Practice rewrite for source example 20.48
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.49
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/learning_logs/apps.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.apps import AppConfig
#
#
# class LearningLogsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'learning_logs'
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.apps import AppConfig
#
#
# class LearningLogsConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'learning_logs'
# ```

# %%
# Practice rewrite for source example 20.49
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.50
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/learning_logs/forms.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django import forms
#
# from .models import Topic, Entry
#
#
# class TopicForm(forms.ModelForm):
#     class Meta:
#         model = Topic
#         fields = ['text']
#         labels = {'text': ''}
#
# class EntryForm(forms.ModelForm):
#     class Meta:
#         model = Entry
# # ... 3 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django import forms
#
# from .models import Topic, Entry
#
#
# class TopicForm(forms.ModelForm):
#     class Meta:
#         model = Topic
#         fields = ['text']
#         labels = {'text': ''}
#
# class EntryForm(forms.ModelForm):
#     class Meta:
#         model = Entry
#         fields = ['text']
#         labels = {'text': ''}
#         widgets = {'text': forms.Textarea(attrs={'cols': 80})}
# ```

# %%
# Practice rewrite for source example 20.50
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Styling Learning Log / Learning Logs / Migrations

# %% [markdown]
# #### Source example 20.51
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/learning_logs/migrations/0001_initial.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:24
#
# from django.db import migrations, models
#
#
# class Migration(migrations.Migration):
#
#     initial = True
#
#     dependencies = [
#     ]
#
#     operations = [
#         migrations.CreateModel(
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:24
#
# from django.db import migrations, models
#
#
# class Migration(migrations.Migration):
#
#     initial = True
#
#     dependencies = [
#     ]
#
#     operations = [
#         migrations.CreateModel(
#             name='Topic',
#             fields=[
#                 ('id', models.BigAutoField(auto_created=True, primary_key=True, serialize=False, verbose_name='ID')),
#                 ('text', models.CharField(max_length=200)),
#                 ('date_added', models.DateTimeField(auto_now_add=True)),
#             ],
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 20.51
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.52
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/learning_logs/migrations/0002_entry.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:28
#
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         ('learning_logs', '0001_initial'),
#     ]
#
#     operations = [
#         migrations.CreateModel(
# # ... 12 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 03:28
#
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         ('learning_logs', '0001_initial'),
#     ]
#
#     operations = [
#         migrations.CreateModel(
#             name='Entry',
#             fields=[
#                 ('id', models.BigAutoField(auto_created=True, primary_key=True, serialize=False, verbose_name='ID')),
#                 ('text', models.TextField()),
#                 ('date_added', models.DateTimeField(auto_now_add=True)),
#                 ('topic', models.ForeignKey(on_delete=django.db.models.deletion.CASCADE, to='learning_logs.topic')),
#             ],
#             options={
#                 'verbose_name_plural': 'entries',
#             },
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 20.52
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.53
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/learning_logs/migrations/0003_topic_owner.py`.
#
# **Context**
#
# 1. This example demonstrates object-oriented structure: data and behavior grouped together.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 23:58
#
# from django.conf import settings
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         migrations.swappable_dependency(settings.AUTH_USER_MODEL),
#         ('learning_logs', '0002_entry'),
#     ]
#
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# # Generated by Django 4.1b1 on 2022-07-01 23:58
#
# from django.conf import settings
# from django.db import migrations, models
# import django.db.models.deletion
#
#
# class Migration(migrations.Migration):
#
#     dependencies = [
#         migrations.swappable_dependency(settings.AUTH_USER_MODEL),
#         ('learning_logs', '0002_entry'),
#     ]
#
#     operations = [
#         migrations.AddField(
#             model_name='topic',
#             name='owner',
#             field=models.ForeignKey(default=1, on_delete=django.db.models.deletion.CASCADE, to=settings.AUTH_USER_MODEL),
#             preserve_default=False,
#         ),
#     ]
# ```

# %%
# Practice rewrite for source example 20.53
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Styling Learning Log / Learning Logs

# %% [markdown]
# #### Source example 20.54
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/learning_logs/models.py`.
#
# **Context**
#
# 1. This example demonstrates a function: a named, reusable block of behavior.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.db import models
# from django.contrib.auth.models import User
#
#
# class Topic(models.Model):
#     """A topic the user is learning about."""
#     text = models.CharField(max_length=200)
#     date_added = models.DateTimeField(auto_now_add=True)
#     owner = models.ForeignKey(User, on_delete=models.CASCADE)
#
#     def __str__(self):
#         """Return a string representation of the model."""
#         return self.text
#
# # ... 13 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.db import models
# from django.contrib.auth.models import User
#
#
# class Topic(models.Model):
#     """A topic the user is learning about."""
#     text = models.CharField(max_length=200)
#     date_added = models.DateTimeField(auto_now_add=True)
#     owner = models.ForeignKey(User, on_delete=models.CASCADE)
#
#     def __str__(self):
#         """Return a string representation of the model."""
#         return self.text
#
#
# class Entry(models.Model):
#     """Something specific learned about a topic."""
#     topic = models.ForeignKey(Topic, on_delete=models.CASCADE)
#     text = models.TextField()
#     date_added = models.DateTimeField(auto_now_add=True)
#
#     class Meta:
#         verbose_name_plural = 'entries'
#
#     def __str__(self):
#         """Return a simple string representing the entry."""
#         return f"{self.text[:50]}..."
# ```

# %%
# Practice rewrite for source example 20.54
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Styling Learning Log / Learning Logs / Templates / Learning Logs

# %% [markdown]
# #### Source example 20.55
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/learning_logs/templates/learning_logs/base.html`.
#
# **Context**
#
# 1. This example demonstrates decision-making, where the program chooses a path based on data.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# <!doctype html>
# <html lang="en">
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <title>Learning Log</title>
#
#   {% load django_bootstrap5 %}
#   {% bootstrap_css %}
#   {% bootstrap_javascript %}
#
# </head>
# <body>
#   <nav class="navbar navbar-expand-md navbar-light bg-light mb-4 border">
# # ... 60 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# <!doctype html>
# <html lang="en">
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <title>Learning Log</title>
#
#   {% load django_bootstrap5 %}
#   {% bootstrap_css %}
#   {% bootstrap_javascript %}
#
# </head>
# <body>
#   <nav class="navbar navbar-expand-md navbar-light bg-light mb-4 border">
#     <div class="container-fluid">
#       <a class="navbar-brand" href="{% url 'learning_logs:index' %}">
#           Learning Log</a>
#
#       <button class="navbar-toggler" type="button" data-bs-toggle="collapse"
#         data-bs-target="#navbarCollapse" aria-controls="navbarCollapse"
#         aria-expanded="false" aria-label="Toggle navigation">
#         <span class="navbar-toggler-icon"></span>
#       </button>
#
#       <div class="collapse navbar-collapse" id="navbarCollapse">
#         <ul class="navbar-nav me-auto mb-2 mb-md-0">
#           <li class="nav-item">
#             <a class="nav-link" href="{% url 'learning_logs:topics' %}">
#               Topics</a></li>
#         </ul> <!-- End of links on left side of navbar -->
#
#         <!-- Account-related links -->
#         <ul class="navbar-nav ms-auto mb-2 mb-md-0">
#
#           {% if user.is_authenticated %}
#             <li class="nav-item">
#               <span class="navbar-text me-2">Hello, {{ user.username }}.
#                 </span></li>
#           {% else %}
#             <li class="nav-item">
#               <a class="nav-link" href="{% url 'accounts:register' %}">
#                   Register</a></li>
#             <li class="nav-item">
#               <a class="nav-link" href="{% url 'accounts:login' %}">
#                   Log in</a></li>
#           {% endif %}
#
#         </ul> <!-- End of account-related links -->
#
#         {% if user.is_authenticated %}
#           <form action="{% url 'accounts:logout' %}" method='post'>
#             {% csrf_token %}
#             <button name='submit' class='btn btn-outline-secondary btn-sm'>
#               Log out</button>
#           </form>
#         {% endif %}
#
#       </div> <!-- Closes collapsible parts of navbar -->
#
#     </div> <!-- Closes navbar's container -->
#   </nav> <!-- End of navbar -->
#
#   <main class="container">
#     <div class="pb-2 mb-2 border-bottom">
#       {% block page_header %}{% endblock page_header %}
#     </div>
#
#     <div>
#       {% block content %}{% endblock content %}
#     </div>
#   </main>
#
# </body>
# </html>
# ```

# %%
# Practice rewrite for source example 20.55
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.56
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/learning_logs/templates/learning_logs/edit_entry.html`.
#
# **Context**
#
# 1. This example belongs to styling and deploying a Django app, from the section `Styling Learning Log / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Edit entry:</p>
#
#   <form action="{% url 'learning_logs:edit_entry' entry.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Save changes</button>
#   </form>
#
# # ... 1 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Edit entry:</p>
#
#   <form action="{% url 'learning_logs:edit_entry' entry.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Save changes</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 20.56
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.57
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/learning_logs/templates/learning_logs/index.html`.
#
# **Context**
#
# 1. This example belongs to styling and deploying a Django app, from the section `Styling Learning Log / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block page_header %}
#   <div class="p-3 mb-4 bg-light border rounded-3">
#     <div class="container-fluid py-4">
#       <h1 class="display-3">Track your learning.</h1>
#
#       <p class="lead">Make your own Learning Log, and keep a list of the
#       topics you're learning about. Whenever you learn something new
#       about a topic, make an entry summarizing what you've learned.</p>
#
#       <a class="btn btn-primary btn-lg mt-1"
#           href="{% url 'accounts:register' %}">Register &raquo;</a>
#     </div>
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block page_header %}
#   <div class="p-3 mb-4 bg-light border rounded-3">
#     <div class="container-fluid py-4">
#       <h1 class="display-3">Track your learning.</h1>
#
#       <p class="lead">Make your own Learning Log, and keep a list of the
#       topics you're learning about. Whenever you learn something new
#       about a topic, make an entry summarizing what you've learned.</p>
#
#       <a class="btn btn-primary btn-lg mt-1"
#           href="{% url 'accounts:register' %}">Register &raquo;</a>
#     </div>
#   </div>
# {% endblock page_header %}
# ```

# %%
# Practice rewrite for source example 20.57
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.58
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/learning_logs/templates/learning_logs/new_entry.html`.
#
# **Context**
#
# 1. This example belongs to styling and deploying a Django app, from the section `Styling Learning Log / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Add a new entry:</p>
#   <form action="{% url 'learning_logs:new_entry' topic.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name='submit'>Add entry</button>
#   </form>
#
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#
#   <p><a href="{% url 'learning_logs:topic' topic.id %}">{{ topic }}</a></p>
#
#   <p>Add a new entry:</p>
#   <form action="{% url 'learning_logs:new_entry' topic.id %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name='submit'>Add entry</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 20.58
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.59
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/learning_logs/templates/learning_logs/new_topic.html`.
#
# **Context**
#
# 1. This example belongs to styling and deploying a Django app, from the section `Styling Learning Log / Learning Logs / Templates / Learning Logs`.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#   <p>Add a new topic:</p>
#
#   <form action="{% url 'learning_logs:new_topic' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Add topic</button>
#   </form>
#
# {% endblock content %}
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends "learning_logs/base.html" %}
#
# {% block content %}
#   <p>Add a new topic:</p>
#
#   <form action="{% url 'learning_logs:new_topic' %}" method='post'>
#     {% csrf_token %}
#     {{ form.as_div }}
#     <button name="submit">Add topic</button>
#   </form>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 20.59
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.60
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/learning_logs/templates/learning_logs/topic.html`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block page_header %}
#   <h1>{{ topic.text }}</h1>
# {% endblock page_header %}
#
# {% block content %}
#
#   <p>
#     <a href="{% url 'learning_logs:new_entry' topic.id %}">Add new entry</a>
#   </p>
#
#   {% for entry in entries %}
#     <div class="card mb-3">
# # ... 14 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block page_header %}
#   <h1>{{ topic.text }}</h1>
# {% endblock page_header %}
#
# {% block content %}
#
#   <p>
#     <a href="{% url 'learning_logs:new_entry' topic.id %}">Add new entry</a>
#   </p>
#
#   {% for entry in entries %}
#     <div class="card mb-3">
#       <!-- Card header with timestamp and edit link -->
#       <h4 class="card-header">
#         {{ entry.date_added|date:'M d, Y H:i' }}
#         <small><a href="{% url 'learning_logs:edit_entry' entry.id %}">
#           edit entry</a></small>
#       </h4>
#       <!-- Card body with entry text -->
#       <div class="card-body">{{ entry.text|linebreaks }}</div>
#     </div>
#   {% empty %}
#     <p>There are no entries for this topic yet.</p>
#   {% endfor %}
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 20.60
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.61
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/learning_logs/templates/learning_logs/topics.html`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block page_header %}
#   <h1>Topics</h1>
# {% endblock page_header %}
#
# {% block content %}
#
#   <ul class="list-group border-bottom pb-2 mb-4">
#     {% for topic in topics %}
#       <li class="list-group-item border-0">
#         <a href="{% url 'learning_logs:topic' topic.id %}">
#           {{ topic.text }}</a>
#       </li>
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```html
# {% extends 'learning_logs/base.html' %}
#
# {% block page_header %}
#   <h1>Topics</h1>
# {% endblock page_header %}
#
# {% block content %}
#
#   <ul class="list-group border-bottom pb-2 mb-4">
#     {% for topic in topics %}
#       <li class="list-group-item border-0">
#         <a href="{% url 'learning_logs:topic' topic.id %}">
#           {{ topic.text }}</a>
#       </li>
#     {% empty %}
#       <li class="list-group-item border-0">No topics have been added yet.</li>
#     {% endfor %}
#   </ul>
#
#   <a href="{% url 'learning_logs:new_topic' %}">Add a new topic</a>
#
# {% endblock content %}
# ```

# %%
# Practice rewrite for source example 20.61
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Styling Learning Log / Learning Logs

# %% [markdown]
# #### Source example 20.62
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/learning_logs/tests.py`.
#
# **Context**
#
# 1. This example demonstrates web app structure: data models, views, templates, URLs, or deployment settings.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.test import TestCase
#
# # Create your tests here.
# ```

# %%
# Practice rewrite for source example 20.62
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.63
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/learning_logs/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# """Defines URL patterns for learning_logs."""
#
# from django.urls import path
#
# from . import views
#
# app_name = 'learning_logs'
# urlpatterns = [
#     # Home page
#     path('', views.index, name='index'),
#     # Page that shows all topics.
#     path('topics/', views.topics, name='topics'),
#     # Detail page for a single topic.
#     path('topics/<int:topic_id>/', views.topic, name='topic'),
# # ... 7 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """Defines URL patterns for learning_logs."""
#
# from django.urls import path
#
# from . import views
#
# app_name = 'learning_logs'
# urlpatterns = [
#     # Home page
#     path('', views.index, name='index'),
#     # Page that shows all topics.
#     path('topics/', views.topics, name='topics'),
#     # Detail page for a single topic.
#     path('topics/<int:topic_id>/', views.topic, name='topic'),
#     # Page for adding a new topic.
#     path('new_topic/', views.new_topic, name='new_topic'),
#     # Page for adding a new entry.
#     path('new_entry/<int:topic_id>/', views.new_entry, name='new_entry'),
#     # Page for editing an entry.
#     path('edit_entry/<int:entry_id>/', views.edit_entry, name='edit_entry'),
# ]
# ```

# %%
# Practice rewrite for source example 20.63
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.64
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/learning_logs/views.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# from django.shortcuts import render, redirect
# from django.contrib.auth.decorators import login_required
# from django.http import Http404
#
# from .models import Topic, Entry
# from .forms import TopicForm, EntryForm
#
#
# def index(request):
#     """The home page for Learning Log."""
#     return render(request, 'learning_logs/index.html')
#
# @login_required
# def topics(request):
# # ... 77 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# from django.shortcuts import render, redirect
# from django.contrib.auth.decorators import login_required
# from django.http import Http404
#
# from .models import Topic, Entry
# from .forms import TopicForm, EntryForm
#
#
# def index(request):
#     """The home page for Learning Log."""
#     return render(request, 'learning_logs/index.html')
#
# @login_required
# def topics(request):
#     """Show all topics."""
#     topics = Topic.objects.filter(owner=request.user).order_by('date_added')
#     context = {'topics': topics}
#     return render(request, 'learning_logs/topics.html', context)
#
# @login_required
# def topic(request, topic_id):
#     """Show a single topic and all its entries."""
#     topic = Topic.objects.get(id=topic_id)
#     # Make sure the topic belongs to the current user.
#     if topic.owner != request.user:
#         raise Http404
#
#     entries = topic.entry_set.order_by('-date_added')
#     context = {'topic': topic, 'entries': entries}
#     return render(request, 'learning_logs/topic.html', context)
#
# @login_required
# def new_topic(request):
#     """Add a new topic."""
#     if request.method != 'POST':
#         # No data submitted; create a blank form.
#         form = TopicForm()
#     else:
#         # POST data submitted; process data.
#         form = TopicForm(data=request.POST)
#         if form.is_valid():
#             new_topic = form.save(commit=False)
#             new_topic.owner = request.user
#             new_topic.save()
#             return redirect('learning_logs:topics')
#
#     # Display a blank or invalid form.
#     context = {'form': form}
#     return render(request, 'learning_logs/new_topic.html', context)
#
# @login_required
# def new_entry(request, topic_id):
#     """Add a new entry for a particular topic."""
#     topic = Topic.objects.get(id=topic_id)
#
#     if request.method != 'POST':
#         # No data submitted; create a blank form.
#         form = EntryForm()
#     else:
#         # POST data submitted; process data.
#         form = EntryForm(data=request.POST)
#         if form.is_valid():
#             new_entry = form.save(commit=False)
#             new_entry.topic = topic
#             new_entry.save()
#             return redirect('learning_logs:topic', topic_id=topic_id)
#
#     # Display a blank or invalid form.
#     context = {'topic': topic, 'form': form}
#     return render(request, 'learning_logs/new_entry.html', context)
#
# @login_required
# def edit_entry(request, entry_id):
#     """Edit an existing entry."""
#     entry = Entry.objects.get(id=entry_id)
#     topic = entry.topic
#     if topic.owner != request.user:
#         raise Http404
#
#     if request.method != 'POST':
#         # Initial request; pre-fill form with the current entry.
#         form = EntryForm(instance=entry)
#     else:
#         # POST data submitted; process data.
#         form = EntryForm(instance=entry, data=request.POST)
#         if form.is_valid():
#             form.save()
#             return redirect('learning_logs:topic', topic_id=topic.id)
#
#     context = {'entry': entry, 'topic': topic, 'form': form}
#     return render(request, 'learning_logs/edit_entry.html', context)
# ```

# %%
# Practice rewrite for source example 20.64
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Styling Learning Log / Ll Project

# %% [markdown]
# #### Source example 20.65
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/ll_project/asgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# ASGI config for ll_project project.
#
# It exposes the ASGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/asgi/
# """
#
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_asgi_application()
# ```

# %%
# Practice rewrite for source example 20.65
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.66
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/ll_project/settings.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # ... 121 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# Django settings for ll_project project.
#
# Generated by 'django-admin startproject' using Django 4.1b1.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/dev/ref/settings/
# """
#
# from pathlib import Path
#
# # Build paths inside the project like this: BASE_DIR / 'subdir'.
# BASE_DIR = Path(__file__).resolve().parent.parent
#
#
# # Quick-start development settings - unsuitable for production
# # See https://docs.djangoproject.com/en/dev/howto/deployment/checklist/
#
# # SECURITY WARNING: keep the secret key used in production secret!
# SECRET_KEY = 'django-insecure-mibxt7sboxg%r)9t6z=a6@weyo(thgbknfcwgyowgx9$5s4&=!'
#
# # SECURITY WARNING: don't run with debug turned on in production!
# DEBUG = True
#
# ALLOWED_HOSTS = []
#
# # Application definition
#
# INSTALLED_APPS = [
#     # My apps.
#     'learning_logs',
#     'accounts',
#
#     # Third party apps.
#     'django_bootstrap5',
#
#     # Default django apps.
#     'django.contrib.admin',
#     'django.contrib.auth',
#     'django.contrib.contenttypes',
#     'django.contrib.sessions',
#     'django.contrib.messages',
#     'django.contrib.staticfiles',
# ]
#
# MIDDLEWARE = [
#     'django.middleware.security.SecurityMiddleware',
#     'django.contrib.sessions.middleware.SessionMiddleware',
#     'django.middleware.common.CommonMiddleware',
#     'django.middleware.csrf.CsrfViewMiddleware',
#     'django.contrib.auth.middleware.AuthenticationMiddleware',
#     'django.contrib.messages.middleware.MessageMiddleware',
#     'django.middleware.clickjacking.XFrameOptionsMiddleware',
# ]
#
# ROOT_URLCONF = 'll_project.urls'
#
# TEMPLATES = [
#     {
#         'BACKEND': 'django.template.backends.django.DjangoTemplates',
#         'DIRS': [],
#         'APP_DIRS': True,
#         'OPTIONS': {
#             'context_processors': [
#                 'django.template.context_processors.debug',
#                 'django.template.context_processors.request',
#                 'django.contrib.auth.context_processors.auth',
#                 'django.contrib.messages.context_processors.messages',
#             ],
#         },
#     },
# ]
#
# WSGI_APPLICATION = 'll_project.wsgi.application'
#
#
# # Database
# # https://docs.djangoproject.com/en/dev/ref/settings/#databases
#
# DATABASES = {
#     'default': {
#         'ENGINE': 'django.db.backends.sqlite3',
#         'NAME': BASE_DIR / 'db.sqlite3',
#     }
# }
#
#
# # Password validation
# # https://docs.djangoproject.com/en/dev/ref/settings/#auth-password-validators
#
# AUTH_PASSWORD_VALIDATORS = [
#     {
#         'NAME': 'django.contrib.auth.password_validation.UserAttributeSimilarityValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.MinimumLengthValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.CommonPasswordValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.NumericPasswordValidator',
#     },
# ]
#
#
# # Internationalization
# # https://docs.djangoproject.com/en/dev/topics/i18n/
#
# LANGUAGE_CODE = 'en-us'
#
# TIME_ZONE = 'UTC'
#
# USE_I18N = True
#
# USE_TZ = True
#
#
# # Static files (CSS, JavaScript, Images)
# # https://docs.djangoproject.com/en/dev/howto/static-files/
#
# STATIC_URL = 'static/'
#
# # Default primary key field type
# # https://docs.djangoproject.com/en/dev/ref/settings/#default-auto-field
#
# DEFAULT_AUTO_FIELD = 'django.db.models.BigAutoField'
#
# # My settings.
# LOGIN_REDIRECT_URL = 'learning_logs:index'
# LOGOUT_REDIRECT_URL = 'learning_logs:index'
# LOGIN_URL = 'accounts:login'
# ```

# %%
# Practice rewrite for source example 20.66
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.67
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/ll_project/urls.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# # ... 9 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """ll_project URL Configuration
#
# The `urlpatterns` list routes URLs to views. For more information please see:
#     https://docs.djangoproject.com/en/dev/topics/http/urls/
# Examples:
# Function views
#     1. Add an import:  from my_app import views
#     2. Add a URL to urlpatterns:  path('', views.home, name='home')
# Class-based views
#     1. Add an import:  from other_app.views import Home
#     2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
# Including another URLconf
#     1. Import the include() function: from django.urls import include, path
#     2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
# """
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('accounts/', include('accounts.urls')),
#     path('', include('learning_logs.urls')),
# ]
# ```

# %%
# Practice rewrite for source example 20.67
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# #### Source example 20.68
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/ll_project/wsgi.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
# # ... 2 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# """
# WSGI config for ll_project project.
#
# It exposes the WSGI callable as a module-level variable named ``application``.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/dev/howto/deployment/wsgi/
# """
#
# import os
#
# from django.core.wsgi import get_wsgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#
# application = get_wsgi_application()
# ```

# %%
# Practice rewrite for source example 20.68
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Styling Learning Log

# %% [markdown]
# #### Source example 20.69
#
# Checklist note: captured from **Chapter 20: Styling and Deploying an App**, official GitHub source `chapter_20/styling_learning_log/manage.py`.
#
# **Context**
#
# 1. This example demonstrates repeated work, which is one of the main ways programs remove manual effort.
# 2. Look for the input, the operation being demonstrated, and the visible result or side effect.
# 3. This finishes the web app by connecting earlier Django work to styling, deployment, and production settings.
# 4. The author's pattern is incremental: introduce one small idea, run it, then combine it into a larger program.
# 5. Change one value at a time and predict the output before running; that habit turns examples into understanding.
#
# **Concept Flow**
#
# ```text
# local app -> style/configure -> deploy -> production URL
# ```
#
# **Code Preview**
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
# # ... 8 more line(s) in this source example
# ```

# %% [markdown]
# Study transcript or context-dependent source block:
#
# ```python
# #!/usr/bin/env python
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'll_project.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
#             "available on your PYTHONPATH environment variable? Did you "
#             "forget to activate a virtual environment?"
#         ) from exc
#     execute_from_command_line(sys.argv)
#
#
# if __name__ == '__main__':
#     main()
# ```

# %%
# Practice rewrite for source example 20.69
# Recreate the idea safely with small sample data before using real project files.

# %% [markdown]
# ### Chapter 20: Styling and Deploying an App Practice Checkpoint

# %% [markdown]
# #### Practice: project-safe rewrite

# %%
# Project chapters often depend on installed packages, files, servers, or assets.
# Rewrite one source example with fake data first:
# - replace file/API/game/web inputs with a small list or dictionary
# - print the planned action
# - only then connect it back to the real project
planned_steps = ["identify input", "transform state", "show or save result"]
for step in planned_steps:
    print(step)

# %% [markdown]
# ## Final Study Routine
#
# For each chapter or appendix:
#
# 1. Read the context.
# 2. Trace the ASCII flow.
# 3. Read the preview.
# 4. Rewrite the example from memory.
# 5. Change one thing and predict the result.
